# %% [markdown]
# # **`README.md`**
#
# # An Auditable AI Agent Loop for Empirical Economics
#
# <!-- PROJECT SHIELDS -->
# [![License: MIT](https://img.shields.io/badge/License-MIT-blue.svg)](https://opensource.org/licenses/MIT)
# [![Python Version](https://img.shields.io/badge/python-3.10%2B-blue.svg)](https://www.python.org/)
# [![arXiv](https://img.shields.io/badge/arXiv-2603.17381v2-b31b1b.svg)](https://arxiv.org/abs/2603.17381v2)
# [![Journal](https://img.shields.io/badge/Journal-ArXiv%20Preprint-003366)](https://arxiv.org/abs/2603.17381v2)
# [![Year](https://img.shields.io/badge/Year-2026-purple)](https://github.com/auditable_AI_agent_loop_for_empirical_economics)
# [![Discipline](https://img.shields.io/badge/Discipline-Econometrics%20%7C%20Agentic%20AI-00529B)](https://github.com/auditable_AI_agent_loop_for_empirical_economics)
# [![Data Sources](https://img.shields.io/badge/Data-ECB%20SPF%20%7C%20Eurostat-lightgrey)](https://www.ecb.europa.eu/stats/ecb_surveys/spf/html/index.en.html)
# [![Core Method](https://img.shields.io/badge/Method-Evaluator--Locked%20Search-orange)](https://github.com/auditable_AI_agent_loop_for_empirical_economics)
# [![Analysis](https://img.shields.io/badge/Analysis-peLASSO%20%7C%20Forecast%20Combination-red)](https://github.com/auditable_AI_agent_loop_for_empirical_economics)
# [![Validation](https://img.shields.io/badge/Validation-Diebold--Mariano%20Test-green)](https://github.com/auditable_AI_agent_loop_for_empirical_economics)
# [![Robustness](https://img.shields.io/badge/Robustness-Post--Search%20Holdout-yellow)](https://github.com/auditable_AI_agent_loop_for_empirical_economics)
# [![Code style: black](https://img.shields.io/badge/code%20style-black-000000.svg)](https://github.com/psf/black)
# [![Type Checking: mypy](https://img.shields.io/badge/type%20checking-mypy-blue)](http://mypy-lang.org/)
# [![NumPy](https://img.shields.io/badge/numpy-%23013243.svg?style=flat&logo=numpy&logoColor=white)](https://numpy.org/)
# [![Pandas](https://img.shields.io/badge/pandas-%23150458.svg?style=flat&logo=pandas&logoColor=white)](https://pandas.pydata.org/)
# [![SciPy](https://img.shields.io/badge/SciPy-%230C55A5.svg?style=flat&logo=scipy&logoColor=white)](https://scipy.org/)
# [![Scikit-Learn](https://img.shields.io/badge/scikit--learn-%23F7931E.svg?style=flat&logo=scikit-learn&logoColor=white)](https://scikit-learn.org/)
# [![Anthropic](https://img.shields.io/badge/Anthropic-Claude%20Opus-black)](https://www.anthropic.com/)
# [![YAML](https://img.shields.io/badge/YAML-%23CB171E.svg?style=flat&logo=yaml&logoColor=white)](https://yaml.org/)
# [![Jupyter](https://img.shields.io/badge/Jupyter-%23F37626.svg?style=flat&logo=Jupyter&logoColor=white)](https://jupyter.org/)
# [![Open Source](https://img.shields.io/badge/Open%20Source-%E2%9D%A4-brightgreen)](https://github.com/auditable_AI_agent_loop_for_empirical_economics)
#
# **Repository:** `https://github.com/chirindaopensource/auditable_AI_agent_loop_for_empirical_economics`
#
# **Owner:** 2026 Craig Chirinda (Open Source Projects)
#
# This repository contains an **independent**, professional-grade Python implementation of the research methodology from the 2026 paper entitled **"An Auditable AI Agent Loop for Empirical Economics: A Case Study in Forecast Combination"** by:
#
# *   **Minchul Shin** (Federal Reserve Bank of Philadelphia)
#
# The project provides a complete, end-to-end computational framework for replicating the paper's findings. It delivers a modular, highly optimized pipeline that executes the entire research workflow: from the rigorous ingestion and imputation of macroeconomic survey data to the execution of a cryptographically secure, evaluator-locked AI agent loop, culminating in out-of-sample Diebold-Mariano predictive accuracy testing.
#
# ## Table of Contents
#
# - [Introduction](#introduction)
# - [Theoretical Background](#theoretical-background)
# - [Features](#features)
# - [Methodology Implemented](#methodology-implemented)
# - [Core Components (Notebook Structure)](#core-components-notebook-structure)
# - [Key Callable: `execute_master_pipeline`](#key-callable-execute_master_pipeline)
# - [Prerequisites](#prerequisites)
# - [Installation](#installation)
# - [Input Data Structure](#input-data-structure)
# - [Usage](#usage)
# - [Output Structure](#output-structure)
# - [Project Structure](#project-structure)
# - [Customization](#customization)
# - [Contributing](#contributing)
# - [Recommended Extensions](#recommended-extensions)
# - [License](#license)
# - [Citation](#citation)
# - [Acknowledgments](#acknowledgments)
#
# ## Introduction
#
# This project provides a Python implementation of the analytical framework presented in Shin (2026). The core of this repository is the iPython Notebook `auditable_AI_agent_loop_for_empirical_economics_draft.ipynb`, which contains a comprehensive suite of 32+ orchestrated tasks to replicate the paper's findings.
#
# The pipeline addresses the "crisis of transparency" in AI-driven empirical science. While Large Language Models (LLMs) drastically reduce the marginal cost of specification search, they simultaneously explode the "garden of forking paths," masking researcher degrees of freedom.
#
# The codebase operationalizes the proposed solution:
# -   **Formalizes** the research process as a bounded stochastic optimization problem.
# -   **Isolates** the LLM agent within a strict Abstract Syntax Tree (AST) execution sandbox, permitting it to edit only a single forecasting script ($\tau$) while the evaluation harness ($S$) remains mathematically immutable.
# -   **Coordinates** the autonomous search using a four-file architecture (`program.md`, `train.py`, `prepare.py`, `results.tsv`), enforcing a greedy keep/revert logic via Git version control.
# -   **Evaluates** the discovered methodologies (e.g., Partially-Egalitarian LASSO tuning, bias correction) on a strictly air-gapped holdout sample, distinguishing robust structural insights from sample-specific overfitting.
#
# ## Theoretical Background
#
# The implemented methods combine techniques from High-Dimensional Econometrics, Agentic AI Engineering, and Secure Systems Architecture.
#
# **1. The Bounded Optimization Problem:**
# The theoretical optimum minimizes the scalar score on the search sample $D^S$. The agent loop seeks the realized bounded optimum $\hat{\tau}_K$ within a finite budget of $K$ experiments:
# $$ \hat{\tau}_K \in \arg \min_{\tau \in \{\tau_0, \tau_1, \dots, \tau_K\}} S(\tau; D^S) $$
#
# **2. Recursive Rolling-Origin Evaluation:**
# To strictly prevent look-ahead bias, the immutable evaluator provides the agent with a sliding window of size $W=20$. At forecast origin $t$, the agent only has access to historical data up to $t-1$:
# $$ S(\tau; D^S) = \sqrt{\frac{1}{65}\sum_{t=6}^{70} (y_t - \hat{y}_t)^2} $$
#
# **3. Discovered Econometric Methodologies:**
# The pipeline mathematically recreates the specific algorithms discovered by the agent, including Run 2's highly successful bias correction mechanism, which exploits serial correlation in combined forecast errors:
# $$ \hat{y}_t = \tilde{y}_t - 0.80 \cdot \hat{e}_n^{LOO,pct} $$
#
# **4. Predictive Accuracy Testing:**
# Out-of-sample generalization is evaluated using the Diebold-Mariano test, utilizing a Newey-West HAC variance estimator to account for serial correlation in the loss differential $d_t = e_{SA,t}^2 - e_{method,t}^2$.
#
# ## Features
#
# The provided iPython Notebook (`auditable_AI_agent_loop_for_empirical_economics_draft.ipynb`) implements the full research pipeline, including:
#
# -   **AST-Based Execution Sandboxing:** Untrusted LLM-generated code is compiled and executed within a strictly restricted `globals` dictionary, mathematically guaranteeing the agent cannot access the OS, the filesystem, or the holdout data.
# -   **OS-Level Process Group Management:** The evaluator subprocess is bound by a strict 30-minute timeout. Upon exhaustion, the entire process tree is eradicated (via `os.killpg` or `CREATE_NEW_PROCESS_GROUP`), ensuring $O(1)$ resource leakage over hundreds of iterations.
# -   **Vectorized Combinatorial Benchmarks:** Exhaustive subset searches (e.g., Best avg flex) are evaluated simultaneously using highly optimized matrix multiplication ($X_{train} M$), bypassing slow Python-level loops.
# -   **Configuration-Driven Design:** All study parameters (hyperparameters, temporal bounds, LLM settings) are managed in an external `config.yaml` file.
# -   **Cryptographic Archival:** Automatically serializes all artifacts (CSV, JSON, TSV) and generates an immutable `.zip` archive with a master SHA-256 checksum manifest for absolute reproducibility.
#
# ## Methodology Implemented
#
# The core analytical steps directly implement the methodology from the paper:
#
# 1.  **Data Engineering (Tasks 1-9):** Ingests raw SPF microdata and Eurostat GDP realizations, standardizes temporal indices, performs an audited inner join, imputes missing values (linear interpolation and cross-sectional means), and physically air-gaps the holdout sample.
# 2.  **Evaluator Construction (Tasks 10-14):** Constructs the 200-point regularization grids, instantiates the look-ahead-free `EvaluatorInfoBuilder`, validates the Simple Average baseline, and establishes the secure editable interface.
# 3.  **Agentic Orchestration (Tasks 15-19):** Materializes the Markdown instruction contract, initializes the Git audit trail, and manages the autonomous LLM session recovery semantics.
# 4.  **Benchmark & Method Recreation (Tasks 20-25):** Ports the required R `glmnet` helpers to Python `scikit-learn` (ensuring exact penalty scaling), evaluates the ex-post peLASSO oracles, and mathematically recreates the Run 1, 2, and 3 method families.
# 5.  **Evaluation & Testing (Tasks 26-29):** Computes in-sample and out-of-sample RMSEs, executes the Diebold-Mariano tests, and performs heuristic NLP analysis on the TSV logs to document methodology drift.
# 6.  **Robustness & Archival (Tasks 30-32):** Executes the ex-COVID robustness checks, validates the five core scientific conclusions, generates the epistemological fidelity matrix, and freezes the research archive.
#
# ## Core Components (Notebook Structure)
#
# The notebook is structured as a logical pipeline with modular orchestrator functions for each of the 32 major tasks. All functions are self-contained, fully documented with strict type hints and comprehensive docstrings, and designed for professional-grade execution.
#
# ## Key Callable: `execute_master_pipeline`
#
# The project is designed around a single, top-level user-facing interface function:
#
# -   **`execute_master_pipeline`:** This master orchestrator function runs the entire automated research pipeline from end-to-end. A single call to this function reproduces the entire computational portion of the project, managing data validation, evaluator construction, agentic search (or method recreation), and cryptographic archival.
#
# ## Prerequisites
#
# -   Python 3.10+
# -   Core dependencies: `pandas`, `numpy`, `scikit-learn`, `scipy`, `pyyaml`.
# -   LLM Integration: `anthropic` (requires a valid API key for `discovery` mode).
# -   System: `git` must be installed and accessible in the system PATH.
#
# ## Installation
#
# 1.  **Clone the repository:**
#     ```sh
#     git clone https://github.com/chirindaopensource/auditable_AI_agent_loop_for_empirical_economics.git
#     cd auditable_AI_agent_loop_for_empirical_economics
#     ```
#
# 2.  **Create and activate a virtual environment (recommended):**
#     ```sh
#     python -m venv venv
#     source venv/bin/activate  # On Windows, use `venv\Scripts\activate`
#     ```
#
# 3.  **Install Python dependencies:**
#     ```sh
#     pip install pandas numpy scikit-learn scipy pyyaml anthropic
#     ```
#
# ## Input Data Structure
#
# The pipeline requires two primary data structures, strictly validated at runtime:
#
# 1.  **`df_spf_panel_wide` (pd.DataFrame):** A wide panel containing a `date` column (`YYYYQq` format) and 23 forecaster columns (`Float64` nullable type). Missing values are permitted pre-imputation.
# 2.  **`df_gdp_target_series` (pd.DataFrame):** A time series containing a `date` column and a `real_gdp_growth_yoy` column (`Float64`). Zero missing values are permitted in the target vector.
#
# *Note: The pipeline includes a synthetic data generator for testing purposes if access to the original ECB/Eurostat data is unavailable.*
#
# ## Usage
#
# The notebook provides a complete, step-by-step guide. The primary workflow is to execute the final cell, which demonstrates how to load the configuration, generate synthetic data, and use the top-level orchestrator in `holdout_evaluation` mode (bypassing the expensive LLM API calls while rigorously testing the deterministic kernel):
#
# ```python
# import os
# import yaml
# import pandas as pd
# import numpy as np
#
# # 1. Load the master configuration from the YAML file.
# # (Assumes config.yaml is in the working directory)
# with open("config.yaml", "r", encoding="utf-8") as f:
#     study_config = yaml.safe_load(f)
#
# # 2. Load raw datasets (Example using synthetic generator provided in the notebook)
# # In production, load from CSV: pd.read_csv("data/spf_raw.csv")
# df_spf_panel_wide, df_gdp_target_series = generate_synthetic_econometric_data()
#
# # 3. Execute the entire replication study.
# master_results = execute_master_pipeline(
#     df_spf_panel_wide=df_spf_panel_wide,
#     df_gdp_target_series=df_gdp_target_series,
#     study_configuration=study_config,
#     mode="holdout_evaluation",
#     output_directory="./reproducibility_archive",
#     data_provenance="synthetic_demonstration",
#     declared_panel_scope="full_panel"
# )
#
# # 4. Access results
# if master_results.get("master_status") == "SUCCESS":
#     report_30 = master_results["task_30_report"]
#
#     print("\n[*] Out-of-Sample Results: Holdout Sample (2017Q1-2025Q4)")
#     print(report_30.holdout_rmse_table[["method_name", "holdout_rmse", "holdout_relative_rmse"]].head().to_string(index=False))
#
#     print("\n[*] Diebold-Mariano Predictive Accuracy Summary")
#     print(report_30.dm_summary_table[["method_name", "holdout_rmse_formatted"]].head().to_string(index=False))
#
#     report_32 = master_results["task_32_report"]
#     print(f"\n[*] Archive frozen at: {report_32.archive_path}")
# ```
#
# ## Output Structure
#
# The pipeline returns a master dictionary containing:
# -   **`task_30_report`**: The core pipeline artifacts, including the cleansed data, imputation audits, benchmark registries, and the comprehensive in-sample and out-of-sample RMSE evaluation tables.
# -   **`task_31_report`**: The robustness analysis artifacts, including the ex-COVID validation records and the ordinal ranking preservation memo.
# -   **`task_32_report`**: The final capstone artifacts, including the empirical verification of the 5 scientific conclusions, the epistemological fidelity classification matrix, and the absolute path to the cryptographic `.zip` archive.
#
# ## Project Structure
#
# ```
# auditable_AI_agent_loop_for_empirical_economics/
# │
# ├── auditable_AI_agent_loop_for_empirical_economics_draft.ipynb   # Main implementation notebook
# ├── config.yaml                                                   # Master configuration file
# ├── requirements.txt                                              # Python package dependencies
# │
# ├── LICENSE                                                       # MIT Project License File
# └── README.md                                                     # This file
# ```
#
# ## Customization
#
# The pipeline is highly customizable via the `config.yaml` file. Users can modify study parameters such as:
# -   **Agent Constraints:** Adjust the search budget ($K$), the timeout limit, or the allowed Python packages in the sandbox.
# -   **Econometrics:** Alter the rolling window size ($W$), the resolution of the $\lambda$ grid, or the specific quarters excluded during robustness checks.
# -   **LLM Settings:** Switch the coding assistant model (e.g., from Claude Opus to GPT-4) or adjust the temperature and top-p parameters.
#
# ## Contributing
#
# Contributions are welcome. Please fork the repository, create a feature branch, and submit a pull request with a clear description of your changes. Adherence to PEP 8, strict type hinting, and the 1:1 inline comment-to-code-line ratio is required.
#
# ## Recommended Extensions
#
# Future extensions could include:
# -   **Alternative Search Strategies:** Replacing the greedy local search with evolutionary population-based search (e.g., AlphaEvolve) or Monte Carlo Tree Search (MCTS).
# -   **Expanded Econometric Domains:** Adapting the immutable evaluator to score Structural VAR identification schemes or real-time Phillips curve specifications, as outlined in the paper's schematic extensions.
# -   **Formal Post-Selection Inference:** Integrating rigorous statistical frameworks to correct for the p-hacking inherent in the agent's high-speed specification search.
#
# ## License
#
# This project is licensed under the MIT License. See the `LICENSE` file for details.
#
# ## Citation
#
# If you use this code or the methodology in your research, please cite the original paper:
#
# ```bibtex
# @article{shin2026auditable,
#   title={An Auditable AI Agent Loop for Empirical Economics: A Case Study in Forecast Combination},
#   author={Shin, Minchul},
#   journal={arXiv preprint arXiv:2603.17381v2},
#   year={2026}
# }
# ```
#
# For the implementation itself, you may cite this repository:
# ```
# Chirinda, C. (2026). An Auditable AI Agent Loop for Empirical Economics: An Open Source Implementation.
# GitHub repository: https://github.com/chirindaopensource/auditable_AI_agent_loop_for_empirical_economics
# ```
#
# ## Acknowledgments
#
# -   Credit to **Minchul Shin** for the foundational research that forms the entire basis for this computational replication.
# -   Credit to **Andrej Karpathy** for the original `autoresearch` open-source agent-loop architecture upon which this econometric adaptation is built.
# -   This project is built upon the exceptional tools provided by the open-source community. Sincere thanks to the developers of the scientific Python ecosystem, particularly the **scikit-learn** and **pandas** contributors.
#
# --
#
# *This README was generated based on the structure and content of the `auditable_AI_agent_loop_for_empirical_economics_draft.ipynb` notebook and follows best practices for research software documentation.*

# %% [markdown]
# # Paper
#
# Title: "*An Auditable AI Agent Loop for Empirical Economics: A Case Study in Forecast Combination*"
#
# Authors: Minchul Shin
#
# Authors' Institutional Affiliation: Federal Reserve Bank of Philadelphia
#
# E-Journal Submission Date: [Submitted on 18 Mar 2026 (v1), last revised 19 Mar 2026 (replicated version, v2)]
#
# Paper's Link: https://arxiv.org/abs/2603.17381v2
#
# Related GitHub Repositories: https://github.com/karpathy/autoresearch
#
# Abstract:
#
# AI coding agents make empirical specification search fast and cheap, but they also widen hidden researcher degrees of freedom. Building on an open-source agent-loop architecture, this paper adapts that framework to an empirical economics workflow and adds a post-search holdout evaluation. In a forecast-combination illustration, multiple independent agent runs outperform standard benchmarks in the original rolling evaluation, but not all continue to do so on a post-search holdout. Logged search and holdout evaluation together make adaptive specification search more transparent and help distinguish robust improvements from sample-specific discoveries.

# %% [markdown]
# # Summary
#
# The following summary provides a technical and rigorous distillation of Minchul Shin’s 2026 paper, which addresses the critical intersection of agentic AI and econometric methodology.
#
# ### Motivation: The Crisis of Transparency in AI-Driven Search
# The advent of AI coding agents significantly lowers the marginal cost of empirical specification search, allowing for hundreds of iterations in a single research session. However, this speed exacerbates a long-standing concern in econometrics: **researcher degrees of freedom**. When an agent can autonomously rewrite estimation scripts to maximize a score, the boundary between "coding assistance" and "undisclosed specification search" vanishes. The paper argues that the central challenge is not whether AI can improve empirical scores, but whether the search process can be made **transparent and auditable**.
#
# ### Formalization of the Auditable Agent-Loop Protocol
# The author formalizes the search process as a bounded, stochastic optimization problem within a strictly defined research protocol. The framework consists of four primary components:
# *   **Instruction Contract ($C$):** A written directive defining the research objective, admissible modifications, and the search budget ($K$).
# *   **Immutable Evaluator ($S$):** A fixed scoring function run on a search sample ($DS$) that cannot be altered by the agent.
# *   **Editable Script ($\tau$):** The specific code surface the agent is permitted to modify.
# *   **Experiment Log ($L$):** A complete, ordered audit trail $(k, \tau_k, s_k, d_k)$ recording every attempt, its associated score, and whether it was kept or discarded.
#
# The objective is to find the best script $\hat{\tau}_K$ found within a bounded search, recognizing that this is often a local rather than global optimum ($\tau^*$) due to finite search costs.
#
# ### Implementation: The Four-File Architecture
# Borrowing from Karpathy’s (2026) *autoresearch* design, the protocol is operationalized through four files in a shared directory:
# 1.  **program.md:** The plain-text contract defining the "rules of the game".
# 2.  **prepare.R:** The fixed evaluation harness that loads data and returns the scalar score.
# 3.  **train.R:** The single editable script where the agent defines the forecasting or estimation function.
# 4.  **results.tsv:** The audit log that records every commit, score, and verbal description of the attempted strategy.
#
# Critically, this architecture separates the **discovery phase** (on the search sample) from the **validation phase** (on a holdout sample withheld from the agent).
#
# ### Empirical Case Study: Real-Time peLASSO Tuning
# The protocol is tested on the "partially egalitarian LASSO" (peLASSO) forecast combination problem from Diebold and Shin (2019). The agent is tasked with finding a **look-ahead-free, data-based selection rule** for two regularization parameters—a problem left unresolved in the original study.
# *   **The Search:** Three independent agent runs (approx. 200 experiments each) were conducted using the euro area real GDP growth dataset.
# *   **Generalization:** A post-search holdout sample (2017Q1–2025Q4) was used to check if the discovered improvements generalized beyond the search sample.
#
# ### Results: Distinguishing Robust Insight from Overfitting
# The results highlight the "split result" of agentic search:
# *   **Search Sample:** All three agent runs successfully outperformed standard benchmarks (Simple Average and ex-post peLASSO) on the original sample.
# *   **Holdout Sample:** Only two of the three discovered methods (Runs 1 and 2) continued to outperform the benchmarks on the holdout data. Run 3, despite performing well in-sample, failed to generalize.
# *   **Log Revelations:** The experiment logs revealed that nominal hyperparameter tuning often drifted into **broader method discovery**. For instance, Run 2 discovered a robust bias-correction mechanism that exploits serial correlation in forecast errors, while Run 3's failure was traced to an over-engineered "egalitarian elastic net blend" that introduced excessive estimation noise.
#
# ### Broad Applicability and Schematic Extensions
# The paper demonstrates that the protocol is subject-matter agnostic and applies to any workflow where evaluation can be separated from implementation. The author provides schematic mappings for:
# *   **Regression Specification Search:** Comparing nuisance function specifications for wage regressions while isolating treatment effects.
# *   **Structural VAR Identification:** Judging candidate monetary policy shock series against external narrative diagnostics.
# *   **Inflation Forecasting:** Optimizing Phillips curve specifications (slack measures, expectations proxies) against pseudo-out-of-sample loss.
#
# ### Critical Limitations and Guardrails
# The author concludes with several vital caveats for the practitioner:
# *   **LLM Background Knowledge:** Language models may have encoded information from the holdout period during their pre-training, potentially reintroducing look-ahead bias.
# *   **Opaque Trade-offs:** The model’s internal logic in balancing score improvement against contract constraints remains a "black box".
# *   **Greedy Search:** The current protocol uses a simple greedy search; more sophisticated evolutionary or tree-search strategies might explore the model space more effectively.
# *   **Inference Warning:** While a useful guardrail, the protocol is **not a substitute** for formal post-selection inference or causal identification assumptions.

# %% [markdown]
# # Import Essential Modules

# %%
# Import Essential Modules

#!/usr/bin/env python3
# ==============================================================================#
#
#  An Auditable AI Agent Loop for Empirical Economics: A Case Study in Forecast Combination
#
#  This module provides a complete, production-grade implementation of the
#  analytical framework presented in "An Auditable AI Agent Loop for Empirical
#  Economics" by Minchul Shin (2026). It delivers a computationally tractable
#  system for the systematic, high-speed exploration of the "garden of forking
#  paths" in empirical modeling within a verifiable and evaluator-locked audit trail.
#
#  Core Methodological Components:
#  • Evaluator-locked local search via an immutable evaluation harness
#  • Partially-Egalitarian LASSO (peLASSO) and Adaptive LASSO implementations
#  • Recursive rolling-origin evaluation strictly preventing look-ahead bias
#  • Forecast aggregation methodologies including median and quantile aggregation
#  • Diebold-Mariano predictive accuracy testing with HAC variance estimation
#  • Autonomous LLM session recovery and stochastic search management
#
#  Technical Implementation Features:
#  • Strict four-file directory architecture (program.md, train.py, prepare.py, results.tsv)
#  • OS-level process group management for O(1) resource leakage on timeouts
#  • AST-based execution sandboxing via restricted globals and custom __import__
#  • Cryptographic-level fidelity verification and SHA-256 archival
#  • Heuristic NLP parsing for methodology drift detection
#
#  Paper Reference:
#  Shin, M. (2026). An Auditable AI Agent Loop for Empirical Economics: A Case
#  Study in Forecast Combination. arXiv preprint arXiv:2603.17381v2.
#  https://arxiv.org/abs/2603.17381v2
#  Related GitHub: https://github.com/karpathy/autoresearch
#
#  Author: CS Chirinda
#  License: MIT
#  Version: 1.0.0
#
# ==============================================================================#

# Standard Library Imports for OS, Filesystem, and Process Management
import os
import sys
import stat
import signal
import subprocess
import shutil
import importlib.util
from pathlib import Path

# Standard Library Imports for Data Serialization, Hashing, and Parsing
import re
import csv
import json
import hashlib

# Standard Library Imports for Mathematics, Time, and Iteration
import math
import time
import datetime
import itertools
import traceback

# Standard Library Imports for Rigorous Static Type Hinting
from typing import (
    Any,
    Dict,
    List,
    Set,
    Tuple,
    Union,
    Optional,
    Callable,
    NamedTuple,
    Protocol,
    TypedDict,
    cast
)

# Standard Library Imports for Immutable Data Structures
from dataclasses import dataclass, field, asdict

# Third-Party Imports for High-Dimensional Data Manipulation and Mathematics
import numpy as np
import pandas as pd
from scipy.stats import norm

# Third-Party Imports for Penalized Regression and Cross-Validation
from sklearn.linear_model import (
    Lasso,
    Ridge,
    LassoCV,
    RidgeCV,
    ElasticNetCV,
    enet_path
)
from sklearn.model_selection import LeaveOneOut, KFold

# Third-Party Imports for LLM API Orchestration
try:
    import anthropic
except ImportError:
    raise ImportError("The 'anthropic' Python SDK is required for LLM interactions. Please install it.")

# %% [markdown]
# # Implementation

# %% [markdown]
# # Draft 1
#
# ## **Discussion of the Inputs-Processes-Outputs (IPO) of Key Callables**
#
# Below is a clinical, granular, and exhaustive assessment of the **33 final orchestrator callables** (Tasks 1 through 32, plus the Master Orchestrator) that constitute the implementation of the research pipeline.
#
#
# ### 1. `execute_task_1_validate_schema_and_type`
# *   **Inputs:** `df_spf_panel_wide` (raw DataFrame), `study_configuration` (Dictionary).
# *   **Processes:** Validates the presence of exactly 24 columns (date + 23 forecasters), verifies numeric data types for forecasters, checks the `YYYYQq` regex format for dates, and confirms the data is a wide panel rather than raw microdata.
# *   **Outputs:** `Task1ValidationReport` (Dataclass).
# *   **Data Transformation:** No data mutation occurs. The raw input is mapped to a boolean validation state and a structured diagnostic report.
# *   **Role in Research Pipeline:** Implements the foundational data integrity gate. The paper relies on a fixed panel of $K=23$ forecasters. This callable ensures the input matrix strictly conforms to the dimensionality required for the peLASSO feature space.
#
# ### 2. `execute_task_2_validate_structural_integrity`
# *   **Inputs:** `df_spf_panel_wide` (DataFrame), `study_configuration` (Dictionary), `declared_panel_scope` (String).
# *   **Processes:** Parses date strings into integer tuples to mathematically verify strict chronological ordering, checks for duplicate dates, and validates the row count against the declared scope (e.g., 70 rows for the search sample).
# *   **Outputs:** `Task2ValidationReport` (Dataclass).
# *   **Data Transformation:** Transforms string-based temporal identifiers into sortable mathematical tuples to compute monotonic increase, outputting a structural integrity boolean.
# *   **Role in Research Pipeline:** Enforces the temporal prerequisites for rolling-origin evaluation. As the paper states, "at each date $t$, only data through $t-1$ is available." Strict chronological ordering is mathematically mandatory to prevent look-ahead bias during array slicing.
#
# ### 3. `execute_task_3_validate_gdp_target_series`
# *   **Inputs:** `df_gdp_target_series` (DataFrame), `study_configuration` (Dictionary), `declared_panel_scope` (String), `vintage_source` (String).
# *   **Processes:** Validates the schema (date and target columns), ensures zero missing values in the target vector, verifies chronological ordering, and documents the GDP vintage.
# *   **Outputs:** `Task3ValidationReport` (Dataclass).
# *   **Data Transformation:** Maps the raw target series to a validation state, explicitly extracting and logging the vintage metadata.
# *   **Role in Research Pipeline:** Secures the ground truth vector $y_t$. The paper notes, "The independent dataset uses the current (2026) GDP vintage rather than the 2018Q1 vintage." This callable enforces the documentation of this critical vintage sensitivity.
#
# ### 4. `execute_task_4_validate_configuration_integrity`
# *   **Inputs:** `study_configuration` (Dictionary).
# *   **Processes:** Recursively traverses the configuration dictionary to ensure all 12 top-level sections exist, cross-verifies numerical constants (e.g., $K=23$, $W=20$), and quarantines unspecified LLM parameters.
# *   **Outputs:** `Task4ValidationReport` (Dataclass).
# *   **Data Transformation:** Transforms a nested dictionary into a flattened list of quarantined fields and a boolean consistency matrix.
# *   **Role in Research Pipeline:** Acts as the epistemological boundary of the replication. It explicitly isolates parameters "unspecified in manuscript" (like LLM temperature), ensuring the replication does not silently fabricate assumptions.
#
# ### 5. `execute_task_5_cleanse_and_standardize_dates`
# *   **Inputs:** `df_spf_panel_wide` (DataFrame), `df_gdp_target_series` (DataFrame), `study_configuration` (Dictionary).
# *   **Processes:** Strips whitespace, normalizes alternative date formats to canonical `YYYYQq`, sorts both DataFrames chronologically, and drops empty rows or import artifacts.
# *   **Outputs:** `Task5CleansingReport` (Dataclass).
# *   **Data Transformation:** Mutates the temporal index strings into a standardized format and reorders the row vectors in memory to guarantee contiguous chronological alignment.
# *   **Role in Research Pipeline:** Prepares the data for the inner join. Standardization is required to ensure that the forecaster predictions $x_{k,t}$ perfectly align with the realization $y_t$.
#
# ### 6. `execute_task_6_align_panel_and_target`
# *   **Inputs:** Cleansed SPF panel (DataFrame), Cleansed GDP target (DataFrame), `study_configuration` (Dictionary), `declared_panel_scope` (String).
# *   **Processes:** Computes the symmetric date difference to audit for missing quarters, performs an inner join on the date field, and constructs the authoritative 1-based to 0-based index map.
# *   **Outputs:** `Task6AlignmentReport` (Dataclass).
# *   **Data Transformation:** Fuses two distinct DataFrames into a single canonical matrix of shape $(T, K+2)$ and generates a parallel metadata mapping DataFrame.
# *   **Role in Research Pipeline:** Creates the unified dataset. The generated `index_map` is the architectural mechanism that translates the manuscript's 1-based mathematical notation (e.g., $t=5 \dots 70$) into safe 0-based Python array slices.
#
# ### 7. `execute_task_7_impute_missing_values`
# *   **Inputs:** Canonical panel (DataFrame), `study_configuration` (Dictionary).
# *   **Processes:** Applies linear interpolation to interior missing values, followed by cross-sectional mean imputation for trailing gaps and inactive forecasters.
# *   **Outputs:** `Task7ImputationReport` (Dataclass).
# *   **Data Transformation:** Transforms a sparse matrix containing `NaN` values into a strictly dense, complete matrix, generating boolean masks to audit exactly which cells were synthesized.
# *   **Role in Research Pipeline:** Implements the exact data fabrication rules specified in Appendix E.1: "Missing forecaster responses... are imputed by linear interpolation for interior gaps and by cross-sectional mean for trailing gaps."
#
# ### 8. `execute_task_8_mark_sample_membership`
# *   **Inputs:** Imputed canonical panel (DataFrame), `index_map` (DataFrame), `study_configuration` (Dictionary).
# *   **Processes:** Appends boolean indicator columns (`is_search_sample`, `is_holdout`, `is_covid`) based on strict temporal bounds and mathematically verifies the partition $D = (D^S, D^H)$.
# *   **Outputs:** `Task8SampleMembershipReport` (Dataclass).
# *   **Data Transformation:** Augments the feature space with binary classification vectors that dictate downstream routing.
# *   **Role in Research Pipeline:** Formalizes the core experimental design. As stated in Section 2: "Let the available data be partitioned as $D = (D^S, D^H)$, where $D^S$ is the search sample and $D^H$ is a post-search holdout."
#
# ### 9. `execute_task_9_separate_holdout`
# *   **Inputs:** Marked canonical panel (DataFrame), `study_configuration` (Dictionary).
# *   **Processes:** Physically slices the panel into two disjoint DataFrames, resets their memory indices, and generates an audit note detailing the isolation policies.
# *   **Outputs:** `Task9HoldoutSeparationReport` (Dataclass).
# *   **Data Transformation:** Splits a single contiguous memory block into two isolated blocks, destroying the original index to prevent accidental positional leakage.
# *   **Role in Research Pipeline:** Enforces the epistemological air-gap. The paper mandates: "The post-search holdout $D^H$ must remain entirely outside the agent's workspace during the search."
#
# ### 10. `execute_task_10_construct_lambda_grids`
# *   **Inputs:** `study_configuration` (Dictionary).
# *   **Processes:** Extracts grid parameters and computes two independent 200-point arrays using exponential decay, validating their bounds and strict monotonic decrease.
# *   **Outputs:** `Task10LambdaGridReport` (Dataclass).
# *   **Data Transformation:** Transforms scalar boundary parameters into dense, 1D floating-point vectors.
# *   **Role in Research Pipeline:** Constructs the hyperparameter search space for the peLASSO estimators. The grid is defined implicitly by the contract: "200-point lambda grid, exp(15) to exp(-15)."
#
# ### 11. `execute_task_11_build_info_constructor`
# *   **Inputs:** Search panel (DataFrame), `index_map` (DataFrame), `lambda_grid` (Array), `lambda_grid2` (Array), `study_configuration` (Dictionary).
# *   **Processes:** Instantiates the `EvaluatorInfoBuilder` factory, which converts the DataFrame into contiguous numpy arrays and provides the `build_info(t)` method for look-ahead-free slicing.
# *   **Outputs:** `Task11EvaluatorConstructorReport` (Dataclass).
# *   **Data Transformation:** Converts pandas DataFrames into raw C-contiguous numpy arrays to guarantee $O(1)$ slicing performance during the high-frequency loop.
# *   **Role in Research Pipeline:** Implements the strict temporal firewall. It guarantees that at time $t$, the agent only receives $X_{train} \in \mathbb{R}^{\min(t-1, W) \times K}$ and $X_{history} \in \mathbb{R}^{(t-1) \times K}$, enforcing the rule: "At time $t$, only data from $1:(t-1)$ is available."
#
# ### 12. `execute_task_12_evaluate_method_score`
# *   **Inputs:** `info_builder` (Object), `target_vector` (Array), `select_lambda_callable` (Function), `baseline_rmse` (Float).
# *   **Processes:** Iterates $t=5 \dots 70$, invokes the callable, collects forecasts, isolates the 65 scored periods, and computes the absolute and relative RMSE.
# *   **Outputs:** `Task12EvaluatorScoreReport` (Dataclass).
# *   **Data Transformation:** Reduces a sequence of 65 high-dimensional matrix operations into a single scalar performance metric.
# *   **Role in Research Pipeline:** Implements the immutable evaluator $S(\tau; D^S)$. It computes the core objective function:
#     $$S(\tau; D^S) = \sqrt{\frac{1}{65}\sum_{t=6}^{70} (y_t - \hat{y}_t)^2}$$
#
# ### 13. `execute_task_13_implement_and_validate_baseline`
# *   **Inputs:** `info_builder` (Object), `target_vector` (Array), `df_search_panel` (DataFrame), `study_configuration` (Dictionary), `data_provenance` (String), `execute_task_12_callable` (Function).
# *   **Processes:** Defines the simple average function, evaluates it via Task 12, and validates the resulting RMSE against the 1.504 target using dynamic tolerances.
# *   **Outputs:** `Task13BaselineReport` (Dataclass).
# *   **Data Transformation:** Maps the current forecast vector $x_{new}$ to its arithmetic mean, transforming it into the baseline scalar score.
# *   **Role in Research Pipeline:** Establishes the initial script $\tau_0$ and the denominator for all relative performance metrics. Equation: $\hat{y}_t = \frac{1}{K}\sum_{k=1}^K x_{k,t}$.
#
# ### 14. `execute_task_14_define_editable_interface`
# *   **Inputs:** `study_configuration` (Dictionary).
# *   **Processes:** Reads the agent's script from disk, compiles it into an AST, executes it within a strictly restricted `globals` dictionary (overriding `__import__`), extracts the function, and wraps it in a type-casting Facade.
# *   **Outputs:** `Task14EditableInterfaceReport` (Dataclass).
# *   **Data Transformation:** Transforms a raw text string (source code) into a secure, executable Python Bytecode object, casting its dynamic output to a strict static type.
# *   **Role in Research Pipeline:** Implements the "evaluator-locked" sandbox. It mathematically guarantees that the agent cannot bypass the protocol, enforcing the rule: "One file: You only edit `train.R`."
#
# ### 15. `execute_task_15_materialize_instruction_contract`
# *   **Inputs:** `study_configuration` (Dictionary).
# *   **Processes:** Writes the verbatim Markdown contract to disk using binary UTF-8 encoding, verifies byte-for-byte fidelity, and extracts the session recovery prompt templates.
# *   **Outputs:** `Task15PromptMaterializationReport` (Dataclass).
# *   **Data Transformation:** Serializes in-memory strings to persistent filesystem artifacts.
# *   **Role in Research Pipeline:** Establishes the Instruction Contract ($C$). This document partitions the LLM's latent space, defining the boundaries of the specification search.
#
# ### 16. `execute_task_16_fix_llm_settings`
# *   **Inputs:** `study_configuration` (Dictionary).
# *   **Processes:** Extracts disclosed agent parameters (e.g., Opus 4.6), documents unspecified settings (e.g., temperature) as implementation choices, and configures the $K=200$ budget.
# *   **Outputs:** `Task16AgentSettingsReport` (Dataclass).
# *   **Data Transformation:** Maps nested configuration dictionaries into immutable, strongly-typed deployment manifests.
# *   **Role in Research Pipeline:** Configures the stochastic optimizer. It ensures the replication acknowledges the epistemological limits of proprietary LLMs, as "the model's internal trade-offs... are opaque."
#
# ### 17. `execute_task_17_initialize_version_control`
# *   **Inputs:** `study_configuration` (Dictionary), `run_tag` (String).
# *   **Processes:** Initializes a git repository, creates an isolated branch, commits the $\tau_0$ baseline, locks the evaluator file permissions, and initializes the uncommitted `results.tsv`.
# *   **Outputs:** `Task17VersionControlReport` (Dataclass).
# *   **Data Transformation:** Transforms the filesystem state into a cryptographically hashed version control tree.
# *   **Role in Research Pipeline:** Implements the audit trail infrastructure. The paper states: "A complete experiment log $L$ records every attempted modification and its outcome."
#
# ### 18. `execute_autonomous_search_loop`
# *   **Inputs:** `working_directory` (Path), `study_configuration` (Dictionary), `anthropic_client` (Object), `prompt_templates` (Object), `vc_report` (Object), `model_version` (String).
# *   **Processes:** Executes Algorithm 1. Iteratively prompts the LLM, parses the XML response, overwrites the script, commits, spawns the evaluator in an OS-level process group, logs the RMSE, and executes the greedy keep/revert logic.
# *   **Outputs:** `Task18SearchLoopReport` (Dataclass).
# *   **Data Transformation:** Transforms the LLM's text output into executable code, and transforms the execution result into a persistent TSV log entry and a git tree mutation.
# *   **Role in Research Pipeline:** The core engine of the paper. It solves for the bounded optimum:
#     $$\hat{\tau}_K \in \arg \min_{\tau \in \{\tau_0, \dots, \tau_K\}} S(\tau; D^S)$$
#
# ### 19. `execute_task_19_recover_session_state`
# *   **Inputs:** `working_directory` (Path), `study_configuration` (Dictionary), `prompt_templates` (Object).
# *   **Processes:** Parses `results.tsv` and `git log`, reconciles unlogged commits or stray edits, identifies $s_{best}$, and formats the budget-aware restart prompt.
# *   **Outputs:** `Task19SessionRecoveryReport` (Dataclass).
# *   **Data Transformation:** Reconstructs the in-memory state machine from immutable filesystem artifacts.
# *   **Role in Research Pipeline:** Manages LLM context limits. As the paper notes, "Because the agent observes what it has already tried, the search is path dependent." This callable injects that path dependency back into the agent's context.
#
# ### 20. `execute_task_20_reproduce_benchmark_helpers`
# *   **Inputs:** `study_configuration` (Dictionary).
# *   **Processes:** Implements the 9 required econometric helpers (e.g., `fit_lasso`, `pelasso_lasso_avg`), applying the egalitarian transformation and scaling `sklearn` penalties to match `glmnet`'s $\frac{1}{2n}$ objective.
# *   **Outputs:** `Task20BenchmarkHelpersReport` (Dataclass).
# *   **Data Transformation:** Provides the mathematical functions that transform predictor matrices and target vectors into penalized coefficient vectors.
# *   **Role in Research Pipeline:** Provides the building blocks for peLASSO. It implements the egalitarian transformation:
#     $$\tilde{y}_s = y_s - K^{-1}\sum_k x_{k,s}$$
#
# ### 21. `execute_task_21_reproduce_benchmarks`
# *   **Inputs:** `info_builder` (Object), `target_vector` (Array), `lambda_grid` (Array), `study_configuration` (Dictionary), `data_provenance` (String), `execute_task_12_callable` (Function).
# *   **Processes:** Evaluates the ex-post oracle peLASSO and the exhaustive combinatorial searches (Best avg flex, Best N,W avg) using highly vectorized matrix operations, validating against published targets.
# *   **Outputs:** `Task21BenchmarkReport` (Dataclass).
# *   **Data Transformation:** Aggregates thousands of subset evaluations into optimal benchmark RMSE scores.
# *   **Role in Research Pipeline:** Establishes the rigorous baselines from Diebold and Shin (2019) that the agent is tasked with beating.
#
# ### 22. `execute_task_22_execute_discovery_runs`
# *   **Inputs:** `working_directory` (Path), `study_configuration` (Dictionary), `prompt_templates` (Object), `baseline_rmse` (Float).
# *   **Processes:** Sequentially executes three isolated instances of the autonomous search loop, parsing the final TSV logs to extract keep/discard/crash statistics.
# *   **Outputs:** `Task22DiscoveryRunsReport` (Dataclass).
# *   **Data Transformation:** Aggregates the outputs of three distinct stochastic processes into a unified summary table.
# *   **Role in Research Pipeline:** Fulfills the experimental design: "We conduct three independent runs, each starting from the simple average."
#
# ### 23. `execute_task_23_recreate_run_1_family`
# *   **Inputs:** `study_configuration` (Dictionary).
# *   **Processes:** Implements the stability selection and performance-weighted aggregation methods discovered in Run 1.
# *   **Outputs:** `Task23Run1FamilyReport` (Dataclass).
# *   **Data Transformation:** Transforms the `info` object into a forecast using selection frequencies and weighted empirical CDF interpolation.
# *   **Role in Research Pipeline:** Recreates the Run 1 discovery:
#     $$\pi_k = |\mathcal{W}|^{-1} \sum_{j \in \mathcal{W}} \mathbf{1}\{\hat{\beta}_k(\lambda_j) \neq 0\}$$
#     $$w_k = \pi_k^2 \cdot RMSE_k^{-14}$$
#
# ### 24. `execute_task_24_recreate_run_2_family`
# *   **Inputs:** `study_configuration` (Dictionary).
# *   **Processes:** Implements the temporally weighted ranking, adaptive window LOO-CV, and bias correction methods discovered in Run 2.
# *   **Outputs:** `Task24Run2FamilyReport` (Dataclass).
# *   **Data Transformation:** Transforms the `info` object into a forecast by applying exponential decay weights and subtracting a fraction of the recent LOO error.
# *   **Role in Research Pipeline:** Recreates the most successful discovery (Run 2):
#     $$\hat{y}_t = \tilde{y}_t - 0.80 \cdot \hat{e}_n^{LOO,pct}$$
#
# ### 25. `execute_task_25_recreate_run_3_family`
# *   **Inputs:** `study_configuration` (Dictionary).
# *   **Processes:** Implements the pilot ridge estimator, adaptive LASSO penalty factors, multi-horizon forward CV, and egalitarian elastic-net blend discovered in Run 3.
# *   **Outputs:** `Task25Run3FamilyReport` (Dataclass).
# *   **Data Transformation:** Transforms the `info` object into a forecast by scaling predictors by penalty factors and blending two distinct model outputs.
# *   **Role in Research Pipeline:** Recreates the overfitting Run 3 discovery:
#     $$\tilde{w}_k = \frac{(|\hat{\beta}_k^{ridge}| + \epsilon)^{-1}}{\text{mean}(|\hat{\beta}^{ridge}| + \epsilon)^{-1}}$$
#     $$\hat{y}_t = 0.70 \cdot \hat{y}_t^{PE} + 0.30 \cdot \hat{y}_t^{eEN}$$
#
# ### 26. `execute_task_26_compute_search_sample_table`
# *   **Inputs:** Evaluator report, target vector, baseline report, benchmark report, method family reports, configuration, provenance, Task 12 callable.
# *   **Processes:** Evaluates all 14 methods (benchmarks + discovered) through the immutable harness on the 65-period search sample, computing relative RMSEs and validating against Table 1 targets.
# *   **Outputs:** `Task26SearchSampleReport` (Dataclass).
# *   **Data Transformation:** Aggregates 14 distinct scalar scores into a formatted pandas DataFrame.
# *   **Role in Research Pipeline:** Proves Conclusion 1: "On the search sample, all three agent runs beat both the simple average and the peLASSO ex post benchmark."
#
# ### 27. `execute_task_27_compute_holdout_table`
# *   **Inputs:** Canonical panel, index map, lambda grids, configuration, method family reports, provenance.
# *   **Processes:** Freezes the discovered methods, instantiates the `HoldoutEvaluator` (which provides history up to $t-1$ for $t \in [71, 106]$), and computes full and ex-COVID holdout RMSEs.
# *   **Outputs:** `Task27HoldoutEvaluationReport` (Dataclass).
# *   **Data Transformation:** Applies the frozen algorithms to the previously air-gapped data matrix, outputting out-of-sample performance metrics.
# *   **Role in Research Pipeline:** The critical validation step. It computes $S^H(\hat{\tau}_K; D^H)$ to "distinguish robust improvements from sample-specific discoveries."
#
# ### 28. `execute_task_28_compute_dm_statistics`
# *   **Inputs:** Holdout evaluator, canonical panel, configuration, lambda grids, frozen registry, method reports, holdout table.
# *   **Processes:** Extracts raw holdout errors, computes the loss differential $d_t$, applies the Newey-West HAC variance estimator, and calculates one-sided p-values, formatting them into brackets.
# *   **Outputs:** `Task28DMSummaryReport` (Dataclass).
# *   **Data Transformation:** Transforms error vectors into a statistical probability metric, appending it as a formatted string to the evaluation table.
# *   **Role in Research Pipeline:** Implements the predictive accuracy test. The paper notes these "have intrinsically low power given the small holdout sample... and should be read as descriptive."
#
# ### 29. `execute_task_29_validate_search_dynamics`
# *   **Inputs:** `working_directory` (Path), `study_configuration` (Dictionary), `run_log_filenames` (Dictionary).
# *   **Processes:** Parses the TSV logs to count experiments/crashes and applies heuristic NLP regex matching to classify the methodological drift across the search phases.
# *   **Outputs:** `Task29SearchDynamicsReport` (Dataclass).
# *   **Data Transformation:** Transforms raw text descriptions into structured categorical classifications of agent behavior.
# *   **Role in Research Pipeline:** Analyzes "What the log reveals." It proves that "nominal hyperparameter tuning readily drifts into broader method discovery."
#
# ### 30. `execute_task_30_end_to_end_orchestrator`
# *   **Inputs:** Raw SPF panel, raw GDP target, configuration, mode, provenance, scope.
# *   **Processes:** Executes the strict Directed Acyclic Graph (DAG) of Tasks 1 through 29, routing control flow based on the execution mode and catching exceptions to populate `halt_diagnostics`.
# *   **Outputs:** `Task30EndToEndReport` (Dataclass).
# *   **Data Transformation:** Aggregates all intermediate dataclass reports into a single, massive state container.
# *   **Role in Research Pipeline:** The core operational engine. It guarantees that data validation strictly precedes imputation, which strictly precedes evaluator construction, ensuring absolute methodological integrity.
#
# ### 31. `execute_task_31_run_robustness_analyses`
# *   **Inputs:** Canonical holdout table, configuration, provenance, orchestrator callable, independent panel, independent target, vintage documentation.
# *   **Processes:** Validates the ex-COVID targets, recursively invokes the orchestrator on the independent dataset, and logically compares the ordinal rankings of the methods across datasets.
# *   **Outputs:** `Task31RobustnessReport` (Dataclass).
# *   **Data Transformation:** Compares two distinct evaluation tables to produce a boolean ranking preservation flag and a vintage sensitivity delta.
# *   **Role in Research Pipeline:** Verifies the robustness claims in Appendix E.5, confirming that Run 2's superiority is not an artifact of the specific 2018Q1 GDP vintage.
#
# ### 32. `execute_task_32_final_validation_and_archival`
# *   **Inputs:** `end_to_end_report` (Object), `output_directory` (String).
# *   **Processes:** Evaluates the 5 scientific conclusions using strict boolean logic, generates the epistemological fidelity matrix, serializes all artifacts to CSV/JSON, computes SHA-256 checksums, and zips the directory.
# *   **Outputs:** `Task32FinalReport` (Dataclass).
# *   **Data Transformation:** Transforms in-memory Python objects into persistent, cryptographically secured filesystem artifacts.
# *   **Role in Research Pipeline:** The ultimate synthesis. It packages the entire auditable loop into a distributable, verifiable research artifact, fulfilling the paper's mandate for transparency.
#
# ### 33. `execute_master_pipeline`
# *   **Inputs:** Raw SPF panel, raw GDP target, configuration, mode, output directory, provenance, scope, independent panel, independent target, vintage documentation.
# *   **Processes:** The top-level router. It sequentially invokes Task 30, Task 31 (conditionally), and Task 32, wrapping the entire execution in a `BaseException` handler to catch catastrophic system exits.
# *   **Outputs:** Dictionary containing the master status and the final reports.
# *   **Data Transformation:** Aggregates the final outputs of the DAG into a single dictionary payload for the end-user.
# *   **Role in Research Pipeline:** The definitive entry point for the researcher, providing a single, unified interface to execute the entire "Auditable AI Agent Loop for Empirical Economics."
#
# <br><br>
#
# ## **Usage Example**
#
# Here is the granular, step-by-step guide to executing the end-to-end pipeline for **"An Auditable AI Agent Loop for Empirical Economics: A Case Study in Forecast Combination"**. This example demonstrates how to synthetically generate the required ECB Survey of Professional Forecasters (SPF) panel and Eurostat GDP target series, load the study configuration from a YAML file, and execute the full research pipeline using the `execute_master_pipeline` orchestrator.
#
# *Assumption Note: It is assumed that all the callables that are presented in this notebook (e.g., `execute_master_pipeline`, `Task30EndToEndReport`) are loaded and available within a single Jupyter notebook namespace. There is no external folder with `.py` functions. It is also assumed that the `config.yaml` file is saved in the current working directory.*
#
# ### **Step 1: Synthetic Data Generation (`df_spf_panel_wide`, `df_gdp_target_series`)**
#
# The first requirement is a high-fidelity synthetic representation of the ECB SPF forecaster panel and the Eurostat Real GDP Growth series. These datasets must adhere strictly to the schema defined in the study: a `date` column (in `YYYYQq` format) and numeric columns cast to pandas' nullable `Float64` extension type to properly handle pre-imputation missingness.
#
# **Methodology:**
# 1.  **Date Generation:** We generate a strictly monotonic sequence of 106 quarters spanning from 1999Q3 to 2025Q4, perfectly matching the combined search and holdout samples.
# 2.  **Target Simulation:** We simulate the realized GDP growth ($y_t$) using a normal distribution calibrated to typical macroeconomic growth rates ($\mu \approx 2.0\%$, $\sigma \approx 1.5\%$).
# 3.  **Panel Simulation & Missingness Injection:** We simulate $K=23$ forecasters by adding idiosyncratic Gaussian noise to the target series. We then programmatically inject interior gaps and trailing gaps to rigorously exercise the downstream linear interpolation and cross-sectional mean imputation algorithms.
# 4.  **Schema Enforcement:** We explicitly cast the numeric columns to `Float64` to match the strict validation requirements of Task 1 and Task 3.
#
# ```python
# import pandas as pd
# import numpy as np
# import yaml
# import os
# from faker import Faker
# from typing import Dict, Any, Tuple
#
# # Initialize the Faker instance to ensure reproducibility of any mock metadata
# fake = Faker()
# # Seed the Faker instance with a fixed integer for deterministic output
# Faker.seed(42)
# # Seed the numpy random number generator to ensure the synthetic econometric data is perfectly reproducible
# np.random.seed(42)
#
# def generate_synthetic_econometric_data(
#     start_year: int = 1999,
#     start_quarter: int = 3,
#     total_periods: int = 106,
#     k_forecasters: int = 23
# ) -> Tuple[pd.DataFrame, pd.DataFrame]:
#     """
#     Generates high-fidelity synthetic representations of the ECB SPF forecaster panel
#     and the Eurostat real GDP growth target series.
#
#     Purpose:
#         To create mathematically plausible, schema-compliant datasets that perfectly
#         mimic the dimensions (106 quarters, 23 forecasters) and missingness patterns
#         of the empirical case study, enabling the execution of the research pipeline.
#
#     Inputs:
#         start_year (int): The starting year of the temporal index (default: 1999).
#         start_quarter (int): The starting quarter of the temporal index (default: 3).
#         total_periods (int): The total number of quarters to generate (default: 106).
#         k_forecasters (int): The cross-sectional dimension of the panel (default: 23).
#
#     Processes:
#         1. Temporal Index Generation: Computes a strictly monotonic sequence of 'YYYYQq' strings.
#         2. Target Simulation: Generates the GDP realization vector y_t ~ N(2.0, 1.5^2).
#         3. Panel Simulation: Generates the forecaster matrix X by adding idiosyncratic noise to y_t.
#         4. Missingness Injection: Programmatically inserts np.nan to simulate interior and trailing gaps.
#         5. Schema Enforcement: Casts the matrices to pandas DataFrames with Float64 extension types.
#
#     Outputs:
#         Tuple[pd.DataFrame, pd.DataFrame]: A tuple containing:
#             - df_spf_panel_wide: The 106x24 forecaster panel.
#             - df_gdp_target_series: The 106x2 target realization series.
#
#     Raises:
#         ValueError: If the requested dimensions are mathematically invalid (e.g., negative periods).
#     """
#     # Validate that the requested number of periods is strictly positive
#     if total_periods <= 0:
#         # Raise a ValueError to prevent the generation of empty or malformed arrays
#         raise ValueError(f"total_periods must be strictly positive. Received: {total_periods}")
#
#     # 1. Generate the strictly monotonic temporal index
#     # Initialize an empty list to store the canonical 'YYYYQq' date strings
#     dates = []
#     # Initialize the current year tracker
#     curr_y = start_year
#     # Initialize the current quarter tracker
#     curr_q = start_quarter
#
#     # Iterate exactly total_periods times to build the temporal sequence
#     for _ in range(total_periods):
#         # Format the current year and quarter into the canonical string and append to the list
#         dates.append(f"{curr_y}Q{curr_q}")
#         # Increment the quarter mathematically
#         curr_q += 1
#         # Handle the rollover from Q4 to Q1 of the subsequent year
#         if curr_q > 4:
#             # Reset the quarter to 1
#             curr_q = 1
#             # Increment the year by 1
#             curr_y += 1
#
#     # 2. Simulate the GDP Target Series (y_t)
#     # Assume a long-run mean GDP growth of 2.0%
#     mu_gdp = 2.0
#     # Define the volatility of the GDP growth as 1.5%
#     sigma_gdp = 1.5
#     # Generate the target vector using a normal distribution: y_t ~ N(mu, sigma^2)
#     y_t = np.random.normal(loc=mu_gdp, scale=sigma_gdp, size=total_periods)
#
#     # 3. Simulate the Forecaster Panel (X)
#     # Initialize a 2D numpy array of zeros with shape (106, 23)
#     X_matrix = np.zeros((total_periods, k_forecasters), dtype=np.float64)
#
#     # Iterate over each forecaster column to generate predictions
#     for k in range(k_forecasters):
#         # Forecasters predict the target with some idiosyncratic noise: x_{k,t} = y_t + e_{k,t}
#         noise = np.random.normal(loc=0.0, scale=0.5, size=total_periods)
#         # Add the noise to the true target to create the prediction vector
#         X_matrix[:, k] = y_t + noise
#
#     # 4. Inject Missing Values to test the imputation algorithms
#     # Inject an interior gap for forecaster 3 at index 10 (will be linearly interpolated)
#     X_matrix[10, 2] = np.nan
#     # Inject a trailing gap for forecaster 22 for the last 5 periods (will be cross-sectional mean imputed)
#     X_matrix[-5:, 21] = np.nan
#     # Inject an inactive forecaster (forecaster 23 is entirely missing for the first 20 periods)
#     X_matrix[:20, 22] = np.nan
#
#     # 5. Construct the DataFrames and Enforce Schema Types
#     # Create the target DataFrame using the dates list and the y_t array
#     df_gdp_target_series = pd.DataFrame({
#         "date": dates,
#         "real_gdp_growth_yoy": y_t
#     })
#     # Explicitly cast the target column to the pandas nullable Float64 type
#     df_gdp_target_series["real_gdp_growth_yoy"] = df_gdp_target_series["real_gdp_growth_yoy"].astype("Float64")
#
#     # Create the forecaster DataFrame starting with the dates list
#     df_spf_panel_wide = pd.DataFrame({"date": dates})
#
#     # Iterate over the K forecasters to append their columns
#     for k in range(k_forecasters):
#         # Construct the zero-padded column name (e.g., 'forecaster_01')
#         col_name = f"forecaster_{k+1:02d}"
#         # Assign the corresponding column from the numpy matrix to the DataFrame
#         df_spf_panel_wide[col_name] = X_matrix[:, k]
#         # Explicitly cast the forecaster column to the pandas nullable Float64 type
#         df_spf_panel_wide[col_name] = df_spf_panel_wide[col_name].astype("Float64")
#
#     # Return the tuple containing both high-fidelity synthetic datasets
#     return df_spf_panel_wide, df_gdp_target_series
#
# # Generate the synthetic datasets
# df_spf_panel_wide, df_gdp_target_series = generate_synthetic_econometric_data()
#
# # Preview the data to verify schema compliance
# print("Synthetic SPF Panel Preview (First 5 Rows):")
# print(df_spf_panel_wide.iloc[:, :5].head())
# print("\nSynthetic GDP Target Preview (First 5 Rows):")
# print(df_gdp_target_series.head())
# ```
#
# <br>
#
# ### **Step 2: Loading the Configuration (`config.yaml`)**
#
# The study relies on a deterministic configuration file (`config.yaml`) that defines all hyperparameters, data splits, and evaluation metrics. We assume this file exists in the working directory.
#
# **Methodology:**
# 1.  **File I/O:** Open `config.yaml` in read mode with strict UTF-8 encoding.
# 2.  **Parsing:** Use `yaml.safe_load` to convert the YAML structure into a nested Python dictionary, preventing arbitrary code execution.
# 3.  **Verification:** Catch `FileNotFoundError` and `yaml.YAMLError` to fail fast if the epistemological bedrock of the study is missing or corrupted.
#
# ```python
# def load_study_configuration(filepath: str = "config.yaml") -> Dict[str, Any]:
#     """
#     Loads the study configuration parameters from a YAML file into a Python dictionary.
#
#     Purpose:
#         To ingest the deterministic hyperparameters, data split definitions, and
#         architectural constraints defined in the external configuration file. This ensures
#         reproducibility by separating code from configuration.
#
#     Inputs:
#         filepath (str): The relative or absolute path to the YAML configuration file.
#                         Default is "config.yaml".
#
#     Processes:
#         1.  File Access: Attempts to open the specified file in read mode with UTF-8 encoding.
#         2.  Parsing: Uses PyYAML's safe_load to parse the YAML structure securely.
#         3.  Validation: Catches file existence errors and parsing errors, raising descriptive exceptions.
#
#     Outputs:
#         Dict[str, Any]: A nested dictionary containing the study configuration.
#
#     Raises:
#         TypeError: If filepath is not a string.
#         FileNotFoundError: If the configuration file does not exist.
#         RuntimeError: If the file contains invalid YAML syntax.
#     """
#     # Validate input type to ensure filesystem operations are safe
#     if not isinstance(filepath, str):
#         # Raise a TypeError if the filepath is not a string
#         raise TypeError(f"filepath must be a string, got {type(filepath)}.")
#
#     # Check if the file actually exists on disk before attempting to open it
#     if not os.path.exists(filepath):
#         # Raise a FileNotFoundError to fail fast if the configuration is missing
#         raise FileNotFoundError(f"Fatal: Configuration file not found at {filepath}.")
#
#     try:
#         # Open the file stream with strict UTF-8 encoding to handle special characters
#         with open(filepath, "r", encoding="utf-8") as file:
#             # Parse the YAML content safely, preventing the execution of arbitrary Python objects
#             config = yaml.safe_load(file)
#
#         # Log success to console
#         print(f"\nSuccessfully loaded configuration from {filepath}")
#
#         # Return the parsed configuration dictionary
#         return config
#
#     except yaml.YAMLError as e:
#         # Catch YAML parsing errors and re-raise with descriptive context
#         raise RuntimeError(f"Fatal: Failed to parse YAML configuration in {filepath}. Details: {e}")
#
# # Load the configuration into memory
# # Note: Ensure 'config.yaml' is in your working directory with the content provided previously.
# config = load_study_configuration()
# ```
#
# <br>
#
# ### **Step 3: Executing the Pipeline (`execute_master_pipeline`)**
#
# With the data (`df_spf_panel_wide`, `df_gdp_target_series`) and configuration (`config`) in memory, we invoke the top-level orchestrator. We will execute the pipeline in `holdout_evaluation` mode. This mode bypasses the live LLM stochastic search (which requires an API key and significant wall-clock time) while rigorously exercising the entire deterministic research kernel: data alignment, imputation, evaluator construction, benchmark reproduction, and out-of-sample Diebold-Mariano testing.
#
# **Methodology:**
# 1.  **Function Call:** Pass the DataFrames, the `config` dictionary, and the required metadata strings to `execute_master_pipeline`.
# 2.  **Output Handling:** The function returns a master dictionary containing the execution status and the nested dataclass reports. We extract the `task_30_report` to view the final evaluation tables.
#
# ```python
# # ==============================================================================
# # Execution of the End-to-End Study Pipeline
# # ==============================================================================
#
# if __name__ == "__main__":
#     # Ensure we have valid inputs before running the computationally intensive pipeline
#     if not df_spf_panel_wide.empty and not df_gdp_target_series.empty and config:
#
#         print("\nInitiating Auditable AI Agent Loop Pipeline (Holdout Evaluation Mode)...")
#
#         # Define the output directory for the final reproducibility archive
#         output_directory_path = "./reproducibility_archive"
#
#         # Execute the master pipeline orchestrator
#         # This will route through Tasks 1-14, 20-21, 23-28, and 32
#         master_results = execute_master_pipeline(
#             df_spf_panel_wide=df_spf_panel_wide,
#             df_gdp_target_series=df_gdp_target_series,
#             study_configuration=config,
#             mode="holdout_evaluation",
#             output_directory=output_directory_path,
#             data_provenance="synthetic_demonstration",
#             declared_panel_scope="full_panel",
#             df_independent_panel=None,
#             df_independent_target=None,
#             vintage_documentation=None
#         )
#
#         # ==============================================================================
#         # Inspecting the Outputs
#         # ==============================================================================
#
#         print("\n" + "="*80)
#         print("STUDY EXECUTION COMPLETE")
#         print("="*80)
#
#         # Extract the master status flag from the results dictionary
#         status = master_results.get("master_status", "UNKNOWN")
#         print(f"\nMaster Pipeline Status: {status}")
#
#         # Check if the pipeline halted prematurely due to a validation error
#         if status == "ERROR" or status == "HALTED_AT_TASK_30":
#             # Extract and print the diagnostic error trace
#             error_trace = master_results.get("master_error_trace", "No trace available.")
#             print(f"\nPipeline Halted. Diagnostics:\n{error_trace}")
#         else:
#             # 1. Accessing the Core Evaluation Reports
#             # Extract the Task 30 End-to-End Report from the master dictionary
#             report_30 = master_results.get("task_30_report")
#
#             if report_30 is not None:
#                 # Extract and print the search-sample RMSE table
#                 search_table = report_30.search_sample_rmse_table
#                 if search_table is not None:
#                     print("\n[In-Sample Results: Search Sample (1999Q3-2016Q4)]")
#                     print(search_table[["method_name", "search_sample_rmse", "search_sample_relative_rmse"]].head(5).to_string(index=False))
#
#                 # Extract and print the holdout RMSE table
#                 holdout_table = report_30.holdout_rmse_table
#                 if holdout_table is not None:
#                     print("\n[Out-of-Sample Results: Holdout Sample (2017Q1-2025Q4)]")
#                     print(holdout_table[["method_name", "holdout_rmse", "holdout_relative_rmse"]].head(5).to_string(index=False))
#
#                 # Extract and print the Diebold-Mariano summary table
#                 dm_table = report_30.dm_summary_table
#                 if dm_table is not None:
#                     print("\n[Diebold-Mariano Predictive Accuracy Summary]")
#                     print(dm_table[["method_name", "holdout_rmse_formatted", "holdout_ex_covid_rmse_formatted"]].head(5).to_string(index=False))
#
#             # 2. Accessing the Archival Report
#             # Extract the Task 32 Final Report from the master dictionary
#             report_32 = master_results.get("task_32_report")
#             if report_32 is not None:
#                 print("\n" + "="*80)
#                 print("FINAL FIDELITY AUDIT & ARCHIVAL")
#                 print("="*80)
#                 # Print the location of the cryptographically secured reproducibility package
#                 print(f"Reproducibility Archive successfully generated at: {report_32.archive_path}")
#
#     else:
#         print("Error: Missing data or configuration. Cannot proceed.")
# ```
#
# ### **Summary of the Execution Flow**
#
# 1.  **Data Ingestion:** The synthetic `df_spf_panel_wide` and `df_gdp_target_series` are passed to the pipeline alongside the parsed `config` dictionary.
# 2.  **Validation & Cleansing:** The pipeline validates the schema (24 columns, `Float64` types), standardizes the `YYYYQq` dates, and sorts the data chronologically.
# 3.  **Alignment & Imputation:** It performs an audited inner join on the date field, then applies linear interpolation for interior gaps and cross-sectional means for trailing gaps.
# 4.  **Evaluator Construction:** It builds the `EvaluatorInfoBuilder` factory, strictly enforcing the no-look-ahead invariant for the rolling window $W=20$.
# 5.  **Benchmark Reproduction:** It computes the absolute and relative RMSEs for the Simple Average, peLASSO ex-post, and exhaustive combinatorial benchmarks.
# 6.  **Method Recreation:** It mathematically recreates the Run 1, Run 2, and Run 3 method families from the post-search registry.
# 7.  **Evaluation & Testing:** It evaluates all 14 methods on the search sample and the air-gapped holdout sample, computing the Newey-West HAC Diebold-Mariano p-values.
# 8.  **Audit & Archival:** It validates the scientific conclusions, generates the epistemological fidelity matrix, and compresses all artifacts into a cryptographically hashed zip archive.
#
# <br><br>
#
# ## **Implemented Callables**

# %%
# Task 1: Validate Schema and Type of df_spf_panel_wide

# ==============================================================================
# Task 1: Validate Schema and Type of df_spf_panel_wide
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Step 1: Validate object type and column existence
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class SchemaValidationResult:
    """
    A structured, implementation-grade record containing the results of the schema validation step.

    Purpose:
        To encapsulate the outcome of the structural schema validation for the SPF panel,
        ensuring that the exact expected columns (date and K=23 forecasters) are present
        and correctly ordered before downstream econometric processing.

    Attributes:
        passed (bool): True if the schema exactly matches expectations, False otherwise.
        expected_columns (List[str]): The exact list of expected column names in order.
        actual_columns (List[str]): The actual list of column names found in the DataFrame.
        missing_columns (Set[str]): Columns expected but not found.
        extra_columns (Set[str]): Columns found but not expected.
        positional_mismatches (List[Tuple[int, str, str]]): List of (index, expected, actual) for ordering errors.
    """
    # Boolean flag indicating whether the schema perfectly matches the expected structure
    passed: bool
    # List of strings representing the exact expected column names in their required order
    expected_columns: List[str]
    # List of strings representing the actual column names extracted from the input DataFrame
    actual_columns: List[str]
    # Set of strings containing column names that were expected but missing from the input
    missing_columns: Set[str]
    # Set of strings containing column names that were present in the input but not expected
    extra_columns: Set[str]
    # List of tuples detailing ordering errors, formatted as (index, expected_name, actual_name)
    positional_mismatches: List[Tuple[int, str, str]]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and type correctness of the schema validation record.

        Raises:
            TypeError: If any attribute does not match its declared type hint.
        """
        # Verify that the 'passed' attribute is strictly a boolean value
        if not isinstance(self.passed, bool):
            # Raise a TypeError if 'passed' is not a boolean, preventing logical errors downstream
            raise TypeError("SchemaValidationResult: 'passed' must be a boolean.")

        # Verify that 'expected_columns' is a list to ensure ordered sequence compatibility
        if not isinstance(self.expected_columns, list):
            # Raise a TypeError if 'expected_columns' is not a list
            raise TypeError("SchemaValidationResult: 'expected_columns' must be a list.")

        # Verify that 'actual_columns' is a list to ensure ordered sequence compatibility
        if not isinstance(self.actual_columns, list):
            # Raise a TypeError if 'actual_columns' is not a list
            raise TypeError("SchemaValidationResult: 'actual_columns' must be a list.")

        # Verify that 'missing_columns' is a set to ensure mathematical set operations are valid
        if not isinstance(self.missing_columns, set):
            # Raise a TypeError if 'missing_columns' is not a set
            raise TypeError("SchemaValidationResult: 'missing_columns' must be a set.")

        # Verify that 'extra_columns' is a set to ensure mathematical set operations are valid
        if not isinstance(self.extra_columns, set):
            # Raise a TypeError if 'extra_columns' is not a set
            raise TypeError("SchemaValidationResult: 'extra_columns' must be a set.")

        # Verify that 'positional_mismatches' is a list to ensure ordered sequence compatibility
        if not isinstance(self.positional_mismatches, list):
            # Raise a TypeError if 'positional_mismatches' is not a list
            raise TypeError("SchemaValidationResult: 'positional_mismatches' must be a list.")


def validate_spf_panel_schema(df_spf_panel_wide: Any, study_configuration: Dict[str, Any]) -> SchemaValidationResult:
    """
    Validates that the input object is a pandas DataFrame and contains the exact
    expected columns in the exact expected order.

    Args:
        df_spf_panel_wide (Any): The input object to validate.
        study_configuration (Dict[str, Any]): The study configuration dictionary containing K_forecasters.

    Returns:
        SchemaValidationResult: A structured record of the validation outcome.

    Raises:
        TypeError: If the input object is not a pandas DataFrame.
        ValueError: If the configuration dictionary is missing required keys.
    """
    # Confirm that the input is a pandas DataFrame
    if not isinstance(df_spf_panel_wide, pd.DataFrame):
        raise TypeError(f"Input df_spf_panel_wide must be a pandas DataFrame. Received: {type(df_spf_panel_wide)}")

    # Extract the expected number of forecasters from the configuration
    try:
        k_forecasters = study_configuration["data_inputs"]["spf_panel_wide"]["K_forecasters"]
    except KeyError as e:
        raise ValueError(f"Missing required configuration key for K_forecasters: {e}")

    # Construct the expected column list programmatically
    # Expected: ["date", "forecaster_01", "forecaster_02", ..., "forecaster_23"]
    expected_columns = ["date"] + [f"forecaster_{k:02d}" for k in range(1, k_forecasters + 1)]

    # Extract actual columns as a list
    actual_columns = list(df_spf_panel_wide.columns)

    # Compute set differences to identify missing or extra columns
    expected_set = set(expected_columns)
    actual_set = set(actual_columns)
    missing_columns = expected_set - actual_set
    extra_columns = actual_set - expected_set

    # Identify positional mismatches by zipping the lists
    positional_mismatches = []
    for i, (exp_col, act_col) in enumerate(zip(expected_columns, actual_columns)):
        if exp_col != act_col:
            positional_mismatches.append((i, exp_col, act_col))

    # The schema passes if and only if the lists are exactly identical
    passed = (expected_columns == actual_columns)

    return SchemaValidationResult(
        passed=passed,
        expected_columns=expected_columns,
        actual_columns=actual_columns,
        missing_columns=missing_columns,
        extra_columns=extra_columns,
        positional_mismatches=positional_mismatches
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Step 2: Validate column data types
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class DtypeValidationResult:
    """
    A structured, implementation-grade record containing the results of the data type validation step.

    Purpose:
        To encapsulate the outcome of the data type and format validation for the SPF panel,
        ensuring that the temporal index (date) and the forecaster predictions adhere to the
        strict numerical and string formatting requirements of the study.

    Attributes:
        passed (bool): True if all dtypes and formats are acceptable, False otherwise.
        date_dtype (str): The string representation of the date column's dtype.
        date_format_valid (bool): True if all date strings match the YYYYQq format.
        date_format_violations (List[Tuple[int, Any]]): List of (row_index, invalid_value).
        forecaster_dtypes (Dict[str, str]): Mapping of forecaster column names to their dtypes.
        forecaster_dtype_violations (List[str]): List of forecaster columns with unacceptable dtypes.
        forecaster_missing_counts (Dict[str, int]): Mapping of forecaster column names to missing value counts.
        warnings (List[str]): List of non-fatal warnings (e.g., integer dtypes).
    """
    # Boolean flag indicating whether all data types and formats meet the strict study requirements
    passed: bool
    # String representation of the pandas data type associated with the date column
    date_dtype: str
    # Boolean flag indicating whether all date entries conform to the canonical 'YYYYQq' regex pattern
    date_format_valid: bool
    # List of tuples capturing the exact row index and invalid value for any date format violations
    date_format_violations: List[Tuple[int, Any]]
    # Dictionary mapping each forecaster column name to its respective pandas data type string
    forecaster_dtypes: Dict[str, str]
    # List of forecaster column names that possess mathematically unacceptable data types (e.g., object/string)
    forecaster_dtype_violations: List[str]
    # Dictionary mapping each forecaster column name to its exact count of missing (NaN/NA) values
    forecaster_missing_counts: Dict[str, int]
    # List of strings containing non-fatal diagnostic warnings generated during the validation process
    warnings: List[str] = field(default_factory=list)

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and type correctness of the data type validation record.

        Raises:
            TypeError: If any attribute does not match its declared type hint.
        """
        # Verify that the 'passed' attribute is strictly a boolean value
        if not isinstance(self.passed, bool):
            # Raise a TypeError if 'passed' is not a boolean, preventing logical errors downstream
            raise TypeError("DtypeValidationResult: 'passed' must be a boolean.")

        # Verify that the 'date_dtype' attribute is strictly a string
        if not isinstance(self.date_dtype, str):
            # Raise a TypeError if 'date_dtype' is not a string
            raise TypeError("DtypeValidationResult: 'date_dtype' must be a string.")

        # Verify that the 'date_format_valid' attribute is strictly a boolean value
        if not isinstance(self.date_format_valid, bool):
            # Raise a TypeError if 'date_format_valid' is not a boolean
            raise TypeError("DtypeValidationResult: 'date_format_valid' must be a boolean.")

        # Verify that 'date_format_violations' is a list to ensure ordered sequence compatibility
        if not isinstance(self.date_format_violations, list):
            # Raise a TypeError if 'date_format_violations' is not a list
            raise TypeError("DtypeValidationResult: 'date_format_violations' must be a list.")

        # Verify that 'forecaster_dtypes' is a dictionary to ensure key-value mapping compatibility
        if not isinstance(self.forecaster_dtypes, dict):
            # Raise a TypeError if 'forecaster_dtypes' is not a dictionary
            raise TypeError("DtypeValidationResult: 'forecaster_dtypes' must be a dictionary.")

        # Verify that 'forecaster_dtype_violations' is a list to ensure ordered sequence compatibility
        if not isinstance(self.forecaster_dtype_violations, list):
            # Raise a TypeError if 'forecaster_dtype_violations' is not a list
            raise TypeError("DtypeValidationResult: 'forecaster_dtype_violations' must be a list.")

        # Verify that 'forecaster_missing_counts' is a dictionary to ensure key-value mapping compatibility
        if not isinstance(self.forecaster_missing_counts, dict):
            # Raise a TypeError if 'forecaster_missing_counts' is not a dictionary
            raise TypeError("DtypeValidationResult: 'forecaster_missing_counts' must be a dictionary.")

        # Verify that 'warnings' is a list to ensure ordered sequence compatibility
        if not isinstance(self.warnings, list):
            # Raise a TypeError if 'warnings' is not a list
            raise TypeError("DtypeValidationResult: 'warnings' must be a list.")


def validate_spf_panel_dtypes(df_spf_panel_wide: pd.DataFrame, expected_columns: List[str]) -> DtypeValidationResult:
    """
    Validates the data types of the date column and the forecaster columns, and checks
    the date strings against the required regular expression format.

    Args:
        df_spf_panel_wide (pd.DataFrame): The schema-validated DataFrame.
        expected_columns (List[str]): The list of expected columns to iterate over.

    Returns:
        DtypeValidationResult: A structured record of the dtype validation outcome.
    """
    warnings = []
    passed = True

    # Validate the date column dtype
    date_dtype_str = str(df_spf_panel_wide["date"].dtype)
    if not (pd.api.types.is_string_dtype(df_spf_panel_wide["date"]) or pd.api.types.is_object_dtype(df_spf_panel_wide["date"])):
        warnings.append(f"Date column dtype is {date_dtype_str}, expected string/object. Will require conversion.")
        # We do not fail here, as Task 5 will cleanse dates, but we flag it.

    # Validate the date format using regex: YYYYQq
    date_regex = re.compile(r"^\d{4}Q[1-4]$")
    date_format_violations = []

    # Safely cast to string for regex matching to avoid errors on nulls or non-strings
    date_strings = df_spf_panel_wide["date"].astype(str)
    invalid_mask = ~date_strings.str.match(date_regex)

    if invalid_mask.any():
        passed = False
        # Extract the indices and values of the violations
        invalid_indices = df_spf_panel_wide.index[invalid_mask].tolist()
        invalid_values = df_spf_panel_wide.loc[invalid_mask, "date"].tolist()
        date_format_violations = list(zip(invalid_indices, invalid_values))

    # Validate forecaster columns
    forecaster_cols = [col for col in expected_columns if col != "date"]
    forecaster_dtypes = {}
    forecaster_dtype_violations = []
    forecaster_missing_counts = {}

    for col in forecaster_cols:
        col_dtype = df_spf_panel_wide[col].dtype
        col_dtype_str = str(col_dtype)
        forecaster_dtypes[col] = col_dtype_str

        # Count missing values (expected pre-imputation)
        missing_count = int(df_spf_panel_wide[col].isna().sum())
        forecaster_missing_counts[col] = missing_count

        # Check if dtype is numeric
        if not pd.api.types.is_numeric_dtype(col_dtype):
            passed = False
            forecaster_dtype_violations.append(col)
        elif pd.api.types.is_integer_dtype(col_dtype):
            warnings.append(f"Forecaster column {col} has integer dtype ({col_dtype_str}). Float64 is recommended.")

    return DtypeValidationResult(
        passed=passed,
        date_dtype=date_dtype_str,
        date_format_valid=(len(date_format_violations) == 0),
        date_format_violations=date_format_violations,
        forecaster_dtypes=forecaster_dtypes,
        forecaster_dtype_violations=forecaster_dtype_violations,
        forecaster_missing_counts=forecaster_missing_counts,
        warnings=warnings
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Step 3: Validate semantic role and provenance
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ProvenanceValidationResult:
    """
    A structured, implementation-grade record containing the results of the semantic and provenance validation step.

    Purpose:
        To encapsulate the outcome of the semantic checks, ensuring the input data
        is a researcher-prepared wide panel (not raw microdata) and that its temporal
        coverage aligns with the expected econometric evaluation periods.

    Attributes:
        passed (bool): True if the structural checks for provenance pass.
        semantic_role (str): Statement regarding the semantic role of the rows.
        source_attestation (str): Statement regarding the raw microdata status.
        quarter_coverage_complete (bool): True if row count matches the quarter span.
        quarter_gaps (List[str]): List of missing quarters if coverage is incomplete.
        provenance_note (str): Detailed memo documenting assumptions and required attestations.
    """
    # Boolean flag indicating whether the structural provenance checks successfully passed
    passed: bool
    # String statement defining the semantic role of the rows (e.g., evaluation/target quarter alignment)
    semantic_role: str
    # String statement attesting to the data source status (e.g., confirming it is not raw microdata)
    source_attestation: str
    # Boolean flag indicating whether the total row count perfectly matches the expected temporal quarter span
    quarter_coverage_complete: bool
    # List of strings detailing the exact 'YYYYQq' identifiers for any missing quarters within the span
    quarter_gaps: List[str]
    # String containing a detailed memo documenting the epistemological assumptions and required human attestations
    provenance_note: str

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and type correctness of the provenance validation record.

        Raises:
            TypeError: If any attribute does not match its declared type hint.
        """
        # Verify that the 'passed' attribute is strictly a boolean value
        if not isinstance(self.passed, bool):
            # Raise a TypeError if 'passed' is not a boolean, preventing logical errors downstream
            raise TypeError("ProvenanceValidationResult: 'passed' must be a boolean.")

        # Verify that the 'semantic_role' attribute is strictly a string
        if not isinstance(self.semantic_role, str):
            # Raise a TypeError if 'semantic_role' is not a string
            raise TypeError("ProvenanceValidationResult: 'semantic_role' must be a string.")

        # Verify that the 'source_attestation' attribute is strictly a string
        if not isinstance(self.source_attestation, str):
            # Raise a TypeError if 'source_attestation' is not a string
            raise TypeError("ProvenanceValidationResult: 'source_attestation' must be a string.")

        # Verify that the 'quarter_coverage_complete' attribute is strictly a boolean value
        if not isinstance(self.quarter_coverage_complete, bool):
            # Raise a TypeError if 'quarter_coverage_complete' is not a boolean
            raise TypeError("ProvenanceValidationResult: 'quarter_coverage_complete' must be a boolean.")

        # Verify that 'quarter_gaps' is a list to ensure ordered sequence compatibility
        if not isinstance(self.quarter_gaps, list):
            # Raise a TypeError if 'quarter_gaps' is not a list
            raise TypeError("ProvenanceValidationResult: 'quarter_gaps' must be a list.")

        # Verify that the 'provenance_note' attribute is strictly a string
        if not isinstance(self.provenance_note, str):
            # Raise a TypeError if 'provenance_note' is not a string
            raise TypeError("ProvenanceValidationResult: 'provenance_note' must be a string.")

def validate_spf_panel_provenance(df_spf_panel_wide: pd.DataFrame) -> ProvenanceValidationResult:
    """
    Validates the semantic role and provenance of the DataFrame by checking date uniqueness
    and comparing the row count to the expected temporal span.

    Args:
        df_spf_panel_wide (pd.DataFrame): The DataFrame with validated dates.

    Returns:
        ProvenanceValidationResult: A structured record of the provenance validation.
    """
    passed = True
    quarter_gaps = []

    # Check if dates are unique (a requirement for it NOT to be raw microdata)
    is_unique = df_spf_panel_wide["date"].is_unique
    if not is_unique:
        passed = False
        source_attestation = "possibly_raw_microdata"
    else:
        source_attestation = "confirmed_not_raw_microdata"

    # Extract valid dates to compute span
    date_regex = re.compile(r"^\d{4}Q[1-4]$")
    valid_dates = [str(d) for d in df_spf_panel_wide["date"] if date_regex.match(str(d))]

    if valid_dates:
        # Parse to (year, quarter) tuples to find absolute min and max
        parsed_dates = [(int(d[:4]), int(d[5])) for d in valid_dates]
        min_date = min(parsed_dates)
        max_date = max(parsed_dates)

        # Compute expected number of quarters: (Y2 - Y1) * 4 + (Q2 - Q1) + 1
        expected_quarters = (max_date[0] - min_date[0]) * 4 + (max_date[1] - min_date[1]) + 1

        # Check if row count matches expected quarters
        quarter_coverage_complete = (len(valid_dates) == expected_quarters)

        if not quarter_coverage_complete:
            # Identify exact gaps
            all_expected_quarters = []
            curr_y, curr_q = min_date
            for _ in range(expected_quarters):
                all_expected_quarters.append(f"{curr_y}Q{curr_q}")
                curr_q += 1
                if curr_q > 4:
                    curr_q = 1
                    curr_y += 1

            quarter_gaps = list(set(all_expected_quarters) - set(valid_dates))
            # We do not fail here; gaps are handled in Task 2. We just record them.
    else:
        quarter_coverage_complete = False

    semantic_role = "unverifiable_computationally"
    provenance_note = (
        "Row semantics are assumed to be evaluation/target quarter alignment as required by the study design. "
        "This cannot be computationally verified and must be attested by the data preparer. "
        f"Source attestation: {source_attestation}."
    )

    return ProvenanceValidationResult(
        passed=passed,
        semantic_role=semantic_role,
        source_attestation=source_attestation,
        quarter_coverage_complete=quarter_coverage_complete,
        quarter_gaps=quarter_gaps,
        provenance_note=provenance_note
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task1ValidationReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the SPF panel schema and type validation phase. This report encapsulates the
    results of column existence checks, data type audits, and semantic provenance
    verifications, ensuring that the forecaster panel (X) is perfectly aligned
    with the study's requirements before downstream processing.

    Attributes:
        schema_result (Any): An instance of SchemaValidationResult documenting
            the presence and order of the 24 required columns.
        dtype_result (Any): An instance of DtypeValidationResult documenting
            the format of date strings and the numeric type of forecaster columns.
        provenance_result (Any): An instance of ProvenanceValidationResult
            confirming the semantic role and non-raw status of the input panel.
    """
    # The result of the schema validation step (Step 1) confirming column existence and order
    schema_result: Any  # Expected type: SchemaValidationResult
    # The result of the data type validation step (Step 2) confirming numeric and date formats
    dtype_result: Any  # Expected type: DtypeValidationResult
    # The result of the semantic and provenance validation step (Step 3) confirming data origin
    provenance_result: Any  # Expected type: ProvenanceValidationResult

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity
        of the validation report before it is consumed by the orchestrator.

        Raises:
            ValueError: If any of the constituent validation results are missing or None.
        """
        # Verify that the schema_result artifact is present and not None to maintain the audit trail
        if self.schema_result is None:
            # Raise a ValueError if the column check result is missing from the report
            raise ValueError("Task1ValidationReport: schema_result cannot be None.")

        # Verify that the dtype_result artifact is present and not None to maintain the audit trail
        if self.dtype_result is None:
            # Raise a ValueError if the type check result is missing from the report
            raise ValueError("Task1ValidationReport: dtype_result cannot be None.")

        # Verify that the provenance_result artifact is present and not None to maintain the audit trail
        if self.provenance_result is None:
            # Raise a ValueError if the semantic check result is missing from the report
            raise ValueError("Task1ValidationReport: provenance_result cannot be None.")


def execute_task_1_validate_schema_and_type(df_spf_panel_wide: Any, study_configuration: Dict[str, Any]) -> Task1ValidationReport:
    """
    Orchestrates Task 1: Validates the schema, data types, and provenance of the SPF panel.
    Halts execution by raising a ValueError if any fatal validation check fails.

    Args:
        df_spf_panel_wide (Any): The raw input object to validate.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Task1ValidationReport: The comprehensive validation report.

    Raises:
        TypeError: If the input is not a DataFrame.
        ValueError: If schema or dtype validation fails fatally.
    """
    # Step 1: Validate Schema
    schema_result = validate_spf_panel_schema(df_spf_panel_wide, study_configuration)
    if not schema_result.passed:
        error_msg = (
            f"Task 1 Step 1 Failed: Schema validation error.\n"
            f"Expected 24 columns, found {len(schema_result.actual_columns)}.\n"
            f"Missing columns: {schema_result.missing_columns}\n"
            f"Extra columns: {schema_result.extra_columns}\n"
            f"Positional mismatches: {schema_result.positional_mismatches}"
        )
        raise ValueError(error_msg)

    # Step 2: Validate Dtypes
    dtype_result = validate_spf_panel_dtypes(df_spf_panel_wide, schema_result.expected_columns)
    if not dtype_result.passed:
        error_msg = "Task 1 Step 2 Failed: Data type validation error.\n"
        if not dtype_result.date_format_valid:
            error_msg += f"Date format violations found: {dtype_result.date_format_violations[:5]}...\n"
        if dtype_result.forecaster_dtype_violations:
            error_msg += f"Unacceptable dtypes in forecaster columns: {dtype_result.forecaster_dtype_violations}\n"
        raise ValueError(error_msg)

    # Step 3: Validate Provenance
    provenance_result = validate_spf_panel_provenance(df_spf_panel_wide)
    if not provenance_result.passed:
        error_msg = (
            f"Task 1 Step 3 Failed: Provenance validation error.\n"
            f"Source attestation failed: {provenance_result.source_attestation}. "
            f"Input appears to be raw microdata (duplicate dates found)."
        )
        raise ValueError(error_msg)

    return Task1ValidationReport(
        schema_result=schema_result,
        dtype_result=dtype_result,
        provenance_result=provenance_result
    )

# %%
# Task 2: Validate Structural Integrity of df_spf_panel_wide

# ==============================================================================
# Task 2: Validate Structural Integrity of df_spf_panel_wide
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Helper Functions for Quarter Arithmetic
# -------------------------------------------------------------------------------------------------------------------------------

def _parse_quarter(q_str: str) -> Tuple[int, int]:
    """
    Parses a canonical YYYYQq string into a (year, quarter) integer tuple.

    Args:
        q_str (str): The quarter string, e.g., "1999Q3".

    Returns:
        Tuple[int, int]: A tuple containing (year, quarter).

    Raises:
        ValueError: If the string does not match the expected format.
    """
    # Validate the format strictly before parsing
    if not re.match(r"^\d{4}Q[1-4]$", str(q_str)):
        raise ValueError(f"Invalid quarter format: {q_str}. Expected YYYYQq.")

    # Extract the year (first 4 characters) and quarter (last character)
    year = int(q_str[:4])
    quarter = int(q_str[5])

    return year, quarter


def _generate_quarter_sequence(start_q: str, end_q: str) -> List[str]:
    """
    Generates a continuous sequence of YYYYQq strings from start_q to end_q inclusive.

    Args:
        start_q (str): The starting quarter string.
        end_q (str): The ending quarter string.

    Returns:
        List[str]: A list of contiguous quarter strings.

    Raises:
        ValueError: If start_q is chronologically after end_q.
    """
    # Parse the start and end bounds
    start_y, start_q_num = _parse_quarter(start_q)
    end_y, end_q_num = _parse_quarter(end_q)

    # Ensure the start is not after the end
    if (start_y, start_q_num) > (end_y, end_q_num):
        raise ValueError(f"Start quarter {start_q} is after end quarter {end_q}.")

    sequence = []
    curr_y, curr_q = start_y, start_q_num

    # Generate quarters iteratively until the end bound is passed
    while (curr_y, curr_q) <= (end_y, end_q_num):
        # Append the formatted string to the sequence
        sequence.append(f"{curr_y}Q{curr_q}")

        # Increment the quarter
        curr_q += 1
        # Handle year rollover
        if curr_q > 4:
            curr_q = 1
            curr_y += 1

    return sequence

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Step 1: Validate uniqueness, ordering, and completeness
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class StructuralIntegrityResult:
    """
    A structured, implementation-grade record containing the results of the uniqueness,
    ordering, and row count validation for the forecaster panel.

    Purpose:
        To encapsulate the outcome of the structural integrity checks (Task 2, Step 1).
        This ensures that the temporal index (date) contains no duplicates and is strictly
        monotonically increasing, which is a mathematical prerequisite for the recursive
        rolling-origin evaluation harness.

    Attributes:
        passed (bool): True if all structural integrity checks pass, False otherwise.
        dates_unique (bool): True if the date column contains absolutely no duplicate values.
        duplicate_dates (List[Tuple[int, str]]): A list of tuples containing the row index and the duplicate date string.
        chronological_order_valid (bool): True if the dates are in strict ascending chronological order.
        order_violations (List[Tuple[int, str, str]]): A list of tuples detailing ordering errors (index, date1, date2).
        row_count (int): The total number of observations (rows) in the DataFrame.
        row_count_matches_expected (bool): True if the row count perfectly matches the declared panel scope.
        declared_panel_scope (Optional[str]): The intended scope of the panel (e.g., 'search_only', 'full_panel').
        expected_row_count (Optional[int]): The theoretical number of rows expected based on the study configuration.
    """
    # Boolean flag indicating whether the overall structural integrity validation was successful
    passed: bool
    # Boolean flag confirming that every date identifier in the panel is mathematically unique
    dates_unique: bool
    # List of tuples capturing the exact row index and string value of any detected duplicate dates
    duplicate_dates: List[Tuple[int, str]]
    # Boolean flag confirming that the temporal sequence is strictly monotonically increasing
    chronological_order_valid: bool
    # List of tuples capturing the index and the specific date strings that violate chronological ordering
    order_violations: List[Tuple[int, str, str]]
    # Integer representing the absolute number of rows present in the evaluated DataFrame
    row_count: int
    # Boolean flag indicating if the empirical row count matches the theoretical expectation
    row_count_matches_expected: bool
    # Optional string denoting the declared scope of the dataset to contextualize the row count
    declared_panel_scope: Optional[str]
    # Optional integer denoting the exact number of rows expected for the declared scope
    expected_row_count: Optional[int]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and type correctness of the structural integrity record itself.

        Raises:
            TypeError: If any attribute does not match its declared type hint.
        """
        # Verify that the 'passed' attribute is strictly a boolean value to prevent logical routing errors
        if not isinstance(self.passed, bool):
            # Raise a TypeError if the validation flag is not a boolean
            raise TypeError("StructuralIntegrityResult: 'passed' must be a boolean.")

        # Verify that the 'dates_unique' attribute is strictly a boolean value
        if not isinstance(self.dates_unique, bool):
            # Raise a TypeError if the uniqueness flag is not a boolean
            raise TypeError("StructuralIntegrityResult: 'dates_unique' must be a boolean.")

        # Verify that 'duplicate_dates' is a list to ensure ordered sequence compatibility
        if not isinstance(self.duplicate_dates, list):
            # Raise a TypeError if the duplicate tracking structure is not a list
            raise TypeError("StructuralIntegrityResult: 'duplicate_dates' must be a list.")

        # Verify that the 'chronological_order_valid' attribute is strictly a boolean value
        if not isinstance(self.chronological_order_valid, bool):
            # Raise a TypeError if the ordering flag is not a boolean
            raise TypeError("StructuralIntegrityResult: 'chronological_order_valid' must be a boolean.")

        # Verify that 'order_violations' is a list to ensure ordered sequence compatibility
        if not isinstance(self.order_violations, list):
            # Raise a TypeError if the violation tracking structure is not a list
            raise TypeError("StructuralIntegrityResult: 'order_violations' must be a list.")

        # Verify that the 'row_count' attribute is strictly an integer
        if not isinstance(self.row_count, int):
            # Raise a TypeError if the row count is not an integer
            raise TypeError("StructuralIntegrityResult: 'row_count' must be an integer.")

        # Verify that the 'row_count_matches_expected' attribute is strictly a boolean value
        if not isinstance(self.row_count_matches_expected, bool):
            # Raise a TypeError if the count matching flag is not a boolean
            raise TypeError("StructuralIntegrityResult: 'row_count_matches_expected' must be a boolean.")

        # Verify that 'declared_panel_scope' is either None or a string
        if self.declared_panel_scope is not None and not isinstance(self.declared_panel_scope, str):
            # Raise a TypeError if the scope declaration is invalid
            raise TypeError("StructuralIntegrityResult: 'declared_panel_scope' must be a string or None.")

        # Verify that 'expected_row_count' is either None or an integer
        if self.expected_row_count is not None and not isinstance(self.expected_row_count, int):
            # Raise a TypeError if the expected count is invalid
            raise TypeError("StructuralIntegrityResult: 'expected_row_count' must be an integer or None.")


def validate_uniqueness_ordering_completeness(
    df_spf_panel_wide: pd.DataFrame,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None
) -> StructuralIntegrityResult:
    """
    Validates that the date column is unique, strictly chronologically ordered,
    and that the row count matches the expected panel size.

    Args:
        df_spf_panel_wide (pd.DataFrame): The schema-validated DataFrame.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope ("search_only", "holdout_only", "full_panel").

    Returns:
        StructuralIntegrityResult: A structured record of the structural validation.
    """
    passed = True

    # 1. Validate Uniqueness
    # Check if the date column contains any duplicate values
    dates_unique = df_spf_panel_wide["date"].is_unique
    duplicate_dates = []

    if not dates_unique:
        passed = False
        # Extract the exact indices and values of the duplicates
        duplicates_mask = df_spf_panel_wide["date"].duplicated(keep=False)
        dup_indices = df_spf_panel_wide.index[duplicates_mask].tolist()
        dup_values = df_spf_panel_wide.loc[duplicates_mask, "date"].tolist()
        duplicate_dates = list(zip(dup_indices, dup_values))

    # 2. Validate Strict Chronological Ordering
    chronological_order_valid = True
    order_violations = []

    # Parse all dates to tuples for rigorous mathematical comparison
    try:
        parsed_dates = [_parse_quarter(str(d)) for d in df_spf_panel_wide["date"]]

        # Iterate through adjacent pairs to ensure strict monotonic increase
        for i in range(len(parsed_dates) - 1):
            if parsed_dates[i] >= parsed_dates[i+1]:
                passed = False
                chronological_order_valid = False
                # Record the index, the offending date, and the subsequent date
                order_violations.append((
                    i,
                    str(df_spf_panel_wide["date"].iloc[i]),
                    str(df_spf_panel_wide["date"].iloc[i+1])
                ))
    except ValueError:
        # If parsing fails, ordering cannot be validated. This should be caught by Task 1,
        # but we handle it defensively here.
        passed = False
        chronological_order_valid = False

    # 3. Validate Row Count Completeness
    row_count = len(df_spf_panel_wide)
    expected_row_count = None
    row_count_matches_expected = False

    # Determine expected row count based on declared scope
    if declared_panel_scope == "search_only":
        expected_row_count = study_configuration["sample_design"]["search_sample"]["total_rows"]
    elif declared_panel_scope == "holdout_only":
        expected_row_count = study_configuration["sample_design"]["holdout_sample"]["quarters"]
    elif declared_panel_scope == "full_panel":
        expected_row_count = study_configuration["sample_design"]["full_study_panel_rows"]

    if expected_row_count is not None:
        row_count_matches_expected = (row_count == expected_row_count)
        if not row_count_matches_expected:
            passed = False
    else:
        # If scope is undeclared, check if it matches ANY valid size
        valid_sizes = [
            study_configuration["sample_design"]["search_sample"]["total_rows"],
            study_configuration["sample_design"]["holdout_sample"]["quarters"],
            study_configuration["sample_design"]["full_study_panel_rows"]
        ]
        row_count_matches_expected = (row_count in valid_sizes)
        # We do not fail the overall check if scope is undeclared and size is weird,
        # but we flag it as not matching expected standard sizes.

    return StructuralIntegrityResult(
        passed=passed,
        dates_unique=dates_unique,
        duplicate_dates=duplicate_dates,
        chronological_order_valid=chronological_order_valid,
        order_violations=order_violations,
        row_count=row_count,
        row_count_matches_expected=row_count_matches_expected,
        declared_panel_scope=declared_panel_scope,
        expected_row_count=expected_row_count
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Step 2: Validate the quarter range
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class QuarterRangeResult:
    """
    A structured, implementation-grade record containing the results of the quarter
    range and continuity validation.

    Purpose:
        To encapsulate the outcome of the temporal bounds validation (Task 2, Step 2).
        This guarantees that the dataset covers the exact econometric periods required
        by the study (e.g., 1999Q3 to 2016Q4 for the search sample) and contains absolutely
        no interior missing quarters.

    Attributes:
        passed (bool): True if the date range matches expectations and has no gaps.
        earliest_date (str): The chronologically first 'YYYYQq' string in the dataset.
        latest_date (str): The chronologically last 'YYYYQq' string in the dataset.
        expected_earliest (Optional[str]): The theoretical start date based on the configuration.
        expected_latest (Optional[str]): The theoretical end date based on the configuration.
        range_valid (bool): True if the empirical bounds perfectly match the theoretical bounds.
        missing_quarters_in_range (List[str]): A list of 'YYYYQq' strings that are mathematically expected but missing.
    """
    # Boolean flag indicating whether the overall quarter range validation was successful
    passed: bool
    # String representing the absolute minimum temporal bound found in the data
    earliest_date: str
    # String representing the absolute maximum temporal bound found in the data
    latest_date: str
    # Optional string representing the theoretical minimum temporal bound required by the study
    expected_earliest: Optional[str]
    # Optional string representing the theoretical maximum temporal bound required by the study
    expected_latest: Optional[str]
    # Boolean flag confirming that the empirical bounds exactly match the theoretical bounds
    range_valid: bool
    # List of strings detailing any specific quarters that are missing from the continuous sequence
    missing_quarters_in_range: List[str]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and type correctness of the quarter range record itself.

        Raises:
            TypeError: If any attribute does not match its declared type hint.
        """
        # Verify that the 'passed' attribute is strictly a boolean value
        if not isinstance(self.passed, bool):
            # Raise a TypeError if the validation flag is not a boolean
            raise TypeError("QuarterRangeResult: 'passed' must be a boolean.")

        # Verify that the 'earliest_date' attribute is strictly a string
        if not isinstance(self.earliest_date, str):
            # Raise a TypeError if the earliest date is not a string
            raise TypeError("QuarterRangeResult: 'earliest_date' must be a string.")

        # Verify that the 'latest_date' attribute is strictly a string
        if not isinstance(self.latest_date, str):
            # Raise a TypeError if the latest date is not a string
            raise TypeError("QuarterRangeResult: 'latest_date' must be a string.")

        # Verify that 'expected_earliest' is either None or a string
        if self.expected_earliest is not None and not isinstance(self.expected_earliest, str):
            # Raise a TypeError if the expected earliest date is invalid
            raise TypeError("QuarterRangeResult: 'expected_earliest' must be a string or None.")

        # Verify that 'expected_latest' is either None or a string
        if self.expected_latest is not None and not isinstance(self.expected_latest, str):
            # Raise a TypeError if the expected latest date is invalid
            raise TypeError("QuarterRangeResult: 'expected_latest' must be a string or None.")

        # Verify that the 'range_valid' attribute is strictly a boolean value
        if not isinstance(self.range_valid, bool):
            # Raise a TypeError if the range validity flag is not a boolean
            raise TypeError("QuarterRangeResult: 'range_valid' must be a boolean.")

        # Verify that 'missing_quarters_in_range' is a list to ensure ordered sequence compatibility
        if not isinstance(self.missing_quarters_in_range, list):
            # Raise a TypeError if the missing quarters tracking structure is not a list
            raise TypeError("QuarterRangeResult: 'missing_quarters_in_range' must be a list.")


def validate_quarter_range(
    df_spf_panel_wide: pd.DataFrame,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None
) -> QuarterRangeResult:
    """
    Validates that the date range covers the required study periods and contains no interior gaps.

    Args:
        df_spf_panel_wide (pd.DataFrame): The DataFrame, guaranteed to be sorted.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope.

    Returns:
        QuarterRangeResult: A structured record of the range validation.
    """
    passed = True

    # Extract earliest and latest dates (safe because Step 1 verified sorting)
    earliest_date = str(df_spf_panel_wide["date"].iloc[0])
    latest_date = str(df_spf_panel_wide["date"].iloc[-1])

    expected_earliest = None
    expected_latest = None
    range_valid = True

    # Determine expected bounds based on declared scope
    if declared_panel_scope == "full_panel":
        expected_earliest = study_configuration["sample_design"]["search_sample"]["start"]
        expected_latest = study_configuration["sample_design"]["holdout_sample"]["end"]
    elif declared_panel_scope == "search_only":
        expected_earliest = study_configuration["sample_design"]["search_sample"]["start"]
        expected_latest = study_configuration["sample_design"]["search_sample"]["end"]
    elif declared_panel_scope == "holdout_only":
        expected_earliest = study_configuration["sample_design"]["holdout_sample"]["start"]
        expected_latest = study_configuration["sample_design"]["holdout_sample"]["end"]

    # Validate bounds if expected bounds are defined
    if expected_earliest is not None and expected_latest is not None:
        if earliest_date != expected_earliest or latest_date != expected_latest:
            passed = False
            range_valid = False
    else:
        # Loose validation if scope is undeclared
        global_start = study_configuration["sample_design"]["search_sample"]["start"]
        global_end = study_configuration["sample_design"]["holdout_sample"]["end"]

        try:
            if _parse_quarter(earliest_date) < _parse_quarter(global_start):
                passed = False
                range_valid = False
            if _parse_quarter(latest_date) > _parse_quarter(global_end):
                passed = False
                range_valid = False
        except ValueError:
            passed = False
            range_valid = False

    # Validate quarter completeness (no interior gaps)
    missing_quarters_in_range = []
    try:
        # Generate the theoretical continuous sequence
        expected_sequence = _generate_quarter_sequence(earliest_date, latest_date)
        actual_sequence = df_spf_panel_wide["date"].astype(str).tolist()

        # Compute set difference to find missing quarters
        missing_quarters_in_range = sorted(list(set(expected_sequence) - set(actual_sequence)))

        if len(missing_quarters_in_range) > 0:
            passed = False
    except ValueError:
        passed = False

    return QuarterRangeResult(
        passed=passed,
        earliest_date=earliest_date,
        latest_date=latest_date,
        expected_earliest=expected_earliest,
        expected_latest=expected_latest,
        range_valid=range_valid,
        missing_quarters_in_range=missing_quarters_in_range
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Step 3: Validate pre-imputation missing-value status
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class MissingValueStatusResult:
    """
    A structured, implementation-grade record containing the results of the pre-imputation
    missing value analysis.

    Purpose:
        To encapsulate the outcome of the missingness audit (Task 2, Step 3). This ensures
        that while missing values are permitted pre-imputation, no single row has all
        forecasters missing, which would mathematically break the cross-sectional mean
        imputation required by the study's data processing rules.

    Attributes:
        passed (bool): True if the missing value patterns are mathematically resolvable.
        missing_counts_by_column (Dict[str, int]): A mapping of each forecaster column to its exact NaN count.
        total_missing_count (int): The absolute sum of all missing values across the forecaster matrix.
        rows_with_all_missing (List[str]): A list of 'YYYYQq' dates where every forecaster failed to report.
        pre_imputation_status (str): A categorical string describing the overall missingness state.
        provenance_note (str): A detailed memo documenting the assumptions regarding pandas NA semantics.
    """
    # Boolean flag indicating whether the missing value patterns can be safely imputed
    passed: bool
    # Dictionary mapping forecaster column names to their respective counts of missing observations
    missing_counts_by_column: Dict[str, int]
    # Integer representing the global sum of missing data points across all forecasters
    total_missing_count: int
    # List of date strings identifying rows that suffer from complete cross-sectional missingness
    rows_with_all_missing: List[str]
    # String categorizing the dataset's missingness profile (e.g., 'missing_values_present')
    pre_imputation_status: str
    # String containing a methodological note regarding the detection of sentinel values versus true NAs
    provenance_note: str

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and type correctness of the missing value status record itself.

        Raises:
            TypeError: If any attribute does not match its declared type hint.
        """
        # Verify that the 'passed' attribute is strictly a boolean value
        if not isinstance(self.passed, bool):
            # Raise a TypeError if the validation flag is not a boolean
            raise TypeError("MissingValueStatusResult: 'passed' must be a boolean.")

        # Verify that 'missing_counts_by_column' is a dictionary to ensure key-value mapping compatibility
        if not isinstance(self.missing_counts_by_column, dict):
            # Raise a TypeError if the column counts structure is not a dictionary
            raise TypeError("MissingValueStatusResult: 'missing_counts_by_column' must be a dictionary.")

        # Verify that the 'total_missing_count' attribute is strictly an integer
        if not isinstance(self.total_missing_count, int):
            # Raise a TypeError if the total missing count is not an integer
            raise TypeError("MissingValueStatusResult: 'total_missing_count' must be an integer.")

        # Verify that 'rows_with_all_missing' is a list to ensure ordered sequence compatibility
        if not isinstance(self.rows_with_all_missing, list):
            # Raise a TypeError if the fatal rows tracking structure is not a list
            raise TypeError("MissingValueStatusResult: 'rows_with_all_missing' must be a list.")

        # Verify that the 'pre_imputation_status' attribute is strictly a string
        if not isinstance(self.pre_imputation_status, str):
            # Raise a TypeError if the status categorization is not a string
            raise TypeError("MissingValueStatusResult: 'pre_imputation_status' must be a string.")

        # Verify that the 'provenance_note' attribute is strictly a string
        if not isinstance(self.provenance_note, str):
            # Raise a TypeError if the provenance documentation is not a string
            raise TypeError("MissingValueStatusResult: 'provenance_note' must be a string.")


def validate_pre_imputation_missing_status(
    df_spf_panel_wide: pd.DataFrame,
    study_configuration: Dict[str, Any]
) -> MissingValueStatusResult:
    """
    Characterizes the missing-value pattern in the forecaster columns before imputation.

    Args:
        df_spf_panel_wide (pd.DataFrame): The DataFrame to analyze.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        MissingValueStatusResult: A structured record of the missing value status.
    """
    passed = True

    # Extract the expected number of forecasters to build column names
    k_forecasters = study_configuration["data_inputs"]["spf_panel_wide"]["K_forecasters"]
    forecaster_cols = [f"forecaster_{k:02d}" for k in range(1, k_forecasters + 1)]

    # 1. Compute missing counts per column
    # Use pandas .isna() to robustly handle np.nan and pd.NA
    missing_counts_series = df_spf_panel_wide[forecaster_cols].isna().sum()
    missing_counts_by_column = missing_counts_series.to_dict()

    # 2. Compute total missing count
    total_missing_count = int(missing_counts_series.sum())

    # 3. Check for rows where ALL forecasters are missing
    # This is fatal because cross-sectional mean imputation would fail
    all_missing_mask = df_spf_panel_wide[forecaster_cols].isna().all(axis=1)
    rows_with_all_missing = df_spf_panel_wide.loc[all_missing_mask, "date"].astype(str).tolist()

    if len(rows_with_all_missing) > 0:
        passed = False
        pre_imputation_status = "all_missing_in_some_rows"
    elif total_missing_count == 0:
        pre_imputation_status = "no_missing_values"
    else:
        pre_imputation_status = "missing_values_present"

    # 4. Generate provenance note
    provenance_note = (
        "Missing-value detection relies on pandas NA semantics. "
        "Sentinel values (e.g., -999.0) are not detected computationally and must be handled upstream. "
    )
    if total_missing_count == 0:
        provenance_note += (
            "Note: No missing values detected. This may indicate that imputation was already "
            "applied upstream, or that the original data source was complete."
        )

    return MissingValueStatusResult(
        passed=passed,
        missing_counts_by_column=missing_counts_by_column,
        total_missing_count=total_missing_count,
        rows_with_all_missing=rows_with_all_missing,
        pre_imputation_status=pre_imputation_status,
        provenance_note=provenance_note
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task2ValidationReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the SPF panel structural validation phase. This report encapsulates the results
    of uniqueness and ordering checks, quarter range continuity audits, and
    pre-imputation missingness analysis, ensuring that the forecaster panel (X)
    is structurally sound and mathematically contiguous before alignment and imputation.

    Attributes:
        integrity_result (Any): An instance of StructuralIntegrityResult documenting
            uniqueness, chronological ordering, and row count compliance.
        range_result (Any): An instance of QuarterRangeResult documenting
            the earliest/latest dates and the absence of interior quarter gaps.
        missing_status_result (Any): An instance of MissingValueStatusResult
            detailing the missing value patterns and identifying fatal empty rows.
    """
    # The result of the uniqueness, ordering, and row count validation step (Step 1)
    integrity_result: Any  # Expected type: StructuralIntegrityResult
    # The result of the quarter range and continuity validation step (Step 2)
    range_result: Any  # Expected type: QuarterRangeResult
    # The result of the pre-imputation missing value analysis step (Step 3)
    missing_status_result: Any  # Expected type: MissingValueStatusResult

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity
        of the structural validation report before it is consumed by the orchestrator.

        Raises:
            ValueError: If any of the constituent validation results are missing or None.
        """
        # Verify that the integrity_result artifact is present and not None to maintain the audit trail
        if self.integrity_result is None:
            # Raise a ValueError if the uniqueness/ordering check result is missing from the report
            raise ValueError("Task2ValidationReport: integrity_result cannot be None.")

        # Verify that the range_result artifact is present and not None to maintain the audit trail
        if self.range_result is None:
            # Raise a ValueError if the quarter range check result is missing from the report
            raise ValueError("Task2ValidationReport: range_result cannot be None.")

        # Verify that the missing_status_result artifact is present and not None to maintain the audit trail
        if self.missing_status_result is None:
            # Raise a ValueError if the missingness analysis result is missing from the report
            raise ValueError("Task2ValidationReport: missing_status_result cannot be None.")


def execute_task_2_validate_structural_integrity(
    df_spf_panel_wide: pd.DataFrame,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None
) -> Task2ValidationReport:
    """
    Orchestrates Task 2: Validates uniqueness, ordering, completeness, quarter range,
    and missing-value status of the SPF panel. Halts execution if fatal errors occur.

    Args:
        df_spf_panel_wide (pd.DataFrame): The schema-validated DataFrame.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope of the panel.

    Returns:
        Task2ValidationReport: The comprehensive structural validation report.

    Raises:
        ValueError: If uniqueness, ordering, range bounds, or missingness checks fail fatally.
    """
    # Step 1: Validate Uniqueness, Ordering, and Completeness
    integrity_result = validate_uniqueness_ordering_completeness(
        df_spf_panel_wide, study_configuration, declared_panel_scope
    )

    if not integrity_result.passed:
        error_msg = "Task 2 Step 1 Failed: Structural integrity violation.\n"
        if not integrity_result.dates_unique:
            error_msg += f"Duplicate dates found: {integrity_result.duplicate_dates[:5]}...\n"
        if not integrity_result.chronological_order_valid:
            error_msg += f"Chronological order violations found: {integrity_result.order_violations[:5]}...\n"
        if not integrity_result.row_count_matches_expected and declared_panel_scope is not None:
            error_msg += f"Row count {integrity_result.row_count} does not match expected {integrity_result.expected_row_count} for scope '{declared_panel_scope}'.\n"

        # Halt immediately to prevent cascading errors in Step 2
        raise ValueError(error_msg)

    # Step 2: Validate Quarter Range
    range_result = validate_quarter_range(
        df_spf_panel_wide, study_configuration, declared_panel_scope
    )

    if not range_result.passed:
        error_msg = "Task 2 Step 2 Failed: Quarter range violation.\n"
        if not range_result.range_valid:
            error_msg += f"Bounds mismatch. Found {range_result.earliest_date} to {range_result.latest_date}, expected {range_result.expected_earliest} to {range_result.expected_latest}.\n"
        if len(range_result.missing_quarters_in_range) > 0:
            error_msg += f"Interior quarter gaps detected: {range_result.missing_quarters_in_range[:5]}...\n"

        raise ValueError(error_msg)

    # Step 3: Validate Pre-imputation Missing Status
    missing_status_result = validate_pre_imputation_missing_status(
        df_spf_panel_wide, study_configuration
    )

    if not missing_status_result.passed:
        error_msg = "Task 2 Step 3 Failed: Fatal missing value pattern.\n"
        if len(missing_status_result.rows_with_all_missing) > 0:
            error_msg += f"Rows with ALL forecasters missing (imputation impossible): {missing_status_result.rows_with_all_missing[:5]}...\n"

        raise ValueError(error_msg)

    return Task2ValidationReport(
        integrity_result=integrity_result,
        range_result=range_result,
        missing_status_result=missing_status_result
    )

# %%
# Task 3: Validate Schema and Type of df_gdp_target_series

# ==============================================================================
# Task 3: Validate Schema and Type of df_gdp_target_series
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Helper Function for Quarter Parsing (Assumed imported or redefined for standalone execution)
# -------------------------------------------------------------------------------------------------------------------------------

def _parse_quarter_string(q_str: str) -> Tuple[int, int]:
    """
    Parses a canonical YYYYQq string into a (year, quarter) integer tuple.

    Args:
        q_str (str): The quarter string, e.g., "1999Q3".

    Returns:
        Tuple[int, int]: A tuple containing (year, quarter).

    Raises:
        ValueError: If the string does not match the expected format.
    """
    # Validate the format strictly before parsing using a regular expression
    if not re.match(r"^\d{4}Q[1-4]$", str(q_str)):
        # Raise an error if the format is invalid
        raise ValueError(f"Invalid quarter format: {q_str}. Expected YYYYQq.")

    # Extract the year from the first 4 characters and convert to integer
    year = int(q_str[:4])
    # Extract the quarter from the 6th character and convert to integer
    quarter = int(q_str[5])

    # Return the parsed tuple
    return year, quarter

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Step 1: Validate object type and column existence
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class TargetSchemaValidationResult:
    """
    A structured record containing the results of the target series schema validation step.

    Attributes:
        passed (bool): True if the schema exactly matches expectations, False otherwise.
        expected_columns (List[str]): The exact list of expected column names in order.
        actual_columns (List[str]): The actual list of column names found in the DataFrame.
        missing_columns (Set[str]): Columns expected but not found.
        extra_columns (Set[str]): Columns found but not expected.
        positional_mismatches (List[Tuple[int, str, str]]): List of (index, expected, actual) for ordering errors.
    """
    # Boolean flag indicating overall success of the schema validation
    passed: bool
    # List of expected column names
    expected_columns: List[str]
    # List of actual column names found in the DataFrame
    actual_columns: List[str]
    # Set of columns that are missing from the DataFrame
    missing_columns: Set[str]
    # Set of extra columns found in the DataFrame
    extra_columns: Set[str]
    # List of positional mismatches for column ordering
    positional_mismatches: List[Tuple[int, str, str]]


def validate_gdp_target_schema(df_gdp_target_series: Any, study_configuration: Dict[str, Any]) -> TargetSchemaValidationResult:
    """
    Validates that the input object is a pandas DataFrame and contains exactly two columns:
    the date column and the target value column, in the exact expected order.

    Args:
        df_gdp_target_series (Any): The input object to validate.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        TargetSchemaValidationResult: A structured record of the validation outcome.

    Raises:
        TypeError: If the input object is not a pandas DataFrame.
        ValueError: If the configuration dictionary is missing required keys.
    """
    # Confirm that the input is a pandas DataFrame to ensure compatibility
    if not isinstance(df_gdp_target_series, pd.DataFrame):
        # Halt execution if the type is incorrect
        raise TypeError(f"Input df_gdp_target_series must be a pandas DataFrame. Received: {type(df_gdp_target_series)}")

    # Extract the expected column names from the configuration dictionary
    try:
        # Retrieve the expected date column name
        date_col = study_configuration["data_inputs"]["gdp_target_series"]["date_column"]
        # Retrieve the expected target value column name
        target_col = study_configuration["data_inputs"]["gdp_target_series"]["value_column"]
    except KeyError as e:
        # Halt execution if the configuration is malformed
        raise ValueError(f"Missing required configuration key for target series schema: {e}")

    # Construct the expected column list programmatically
    expected_columns = [date_col, target_col]

    # Extract actual columns from the DataFrame as a list
    actual_columns = list(df_gdp_target_series.columns)

    # Compute set differences to identify missing or extra columns
    expected_set = set(expected_columns)
    # Convert actual columns to a set for comparison
    actual_set = set(actual_columns)
    # Identify columns that are expected but missing
    missing_columns = expected_set - actual_set
    # Identify columns that are present but not expected
    extra_columns = actual_set - expected_set

    # Identify positional mismatches by zipping the expected and actual lists
    positional_mismatches = []
    # Iterate over the zipped lists with an index
    for i, (exp_col, act_col) in enumerate(zip(expected_columns, actual_columns)):
        # Check if the expected column matches the actual column at the current position
        if exp_col != act_col:
            # Record the mismatch
            positional_mismatches.append((i, exp_col, act_col))

    # The schema passes if and only if the lists are exactly identical in content and order
    passed = (expected_columns == actual_columns)

    # Return the structured validation result
    return TargetSchemaValidationResult(
        passed=passed,
        expected_columns=expected_columns,
        actual_columns=actual_columns,
        missing_columns=missing_columns,
        extra_columns=extra_columns,
        positional_mismatches=positional_mismatches
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Step 2: Validate data types and completeness
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class TargetDtypeValidationResult:
    """
    A structured record containing the results of the target series data type and completeness validation.

    Attributes:
        passed (bool): True if all dtypes, formats, and completeness checks are acceptable.
        date_format_valid (bool): True if all date strings match the YYYYQq format.
        date_format_violations (List[Tuple[int, Any]]): List of (row_index, invalid_value).
        target_dtype (str): The string representation of the target column's dtype.
        target_dtype_valid (bool): True if the target column is numeric.
        target_missing_count (int): The number of missing values in the target column.
        target_missing_quarters (List[str]): List of quarters where the target is missing.
        unit_scale_note (str): Warning regarding the scale of the target variable (percentage vs decimal).
    """
    # Boolean flag indicating overall success of the dtype and completeness validation
    passed: bool
    # Boolean flag indicating if all dates match the required format
    date_format_valid: bool
    # List of specific date format violations
    date_format_violations: List[Tuple[int, Any]]
    # String representation of the target column's data type
    target_dtype: str
    # Boolean flag indicating if the target data type is valid
    target_dtype_valid: bool
    # Integer count of missing values in the target column
    target_missing_count: int
    # List of specific quarters with missing target values
    target_missing_quarters: List[str]
    # String note regarding the unit scale of the target variable
    unit_scale_note: str


def validate_gdp_target_dtypes_and_completeness(
    df_gdp_target_series: pd.DataFrame,
    study_configuration: Dict[str, Any]
) -> TargetDtypeValidationResult:
    """
    Validates the data types of the date and target columns, checks the date strings
    against the required format, and ensures there are no missing target values.

    Args:
        df_gdp_target_series (pd.DataFrame): The schema-validated DataFrame.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        TargetDtypeValidationResult: A structured record of the dtype validation outcome.
    """
    # Initialize the overall pass flag to True
    passed = True

    # Retrieve column names from configuration
    date_col = study_configuration["data_inputs"]["gdp_target_series"]["date_column"]
    # Retrieve target column name
    target_col = study_configuration["data_inputs"]["gdp_target_series"]["value_column"]

    # 1. Validate the date format using regex: YYYYQq
    date_regex = re.compile(r"^\d{4}Q[1-4]$")
    # Initialize list for format violations
    date_format_violations = []

    # Safely cast the date column to string for regex matching
    date_strings = df_gdp_target_series[date_col].astype(str)
    # Create a boolean mask for invalid dates
    invalid_mask = ~date_strings.str.match(date_regex)

    # Check if any dates are invalid
    if invalid_mask.any():
        # Mark validation as failed
        passed = False
        # Extract the indices of the invalid dates
        invalid_indices = df_gdp_target_series.index[invalid_mask].tolist()
        # Extract the actual invalid values
        invalid_values = df_gdp_target_series.loc[invalid_mask, date_col].tolist()
        # Combine indices and values into a list of tuples
        date_format_violations = list(zip(invalid_indices, invalid_values))

    # 2. Validate target column dtype
    target_dtype_obj = df_gdp_target_series[target_col].dtype
    # Convert dtype to string for reporting
    target_dtype_str = str(target_dtype_obj)
    # Check if the dtype is numeric
    target_dtype_valid = pd.api.types.is_numeric_dtype(target_dtype_obj)

    # If the dtype is not numeric, validation fails
    if not target_dtype_valid:
        passed = False

    # 3. Validate completeness (no missing values)
    # Count the number of missing values in the target column
    target_missing_count = int(df_gdp_target_series[target_col].isna().sum())
    # Initialize list for missing quarters
    target_missing_quarters = []

    # If missing values exist, validation fails
    if target_missing_count > 0:
        passed = False
        # Create a boolean mask for missing target values
        missing_mask = df_gdp_target_series[target_col].isna()
        # Extract the quarters corresponding to the missing values
        target_missing_quarters = df_gdp_target_series.loc[missing_mask, date_col].astype(str).tolist()

    # 4. Check unit scale (percentage vs decimal)
    unit_scale_note = "Target values appear to be in an acceptable range."
    # Only check scale if the dtype is valid and there are some non-missing values
    if target_dtype_valid and target_missing_count < len(df_gdp_target_series):
        # Compute the maximum absolute value of the target series
        max_abs_val = df_gdp_target_series[target_col].abs().max()
        # If the maximum absolute value is suspiciously small, it might be in decimal format
        if max_abs_val < 0.2:
            unit_scale_note = "WARNING: Maximum absolute GDP growth is < 0.2. Ensure values are in percentage points (e.g., 2.0 for 2%), not decimals (0.02), to match expected RMSE magnitudes."
        # If the maximum absolute value is suspiciously large, it might be unscaled
        elif max_abs_val > 20.0:
            unit_scale_note = "WARNING: Maximum absolute GDP growth is > 20.0. Ensure values are correctly scaled."

    # Return the structured validation result
    return TargetDtypeValidationResult(
        passed=passed,
        date_format_valid=(len(date_format_violations) == 0),
        date_format_violations=date_format_violations,
        target_dtype=target_dtype_str,
        target_dtype_valid=target_dtype_valid,
        target_missing_count=target_missing_count,
        target_missing_quarters=target_missing_quarters,
        unit_scale_note=unit_scale_note
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Step 3: Validate uniqueness, ordering, and vintage provenance
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class TargetStructuralIntegrityResult:
    """
    A structured record containing the results of the target series structural and provenance validation.

    Attributes:
        passed (bool): True if uniqueness, ordering, and row counts are valid.
        dates_unique (bool): True if the date column contains no duplicates.
        chronological_order_valid (bool): True if dates are strictly monotonically increasing.
        row_count (int): The total number of rows in the DataFrame.
        row_count_matches_expected (bool): True if the row count matches the declared scope.
        vintage_source (str): The documented source of the GDP vintage.
        provenance_record (str): Detailed memo documenting the vintage and series concept.
    """
    # Boolean flag indicating overall success of the structural validation
    passed: bool
    # Boolean flag indicating if dates are unique
    dates_unique: bool
    # Boolean flag indicating if dates are in strict chronological order
    chronological_order_valid: bool
    # Integer count of total rows
    row_count: int
    # Boolean flag indicating if row count matches expectations
    row_count_matches_expected: bool
    # String documenting the vintage source
    vintage_source: str
    # String containing the full provenance record
    provenance_record: str


def validate_gdp_target_structural_integrity(
    df_gdp_target_series: pd.DataFrame,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None,
    vintage_source: Optional[str] = None
) -> TargetStructuralIntegrityResult:
    """
    Validates that the target series dates are unique and strictly ordered, checks the row count,
    and documents the vintage provenance.

    Args:
        df_gdp_target_series (pd.DataFrame): The DataFrame with validated dtypes.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope ("search_only", "holdout_only", "full_panel").
        vintage_source (Optional[str]): The documented source of the GDP vintage.

    Returns:
        TargetStructuralIntegrityResult: A structured record of the structural validation.
    """
    # Initialize the overall pass flag to True
    passed = True

    # Retrieve the date column name from configuration
    date_col = study_configuration["data_inputs"]["gdp_target_series"]["date_column"]

    # 1. Validate Uniqueness
    # Check if the date column contains any duplicate values
    dates_unique = df_gdp_target_series[date_col].is_unique
    # If duplicates exist, validation fails
    if not dates_unique:
        passed = False

    # 2. Validate Strict Chronological Ordering
    chronological_order_valid = True

    try:
        # Parse all dates to tuples for rigorous mathematical comparison
        parsed_dates = [_parse_quarter_string(str(d)) for d in df_gdp_target_series[date_col]]

        # Iterate through adjacent pairs to ensure strict monotonic increase
        for i in range(len(parsed_dates) - 1):
            # If the current date is greater than or equal to the next date, ordering is violated
            if parsed_dates[i] >= parsed_dates[i+1]:
                passed = False
                chronological_order_valid = False
                break
    except ValueError:
        # If parsing fails, ordering cannot be validated
        passed = False
        chronological_order_valid = False

    # 3. Validate Row Count Consistency
    # Count the total number of rows
    row_count = len(df_gdp_target_series)
    row_count_matches_expected = False

    # Determine expected row count based on declared scope
    if declared_panel_scope == "search_only":
        expected_row_count = study_configuration["sample_design"]["search_sample"]["total_rows"]
        row_count_matches_expected = (row_count == expected_row_count)
    elif declared_panel_scope == "holdout_only":
        expected_row_count = study_configuration["sample_design"]["holdout_sample"]["quarters"]
        row_count_matches_expected = (row_count == expected_row_count)
    elif declared_panel_scope == "full_panel":
        expected_row_count = study_configuration["sample_design"]["full_study_panel_rows"]
        row_count_matches_expected = (row_count == expected_row_count)
    else:
        # If scope is undeclared, we cannot strictly validate the row count
        row_count_matches_expected = True

    # If the row count does not match the expected count for the declared scope, validation fails
    if not row_count_matches_expected and declared_panel_scope is not None:
        passed = False

    # 4. Document Vintage Provenance
    # Retrieve the expected series concept from configuration
    series_concept = study_configuration["data_inputs"]["gdp_target_series"]["series_concept"]

    # Handle undeclared vintage source
    if vintage_source is None:
        actual_vintage_source = "undeclared"
        provenance_record = (
            f"Vintage source undeclared; the configuration requires explicit documentation "
            f"per `vintage_control` field. Expected series concept: {series_concept}."
        )
    else:
        actual_vintage_source = vintage_source
        provenance_record = (
            f"Vintage source documented as: '{actual_vintage_source}'. "
            f"Expected series concept: {series_concept}."
        )

    # Return the structured validation result
    return TargetStructuralIntegrityResult(
        passed=passed,
        dates_unique=dates_unique,
        chronological_order_valid=chronological_order_valid,
        row_count=row_count,
        row_count_matches_expected=row_count_matches_expected,
        vintage_source=actual_vintage_source,
        provenance_record=provenance_record
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task3ValidationReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the GDP target series validation phase. This report encapsulates the results
    of schema verification, data type and completeness audits, and structural
    integrity checks, ensuring that the realized GDP growth series (y_t) is
    mathematically and temporally aligned with the forecaster panel before
    downstream RMSE scoring.

    Attributes:
        schema_result (Any): An instance of TargetSchemaValidationResult documenting
            the presence and order of the 'date' and 'real_gdp_growth_yoy' columns.
        dtype_result (Any): An instance of TargetDtypeValidationResult documenting
            the format of date strings, the numeric type of targets, and zero-missingness.
        structural_result (Any): An instance of TargetStructuralIntegrityResult
            confirming uniqueness, chronological ordering, and vintage provenance.
    """
    # The result of the schema validation step (Step 1) confirming column existence
    schema_result: Any  # Expected type: TargetSchemaValidationResult
    # The result of the data type and completeness validation step (Step 2)
    dtype_result: Any  # Expected type: TargetDtypeValidationResult
    # The result of the structural integrity and provenance validation step (Step 3)
    structural_result: Any  # Expected type: TargetStructuralIntegrityResult

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity
        of the target series validation report before it is consumed by the orchestrator.

        Raises:
            ValueError: If any of the constituent validation results are missing or None.
        """
        # Verify that the schema_result artifact is present and not None to maintain the audit trail
        if self.schema_result is None:
            # Raise a ValueError if the column check result is missing from the report
            raise ValueError("Task3ValidationReport: schema_result cannot be None.")

        # Verify that the dtype_result artifact is present and not None to maintain the audit trail
        if self.dtype_result is None:
            # Raise a ValueError if the type and completeness check result is missing from the report
            raise ValueError("Task3ValidationReport: dtype_result cannot be None.")

        # Verify that the structural_result artifact is present and not None to maintain the audit trail
        if self.structural_result is None:
            # Raise a ValueError if the ordering and uniqueness check result is missing from the report
            raise ValueError("Task3ValidationReport: structural_result cannot be None.")


def execute_task_3_validate_gdp_target_series(
    df_gdp_target_series: Any,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None,
    vintage_source: Optional[str] = None
) -> Task3ValidationReport:
    """
    Orchestrates Task 3: Validates the schema, data types, completeness, structural integrity,
    and provenance of the GDP target series. Halts execution if fatal errors occur.

    Args:
        df_gdp_target_series (Any): The raw input object to validate.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope of the panel.
        vintage_source (Optional[str]): The documented source of the GDP vintage.

    Returns:
        Task3ValidationReport: The comprehensive validation report.

    Raises:
        TypeError: If the input is not a DataFrame.
        ValueError: If schema, dtype, completeness, or structural validation fails fatally.
    """
    # Step 1: Validate Schema
    # Execute the schema validation function
    schema_result = validate_gdp_target_schema(df_gdp_target_series, study_configuration)

    # Halt immediately if schema validation fails
    if not schema_result.passed:
        error_msg = (
            f"Task 3 Step 1 Failed: Target series schema validation error.\n"
            f"Expected columns: {schema_result.expected_columns}\n"
            f"Actual columns: {schema_result.actual_columns}\n"
            f"Missing columns: {schema_result.missing_columns}\n"
            f"Extra columns: {schema_result.extra_columns}"
        )
        raise ValueError(error_msg)

    # Step 2: Validate Dtypes and Completeness
    # Execute the dtype and completeness validation function
    dtype_result = validate_gdp_target_dtypes_and_completeness(df_gdp_target_series, study_configuration)

    # Halt immediately if dtype or completeness validation fails
    if not dtype_result.passed:
        error_msg = "Task 3 Step 2 Failed: Target series data type or completeness error.\n"
        if not dtype_result.date_format_valid:
            error_msg += f"Date format violations found: {dtype_result.date_format_violations[:5]}...\n"
        if not dtype_result.target_dtype_valid:
            error_msg += f"Invalid target dtype: {dtype_result.target_dtype}. Expected numeric.\n"
        if dtype_result.target_missing_count > 0:
            error_msg += f"Missing target values found in quarters: {dtype_result.target_missing_quarters[:5]}...\n"
        raise ValueError(error_msg)

    # Step 3: Validate Structural Integrity and Provenance
    # Execute the structural integrity validation function
    structural_result = validate_gdp_target_structural_integrity(
        df_gdp_target_series, study_configuration, declared_panel_scope, vintage_source
    )

    # Halt immediately if structural validation fails
    if not structural_result.passed:
        error_msg = "Task 3 Step 3 Failed: Target series structural integrity error.\n"
        if not structural_result.dates_unique:
            error_msg += "Duplicate dates found in target series.\n"
        if not structural_result.chronological_order_valid:
            error_msg += "Target series dates are not in strict chronological order.\n"
        if not structural_result.row_count_matches_expected:
            error_msg += f"Row count {structural_result.row_count} does not match expected for scope '{declared_panel_scope}'.\n"
        raise ValueError(error_msg)

    # Return the composite validation report
    return Task3ValidationReport(
        schema_result=schema_result,
        dtype_result=dtype_result,
        structural_result=structural_result
    )

# %%
# Task 4: Validate Integrity and Internal Consistency of study_configuration

# ==============================================================================
# Task 4: Validate Integrity and Internal Consistency of study_configuration
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 4, Step 1: Validate existence of all required top-level sections
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ConfigSectionValidationResult:
    """
    A structured record containing the results of the top-level configuration section validation.

    Attributes:
        passed (bool): True if all required top-level keys are present, False otherwise.
        all_top_level_keys_present (bool): Alias for passed, indicating presence of all keys.
        missing_keys (List[str]): List of required keys that are missing from the configuration.
        extra_keys (List[str]): List of keys present in the configuration that are not required.
    """
    # Boolean flag indicating overall success of the section validation
    passed: bool
    # Boolean flag explicitly indicating if all required keys are present
    all_top_level_keys_present: bool
    # List of keys that were expected but not found
    missing_keys: List[str]
    # List of keys that were found but not expected
    extra_keys: List[str]


def validate_config_top_level_sections(study_configuration: Dict[str, Any]) -> ConfigSectionValidationResult:
    """
    Validates that the study configuration dictionary contains exactly the 12 required top-level keys.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary to validate.

    Returns:
        ConfigSectionValidationResult: A structured record of the validation outcome.
    """
    # Define the exact set of 12 required top-level keys as specified in the manuscript
    required_keys = {
        "artifact_paths",
        "search_protocol",
        "data_inputs",
        "sample_design",
        "prepare_script_data",
        "train_script_initial_data",
        "program_md_data",
        "results_log_data",
        "econometric_setup",
        "researcher_only_holdout_inputs",
        "post_search_replication_registry",
        "method_notes"
    }

    # Extract the actual top-level keys from the provided configuration dictionary
    actual_keys = set(study_configuration.keys())

    # Compute the set difference to find required keys that are missing
    missing_keys_set = required_keys - actual_keys
    # Compute the set difference to find actual keys that are not in the required set
    extra_keys_set = actual_keys - required_keys

    # Convert sets to sorted lists for deterministic output and reporting
    missing_keys = sorted(list(missing_keys_set))
    extra_keys = sorted(list(extra_keys_set))

    # The validation passes if and only if there are no missing keys
    all_top_level_keys_present = (len(missing_keys) == 0)
    passed = all_top_level_keys_present

    # Return the structured validation result
    return ConfigSectionValidationResult(
        passed=passed,
        all_top_level_keys_present=all_top_level_keys_present,
        missing_keys=missing_keys,
        extra_keys=extra_keys
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Helper Function for Nested Dictionary Access
# -------------------------------------------------------------------------------------------------------------------------------

def _get_nested_value(config: Dict[str, Any], path: str) -> Any:
    """
    Safely retrieves a value from a nested dictionary using a dotted path string.

    Args:
        config (Dict[str, Any]): The dictionary to traverse.
        path (str): The dotted path string (e.g., "data_inputs.spf_panel_wide.K_forecasters").

    Returns:
        Any: The value at the specified path.

    Raises:
        KeyError: If any key in the path is not found.
        TypeError: If traversal attempts to access a key on a non-dictionary object.
    """
    # Split the dotted path into individual keys
    keys = path.split(".")
    # Initialize the current object to the root configuration dictionary
    current = config

    # Iterate through each key in the path
    for key in keys:
        # Ensure the current object is a dictionary before attempting key access
        if not isinstance(current, dict):
            raise TypeError(f"Expected a dictionary at key '{key}' in path '{path}', but got {type(current)}.")
        # Ensure the key exists in the current dictionary
        if key not in current:
            raise KeyError(f"Key '{key}' not found in path '{path}'.")
        # Traverse one level deeper
        current = current[key]

    # Return the final retrieved value
    return current

# -------------------------------------------------------------------------------------------------------------------------------
# Task 4, Step 2: Validate cross-section numerical consistency
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ConfigConsistencyValidationResult:
    """
    A structured record containing the results of the cross-section numerical consistency validation.

    Attributes:
        passed (bool): True if all numerical consistency checks pass, False otherwise.
        all_consistent (bool): Alias for passed.
        inconsistencies (List[Tuple[str, Any, str, Any, str]]): List of tuples detailing inconsistencies.
            Format: (path_a, value_a, path_b, value_b, expected_relationship)
    """
    # Boolean flag indicating overall success of the consistency validation
    passed: bool
    # Boolean flag explicitly indicating if all checks are consistent
    all_consistent: bool
    # List of detailed inconsistency records
    inconsistencies: List[Tuple[str, Any, str, Any, str]]


def validate_config_numerical_consistency(study_configuration: Dict[str, Any]) -> ConfigConsistencyValidationResult:
    """
    Validates that numerical constants and derived values are consistent across different
    sections of the study configuration dictionary.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary to validate.

    Returns:
        ConfigConsistencyValidationResult: A structured record of the consistency validation outcome.
    """
    # Initialize the list to store any found inconsistencies
    inconsistencies = []

    # Helper function to record an inconsistency
    def record_inconsistency(path_a: str, val_a: Any, path_b: str, val_b: Any, relationship: str):
        inconsistencies.append((path_a, val_a, path_b, val_b, relationship))

    try:
        # (a) Validate K = 23 (number of forecasters) across three locations
        path_k1 = "data_inputs.spf_panel_wide.K_forecasters"
        path_k2 = "prepare_script_data.K_forecasters"
        path_k3 = "econometric_setup.K_forecasters"

        val_k1 = _get_nested_value(study_configuration, path_k1)
        val_k2 = _get_nested_value(study_configuration, path_k2)
        val_k3 = _get_nested_value(study_configuration, path_k3)

        # Check equality between the first and second K values
        if val_k1 != val_k2:
            record_inconsistency(path_k1, val_k1, path_k2, val_k2, "equality")
        # Check equality between the first and third K values
        if val_k1 != val_k3:
            record_inconsistency(path_k1, val_k1, path_k3, val_k3, "equality")

        # (b) Validate W = 20 (rolling window size) across two locations
        path_w1 = "prepare_script_data.rolling_window_W"
        path_w2 = "econometric_setup.rolling_window_W"

        val_w1 = _get_nested_value(study_configuration, path_w1)
        val_w2 = _get_nested_value(study_configuration, path_w2)

        # Check equality between the two W values
        if val_w1 != val_w2:
            record_inconsistency(path_w1, val_w1, path_w2, val_w2, "equality")

        # (c) Validate Search sample temporal bounds
        path_ss_start = "sample_design.search_sample.start"
        path_ss_end = "sample_design.search_sample.end"

        val_ss_start = _get_nested_value(study_configuration, path_ss_start)
        val_ss_end = _get_nested_value(study_configuration, path_ss_end)

        # Ensure the search sample start is exactly "1999Q3"
        if val_ss_start != "1999Q3":
            record_inconsistency(path_ss_start, val_ss_start, "literal", "1999Q3", "equality")
        # Ensure the search sample end is exactly "2016Q4"
        if val_ss_end != "2016Q4":
            record_inconsistency(path_ss_end, val_ss_end, "literal", "2016Q4", "equality")

        # (d) Validate Holdout temporal bounds
        path_hs_start = "sample_design.holdout_sample.start"
        path_hs_end = "sample_design.holdout_sample.end"
        path_hs_period = "researcher_only_holdout_inputs.holdout_period"

        val_hs_start = _get_nested_value(study_configuration, path_hs_start)
        val_hs_end = _get_nested_value(study_configuration, path_hs_end)
        val_hs_period = _get_nested_value(study_configuration, path_hs_period)

        # Ensure the holdout start is exactly "2017Q1"
        if val_hs_start != "2017Q1":
            record_inconsistency(path_hs_start, val_hs_start, "literal", "2017Q1", "equality")
        # Ensure the holdout end is exactly "2025Q4"
        if val_hs_end != "2025Q4":
            record_inconsistency(path_hs_end, val_hs_end, "literal", "2025Q4", "equality")
        # Ensure the holdout period list matches the start and end bounds
        if val_hs_period[0] != val_hs_start or val_hs_period[1] != val_hs_end:
            record_inconsistency(path_hs_period, val_hs_period, "derived_bounds", [val_hs_start, val_hs_end], "equality")

        # (e) Validate Derived consistency checks
        path_full_rows = "sample_design.full_study_panel_rows"
        path_ss_rows = "sample_design.search_sample.total_rows"
        path_hs_quarters = "sample_design.holdout_sample.quarters"

        val_full_rows = _get_nested_value(study_configuration, path_full_rows)
        val_ss_rows = _get_nested_value(study_configuration, path_ss_rows)
        val_hs_quarters = _get_nested_value(study_configuration, path_hs_quarters)

        # Ensure full panel rows equals search rows plus holdout quarters
        if val_full_rows != (val_ss_rows + val_hs_quarters):
            record_inconsistency(path_full_rows, val_full_rows, "sum(search, holdout)", val_ss_rows + val_hs_quarters, "equality")

        path_hs_ex_covid_q = "sample_design.holdout_excluding_covid.quarters"
        path_covid_q = "researcher_only_holdout_inputs.covid_quarters"

        val_hs_ex_covid_q = _get_nested_value(study_configuration, path_hs_ex_covid_q)
        val_covid_q = _get_nested_value(study_configuration, path_covid_q)

        # Ensure holdout excluding COVID equals total holdout minus number of COVID quarters
        if val_hs_ex_covid_q != (val_hs_quarters - len(val_covid_q)):
            record_inconsistency(path_hs_ex_covid_q, val_hs_ex_covid_q, "holdout - len(covid)", val_hs_quarters - len(val_covid_q), "equality")

        path_scored_total = "prepare_script_data.scored_periods_total"
        path_calls_total = "prepare_script_data.evaluator_calls_total"
        path_call_range = "prepare_script_data.call_index_range_t"
        path_score_range = "prepare_script_data.score_index_range_t"

        val_scored_total = _get_nested_value(study_configuration, path_scored_total)
        val_calls_total = _get_nested_value(study_configuration, path_calls_total)
        val_call_range = _get_nested_value(study_configuration, path_call_range)
        val_score_range = _get_nested_value(study_configuration, path_score_range)

        # Ensure scored periods total is exactly 65
        if val_scored_total != 65:
            record_inconsistency(path_scored_total, val_scored_total, "literal", 65, "equality")
        # Ensure evaluator calls total is exactly 66
        if val_calls_total != 66:
            record_inconsistency(path_calls_total, val_calls_total, "literal", 66, "equality")

        # Calculate the span of the call range (inclusive)
        derived_call_span = val_call_range["end"] - val_call_range["start"] + 1
        # Ensure the derived call span matches the total calls
        if derived_call_span != val_calls_total:
            record_inconsistency(path_call_range, derived_call_span, path_calls_total, val_calls_total, "equality")

        # Calculate the span of the score range (inclusive)
        derived_score_span = val_score_range["end"] - val_score_range["start"] + 1
        # Ensure the derived score span matches the total scored periods
        if derived_score_span != val_scored_total:
            record_inconsistency(path_score_range, derived_score_span, path_scored_total, val_scored_total, "equality")

    except (KeyError, TypeError) as e:
        # If a key is missing or type is wrong during traversal, record it as a fatal inconsistency
        record_inconsistency("traversal_error", str(e), "expected_structure", "valid", "successful_access")

    # The validation passes if and only if no inconsistencies were recorded
    all_consistent = (len(inconsistencies) == 0)
    passed = all_consistent

    # Return the structured validation result
    return ConfigConsistencyValidationResult(
        passed=passed,
        all_consistent=all_consistent,
        inconsistencies=inconsistencies
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 4, Step 3: Identify and quarantine unspecified fields
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ConfigQuarantineResult:
    """
    A structured record containing the results of the unspecified fields quarantine process.

    Attributes:
        quarantine_list (List[Tuple[str, Any, str]]): List of quarantined fields.
            Format: (dotted_key_path, current_value, quarantine_reason)
    """
    # List of tuples detailing each quarantined field and the reason
    quarantine_list: List[Tuple[str, Any, str]]


def identify_quarantined_fields(study_configuration: Dict[str, Any]) -> ConfigQuarantineResult:
    """
    Recursively traverses the configuration dictionary to identify and quarantine fields
    that are None or annotated as "unspecified in manuscript".

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary to traverse.

    Returns:
        ConfigQuarantineResult: A structured record containing the quarantine list.
    """
    # Initialize the list to store quarantined fields
    quarantine_list: List[Tuple[str, Any, str]] = []

    # Define a recursive helper function for Depth-First Search (DFS) traversal
    def _traverse_and_quarantine(obj: Any, current_path: str):
        # If the current object is a dictionary, iterate over its key-value pairs
        if isinstance(obj, dict):
            for key, value in obj.items():
                # Construct the new path by appending the key
                new_path = f"{current_path}.{key}" if current_path else key
                # Recursively traverse the value
                _traverse_and_quarantine(value, new_path)
        # If the current object is a list, iterate over its elements with indices
        elif isinstance(obj, list):
            for index, item in enumerate(obj):
                # Construct the new path by appending the index in bracket notation
                new_path = f"{current_path}[{index}]"
                # Recursively traverse the item
                _traverse_and_quarantine(item, new_path)
        # If the current object is a leaf node (scalar, string, None, etc.)
        else:
            # Check if the value is exactly None
            if obj is None:
                # Append to quarantine list with reason "None_value"
                quarantine_list.append((current_path, obj, "None_value"))
            # Check if the value is a string and contains the target substring (case-insensitive)
            elif isinstance(obj, str) and "unspecified in manuscript" in obj.lower():
                # Append to quarantine list with reason "annotated_as_unspecified"
                quarantine_list.append((current_path, obj, "annotated_as_unspecified"))

    # Initiate the recursive traversal from the root of the configuration dictionary
    _traverse_and_quarantine(study_configuration, "")

    # Return the structured quarantine result
    return ConfigQuarantineResult(quarantine_list=quarantine_list)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 4, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task4ValidationReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the study configuration validation phase. This report encapsulates the results
    of top-level section presence checks, cross-section numerical consistency audits,
    and the identification of quarantined (unspecified) fields, ensuring that the
    single source of truth for the research loop is mathematically and structurally sound
    before any data processing or agentic discovery begins.

    Attributes:
        section_result (Any): An instance of ConfigSectionValidationResult documenting
            the presence of the 12 required top-level configuration keys.
        consistency_result (Any): An instance of ConfigConsistencyValidationResult
            documenting the equality and arithmetic alignment of constants (K, W, dates).
        quarantine_result (Any): An instance of ConfigQuarantineResult containing
            the list of fields set to None or annotated as unspecified in the manuscript.
    """
    # The result of the top-level section validation step (Step 1)
    section_result: Any  # Expected type: ConfigSectionValidationResult
    # The result of the numerical consistency validation step (Step 2)
    consistency_result: Any  # Expected type: ConfigConsistencyValidationResult
    # The result of the unspecified fields quarantine step (Step 3)
    quarantine_result: Any  # Expected type: ConfigQuarantineResult

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity
        of the configuration validation report before it is consumed by the orchestrator.

        Raises:
            ValueError: If any of the constituent validation results are missing or None.
        """
        # Verify that the section_result artifact is present and not None to maintain the audit trail
        if self.section_result is None:
            # Raise a ValueError if the top-level key check result is missing from the report
            raise ValueError("Task4ValidationReport: section_result cannot be None.")

        # Verify that the consistency_result artifact is present and not None to maintain the audit trail
        if self.consistency_result is None:
            # Raise a ValueError if the numerical alignment check result is missing from the report
            raise ValueError("Task4ValidationReport: consistency_result cannot be None.")

        # Verify that the quarantine_result artifact is present and not None to maintain the audit trail
        if self.quarantine_result is None:
            # Raise a ValueError if the unspecified fields list is missing from the report
            raise ValueError("Task4ValidationReport: quarantine_result cannot be None.")


def execute_task_4_validate_configuration_integrity(study_configuration: Dict[str, Any]) -> Task4ValidationReport:
    """
    Orchestrates Task 4: Validates the existence of required sections, cross-section
    numerical consistency, and identifies quarantined fields in the study configuration.
    Halts execution if fatal structural or consistency errors occur.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary to validate.

    Returns:
        Task4ValidationReport: The comprehensive configuration validation report.

    Raises:
        ValueError: If top-level sections are missing or numerical inconsistencies are found.
    """
    # Step 1: Validate existence of all required top-level sections
    # Execute the section validation function
    section_result = validate_config_top_level_sections(study_configuration)

    # Halt immediately if required sections are missing
    if not section_result.passed:
        error_msg = (
            f"Task 4 Step 1 Failed: Configuration section validation error.\n"
            f"Missing required top-level keys: {section_result.missing_keys}\n"
            f"Extra keys found (warning): {section_result.extra_keys}"
        )
        raise ValueError(error_msg)

    # Step 2: Validate cross-section numerical consistency
    # Execute the numerical consistency validation function
    consistency_result = validate_config_numerical_consistency(study_configuration)

    # Halt immediately if numerical inconsistencies are found
    if not consistency_result.passed:
        error_msg = "Task 4 Step 2 Failed: Configuration numerical consistency error.\n"
        # Append each specific inconsistency to the error message
        for inc in consistency_result.inconsistencies:
            path_a, val_a, path_b, val_b, rel = inc
            error_msg += f"  - Inconsistency: {path_a} ({val_a}) vs {path_b} ({val_b}) [Expected: {rel}]\n"
        raise ValueError(error_msg)

    # Step 3: Identify and quarantine unspecified fields
    # Execute the quarantine identification function
    quarantine_result = identify_quarantined_fields(study_configuration)

    # Note: Step 3 does not produce fatal errors, so we do not halt based on its result.
    # The quarantined fields are simply recorded for downstream awareness.

    # Return the composite validation report
    return Task4ValidationReport(
        section_result=section_result,
        consistency_result=consistency_result,
        quarantine_result=quarantine_result
    )

# %%
# Task 5: Cleanse and Standardize Date Fields in Both Datasets

# ==============================================================================
# Task 5: Cleanse and Standardize Date Fields in Both Datasets
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Step 1: Normalize all quarter identifiers to canonical form
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class DateNormalizationLog:
    """
    A structured record documenting the date normalization process for auditability.

    Attributes:
        dataset_name (str): Identifier for the dataset (e.g., 'spf_panel' or 'gdp_target').
        total_processed (int): Total number of date values processed.
        transformed_entries (List[Tuple[int, Any, str]]): List of (row_index, original_value, new_value).
        failed_entries (List[Tuple[int, Any, str]]): List of (row_index, original_value, error_reason).
    """
    # Name of the dataset being processed to distinguish logs
    dataset_name: str
    # Total number of rows processed in the dataset
    total_processed: int
    # Log of successfully transformed dates: (index, old_value, new_value)
    transformed_entries: List[Tuple[int, Any, str]] = field(default_factory=list)
    # Log of dates that could not be parsed: (index, old_value, reason)
    failed_entries: List[Tuple[int, Any, str]] = field(default_factory=list)


def _normalize_single_date(val: Any) -> str:
    """
    Converts a single date representation into the canonical 'YYYYQq' string format.

    Args:
        val (Any): The raw date value (string, pandas.Period, datetime, etc.).

    Returns:
        str: The canonical 'YYYYQq' string.

    Raises:
        ValueError: If the value is an ambiguous numeric type or cannot be parsed.
    """
    # Reject ambiguous numeric formats explicitly to prevent silent data corruption
    if isinstance(val, (int, float, np.number)):
        # Raise an error immediately for numeric types
        raise ValueError(f"Ambiguous numeric date format forbidden: {val}")

    # Handle pandas Period objects by extracting year and quarter attributes
    if isinstance(val, pd.Period):
        # Format the extracted attributes into the canonical string
        return f"{val.year}Q{val.quarter}"

    # Handle pandas Timestamp or Python datetime objects
    if isinstance(val, (pd.Timestamp, datetime.datetime)):
        # Calculate the quarter mathematically from the month: (month - 1) // 3 + 1
        quarter = (val.month - 1) // 3 + 1
        # Format the extracted year and computed quarter into the canonical string
        return f"{val.year}Q{quarter}"

    # Handle string representations by stripping leading/trailing whitespace
    val_str = str(val).strip()

    # Check if the string already matches the canonical format perfectly
    if re.match(r"^\d{4}Q[1-4]$", val_str):
        # Return the string as-is if it is already canonical
        return val_str

    # Attempt to parse alternative string formats using regex with capture groups
    # Matches formats like: "1999-Q3", "1999q3", "1999 Q3", "1999:3"
    alt_pattern_1 = re.match(r"^(\d{4})[- :]*[qQ]?([1-4])$", val_str, re.IGNORECASE)
    if alt_pattern_1:
        # Reconstruct the string using the captured year (group 1) and quarter (group 2)
        return f"{alt_pattern_1.group(1)}Q{alt_pattern_1.group(2)}"

    # Matches formats where quarter precedes year like: "Q3 1999", "q3-1999"
    alt_pattern_2 = re.match(r"^[qQ]?([1-4])[- :]*(\d{4})$", val_str, re.IGNORECASE)
    if alt_pattern_2:
        # Reconstruct the string using the captured year (group 2) and quarter (group 1)
        return f"{alt_pattern_2.group(2)}Q{alt_pattern_2.group(1)}"

    # If all parsing attempts fail, raise a descriptive error
    raise ValueError(f"Unrecognized date string format: '{val_str}'")


def normalize_dates_in_dataframe(df: pd.DataFrame, date_col: str, dataset_name: str) -> Tuple[pd.DataFrame, DateNormalizationLog]:
    """
    Normalizes the date column of a DataFrame to the canonical 'YYYYQq' format.

    Args:
        df (pd.DataFrame): The input DataFrame.
        date_col (str): The name of the date column to normalize.
        dataset_name (str): Identifier for logging purposes.

    Returns:
        Tuple[pd.DataFrame, DateNormalizationLog]: The normalized DataFrame (deep copy) and the audit log.

    Raises:
        ValueError: If any date value cannot be parsed into the canonical format.
    """
    # Create a deep copy to ensure the original ingested data is not mutated
    df_clean = df.copy(deep=True)
    # Initialize the audit log with the dataset name and total row count
    log = DateNormalizationLog(dataset_name=dataset_name, total_processed=len(df_clean))

    # Initialize an empty list to store the normalized date strings
    normalized_dates = []

    # Iterate over the date column to apply normalization and track changes
    for idx, val in df_clean[date_col].items():
        try:
            # Attempt to normalize the single value using the helper function
            norm_val = _normalize_single_date(val)
            # Append the normalized value to the list
            normalized_dates.append(norm_val)

            # If the string representation changed, log it as a transformation
            if str(val) != norm_val:
                # Record the index, original value, and new value
                log.transformed_entries.append((idx, val, norm_val))

        except ValueError as e:
            # Log the failure with the index, original value, and error message
            log.failed_entries.append((idx, val, str(e)))
            # Re-raise the exception to halt execution, as unparseable dates are fatal
            raise ValueError(f"Failed to normalize date at index {idx} in {dataset_name}: {e}")

    # Assign the fully normalized list back to the DataFrame column
    df_clean[date_col] = normalized_dates

    # Perform a final strict validation pass to guarantee absolute compliance
    final_check_mask = df_clean[date_col].str.match(r"^\d{4}Q[1-4]$")
    # If any value fails the final regex check, halt execution
    if not final_check_mask.all():
        # Extract the exact indices that failed the final check for the error message
        failed_indices = df_clean.index[~final_check_mask].tolist()
        # Raise a fatal error
        raise ValueError(f"Final regex validation failed for {dataset_name} at indices: {failed_indices}")

    # Return the normalized DataFrame and the audit log
    return df_clean, log

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Step 2: Sort both datasets chronologically
# -------------------------------------------------------------------------------------------------------------------------------

def sort_dataframe_chronologically(df: pd.DataFrame, date_col: str) -> pd.DataFrame:
    """
    Sorts a DataFrame in ascending chronological order based on a canonical 'YYYYQq' date column,
    resets the integer index, and rigorously verifies strict monotonicity and uniqueness.

    Args:
        df (pd.DataFrame): The DataFrame with normalized dates.
        date_col (str): The name of the date column.

    Returns:
        pd.DataFrame: The sorted DataFrame with a reset 0-based integer index.

    Raises:
        ValueError: If the sorted dates are not strictly monotonically increasing or unique.
    """
    # Create a deep copy to prevent side effects on the input DataFrame
    df_sorted = df.copy(deep=True)
    # Record the original row count to ensure no data loss occurs during sorting
    original_len = len(df_sorted)

    # Define a sorting key function that parses 'YYYYQq' into a sortable integer
    def _sort_key(series: pd.Series) -> pd.Series:
        # Extract year and quarter, multiply year by 10 and add quarter to create a monotonic integer
        return series.apply(lambda x: int(x[:4]) * 10 + int(x[5]))

    # Sort the DataFrame using the custom key in ascending order
    df_sorted = df_sorted.sort_values(by=date_col, key=_sort_key, ascending=True)

    # Reset the index to establish a clean 0, 1, ..., N-1 positional index.
    # drop=True prevents the old scrambled index from being added as a new column.
    df_sorted = df_sorted.reset_index(drop=True)

    # Verify no rows were lost or duplicated during the sort operation
    if len(df_sorted) != original_len:
        # Raise an error if the row count changed
        raise ValueError(f"Row count changed during sort. Original: {original_len}, New: {len(df_sorted)}")

    # Rigorous post-sort verification: parse dates to tuples for strict monotonicity check
    # We utilize the _parse_quarter_string callable defined in Task 3
    parsed_dates = [_parse_quarter_string(d) for d in df_sorted[date_col]]

    # Iterate through adjacent pairs to ensure strict monotonic increase
    for i in range(len(parsed_dates) - 1):
        # If the current date is greater than or equal to the next date, ordering is violated
        if parsed_dates[i] >= parsed_dates[i+1]:
            # Raise a fatal error detailing the exact location of the violation
            raise ValueError(
                f"Strict chronological ordering violated after sort at index {i}: "
                f"{df_sorted[date_col].iloc[i]} >= {df_sorted[date_col].iloc[i+1]}"
            )

    # Return the sorted and verified DataFrame
    return df_sorted

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Step 3: Remove accidental contamination
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ContaminationRemovalLog:
    """
    A structured record documenting the removal of import artifacts and empty rows.

    Attributes:
        dataset_name (str): Identifier for the dataset.
        stripped_column_names (List[str]): List of column names that had whitespace stripped.
        dropped_columns (List[str]): List of column names that were removed.
        dropped_empty_rows (List[int]): List of original row indices that were fully empty and removed.
    """
    # Name of the dataset being cleansed
    dataset_name: str
    # Columns whose names were modified to remove whitespace
    stripped_column_names: List[str] = field(default_factory=list)
    # Columns that were entirely dropped from the DataFrame
    dropped_columns: List[str] = field(default_factory=list)
    # Row indices that were dropped because they contained no data
    dropped_empty_rows: List[int] = field(default_factory=list)


def remove_contamination(df: pd.DataFrame, expected_columns: List[str], dataset_name: str) -> Tuple[pd.DataFrame, ContaminationRemovalLog]:
    """
    Strips whitespace from column names, removes unauthorized columns (e.g., 'Unnamed: 0'),
    and drops fully empty rows from the DataFrame.

    Args:
        df (pd.DataFrame): The sorted DataFrame.
        expected_columns (List[str]): The exact list of authorized column names.
        dataset_name (str): Identifier for logging purposes.

    Returns:
        Tuple[pd.DataFrame, ContaminationRemovalLog]: The cleansed DataFrame and the audit log.

    Raises:
        ValueError: If the final cleansed DataFrame does not match the expected schema.
    """
    # Create a deep copy to prevent side effects on the input DataFrame
    df_clean = df.copy(deep=True)
    # Initialize the audit log with the dataset name
    log = ContaminationRemovalLog(dataset_name=dataset_name)

    # 1. Strip hidden whitespace from column names
    # Capture the original column names
    original_cols = list(df_clean.columns)
    # Apply the strip method to the column index
    df_clean.columns = df_clean.columns.str.strip()
    # Capture the new column names
    new_cols = list(df_clean.columns)

    # Log any columns that were modified by the strip operation
    for orig, new in zip(original_cols, new_cols):
        if orig != new:
            # Record the original name in the log
            log.stripped_column_names.append(orig)

    # 2. Identify and drop unauthorized columns (e.g., 'Unnamed: 0' or extra data)
    # Convert expected columns to a set for efficient comparison
    expected_set = set(expected_columns)
    # Convert actual columns to a set
    actual_set = set(df_clean.columns)
    # Compute the set difference to find unauthorized columns
    unauthorized_cols = list(actual_set - expected_set)

    # If unauthorized columns exist, remove them
    if unauthorized_cols:
        # Drop the unauthorized columns from the DataFrame
        df_clean = df_clean.drop(columns=unauthorized_cols)
        # Log the dropped columns
        log.dropped_columns.extend(unauthorized_cols)

    # 3. Identify and drop fully empty rows
    # A row is considered empty if all expected data columns (excluding 'date') are NaN
    data_cols = [col for col in expected_columns if col != "date"]

    # Find rows where all data columns are NA using boolean masking
    empty_row_mask = df_clean[data_cols].isna().all(axis=1)

    # If any empty rows exist, remove them
    if empty_row_mask.any():
        # Extract the indices of the empty rows for logging
        empty_indices = df_clean.index[empty_row_mask].tolist()
        # Record the indices in the log
        log.dropped_empty_rows.extend(empty_indices)
        # Drop the empty rows from the DataFrame
        df_clean = df_clean.dropna(subset=data_cols, how='all')
        # Reset index again after dropping rows to maintain contiguous positional indexing
        df_clean = df_clean.reset_index(drop=True)

    # 4. Final schema verification
    # Ensure the remaining columns exactly match the expected columns in content and order
    # This operation reorders the columns to match the expected list
    df_clean = df_clean[expected_columns]

    # Verify the column count matches the expected count
    if len(df_clean.columns) != len(expected_columns):
        # Raise a fatal error if the schema is still incorrect
        raise ValueError(f"Cleansing failed for {dataset_name}: Final column count {len(df_clean.columns)} != expected {len(expected_columns)}.")

    # Return the cleansed DataFrame and the audit log
    return df_clean, log

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task5CleansingReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the data cleansing and standardization phase. This report encapsulates the
    normalized, sorted, and decontaminated DataFrames for both the SPF panel and
    the GDP target series, alongside a comprehensive suite of audit logs that
    document every transformation, ensuring a transparent and auditable research path.

    Attributes:
        cleansed_spf_panel (pd.DataFrame): The finalized SPF forecaster panel,
            guaranteed to be in canonical YYYYQq format, chronologically sorted,
            and free of import artifacts.
        cleansed_gdp_target (pd.DataFrame): The finalized GDP target series,
            guaranteed to be aligned in format and order with the SPF panel.
        spf_date_log (DateNormalizationLog): Audit record of all date-string
            transformations performed on the SPF panel.
        gdp_date_log (DateNormalizationLog): Audit record of all date-string
            transformations performed on the GDP target series.
        spf_contamination_log (ContaminationRemovalLog): Audit record of all
            dropped columns and empty rows from the SPF panel.
        gdp_contamination_log (ContaminationRemovalLog): Audit record of all
            dropped columns and empty rows from the GDP target series.
    """
    # The fully cleansed, normalized, and sorted SPF panel DataFrame ready for alignment
    cleansed_spf_panel: pd.DataFrame
    # The fully cleansed, normalized, and sorted GDP target DataFrame ready for alignment
    cleansed_gdp_target: pd.DataFrame
    # Audit log documenting the normalization of date identifiers in the SPF panel
    spf_date_log: Any  # Expected type: DateNormalizationLog
    # Audit log documenting the normalization of date identifiers in the GDP target series
    gdp_date_log: Any  # Expected type: DateNormalizationLog
    # Audit log documenting the removal of artifacts and empty rows from the SPF panel
    spf_contamination_log: Any  # Expected type: ContaminationRemovalLog
    # Audit log documenting the removal of artifacts and empty rows from the GDP target series
    gdp_contamination_log: Any  # Expected type: ContaminationRemovalLog

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and completeness of the cleansing artifacts before they are
        passed to the Task 6 alignment orchestrator.

        Raises:
            TypeError: If any attribute does not match the required type.
            ValueError: If the DataFrames are empty or critical logs are missing.
        """
        # Verify that cleansed_spf_panel is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.cleansed_spf_panel, pd.DataFrame):
            # Raise a TypeError if the SPF panel data structure is incorrect
            raise TypeError("Task5CleansingReport: cleansed_spf_panel must be a pandas.DataFrame.")

        # Verify that cleansed_gdp_target is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.cleansed_gdp_target, pd.DataFrame):
            # Raise a TypeError if the GDP target data structure is incorrect
            raise TypeError("Task5CleansingReport: cleansed_gdp_target must be a pandas.DataFrame.")

        # Ensure the cleansed SPF panel is not empty to prevent downstream pipeline failures
        if self.cleansed_spf_panel.empty:
            # Raise a ValueError if the cleansing process resulted in zero rows
            raise ValueError("Task5CleansingReport: cleansed_spf_panel cannot be empty.")

        # Ensure the cleansed GDP target series is not empty to prevent downstream pipeline failures
        if self.cleansed_gdp_target.empty:
            # Raise a ValueError if the cleansing process resulted in zero rows
            raise ValueError("Task5CleansingReport: cleansed_gdp_target cannot be empty.")

        # Verify that the SPF date normalization log is present and not None
        if self.spf_date_log is None:
            # Raise a ValueError if the critical audit documentation is missing
            raise ValueError("Task5CleansingReport: spf_date_log cannot be None.")

        # Verify that the GDP date normalization log is present and not None
        if self.gdp_date_log is None:
            # Raise a ValueError if the critical audit documentation is missing
            raise ValueError("Task5CleansingReport: gdp_date_log cannot be None.")

        # Verify that the SPF contamination removal log is present and not None
        if self.spf_contamination_log is None:
            # Raise a ValueError if the critical audit documentation is missing
            raise ValueError("Task5CleansingReport: spf_contamination_log cannot be None.")

        # Verify that the GDP contamination removal log is present and not None
        if self.gdp_contamination_log is None:
            # Raise a ValueError if the critical audit documentation is missing
            raise ValueError("Task5CleansingReport: gdp_contamination_log cannot be None.")


def execute_task_5_cleanse_and_standardize_dates(
    df_spf_panel_wide: pd.DataFrame,
    df_gdp_target_series: pd.DataFrame,
    study_configuration: Dict[str, Any]
) -> Task5CleansingReport:
    """
    Orchestrates Task 5: Normalizes date formats, sorts chronologically, and removes
    accidental contamination from both the SPF panel and the GDP target series.

    Args:
        df_spf_panel_wide (pd.DataFrame): The raw SPF panel DataFrame.
        df_gdp_target_series (pd.DataFrame): The raw GDP target DataFrame.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Task5CleansingReport: The comprehensive cleansing report containing the finalized DataFrames.

    Raises:
        ValueError: If any cleansing step fails or if final schema validation fails.
    """
    # Extract expected column names for the SPF panel from the configuration
    k_forecasters = study_configuration["data_inputs"]["spf_panel_wide"]["K_forecasters"]
    # Construct the expected SPF columns list programmatically
    expected_spf_cols = ["date"] + [f"forecaster_{k:02d}" for k in range(1, k_forecasters + 1)]

    # Extract expected column names for the GDP target series from the configuration
    date_col = study_configuration["data_inputs"]["gdp_target_series"]["date_column"]
    target_col = study_configuration["data_inputs"]["gdp_target_series"]["value_column"]
    # Construct the expected GDP columns list
    expected_gdp_cols = [date_col, target_col]

    # Step 1: Normalize all quarter identifiers to canonical form
    # Normalize the SPF panel dates
    norm_spf, spf_date_log = normalize_dates_in_dataframe(df_spf_panel_wide, "date", "spf_panel")
    # Normalize the GDP target dates
    norm_gdp, gdp_date_log = normalize_dates_in_dataframe(df_gdp_target_series, date_col, "gdp_target")

    # Step 2: Sort both datasets chronologically
    # Sort the normalized SPF panel
    sorted_spf = sort_dataframe_chronologically(norm_spf, "date")
    # Sort the normalized GDP target series
    sorted_gdp = sort_dataframe_chronologically(norm_gdp, date_col)

    # Step 3: Remove accidental contamination
    # Cleanse the sorted SPF panel
    clean_spf, spf_contam_log = remove_contamination(sorted_spf, expected_spf_cols, "spf_panel")
    # Cleanse the sorted GDP target series
    clean_gdp, gdp_contam_log = remove_contamination(sorted_gdp, expected_gdp_cols, "gdp_target")

    # Final Sanity Check: Re-run schema validation using the callables defined in Tasks 1 and 3
    # Validate the cleansed SPF panel schema
    spf_schema_check = validate_spf_panel_schema(clean_spf, study_configuration)
    if not spf_schema_check.passed:
        # Raise a fatal error if the schema is invalid post-cleansing
        raise ValueError("Post-cleansing schema validation failed for SPF panel.")

    # Validate the cleansed GDP target series schema
    gdp_schema_check = validate_gdp_target_schema(clean_gdp, study_configuration)
    if not gdp_schema_check.passed:
        # Raise a fatal error if the schema is invalid post-cleansing
        raise ValueError("Post-cleansing schema validation failed for GDP target series.")

    # Return the composite cleansing report containing the finalized DataFrames and logs
    return Task5CleansingReport(
        cleansed_spf_panel=clean_spf,
        cleansed_gdp_target=clean_gdp,
        spf_date_log=spf_date_log,
        gdp_date_log=gdp_date_log,
        spf_contamination_log=spf_contam_log,
        gdp_contamination_log=gdp_contam_log
    )

# %%
# Task 6: Align the Panel and Target Series on the date Field

# ==============================================================================
# Task 6: Align the Panel and Target Series on the date Field
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Step 1: Perform an inner join on `date` — preceded by a date-difference audit
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class PreMergeAuditReport:
    """
    A structured record documenting the symmetric date difference between the panel and target series.

    Attributes:
        passed (bool): True if the merge is safe to proceed, False if fatal misalignments exist.
        panel_only_dates (List[str]): Quarters present in the forecaster panel but missing from targets.
        target_only_dates (List[str]): Quarters present in the targets but missing from the panel.
        fatal_error_message (Optional[str]): Description of why the audit failed, if applicable.
    """
    # Boolean flag indicating if the merge is safe
    passed: bool
    # List of dates only in the panel
    panel_only_dates: List[str]
    # List of dates only in the target series
    target_only_dates: List[str]
    # Optional error message for fatal conditions
    fatal_error_message: Optional[str] = None


def perform_audited_inner_join(
    df_spf_panel_wide: pd.DataFrame,
    df_gdp_target_series: pd.DataFrame,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None
) -> Tuple[Optional[pd.DataFrame], PreMergeAuditReport]:
    """
    Computes the symmetric date difference between the panel and target series, evaluates
    halt conditions, and performs an inner join on the 'date' column if safe.

    Args:
        df_spf_panel_wide (pd.DataFrame): The cleansed SPF panel.
        df_gdp_target_series (pd.DataFrame): The cleansed GDP target series.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope of the panel.

    Returns:
        Tuple[Optional[pd.DataFrame], PreMergeAuditReport]: The merged DataFrame (if successful) and the audit report.
    """
    # Extract the sets of dates from both DataFrames
    s_panel = set(df_spf_panel_wide["date"].astype(str))
    s_target = set(df_gdp_target_series["date"].astype(str))

    # Compute symmetric differences
    panel_only = sorted(list(s_panel - s_target))
    target_only = sorted(list(s_target - s_panel))

    passed = True
    fatal_error_message = None

    # Condition 1: panel_only must be empty. We cannot evaluate forecasts without realizations.
    if len(panel_only) > 0:
        passed = False
        fatal_error_message = f"Fatal: Forecaster data exists without GDP realizations for quarters: {panel_only}"

    # Condition 2: target_only dates must not fall within the declared evaluation range.
    if passed and len(target_only) > 0 and declared_panel_scope is not None:
        # Determine the expected bounds based on the scope
        if declared_panel_scope == "search_only":
            start_bound = study_configuration["sample_design"]["search_sample"]["start"]
            end_bound = study_configuration["sample_design"]["search_sample"]["end"]
        elif declared_panel_scope == "holdout_only":
            start_bound = study_configuration["sample_design"]["holdout_sample"]["start"]
            end_bound = study_configuration["sample_design"]["holdout_sample"]["end"]
        elif declared_panel_scope == "full_panel":
            start_bound = study_configuration["sample_design"]["search_sample"]["start"]
            end_bound = study_configuration["sample_design"]["holdout_sample"]["end"]
        else:
            start_bound, end_bound = None, None

        if start_bound and end_bound:
            start_tuple = _parse_quarter_string(start_bound)
            end_tuple = _parse_quarter_string(end_bound)

            # Check if any target_only date falls strictly within the bounds
            violating_quarters = []
            for q in target_only:
                q_tuple = _parse_quarter_string(q)
                if start_tuple <= q_tuple <= end_tuple:
                    violating_quarters.append(q)

            if len(violating_quarters) > 0:
                passed = False
                fatal_error_message = f"Fatal: Required quarters missing from forecaster panel: {violating_quarters}"

    # Construct the audit report
    audit_report = PreMergeAuditReport(
        passed=passed,
        panel_only_dates=panel_only,
        target_only_dates=target_only,
        fatal_error_message=fatal_error_message
    )

    # If the audit fails, return None for the DataFrame
    if not passed:
        return None, audit_report

    # Perform the inner join on the 'date' column
    # how='inner' is safe because the audit confirmed no required quarters are missing
    df_merged = pd.merge(df_spf_panel_wide, df_gdp_target_series, on="date", how="inner")

    # Check for accidental column collisions resulting in pandas suffixes (_x, _y)
    collision_cols = [col for col in df_merged.columns if col.endswith('_x') or col.endswith('_y')]
    if len(collision_cols) > 0:
        audit_report.passed = False
        audit_report.fatal_error_message = f"Fatal: Column name collisions detected during merge: {collision_cols}"
        return None, audit_report

    return df_merged, audit_report

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Step 2: Validate the merged row count
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class MergedDimensionalValidationResult:
    """
    A structured, implementation-grade record containing the results of the post-merge
    dimensional validation for the canonical aligned panel. This class ensures that
    the inner join operation between the SPF forecaster panel and the GDP target
    series resulted in a DataFrame with the exact expected geometry and structural
    integrity required for downstream econometric evaluation.

    Attributes:
        passed (bool): A global flag indicating whether all dimensional and
            uniqueness invariants were satisfied.
        row_count (int): The total number of observations in the merged DataFrame.
        column_count (int): The total number of features in the merged DataFrame
            (expected: 1 date + 23 forecasters + 1 target = 25).
        column_names (List[str]): The ordered list of column names in the
            finalized DataFrame.
        dates_unique (bool): A flag indicating whether the temporal index remains
            unique, ensuring no Cartesian product occurred during the join.
        error_message (Optional[str]): A detailed description of any invariant
            violation detected during validation.
    """
    # Boolean flag indicating overall success of the dimensional validation
    passed: bool
    # Integer count of total rows in the merged canonical panel
    row_count: int
    # Integer count of total columns in the merged canonical panel
    column_count: int
    # List of actual column names in the exact order they appear in the DataFrame
    column_names: List[str]
    # Boolean flag indicating if the date column contains zero duplicates
    dates_unique: bool
    # Optional string containing the description of a fatal validation error
    error_message: Optional[str] = None

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity
        of the validation record itself and enforces the structural invariants
        of the auditable framework.

        Raises:
            TypeError: If any attribute does not match the required type.
            ValueError: If the column count deviates from the fixed K=23 specification.
        """
        # Verify that row_count is a non-negative integer to ensure data consistency
        if not isinstance(self.row_count, int) or self.row_count < 0:
            # Raise a TypeError if the row count is mathematically invalid
            raise TypeError("MergedDimensionalValidationResult: row_count must be a non-negative integer.")

        # Verify that column_count is exactly 25 (1 date + 23 forecasters + 1 target)
        # This enforces the fixed-K panel requirement of the Diebold and Shin (2019) design.
        if self.column_count != 25:
            # Raise a ValueError if the feature dimension is incorrect
            raise ValueError(f"MergedDimensionalValidationResult: column_count must be exactly 25. Found {self.column_count}.")

        # Verify that column_names is a list of strings with the correct length
        if not isinstance(self.column_names, list) or len(self.column_names) != 25:
            # Raise a TypeError if the column metadata is malformed
            raise TypeError("MergedDimensionalValidationResult: column_names must be a list of 25 strings.")

        # Ensure that dates_unique is a boolean to prevent logical ambiguity
        if not isinstance(self.dates_unique, bool):
            # Raise a TypeError if the uniqueness flag is not a boolean
            raise TypeError("MergedDimensionalValidationResult: dates_unique must be a boolean.")

def validate_merged_dimensions(
    df_merged: pd.DataFrame,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None
) -> Tuple[pd.DataFrame, MergedDimensionalValidationResult]:
    """
    Validates the dimensions, column order, and uniqueness of the merged DataFrame,
    explicitly reordering columns to the guaranteed expected list.

    Args:
        df_merged (pd.DataFrame): The merged DataFrame from Step 1.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope of the panel.

    Returns:
        Tuple[pd.DataFrame, MergedDimensionalValidationResult]: The reordered DataFrame and the validation result.
    """
    passed = True
    error_message = None

    # 1. Validate Row Count
    row_count = len(df_merged)
    expected_row_count = None

    if declared_panel_scope == "search_only":
        expected_row_count = study_configuration["sample_design"]["search_sample"]["total_rows"]
    elif declared_panel_scope == "holdout_only":
        expected_row_count = study_configuration["sample_design"]["holdout_sample"]["quarters"]
    elif declared_panel_scope == "full_panel":
        expected_row_count = study_configuration["sample_design"]["full_study_panel_rows"]

    if expected_row_count is not None and row_count != expected_row_count:
        passed = False
        error_message = f"Row count {row_count} does not match expected {expected_row_count} for scope '{declared_panel_scope}'."
    elif expected_row_count is None:
        # Loose validation against all valid sizes
        valid_sizes = [
            study_configuration["sample_design"]["search_sample"]["total_rows"],
            study_configuration["sample_design"]["holdout_sample"]["quarters"],
            study_configuration["sample_design"]["full_study_panel_rows"]
        ]
        if row_count not in valid_sizes:
            passed = False
            error_message = f"Row count {row_count} does not match any valid panel size {valid_sizes}."

    # 2. Validate and Enforce Column Order
    k_forecasters = study_configuration["data_inputs"]["spf_panel_wide"]["K_forecasters"]
    target_col = study_configuration["data_inputs"]["gdp_target_series"]["value_column"]

    # Construct the exact expected column list
    expected_columns = ["date"] + [f"forecaster_{k:02d}" for k in range(1, k_forecasters + 1)] + [target_col]

    column_count = len(df_merged.columns)
    if column_count != 25:
        passed = False
        error_message = f"Column count {column_count} != expected 25."

    # Explicitly reorder the DataFrame columns to guarantee the strict sequence
    try:
        df_merged_ordered = df_merged[expected_columns].copy(deep=True)
    except KeyError as e:
        passed = False
        error_message = f"Missing expected columns during reordering: {e}"
        df_merged_ordered = df_merged # Fallback for return type

    # 3. Validate Date Uniqueness Post-Merge
    dates_unique = df_merged_ordered["date"].is_unique
    if not dates_unique:
        passed = False
        error_message = "Duplicate dates detected post-merge. Cartesian product likely occurred."

    result = MergedDimensionalValidationResult(
        passed=passed,
        row_count=row_count,
        column_count=column_count,
        column_names=list(df_merged_ordered.columns),
        dates_unique=dates_unique,
        error_message=error_message
    )

    return df_merged_ordered, result

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Step 3: Name the canonical aligned panel
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class CanonicalPanelArtifacts:
    """
    A structured, implementation-grade container for the finalized artifacts produced
    during the panel alignment phase. This class encapsulates the canonical aligned
    panel, the authoritative index map for temporal slicing, and the associated
    metadata, ensuring that all downstream tasks (imputation, partitioning, and
    evaluation) operate on a mathematically verified and synchronized data foundation.

    Attributes:
        df_canonical_panel (pd.DataFrame): The finalized, aligned, and ordered
            canonical panel containing the date, 23 forecaster columns, and the
            GDP target column.
        index_map (pd.DataFrame): The standing index map providing 1-based to 0-based
            translations and boolean eligibility flags for the evaluator calls.
        metadata (Dict[str, Any]): A dictionary documenting the panel's properties,
            including row counts, column structure, and date ranges.

    Algorithm:
        The class uses post-initialization validation to enforce structural invariants,
        guaranteeing that the DataFrames are non-empty and that the index map contains
        the required columns for manuscript-to-Python index translation.
    """
    # The finalized canonical panel DataFrame ready for downstream econometric processing
    df_canonical_panel: pd.DataFrame
    # The standing index map used to prevent off-by-one errors in temporal slicing
    index_map: pd.DataFrame
    # Metadata dictionary documenting the provenance and role of the canonical panel
    metadata: Dict[str, Any]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and consistency of the canonical artifacts.

        Raises:
            TypeError: If any attribute does not match the required type.
            ValueError: If the DataFrames are empty or the index map schema is invalid.
        """
        # Verify that df_canonical_panel is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.df_canonical_panel, pd.DataFrame):
            # Raise a TypeError if the panel data structure is incorrect
            raise TypeError("CanonicalPanelArtifacts: df_canonical_panel must be a pandas.DataFrame.")

        # Verify that index_map is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.index_map, pd.DataFrame):
            # Raise a TypeError if the index map data structure is incorrect
            raise TypeError("CanonicalPanelArtifacts: index_map must be a pandas.DataFrame.")

        # Ensure the canonical panel is not empty to prevent downstream pipeline failures
        if self.df_canonical_panel.empty:
            # Raise a ValueError if the alignment resulted in zero rows
            raise ValueError("CanonicalPanelArtifacts: df_canonical_panel cannot be empty.")

        # Verify that the metadata dictionary is present and correctly typed
        if not isinstance(self.metadata, dict):
            # Raise a TypeError if the metadata structure is incorrect
            raise TypeError("CanonicalPanelArtifacts: metadata must be a dictionary.")

        # Define the set of required columns for the index map to ensure contract compliance
        required_idx_cols = {
            "manuscript_row_number",
            "python_positional_index",
            "date",
            "evaluator_call_eligible",
            "evaluator_score_eligible",
            "warmup_only"
        }

        # Check for the presence of all required columns in the index map schema
        if not required_idx_cols.issubset(self.index_map.columns):
            # Identify the specific missing columns for the error message
            missing = required_idx_cols - set(self.index_map.columns)
            # Raise a ValueError if the index map schema is incomplete
            raise ValueError(f"CanonicalPanelArtifacts: index_map missing required columns: {missing}")


def construct_canonical_panel_and_index_map(
    df_merged_ordered: pd.DataFrame,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None
) -> CanonicalPanelArtifacts:
    """
    Designates the DataFrame as the canonical panel, constructs the authoritative index map,
    and generates the metadata dictionary.

    Args:
        df_merged_ordered (pd.DataFrame): The validated and ordered merged DataFrame.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope of the panel.

    Returns:
        CanonicalPanelArtifacts: The container with the panel, index map, and metadata.
    """
    # Designate the canonical panel
    df_canonical_panel = df_merged_ordered.copy(deep=True)

    # Ensure the integer index is perfectly contiguous from 0 to N-1
    df_canonical_panel = df_canonical_panel.reset_index(drop=True)

    # Construct the Index Map
    # Extract the call and score ranges from configuration
    call_start = study_configuration["prepare_script_data"]["call_index_range_t"]["start"]
    call_end = study_configuration["prepare_script_data"]["call_index_range_t"]["end"]
    score_start = study_configuration["prepare_script_data"]["score_index_range_t"]["start"]
    score_end = study_configuration["prepare_script_data"]["score_index_range_t"]["end"]

    # Initialize lists for the index map columns
    manuscript_rows = []
    python_indices = []
    dates = []
    call_eligible = []
    score_eligible = []
    warmup_flags = []

    # Iterate over the canonical panel to populate the map
    for i, row in df_canonical_panel.iterrows():
        # Python positional index is exactly the loop counter i
        python_indices.append(i)
        # Manuscript row number is 1-based
        m_row = i + 1
        manuscript_rows.append(m_row)
        dates.append(row["date"])

        # Determine eligibility based on manuscript row number
        # Note: These flags are strictly defined for the search sample (rows 1-70).
        # For holdout rows (m_row > 70), they will be False here, which is safe as Task 27 handles holdout scoring.
        is_call = (call_start <= m_row <= call_end)
        is_score = (score_start <= m_row <= score_end)
        is_warmup = (m_row == call_start)

        call_eligible.append(is_call)
        score_eligible.append(is_score)
        warmup_flags.append(is_warmup)

    # Create the index map DataFrame
    index_map = pd.DataFrame({
        "manuscript_row_number": manuscript_rows,
        "python_positional_index": python_indices,
        "date": dates,
        "sample_membership": [None] * len(dates), # To be filled in Task 8
        "evaluator_call_eligible": call_eligible,
        "evaluator_score_eligible": score_eligible,
        "warmup_only": warmup_flags
    })

    # Construct the metadata dictionary
    metadata = {
        "row_count": len(df_canonical_panel),
        "column_structure": {
            "date": 1,
            "forecaster_columns": study_configuration["data_inputs"]["spf_panel_wide"]["K_forecasters"],
            "target_column": 1
        },
        "date_range": (df_canonical_panel["date"].iloc[0], df_canonical_panel["date"].iloc[-1]),
        "panel_scope": declared_panel_scope,
        "downstream_role": "This panel is the basis for all subsequent slicing into the evaluator's runtime objects: X_train, X_history, x_new, y_train, y_history."
    }

    return CanonicalPanelArtifacts(
        df_canonical_panel=df_canonical_panel,
        index_map=index_map,
        metadata=metadata
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task6AlignmentReport:
    """
    A structured, implementation-grade container for the artifacts produced during the
    alignment of the forecaster panel and the GDP target series. This report
    encapsulates the finalized canonical panel, the authoritative index map,
    and the comprehensive audit logs required to verify the integrity of the
    inner join operation, ensuring a transparent and evaluator-locked audit trail.

    Attributes:
        df_canonical_panel (pd.DataFrame): The finalized, aligned, and ordered
            canonical panel containing 25 columns (date, 23 forecasters, target).
        index_map (pd.DataFrame): The standing index map providing 1-based to 0-based
            translations and boolean eligibility flags for the evaluator.
        metadata (Dict[str, Any]): A dictionary documenting the panel's properties,
            including row counts, column structure, and date ranges.
        pre_merge_audit (Any): An instance of PreMergeAuditReport documenting
            the symmetric date difference analysis.
        dimensional_validation (Any): An instance of MergedDimensionalValidationResult
            confirming the post-merge structural invariants.
    """
    # The finalized canonical panel DataFrame ready for downstream imputation
    df_canonical_panel: pd.DataFrame
    # The standing index map used to prevent off-by-one errors in temporal slicing
    index_map: pd.DataFrame
    # Metadata dictionary documenting the provenance and role of the canonical panel
    metadata: Dict[str, Any]
    # The pre-merge audit report documenting the safety of the join operation
    pre_merge_audit: Any  # Expected type: PreMergeAuditReport
    # The post-merge dimensional validation result confirming structural integrity
    dimensional_validation: Any  # Expected type: MergedDimensionalValidationResult

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and consistency of the alignment artifacts.

        Raises:
            TypeError: If any attribute does not match the required type.
            ValueError: If the DataFrames are empty or metadata is incomplete.
        """
        # Verify that df_canonical_panel is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.df_canonical_panel, pd.DataFrame):
            # Raise a TypeError if the panel data structure is incorrect
            raise TypeError("Task6AlignmentReport: df_canonical_panel must be a pandas.DataFrame.")

        # Verify that index_map is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.index_map, pd.DataFrame):
            # Raise a TypeError if the index map data structure is incorrect
            raise TypeError("Task6AlignmentReport: index_map must be a pandas.DataFrame.")

        # Ensure the canonical panel is not empty to prevent downstream pipeline failures
        if self.df_canonical_panel.empty:
            # Raise a ValueError if the alignment resulted in zero rows
            raise ValueError("Task6AlignmentReport: df_canonical_panel cannot be empty.")

        # Verify that the metadata dictionary is present and contains the required keys
        if not isinstance(self.metadata, dict):
            # Raise a TypeError if the metadata structure is incorrect
            raise TypeError("Task6AlignmentReport: metadata must be a dictionary.")

        # Verify that the pre_merge_audit artifact is present and not None
        if self.pre_merge_audit is None:
            # Raise a ValueError if the critical audit documentation is missing
            raise ValueError("Task6AlignmentReport: pre_merge_audit cannot be None.")

        # Verify that the dimensional_validation artifact is present and not None
        if self.dimensional_validation is None:
            # Raise a ValueError if the structural verification record is missing
            raise ValueError("Task6AlignmentReport: dimensional_validation cannot be None.")


def execute_task_6_align_panel_and_target(
    df_spf_panel_wide: pd.DataFrame,
    df_gdp_target_series: pd.DataFrame,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None
) -> Task6AlignmentReport:
    """
    Orchestrates Task 6: Performs a pre-merge audit, executes an inner join on the date field,
    validates the merged dimensions, and constructs the canonical panel and index map.

    Args:
        df_spf_panel_wide (pd.DataFrame): The cleansed SPF panel.
        df_gdp_target_series (pd.DataFrame): The cleansed GDP target series.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope of the panel.

    Returns:
        Task6AlignmentReport: The comprehensive alignment report containing the canonical artifacts.

    Raises:
        ValueError: If the pre-merge audit fails or post-merge dimensions are invalid.
    """
    # Step 1: Perform an inner join on `date` — preceded by a date-difference audit
    df_merged, pre_merge_audit = perform_audited_inner_join(
        df_spf_panel_wide, df_gdp_target_series, study_configuration, declared_panel_scope
    )

    # Halt immediately if the pre-merge audit failed
    if not pre_merge_audit.passed:
        raise ValueError(f"Task 6 Step 1 Failed: Pre-merge audit violation. {pre_merge_audit.fatal_error_message}")

    # Step 2: Validate the merged row count and enforce column order
    df_merged_ordered, dim_validation = validate_merged_dimensions(
        df_merged, study_configuration, declared_panel_scope
    )

    # Halt immediately if the dimensional validation failed
    if not dim_validation.passed:
        raise ValueError(f"Task 6 Step 2 Failed: Post-merge dimensional violation. {dim_validation.error_message}")

    # Step 3: Name the canonical aligned panel and construct the index map
    canonical_artifacts = construct_canonical_panel_and_index_map(
        df_merged_ordered, study_configuration, declared_panel_scope
    )

    # Return the composite alignment report
    return Task6AlignmentReport(
        df_canonical_panel=canonical_artifacts.df_canonical_panel,
        index_map=canonical_artifacts.index_map,
        metadata=canonical_artifacts.metadata,
        pre_merge_audit=pre_merge_audit,
        dimensional_validation=dim_validation
    )

# %%
# Task 7: Impute Missing Forecaster Values Using the Paper's Exact Rules

# ==============================================================================
# Task 7: Impute Missing Forecaster Values Using the Paper's Exact Rules
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Step 1: Apply linear interpolation to interior gaps
# -------------------------------------------------------------------------------------------------------------------------------

def impute_interior_gaps_linear(
    df_canonical_panel: pd.DataFrame,
    forecaster_cols: List[str]
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Applies linear interpolation strictly to interior missing values (gaps bounded by
    valid observations on both sides) for each forecaster column.

    Args:
        df_canonical_panel (pd.DataFrame): The aligned and sorted canonical panel.
        forecaster_cols (List[str]): The list of 23 forecaster column names.

    Returns:
        Tuple[pd.DataFrame, pd.DataFrame]:
            - The partially imputed DataFrame (deep copy).
            - A boolean DataFrame mask indicating exactly which cells were interpolated.

    Raises:
        ValueError: If the pandas version does not support the required interpolation arguments.
    """
    # Create a deep copy to ensure the original canonical panel remains immutable
    df_imputed = df_canonical_panel.copy(deep=True)

    # Capture the boolean mask of missing values before interpolation
    pre_imputation_mask = df_imputed[forecaster_cols].isna()

    try:
        # Apply linear interpolation column-wise.
        # method='linear' uses the contiguous integer index, perfectly matching the equation:
        # x_{k,t} = x_{k,t_0} + ((t - t_0) / (t_1 - t_0)) * (x_{k,t_1} - x_{k,t_0})
        # limit_area='inside' strictly prevents extrapolation into leading or trailing gaps.
        df_imputed[forecaster_cols] = df_imputed[forecaster_cols].interpolate(
            method='linear',
            limit_area='inside',
            axis=0
        )
    except (TypeError, ValueError) as e:
        # Catch errors related to unsupported arguments in older pandas versions
        raise ValueError(f"Linear interpolation failed. Ensure pandas >= 1.1.0 for 'limit_area' support. Details: {e}")

    # Capture the boolean mask of missing values after interpolation
    post_imputation_mask = df_imputed[forecaster_cols].isna()

    # Compute the logical difference to identify exactly which cells were modified in this step
    # A cell was interpolated if it was missing before AND is NOT missing after
    interpolated_mask = pre_imputation_mask & ~post_imputation_mask

    # Return the mutated DataFrame and the tracking mask
    return df_imputed, interpolated_mask

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Step 2: Apply cross-sectional mean imputation to trailing gaps and inactive forecasters
# -------------------------------------------------------------------------------------------------------------------------------

def impute_trailing_and_inactive_cross_sectional(
    df_partially_imputed: pd.DataFrame,
    forecaster_cols: List[str]
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Fills all remaining missing values (leading gaps, trailing gaps, inactive forecasters)
    using the same-quarter cross-sectional mean of the observed forecasters.

    Args:
        df_partially_imputed (pd.DataFrame): The DataFrame after interior gap interpolation.
        forecaster_cols (List[str]): The list of 23 forecaster column names.

    Returns:
        Tuple[pd.DataFrame, pd.DataFrame]:
            - The fully imputed DataFrame.
            - A boolean DataFrame mask indicating exactly which cells were mean-imputed.

    Raises:
        ValueError: If any row has zero observed forecasters, making the mean undefined.
    """
    # Create a deep copy to maintain functional purity
    df_imputed = df_partially_imputed.copy(deep=True)

    # Capture the boolean mask of missing values before cross-sectional imputation
    pre_imputation_mask = df_imputed[forecaster_cols].isna()

    # Compute the cross-sectional mean for each row across the forecaster columns
    # Equation: (1 / |A_t|) * sum_{j in A_t} x_{j,t}
    row_means = df_imputed[forecaster_cols].mean(axis=1)

    # Verify that no row mean is NaN, which would occur if |A_t| == 0
    if row_means.isna().any():
        # Extract the indices of the fatal rows for the error message
        fatal_indices = row_means[row_means.isna()].index.tolist()
        raise ValueError(f"Fatal: Cannot compute cross-sectional mean. Zero observed forecasters at indices: {fatal_indices}")

    # Construct a DataFrame of the row means with the exact same shape as the forecaster matrix
    # This allows for a perfectly aligned, vectorized fillna operation without using .apply()
    means_df = pd.DataFrame({col: row_means for col in forecaster_cols})

    # Fill the remaining NaNs in the forecaster columns using the aligned means DataFrame
    df_imputed[forecaster_cols] = df_imputed[forecaster_cols].fillna(means_df)

    # Capture the boolean mask of missing values after cross-sectional imputation
    post_imputation_mask = df_imputed[forecaster_cols].isna()

    # Compute the logical difference to identify exactly which cells were modified in this step
    cross_sectional_mask = pre_imputation_mask & ~post_imputation_mask

    # Return the fully imputed DataFrame and the tracking mask
    return df_imputed, cross_sectional_mask

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Step 3: Validate imputation completeness and create an audit report
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ImputationAuditReport:
    """
    A structured, immutable record documenting the exact scope and integrity of the imputation process.

    Attributes:
        total_cells_interpolated (int): Total number of interior gaps filled via linear interpolation.
        total_cells_crosssectional_mean (int): Total number of gaps filled via cross-sectional mean.
        total_cells_imputed (int): Sum of all imputed cells.
        breakdown_by_forecaster (Dict[str, Dict[str, int]]): Imputation counts per forecaster.
        breakdown_by_quarter (Dict[str, int]): Total imputation counts per quarter.
        target_column_integrity (bool): True if the GDP target column was mathematically untouched.
        date_column_integrity (bool): True if the date column was untouched.
        remaining_missing_count (int): Must be 0 for a successful imputation.
    """
    # Total count of linearly interpolated cells
    total_cells_interpolated: int
    # Total count of cross-sectional mean imputed cells
    total_cells_crosssectional_mean: int
    # Grand total of all imputed cells
    total_cells_imputed: int
    # Nested dictionary detailing counts per forecaster
    breakdown_by_forecaster: Dict[str, Dict[str, int]]
    # Dictionary detailing total imputed cells per quarter string
    breakdown_by_quarter: Dict[str, int]
    # Boolean flag confirming the target variable was not mutated
    target_column_integrity: bool
    # Boolean flag confirming the date variable was not mutated
    date_column_integrity: bool
    # Integer count of any remaining NaNs (expected 0)
    remaining_missing_count: int


def validate_imputation_and_generate_report(
    df_original: pd.DataFrame,
    df_imputed: pd.DataFrame,
    interpolated_mask: pd.DataFrame,
    cross_sectional_mask: pd.DataFrame,
    forecaster_cols: List[str],
    target_col: str,
    date_col: str
) -> ImputationAuditReport:
    """
    Validates that zero missing values remain, verifies the integrity of non-forecaster columns,
    and compiles a comprehensive audit report of the imputation transformations.

    Args:
        df_original (pd.DataFrame): The canonical panel before any imputation.
        df_imputed (pd.DataFrame): The canonical panel after all imputation steps.
        interpolated_mask (pd.DataFrame): Boolean mask of linearly interpolated cells.
        cross_sectional_mask (pd.DataFrame): Boolean mask of mean-imputed cells.
        forecaster_cols (List[str]): The list of 23 forecaster column names.
        target_col (str): The name of the GDP target column.
        date_col (str): The name of the date column.

    Returns:
        ImputationAuditReport: The structured audit record.

    Raises:
        ValueError: If missing values remain or if protected columns were mutated.
    """
    # 1. Validate Completeness
    # Sum all remaining NaNs across all forecaster columns
    remaining_missing_count = int(df_imputed[forecaster_cols].isna().sum().sum())

    if remaining_missing_count > 0:
        # Halt execution if the imputation failed to fill all gaps
        raise ValueError(f"Imputation incomplete. {remaining_missing_count} missing values remain in forecaster columns.")

    # 2. Validate Target Column Integrity
    # Use np.allclose with equal_nan=True to rigorously compare floating-point arrays
    target_integrity = bool(np.allclose(
        df_original[target_col].values,
        df_imputed[target_col].values,
        equal_nan=True
    ))

    if not target_integrity:
        # Halt execution if the target variable was corrupted
        raise ValueError(f"Fatal: The target column '{target_col}' was mutated during imputation.")

    # 3. Validate Date Column Integrity
    # Use exact string equality for the date column
    date_integrity = bool((df_original[date_col] == df_imputed[date_col]).all())

    if not date_integrity:
        # Halt execution if the temporal index was corrupted
        raise ValueError(f"Fatal: The date column '{date_col}' was mutated during imputation.")

    # 4. Compile Audit Statistics
    # Calculate global totals
    total_interpolated = int(interpolated_mask.sum().sum())
    total_cross_sectional = int(cross_sectional_mask.sum().sum())
    total_imputed = total_interpolated + total_cross_sectional

    # Compile breakdown by forecaster
    breakdown_by_forecaster = {}
    for col in forecaster_cols:
        breakdown_by_forecaster[col] = {
            "interpolated_count": int(interpolated_mask[col].sum()),
            "crosssectional_mean_count": int(cross_sectional_mask[col].sum())
        }

    # Compile breakdown by quarter
    # Sum the masks across the column axis to get row-wise totals
    interp_by_row = interpolated_mask.sum(axis=1)
    cs_by_row = cross_sectional_mask.sum(axis=1)
    total_by_row = interp_by_row + cs_by_row

    # Map the row-wise totals to the corresponding date strings, excluding quarters with 0 imputations
    breakdown_by_quarter = {
        str(date_val): int(count)
        for date_val, count in zip(df_imputed[date_col], total_by_row)
        if count > 0
    }

    # Construct and return the final immutable report
    return ImputationAuditReport(
        total_cells_interpolated=total_interpolated,
        total_cells_crosssectional_mean=total_cross_sectional,
        total_cells_imputed=total_imputed,
        breakdown_by_forecaster=breakdown_by_forecaster,
        breakdown_by_quarter=breakdown_by_quarter,
        target_column_integrity=target_integrity,
        date_column_integrity=date_integrity,
        remaining_missing_count=remaining_missing_count
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task7ImputationReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the data imputation phase. This report encapsulates the fully imputed canonical
    panel and the comprehensive audit report, providing a verifiable record that all
    missing forecaster values have been resolved according to the manuscript's
    hierarchical rules (linear interpolation followed by cross-sectional mean).

    Attributes:
        df_imputed_panel (pd.DataFrame): The finalized canonical panel where all 23
            forecaster columns are guaranteed to be complete and free of missing values.
        audit_report (ImputationAuditReport): The detailed record documenting the
            exact count and location of every imputation performed for auditability.
    """
    # The finalized, fully imputed canonical panel DataFrame ready for sample partitioning
    df_imputed_panel: pd.DataFrame
    # The comprehensive audit report documenting the transformations for the research log
    audit_report: Any  # Expected type: ImputationAuditReport

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and completeness of the imputation artifacts.

        Raises:
            TypeError: If the attributes do not match the required types.
            ValueError: If the imputed panel still contains missing values or is empty.
        """
        # Verify that df_imputed_panel is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.df_imputed_panel, pd.DataFrame):
            # Raise a TypeError if the panel data structure is incorrect
            raise TypeError("Task7ImputationReport: df_imputed_panel must be a pandas.DataFrame.")

        # Ensure the imputed panel is not empty to prevent downstream pipeline failures
        if self.df_imputed_panel.empty:
            # Raise a ValueError if the panel contains no data rows
            raise ValueError("Task7ImputationReport: df_imputed_panel cannot be empty.")

        # Verify that the audit_report is present and not None to maintain the audit trail
        if self.audit_report is None:
            # Raise a ValueError if the critical audit documentation is missing
            raise ValueError("Task7ImputationReport: audit_report cannot be None.")

        # Perform a final check for any remaining NaNs in the forecaster columns
        # This ensures the 'conclusive' requirement of the imputation task is met
        if self.df_imputed_panel.iloc[:, 1:24].isna().any().any():
            # Raise a ValueError if the imputation logic failed to fill all gaps
            raise ValueError("Task7ImputationReport: df_imputed_panel still contains missing values.")


def execute_task_7_impute_missing_values(
    df_canonical_panel: pd.DataFrame,
    study_configuration: Dict[str, Any]
) -> Task7ImputationReport:
    """
    Orchestrates Task 7: Applies linear interpolation to interior gaps, applies cross-sectional
    mean imputation to remaining gaps, and validates the integrity of the transformations.

    Args:
        df_canonical_panel (pd.DataFrame): The aligned and sorted canonical panel.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Task7ImputationReport: The comprehensive report containing the imputed panel and audit log.

    Raises:
        ValueError: If any imputation step fails or if integrity validation fails.
    """
    # Extract required column names from the configuration dictionary
    k_forecasters = study_configuration["data_inputs"]["spf_panel_wide"]["K_forecasters"]
    # Construct the list of forecaster column names programmatically
    forecaster_cols = [f"forecaster_{k:02d}" for k in range(1, k_forecasters + 1)]

    # Extract the target and date column names
    target_col = study_configuration["data_inputs"]["gdp_target_series"]["value_column"]
    date_col = study_configuration["data_inputs"]["gdp_target_series"]["date_column"]

    # Step 1: Apply linear interpolation to interior gaps
    # Execute the linear interpolation function and capture the tracking mask
    df_partially_imputed, interpolated_mask = impute_interior_gaps_linear(
        df_canonical_panel, forecaster_cols
    )

    # Step 2: Apply cross-sectional mean imputation to trailing gaps and inactive forecasters
    # Execute the cross-sectional mean function on the partially imputed DataFrame
    df_fully_imputed, cross_sectional_mask = impute_trailing_and_inactive_cross_sectional(
        df_partially_imputed, forecaster_cols
    )

    # Step 3: Validate imputation completeness and create an audit report
    # Execute the validation function comparing the original and fully imputed DataFrames
    audit_report = validate_imputation_and_generate_report(
        df_original=df_canonical_panel,
        df_imputed=df_fully_imputed,
        interpolated_mask=interpolated_mask,
        cross_sectional_mask=cross_sectional_mask,
        forecaster_cols=forecaster_cols,
        target_col=target_col,
        date_col=date_col
    )

    # Return the composite imputation report
    return Task7ImputationReport(
        df_imputed_panel=df_fully_imputed,
        audit_report=audit_report
    )

# %%
# Task 8: Mark Sample Membership on the Canonical Panel

# ==============================================================================
# Task 8: Mark Sample Membership on the Canonical Panel
# ==============================================================================

# ------------------------------------------------------------------------------
# Task 8: Helper Functions for Quarter Arithmetic
# ------------------------------------------------------------------------------

def _parse_quarter_string(q_str: str) -> Tuple[int, int]:
    """
    Parses a canonical YYYYQq string into a (year, quarter) integer tuple to facilitate
    rigorous mathematical comparisons and temporal bounding.

    Args:
        q_str (str): The quarter identifier string in the strict format 'YYYYQq'
            (e.g., '1999Q3').

    Returns:
        Tuple[int, int]: A tuple containing the year and quarter as integers
            (e.g., (1999, 3)).

    Processes:
        1. Validates input type to ensure string operations are safe.
        2. Applies a regular expression to enforce the 'YYYYQq' format.
        3. Extracts the year component via string slicing and casts to integer.
        4. Extracts the quarter component via string slicing and casts to integer.

    Raises:
        TypeError: If the input q_str is not a string.
        ValueError: If the string does not match the required 'YYYYQq' format.
    """
    # Validate that the input is a string to prevent attribute errors during regex matching
    if not isinstance(q_str, str):
        # Raise a TypeError if the input does not meet the string requirement
        raise TypeError(f"Input q_str must be a string. Received: {type(q_str)}")

    # Strictly validate the format using a regular expression to prevent downstream data corruption
    if not re.match(r"^\d{4}Q[1-4]$", q_str):
        # Raise a ValueError if the string deviates from the canonical YYYYQq format
        raise ValueError(f"Invalid quarter format: {q_str}. Expected YYYYQq.")

    # Extract the year from the first four characters of the string and convert to an integer
    year = int(q_str[:4])

    # Extract the quarter digit from the sixth character of the string and convert to an integer
    quarter = int(q_str[5])

    # Return the parsed year and quarter as a tuple for rigorous mathematical comparison
    return year, quarter


def _increment_quarter(year: int, quarter: int) -> Tuple[int, int]:
    """
    Increments a (year, quarter) integer tuple by exactly one quarter, handling
    the rollover from Q4 to Q1 of the subsequent year.

    Args:
        year (int): The four-digit year as an integer.
        quarter (int): The quarter digit as an integer (must be in [1, 2, 3, 4]).

    Returns:
        Tuple[int, int]: A tuple containing the incremented year and quarter.

    Processes:
        1. Validates that the input quarter is within the mathematically valid range.
        2. Increments the quarter digit by one.
        3. Checks for year rollover if the incremented quarter exceeds 4.
        4. Adjusts the year and resets the quarter to 1 if rollover occurs.

    Raises:
        ValueError: If the input quarter is not in the range [1, 4].
    """
    # Validate that the input quarter is within the valid range [1, 4] to ensure logical consistency
    if not (1 <= quarter <= 4):
        # Raise a ValueError if the input quarter is mathematically invalid for a quarterly series
        raise ValueError(f"Invalid quarter: {quarter}. Must be an integer in [1, 4].")

    # Increment the quarter digit by exactly one unit
    next_q = quarter + 1

    # Initialize the next year as the current year before checking for rollover
    next_y = year

    # Handle the rollover logic if the incremented quarter exceeds the maximum value of 4
    if next_q > 4:
        # Reset the quarter digit to 1 for the start of the new year
        next_q = 1
        # Increment the year count by exactly one unit
        next_y += 1

    # Return the mathematically incremented year and quarter as a tuple
    return next_y, next_q

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Step 1: Create search-sample indicators
# -------------------------------------------------------------------------------------------------------------------------------

def mark_search_sample(
    df_canonical_panel: pd.DataFrame,
    index_map: pd.DataFrame,
    study_configuration: Dict[str, Any]
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Adds a boolean indicator for the search sample to the canonical panel and updates the index map.

    Args:
        df_canonical_panel (pd.DataFrame): The imputed canonical panel.
        index_map (pd.DataFrame): The standing index map.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Tuple[pd.DataFrame, pd.DataFrame]: The updated canonical panel and index map (deep copies).

    Raises:
        ValueError: If the number of search sample rows does not exactly match the configuration.
    """
    # Create deep copies to ensure functional purity and preserve the audit trail
    df_marked = df_canonical_panel.copy(deep=True)
    idx_map_marked = index_map.copy(deep=True)

    # Extract the search sample temporal bounds from the configuration
    start_str = study_configuration["sample_design"]["search_sample"]["start"]
    end_str = study_configuration["sample_design"]["search_sample"]["end"]
    expected_count = study_configuration["sample_design"]["search_sample"]["total_rows"]

    # Parse the bounds into comparable integer tuples
    start_tuple = _parse_quarter_string(start_str)
    end_tuple = _parse_quarter_string(end_str)

    # Initialize a list to hold the boolean mask values
    is_search_mask = []

    # Iterate over the date column to evaluate the mathematical bounds for each row
    for date_val in df_marked["date"]:
        # Parse the current row's date
        current_tuple = _parse_quarter_string(str(date_val))
        # Evaluate if the date falls within the closed interval [start, end]
        is_in_search = start_tuple <= current_tuple <= end_tuple
        # Append the boolean result to the mask list
        is_search_mask.append(is_in_search)

    # Assign the boolean mask as a new column in the canonical panel
    df_marked["is_search_sample"] = is_search_mask

    # Update the sample_membership column in the index map where the mask is True
    idx_map_marked.loc[is_search_mask, "sample_membership"] = "search"

    # Rigorously validate that the number of flagged rows exactly matches the expected count
    actual_count = sum(is_search_mask)
    if actual_count != expected_count:
        # Halt execution immediately if the count is incorrect
        raise ValueError(
            f"Search sample count mismatch. Expected {expected_count} rows between "
            f"{start_str} and {end_str}, but found {actual_count}."
        )

    # Return the updated DataFrames
    return df_marked, idx_map_marked

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Step 2: Create holdout and COVID-exclusion indicators
# -------------------------------------------------------------------------------------------------------------------------------

def mark_holdout_and_covid_samples(
    df_marked: pd.DataFrame,
    idx_map_marked: pd.DataFrame,
    study_configuration: Dict[str, Any]
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Adds boolean indicators for the holdout sample, COVID quarters, and holdout-excluding-COVID
    to the canonical panel, and updates the index map accordingly.

    Args:
        df_marked (pd.DataFrame): The canonical panel with search sample indicators.
        idx_map_marked (pd.DataFrame): The index map with search sample indicators.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Tuple[pd.DataFrame, pd.DataFrame]: The updated canonical panel and index map.

    Raises:
        ValueError: If row counts mismatch or if COVID quarters fall outside the holdout bounds.
    """
    # Extract the holdout temporal bounds and expected counts from the configuration
    h_start_str = study_configuration["sample_design"]["holdout_sample"]["start"]
    h_end_str = study_configuration["sample_design"]["holdout_sample"]["end"]
    expected_h_count = study_configuration["sample_design"]["holdout_sample"]["quarters"]

    # Extract the explicit list of COVID quarters and expected counts
    covid_quarters = study_configuration["researcher_only_holdout_inputs"]["covid_quarters"]
    expected_covid_count = len(covid_quarters)
    expected_h_ex_covid_count = study_configuration["sample_design"]["holdout_excluding_covid"]["quarters"]

    # Parse the holdout bounds into comparable integer tuples
    h_start_tuple = _parse_quarter_string(h_start_str)
    h_end_tuple = _parse_quarter_string(h_end_str)

    # Initialize a list to hold the holdout boolean mask values
    is_holdout_mask = []

    # Iterate over the date column to evaluate the mathematical bounds for the holdout
    for date_val in df_marked["date"]:
        # Parse the current row's date
        current_tuple = _parse_quarter_string(str(date_val))
        # Evaluate if the date falls within the closed interval [h_start, h_end]
        is_in_holdout = h_start_tuple <= current_tuple <= h_end_tuple
        # Append the boolean result to the mask list
        is_holdout_mask.append(is_in_holdout)

    # Assign the holdout boolean mask as a new column
    df_marked["is_holdout"] = is_holdout_mask

    # Create the COVID mask using exact set membership against the configured list
    df_marked["is_covid"] = df_marked["date"].isin(covid_quarters)

    # Create the holdout-excluding-COVID mask using bitwise logical AND and NOT
    df_marked["is_holdout_ex_covid"] = df_marked["is_holdout"] & ~df_marked["is_covid"]

    # Update the sample_membership column in the index map where the holdout mask is True
    idx_map_marked.loc[is_holdout_mask, "sample_membership"] = "holdout"
    # Add the COVID flag directly to the index map
    idx_map_marked["covid_flag"] = df_marked["is_covid"]

    # 1. Validate that all COVID quarters strictly fall within the holdout period
    covid_outside_holdout = (df_marked["is_covid"] & ~df_marked["is_holdout"]).sum()
    if covid_outside_holdout > 0:
        # Halt execution if the subset invariant is violated
        raise ValueError("Fatal: Detected COVID quarters that fall outside the defined holdout bounds.")

    # 2. Validate the exact row counts for all three indicators
    actual_h_count = df_marked["is_holdout"].sum()
    actual_covid_count = df_marked["is_covid"].sum()
    actual_h_ex_covid_count = df_marked["is_holdout_ex_covid"].sum()

    # Only validate holdout counts if holdout rows are actually present (e.g., not a search-only panel)
    if actual_h_count > 0:
        if actual_h_count != expected_h_count:
            raise ValueError(f"Holdout count mismatch. Expected {expected_h_count}, found {actual_h_count}.")
        if actual_covid_count != expected_covid_count:
            raise ValueError(f"COVID count mismatch. Expected {expected_covid_count}, found {actual_covid_count}.")
        if actual_h_ex_covid_count != expected_h_ex_covid_count:
            raise ValueError(f"Holdout ex-COVID count mismatch. Expected {expected_h_ex_covid_count}, found {actual_h_ex_covid_count}.")

    # Return the fully marked DataFrames
    return df_marked, idx_map_marked

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Step 3: Validate the formal data partition
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class PartitionValidationReport:
    """
    A structured record documenting the mathematical verification of the formal data partition D = (D^S, D^H).

    Attributes:
        partition_valid (bool): True if all partition invariants hold.
        non_overlapping (bool): True if D^S intersect D^H is empty.
        jointly_exhaustive (bool): True if D^S union D^H equals D (for full panels).
        total_count_valid (bool): True if the sum of subset counts equals the total row count.
        temporally_contiguous (bool): True if max(D^S) is exactly adjacent to min(D^H).
        error_message (Optional[str]): Description of any invariant violation.
    """
    # Overall validity flag
    partition_valid: bool
    # Flag for empty intersection
    non_overlapping: bool
    # Flag for complete union
    jointly_exhaustive: bool
    # Flag for count consistency
    total_count_valid: bool
    # Flag for temporal adjacency without gaps
    temporally_contiguous: bool
    # Optional error message for failures
    error_message: Optional[str] = None


def validate_formal_data_partition(
    df_marked: pd.DataFrame,
    declared_panel_scope: Optional[str] = None
) -> PartitionValidationReport:
    """
    Mathematically verifies that the search and holdout samples form a valid, non-overlapping,
    and temporally contiguous partition of the dataset.

    Args:
        df_marked (pd.DataFrame): The fully marked canonical panel.
        declared_panel_scope (Optional[str]): The declared scope of the panel.

    Returns:
        PartitionValidationReport: The structured validation record.
    """
    error_message = None

    # 1. Verify Non-Overlap: D^S \cap D^H = \emptyset
    # Compute the bitwise AND of the two masks and sum the True values
    overlap_count = (df_marked["is_search_sample"] & df_marked["is_holdout"]).sum()
    non_overlapping = (overlap_count == 0)

    if not non_overlapping:
        error_message = f"Partition violation: {overlap_count} rows belong to both search and holdout samples."

    # 2. Verify Joint Exhaustiveness: D^S \cup D^H = D
    # This is only strictly required if the panel is declared as the full 106-row panel
    if declared_panel_scope == "full_panel":
        # Compute the bitwise OR and check if all rows are True
        jointly_exhaustive = bool((df_marked["is_search_sample"] | df_marked["is_holdout"]).all())
        if not jointly_exhaustive:
            unassigned_count = (~(df_marked["is_search_sample"] | df_marked["is_holdout"])).sum()
            error_message = f"Partition violation: {unassigned_count} rows belong to neither sample in a full panel."
    else:
        # For partial panels, we assume exhaustiveness holds for the provided subset
        jointly_exhaustive = True

    # 3. Verify Total Count Consistency
    # The sum of the individual counts must equal the total row count (if full panel)
    total_rows = len(df_marked)
    search_count = df_marked["is_search_sample"].sum()
    holdout_count = df_marked["is_holdout"].sum()

    if declared_panel_scope == "full_panel":
        total_count_valid = (search_count + holdout_count == total_rows)
        if not total_count_valid:
            error_message = f"Count violation: {search_count} (search) + {holdout_count} (holdout) != {total_rows} (total)."
    else:
        total_count_valid = True

    # 4. Verify Temporal Contiguity: max(D^S) + 1 quarter == min(D^H)
    temporally_contiguous = True
    if search_count > 0 and holdout_count > 0:
        # Extract the maximum date string from the search sample
        max_search_date = df_marked.loc[df_marked["is_search_sample"], "date"].max()
        # Extract the minimum date string from the holdout sample
        min_holdout_date = df_marked.loc[df_marked["is_holdout"], "date"].min()

        # Parse both boundary dates into tuples
        max_s_tuple = _parse_quarter_string(str(max_search_date))
        min_h_tuple = _parse_quarter_string(str(min_holdout_date))

        # Mathematically increment the max search quarter by exactly one quarter
        expected_min_h_tuple = _increment_quarter(max_s_tuple[0], max_s_tuple[1])

        # Verify that the incremented search boundary exactly equals the holdout boundary
        if expected_min_h_tuple != min_h_tuple:
            temporally_contiguous = False
            error_message = (
                f"Contiguity violation: Search ends at {max_search_date}, "
                f"but holdout begins at {min_holdout_date}. Expected no gaps."
            )

    # The partition is valid if and only if all invariants hold
    partition_valid = non_overlapping and jointly_exhaustive and total_count_valid and temporally_contiguous

    # Return the comprehensive validation report
    return PartitionValidationReport(
        partition_valid=partition_valid,
        non_overlapping=non_overlapping,
        jointly_exhaustive=jointly_exhaustive,
        total_count_valid=total_count_valid,
        temporally_contiguous=temporally_contiguous,
        error_message=error_message
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task8SampleMembershipReport:
    """
    A structured, implementation-grade container for the artifacts produced during the
    sample membership marking phase. This report encapsulates the fully marked canonical
    panel, the updated index map, and the formal mathematical verification of the
    data partition D = (D^S, D^H), ensuring that the search and holdout samples are
    non-overlapping and temporally contiguous.

    Attributes:
        df_marked_panel (pd.DataFrame): The canonical panel augmented with boolean
            indicators: 'is_search_sample', 'is_holdout', 'is_covid', and 'is_holdout_ex_covid'.
        index_map_marked (pd.DataFrame): The standing index map updated with
            'sample_membership' strings and 'covid_flag' booleans for positional alignment.
        partition_validation (Any): An instance of PartitionValidationReport documenting
            the mathematical proof of non-overlap and joint exhaustiveness.
    """
    # The canonical panel with all sample membership boolean columns appended for slicing
    df_marked_panel: pd.DataFrame
    # The index map updated with sample membership labels and COVID flags for the audit trail
    index_map_marked: pd.DataFrame
    # The mathematical verification report of the formal data partition D = (D^S, D^H)
    partition_validation: Any  # Expected type: PartitionValidationReport

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and consistency of the sample membership artifacts.

        Raises:
            TypeError: If any attribute does not match the required type.
            ValueError: If the DataFrames are empty or missing required indicator columns.
        """
        # Verify that df_marked_panel is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.df_marked_panel, pd.DataFrame):
            # Raise a TypeError if the panel data structure is incorrect
            raise TypeError("Task8SampleMembershipReport: df_marked_panel must be a pandas.DataFrame.")

        # Verify that index_map_marked is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.index_map_marked, pd.DataFrame):
            # Raise a TypeError if the index map data structure is incorrect
            raise TypeError("Task8SampleMembershipReport: index_map_marked must be a pandas.DataFrame.")

        # Ensure the marked panel is not empty to prevent downstream slicing failures
        if self.df_marked_panel.empty:
            # Raise a ValueError if the panel contains no data rows
            raise ValueError("Task8SampleMembershipReport: df_marked_panel cannot be empty.")

        # Define the set of required boolean indicator columns for the marked panel
        required_panel_cols = {"is_search_sample", "is_holdout", "is_covid", "is_holdout_ex_covid"}

        # Check for the presence of all required indicators in the panel schema
        if not required_panel_cols.issubset(self.df_marked_panel.columns):
            # Identify the specific missing indicators for the error message
            missing = required_panel_cols - set(self.df_marked_panel.columns)
            # Raise a ValueError if the sample marking is incomplete
            raise ValueError(f"Task8SampleMembershipReport: df_marked_panel missing indicators: {missing}")

        # Verify that the partition_validation report is present and not None
        if self.partition_validation is None:
            # Raise a ValueError if the critical partition verification is missing
            raise ValueError("Task8SampleMembershipReport: partition_validation cannot be None.")


def execute_task_8_mark_sample_membership(
    df_canonical_panel: pd.DataFrame,
    index_map: pd.DataFrame,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None
) -> Task8SampleMembershipReport:
    """
    Orchestrates Task 8: Appends boolean indicators for the search sample, holdout sample,
    and COVID quarters to the canonical panel, updates the index map, and mathematically
    verifies the integrity of the formal data partition.

    Args:
        df_canonical_panel (pd.DataFrame): The imputed canonical panel.
        index_map (pd.DataFrame): The standing index map.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope of the panel.

    Returns:
        Task8SampleMembershipReport: The comprehensive report containing the marked artifacts.

    Raises:
        ValueError: If any marking step fails or if the formal partition is invalid.
    """
    # Step 1: Create search-sample indicators
    # Execute the search sample marking function, which returns deep copies
    df_step1, idx_map_step1 = mark_search_sample(
        df_canonical_panel, index_map, study_configuration
    )

    # Step 2: Create holdout and COVID-exclusion indicators
    # Execute the holdout and COVID marking function on the outputs of Step 1
    df_step2, idx_map_step2 = mark_holdout_and_covid_samples(
        df_step1, idx_map_step1, study_configuration
    )

    # Step 3: Validate the formal data partition
    # Execute the mathematical verification of the partition invariants
    partition_report = validate_formal_data_partition(
        df_step2, declared_panel_scope
    )

    # Enforce the fail-fast mandate: halt immediately if the partition is invalid
    if not partition_report.partition_valid:
        raise ValueError(f"Task 8 Step 3 Failed: Formal data partition is invalid. {partition_report.error_message}")

    # Return the composite sample membership report
    return Task8SampleMembershipReport(
        df_marked_panel=df_step2,
        index_map_marked=idx_map_step2,
        partition_validation=partition_report
    )

# %%
# Task 9: Separate the Holdout from the Discovery Workspace

# ==============================================================================
# Task 9: Separate the Holdout from the Discovery Workspace
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Step 1: Physically isolate holdout data
# -------------------------------------------------------------------------------------------------------------------------------

def isolate_holdout_data(
    df_marked_panel: pd.DataFrame,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Physically separates the canonical panel into disjoint search and holdout DataFrames,
    resetting their indices to ensure clean positional slicing for downstream evaluators.

    Args:
        df_marked_panel (pd.DataFrame): The canonical panel with sample membership indicators.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope of the panel.

    Returns:
        Tuple[pd.DataFrame, pd.DataFrame]: The isolated search panel and holdout panel (deep copies).

    Raises:
        ValueError: If the resulting row counts do not match the configuration expectations.
    """
    # Extract the search sample using vectorized boolean indexing and create a deep copy
    df_search_panel = df_marked_panel[df_marked_panel["is_search_sample"]].copy(deep=True)

    # Extract the holdout sample using vectorized boolean indexing and create a deep copy
    df_holdout_panel = df_marked_panel[df_marked_panel["is_holdout"]].copy(deep=True)

    # Reset the integer index for the search panel to establish a contiguous 0-based sequence
    df_search_panel = df_search_panel.reset_index(drop=True)

    # Reset the integer index for the holdout panel to establish a contiguous 0-based sequence
    df_holdout_panel = df_holdout_panel.reset_index(drop=True)

    # Extract expected row counts from the configuration
    expected_search_count = study_configuration["sample_design"]["search_sample"]["total_rows"]
    expected_holdout_count = study_configuration["sample_design"]["holdout_sample"]["quarters"]

    # Validate the search panel row count
    if len(df_search_panel) != expected_search_count:
        # Halt execution if the search sample size is incorrect
        raise ValueError(
            f"Search panel isolation failed. Expected {expected_search_count} rows, "
            f"but extracted {len(df_search_panel)}."
        )

    # Validate the holdout panel row count, conditional on the declared scope
    if declared_panel_scope in ["full_panel", "holdout_only"]:
        if len(df_holdout_panel) != expected_holdout_count:
            # Halt execution if the holdout sample size is incorrect when expected
            raise ValueError(
                f"Holdout panel isolation failed. Expected {expected_holdout_count} rows, "
                f"but extracted {len(df_holdout_panel)}."
            )

    # Return the strictly isolated and index-reset DataFrames
    return df_search_panel, df_holdout_panel

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Step 2: Verify that the evaluator will load only the search sample
# -------------------------------------------------------------------------------------------------------------------------------

def verify_evaluator_data_constraints(study_configuration: Dict[str, Any]) -> bool:
    """
    Verifies the architectural invariants that guarantee the evaluator will only load
    the search sample during the discovery phase, preventing look-ahead bias.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        bool: True if the architectural constraints are strictly satisfied.

    Raises:
        ValueError: If the required configuration keys are missing or violate the constraints.
    """
    try:
        # Extract the constraint flag for loading only the search sample
        loads_search_only = study_configuration["prepare_script_data"]["loads_search_sample_only_during_discovery"]

        # Extract the constraint flag ensuring the holdout is not loaded
        holdout_loaded = study_configuration["prepare_script_data"]["holdout_loaded_during_discovery"]

    except KeyError as e:
        # Halt execution if the architectural constraints are not defined
        raise ValueError(f"Missing required architectural constraint in configuration: {e}")

    # Enforce strict boolean type checking to prevent truthy/falsy ambiguity
    if not isinstance(loads_search_only, bool) or not isinstance(holdout_loaded, bool):
        raise ValueError("Architectural constraint flags must be strict booleans.")

    # Evaluate the mathematical logic: loads_search_only MUST be True AND holdout_loaded MUST be False
    constraints_satisfied = (loads_search_only is True) and (holdout_loaded is False)

    if not constraints_satisfied:
        # Halt execution if the constraints are violated, as this compromises the entire study
        raise ValueError(
            f"Architectural constraint violation. loads_search_sample_only_during_discovery "
            f"must be True (found {loads_search_only}) and holdout_loaded_during_discovery "
            f"must be False (found {holdout_loaded})."
        )

    # Return confirmation of compliance
    return constraints_satisfied

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Step 3: Produce a holdout-isolation audit note
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class HoldoutIsolationAuditNote:
    """
    A structured, immutable record documenting the physical and logical isolation measures
    applied to the holdout dataset to prevent undisclosed specification search.

    Attributes:
        holdout_object_location (str): Description of where the holdout data is stored.
        discovery_evaluator_data_source (str): Description of the data exposed to the evaluator.
        holdout_passed_to_discovery_evaluator (bool): Must be False.
        holdout_passed_to_editable_callable (bool): Must be False.
        internet_access_during_discovery (str): The documented internet access policy.
        filesystem_access_during_discovery (str): The documented filesystem access policy.
        isolation_level (str): Classification of the isolation rigor (e.g., 'logical_only').
    """
    # Location of the holdout data
    holdout_object_location: str
    # Data source for the discovery evaluator
    discovery_evaluator_data_source: str
    # Flag confirming holdout is hidden from evaluator
    holdout_passed_to_discovery_evaluator: bool
    # Flag confirming holdout is hidden from the agent's editable script
    holdout_passed_to_editable_callable: bool
    # Documented internet policy
    internet_access_during_discovery: str
    # Documented filesystem policy
    filesystem_access_during_discovery: str
    # Classification of the isolation mechanism
    isolation_level: str


def generate_isolation_audit_note(
    df_search_panel: pd.DataFrame,
    study_configuration: Dict[str, Any]
) -> HoldoutIsolationAuditNote:
    """
    Compiles a structured audit note detailing the isolation policies and residual risks
    associated with the agentic discovery environment.

    Args:
        df_search_panel (pd.DataFrame): The isolated search panel.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        HoldoutIsolationAuditNote: The comprehensive isolation audit record.
    """
    # Extract the temporal bounds of the search panel for documentation
    if not df_search_panel.empty:
        search_start = df_search_panel["date"].iloc[0]
        search_end = df_search_panel["date"].iloc[-1]
        search_rows = len(df_search_panel)
        evaluator_source_desc = f"df_search_panel ({search_rows} rows, {search_start}-{search_end})"
    else:
        evaluator_source_desc = "df_search_panel (Empty)"

    # Extract the internet access policy from the agent specification
    internet_policy = study_configuration["search_protocol"]["agent_specification"].get("internet_access_policy")

    if internet_policy is None:
        # Inject standardized warning if the policy is unspecified
        internet_desc = (
            "Internet access policy was not specified in the manuscript. "
            "Residual look-ahead risk from internet access cannot be ruled out."
        )
    else:
        internet_desc = str(internet_policy)

    # Extract the filesystem permission policy from the agent specification
    fs_policy = study_configuration["search_protocol"]["agent_specification"].get("filesystem_permission_policy")

    if fs_policy is None:
        # Inject standardized warning if the policy is unspecified
        fs_desc = (
            "Filesystem permission policy was not specified in the manuscript. "
            "Residual look-ahead risk from local file access cannot be ruled out."
        )
    else:
        fs_desc = str(fs_policy)

    # Define the isolation level based on the Python implementation architecture
    # Since the holdout is held in a separate variable within the same process, it is 'logical_only'
    isolation_level = "logical_only"

    # Define the storage location description
    holdout_location = "Separate Python variable (df_holdout_panel) not passed to any discovery-phase callable."

    # Construct and return the immutable audit note
    return HoldoutIsolationAuditNote(
        holdout_object_location=holdout_location,
        discovery_evaluator_data_source=evaluator_source_desc,
        holdout_passed_to_discovery_evaluator=False,
        holdout_passed_to_editable_callable=False,
        internet_access_during_discovery=internet_desc,
        filesystem_access_during_discovery=fs_desc,
        isolation_level=isolation_level
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task9HoldoutSeparationReport:
    """
    A structured, implementation-grade container for the artifacts produced during the
    physical and logical separation of the search and holdout samples. This report
    encapsulates the isolated DataFrames and the formal audit note, providing a
    verifiable record that the holdout data (D^H) has been strictly air-gapped
    from the discovery workspace to prevent look-ahead bias and undisclosed
    specification search.

    Attributes:
        df_search_panel (pd.DataFrame): The isolated search sample (D^S) containing
            exactly 70 rows (1999Q3-2016Q4), ready for the discovery phase.
        df_holdout_panel (pd.DataFrame): The isolated holdout sample (D^H) containing
            exactly 36 rows (2017Q1-2025Q4), strictly withheld from the agent.
        isolation_audit_note (Any): An instance of HoldoutIsolationAuditNote
            documenting the isolation rigor, internet policies, and residual risks.
    """
    # The isolated search sample DataFrame, safe for exposure to the discovery evaluator
    df_search_panel: pd.DataFrame
    # The isolated holdout sample DataFrame, strictly air-gapped from the agent's workspace
    df_holdout_panel: pd.DataFrame
    # The comprehensive audit note documenting the isolation measures and policies
    isolation_audit_note: Any  # Expected type: HoldoutIsolationAuditNote

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and isolation of the separated data artifacts before discovery begins.

        Raises:
            TypeError: If any attribute does not match the required type.
            ValueError: If the DataFrames are empty or the audit note is missing.
        """
        # Verify that df_search_panel is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.df_search_panel, pd.DataFrame):
            # Raise a TypeError if the search panel data structure is incorrect
            raise TypeError("Task9HoldoutSeparationReport: df_search_panel must be a pandas.DataFrame.")

        # Verify that df_holdout_panel is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.df_holdout_panel, pd.DataFrame):
            # Raise a TypeError if the holdout panel data structure is incorrect
            raise TypeError("Task9HoldoutSeparationReport: df_holdout_panel must be a pandas.DataFrame.")

        # Ensure the search panel is not empty to prevent downstream evaluator failures
        if self.df_search_panel.empty:
            # Raise a ValueError if the search sample contains no data
            raise ValueError("Task9HoldoutSeparationReport: df_search_panel cannot be empty.")

        # Verify that the isolation_audit_note is present and not None
        if self.isolation_audit_note is None:
            # Raise a ValueError if the critical audit documentation is missing
            raise ValueError("Task9HoldoutSeparationReport: isolation_audit_note cannot be None.")


def execute_task_9_separate_holdout(
    df_marked_panel: pd.DataFrame,
    study_configuration: Dict[str, Any],
    declared_panel_scope: Optional[str] = None
) -> Task9HoldoutSeparationReport:
    """
    Orchestrates Task 9: Physically isolates the holdout data from the search sample,
    verifies the architectural constraints of the evaluator, and generates the isolation audit note.

    Args:
        df_marked_panel (pd.DataFrame): The canonical panel with sample membership indicators.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        declared_panel_scope (Optional[str]): The declared scope of the panel.

    Returns:
        Task9HoldoutSeparationReport: The comprehensive separation report.

    Raises:
        ValueError: If physical isolation fails or architectural constraints are violated.
    """
    # Step 1: Verify that the evaluator will load only the search sample
    # We execute this architectural check first to fail-fast before data manipulation
    constraints_valid = verify_evaluator_data_constraints(study_configuration)

    if not constraints_valid:
        # This branch is technically unreachable due to the exception raised in the step function,
        # but included for logical completeness.
        raise ValueError("Task 9 Step 2 Failed: Evaluator architectural constraints violated.")

    # Step 2: Physically isolate holdout data
    # Execute the slicing and index reset operations
    df_search_panel, df_holdout_panel = isolate_holdout_data(
        df_marked_panel, study_configuration, declared_panel_scope
    )

    # Step 3: Produce a holdout-isolation audit note
    # Compile the documentation regarding policies and residual risks
    audit_note = generate_isolation_audit_note(
        df_search_panel, study_configuration
    )

    # Return the composite separation report
    return Task9HoldoutSeparationReport(
        df_search_panel=df_search_panel,
        df_holdout_panel=df_holdout_panel,
        isolation_audit_note=audit_note
    )

# %%
# Task 10: Construct the Lambda Grids Exactly

# ==============================================================================
# Task 10: Construct the Lambda Grids Exactly
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 10, Step 1: Read the grid specification from the configuration
# -------------------------------------------------------------------------------------------------------------------------------

def extract_lambda_grid_parameters(study_configuration: Dict[str, Any]) -> Tuple[int, float, float]:
    """
    Extracts and rigorously validates the scalar parameters required to construct
    the regularization lambda grids from the study configuration.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Tuple[int, float, float]: A tuple containing (grid_points, log_lambda_start, log_lambda_end).

    Raises:
        ValueError: If keys are missing, types are invalid, or mathematical logic is violated.
    """
    try:
        # Navigate the nested dictionary to extract the grid specification block
        grid_spec = study_configuration["prepare_script_data"]["lambda_grid_specification"]

        # Extract and explicitly cast the parameters to enforce strict typing
        grid_points = int(grid_spec["grid_points"])
        log_lambda_start = float(grid_spec["log_lambda_start"])
        log_lambda_end = float(grid_spec["log_lambda_end"])

    except KeyError as e:
        # Halt execution if the required configuration keys are absent
        raise ValueError(f"Missing required lambda grid configuration key: {e}")
    except (TypeError, ValueError) as e:
        # Halt execution if the values cannot be cast to the required numeric types
        raise ValueError(f"Invalid data type for lambda grid parameters: {e}")

    # Enforce the mathematical requirement that the grid must be strictly decreasing
    # Regularization paths conventionally start with heavy penalty (large lambda) and decrease
    if log_lambda_start <= log_lambda_end:
        raise ValueError(
            f"Mathematical violation: log_lambda_start ({log_lambda_start}) must be "
            f"strictly greater than log_lambda_end ({log_lambda_end})."
        )

    # Enforce a minimum number of grid points to ensure a dense path
    if grid_points < 2:
        raise ValueError(f"Mathematical violation: grid_points ({grid_points}) must be at least 2.")

    # Return the validated parameters
    return grid_points, log_lambda_start, log_lambda_end

# -------------------------------------------------------------------------------------------------------------------------------
# Task 10, Step 2: Compute both grids using the exact construction rule
# -------------------------------------------------------------------------------------------------------------------------------

def construct_lambda_grids(
    grid_points: int,
    log_lambda_start: float,
    log_lambda_end: float
) -> Tuple[np.ndarray, np.ndarray]:
    """
    Constructs two identical, independent 1D numpy arrays representing the lambda grid,
    using the exact exponential decay formula specified in the manuscript.

    Args:
        grid_points (int): The number of elements in the grid (e.g., 200).
        log_lambda_start (float): The natural log of the first (largest) lambda value (e.g., 15.0).
        log_lambda_end (float): The natural log of the last (smallest) lambda value (e.g., -15.0).

    Returns:
        Tuple[np.ndarray, np.ndarray]: Two independent numpy arrays of shape (grid_points,) and dtype float64.
    """
    # Construct the log-lambda grid: a dense array of linearly spaced points.
    # numpy.linspace guarantees the exact inclusion of both endpoints.
    # We explicitly enforce float64 (double precision) to prevent underflow during exponentiation.
    log_lambda_grid = np.linspace(
        start=log_lambda_start,
        stop=log_lambda_end,
        num=grid_points,
        dtype=np.float64
    )

    # Apply the exponential function element-wise to transform from log-space to lambda-space.
    # Equation: lambda_j = exp(15 - 30*(j-1)/199)
    lambda_grid = np.exp(log_lambda_grid)

    # Construct the second grid as an independent, deep copy of the first.
    # This is critical to prevent downstream mutation of one grid from affecting the other
    # during the two-step peLASSO estimation process.
    lambda_grid2 = lambda_grid.copy()

    # Return the two independent arrays
    return lambda_grid, lambda_grid2

# -------------------------------------------------------------------------------------------------------------------------------
# Task 10, Step 3: Validate the grid endpoints
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class GridValidationReport:
    """
    A structured, immutable record documenting the mathematical verification of the lambda grids.

    Attributes:
        passed (bool): True if all mathematical invariants hold.
        first_element_valid (bool): True if grid[0] matches exp(log_lambda_start) within tolerance.
        last_element_valid (bool): True if grid[-1] matches exp(log_lambda_end) within tolerance.
        strictly_decreasing (bool): True if the grid is strictly monotonically decreasing.
        grids_identical (bool): True if grid1 and grid2 are numerically identical.
        grids_distinct_objects (bool): True if grid1 and grid2 occupy different memory locations.
        length_valid (bool): True if the grid length matches the expected grid_points.
        error_message (Optional[str]): Description of any invariant violation.
    """
    # Overall validity flag
    passed: bool
    # Flag for upper bound accuracy
    first_element_valid: bool
    # Flag for lower bound accuracy
    last_element_valid: bool
    # Flag for monotonic decrease
    strictly_decreasing: bool
    # Flag for numerical equality between the two grids
    grids_identical: bool
    # Flag for memory isolation between the two grids
    grids_distinct_objects: bool
    # Flag for correct dimensionality
    length_valid: bool
    # Optional error message for failures
    error_message: Optional[str] = None


def validate_lambda_grids(
    lambda_grid: np.ndarray,
    lambda_grid2: np.ndarray,
    expected_points: int,
    expected_log_start: float,
    expected_log_end: float
) -> GridValidationReport:
    """
    Mathematically verifies the integrity, bounds, monotonicity, and memory isolation
    of the generated lambda grids.

    Args:
        lambda_grid (np.ndarray): The primary lambda grid.
        lambda_grid2 (np.ndarray): The secondary lambda grid.
        expected_points (int): The expected number of elements.
        expected_log_start (float): The expected natural log of the first element.
        expected_log_end (float): The expected natural log of the last element.

    Returns:
        GridValidationReport: The structured validation record.
    """
    error_message = None

    # 1. Validate Dimensionality
    length_valid = (len(lambda_grid) == expected_points) and (len(lambda_grid2) == expected_points)
    if not length_valid:
        error_message = f"Dimensionality violation: Expected {expected_points} points, got {len(lambda_grid)}."

    # 2. Validate Upper Bound (First Element)
    # Compute the exact mathematical reference value
    ref_start = math.exp(expected_log_start)
    # Use relative tolerance (1e-6) because the absolute value is very large (~3.2e6)
    first_element_valid = bool(np.isclose(lambda_grid[0], ref_start, rtol=1e-6, atol=0.0))
    if not first_element_valid:
        error_message = f"Upper bound violation: Expected ~{ref_start}, got {lambda_grid[0]}."

    # 3. Validate Lower Bound (Last Element)
    # Compute the exact mathematical reference value
    ref_end = math.exp(expected_log_end)
    # Use relative tolerance (1e-6) because the absolute value is very small (~3.0e-7)
    last_element_valid = bool(np.isclose(lambda_grid[-1], ref_end, rtol=1e-6, atol=0.0))
    if not last_element_valid:
        error_message = f"Lower bound violation: Expected ~{ref_end}, got {lambda_grid[-1]}."

    # 4. Validate Strict Monotonic Decrease
    # Compute the first discrete difference; all values must be strictly less than 0
    strictly_decreasing = bool(np.all(np.diff(lambda_grid) < 0))
    if not strictly_decreasing:
        error_message = "Monotonicity violation: The grid is not strictly decreasing."

    # 5. Validate Numerical Identity
    # The two grids must contain the exact same floating-point values
    grids_identical = bool(np.array_equal(lambda_grid, lambda_grid2))
    if not grids_identical:
        error_message = "Identity violation: lambda_grid and lambda_grid2 are not numerically identical."

    # 6. Validate Memory Isolation
    # The two grids must not be references to the same underlying object
    grids_distinct_objects = (lambda_grid is not lambda_grid2)
    if not grids_distinct_objects:
        error_message = "Memory violation: lambda_grid and lambda_grid2 point to the same object."

    # The grids are valid if and only if all mathematical and structural invariants hold
    passed = (
        length_valid and
        first_element_valid and
        last_element_valid and
        strictly_decreasing and
        grids_identical and
        grids_distinct_objects
    )

    # Return the comprehensive validation report
    return GridValidationReport(
        passed=passed,
        first_element_valid=first_element_valid,
        last_element_valid=last_element_valid,
        strictly_decreasing=strictly_decreasing,
        grids_identical=grids_identical,
        grids_distinct_objects=grids_distinct_objects,
        length_valid=length_valid,
        error_message=error_message
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 10, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task10LambdaGridReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the high-dimensional regularization grid construction. This report encapsulates
    the primary and secondary lambda grids alongside their rigorous mathematical
    validation record, ensuring that the numerical conventions of the peLASSO
    framework are preserved without drift.

    Attributes:
        lambda_grid (np.ndarray): The primary 200-point regularization grid,
            constructed as exp(linspace(15, -15, 200)).
        lambda_grid2 (np.ndarray): The secondary 200-point regularization grid,
            maintained as an independent deep copy for two-stage estimation.
        validation_report (Any): An instance of GridValidationReport documenting
            the mathematical integrity, bounds, and monotonicity of the grids.
    """
    # The primary 1D numpy array representing the first-stage regularization path
    lambda_grid: np.ndarray
    # The secondary 1D numpy array representing the second-stage regularization path
    lambda_grid2: np.ndarray
    # The structured validation record confirming mathematical and structural invariants
    validation_report: Any  # Expected type: GridValidationReport

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and memory isolation of the lambda grid artifacts.

        Raises:
            TypeError: If the grids are not numpy ndarrays or the report is missing.
            ValueError: If the grid dimensions deviate from the 200-point specification
                or if memory isolation is violated.
        """
        # Verify that the primary lambda_grid is a numpy array for vectorized compatibility
        if not isinstance(self.lambda_grid, np.ndarray):
            # Raise a TypeError if the data structure is incorrect
            raise TypeError("Task10LambdaGridReport: lambda_grid must be a numpy.ndarray.")

        # Verify that the secondary lambda_grid2 is a numpy array for vectorized compatibility
        if not isinstance(self.lambda_grid2, np.ndarray):
            # Raise a TypeError if the data structure is incorrect
            raise TypeError("Task10LambdaGridReport: lambda_grid2 must be a numpy.ndarray.")

        # Validate that the primary grid has exactly 200 elements as per manuscript specs
        if self.lambda_grid.shape != (200,):
            # Raise a ValueError if the dimensionality is incorrect
            raise ValueError(f"Task10LambdaGridReport: lambda_grid shape must be (200,). Found {self.lambda_grid.shape}.")

        # Validate that the secondary grid has exactly 200 elements as per manuscript specs
        if self.lambda_grid2.shape != (200,):
            # Raise a ValueError if the dimensionality is incorrect
            raise ValueError(f"Task10LambdaGridReport: lambda_grid2 shape must be (200,). Found {self.lambda_grid2.shape}.")

        # Enforce strict memory isolation between the two grids to prevent side-effect corruption
        if self.lambda_grid is self.lambda_grid2:
            # Raise a ValueError if the grids share the same memory address
            raise ValueError("Task10LambdaGridReport: lambda_grid and lambda_grid2 must be distinct objects.")

        # Verify that the validation_report is present and not None
        if self.validation_report is None:
            # Raise a ValueError if the critical validation metadata is missing
            raise ValueError("Task10LambdaGridReport: validation_report cannot be None.")


def execute_task_10_construct_lambda_grids(study_configuration: Dict[str, Any]) -> Task10LambdaGridReport:
    """
    Orchestrates Task 10: Extracts grid parameters from the configuration, constructs two
    independent lambda grids using the exact exponential decay formula, and mathematically
    verifies their integrity.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Task10LambdaGridReport: The comprehensive report containing the grids and validation.

    Raises:
        ValueError: If parameter extraction fails or if the mathematical validation fails.
    """
    # Step 1: Read the grid specification from the configuration
    # Execute the extraction and validation of the scalar parameters
    grid_points, log_start, log_end = extract_lambda_grid_parameters(study_configuration)

    # Step 2: Compute both grids using the exact construction rule
    # Execute the generation of the dense, exponentiated arrays
    lambda_grid, lambda_grid2 = construct_lambda_grids(grid_points, log_start, log_end)

    # Step 3: Validate the grid endpoints
    # Execute the rigorous mathematical verification of the generated arrays
    validation_report = validate_lambda_grids(
        lambda_grid=lambda_grid,
        lambda_grid2=lambda_grid2,
        expected_points=grid_points,
        expected_log_start=log_start,
        expected_log_end=log_end
    )

    # Enforce the fail-fast mandate: halt immediately if the grids are mathematically invalid
    if not validation_report.passed:
        raise ValueError(f"Task 10 Step 3 Failed: Lambda grid validation error. {validation_report.error_message}")

    # Return the composite lambda grid report
    return Task10LambdaGridReport(
        lambda_grid=lambda_grid,
        lambda_grid2=lambda_grid2,
        validation_report=validation_report
    )

# %%
# Task 11: Implement the Immutable Evaluator's info Object Construction

# ==============================================================================
# Task 11: Implement the Immutable Evaluator's info Object Construction
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 11, Steps 1 & 2: Define the info object schema & Enforce no-lookahead invariant
# -------------------------------------------------------------------------------------------------------------------------------

class EvaluatorInfoBuilder:
    """
    An elite, highly optimized factory class responsible for constructing the `info`
    dictionary at each time step t. It encapsulates the search sample data as contiguous
    numpy arrays to maximize slicing performance and structurally enforces the absolute
    absence of look-ahead bias.

    This class serves as the foundational data provider for the immutable evaluator harness,
    ensuring that the stochastic LLM optimizer only receives mathematically permissible
    historical data during the recursive rolling-origin evaluation.
    """

    def __init__(
        self,
        df_search_panel: pd.DataFrame,
        lambda_grid: np.ndarray,
        lambda_grid2: np.ndarray,
        study_configuration: Dict[str, Any]
    ) -> None:
        """
        Initializes the builder by extracting and validating the underlying data matrices.

        Args:
            df_search_panel (pd.DataFrame): The strictly isolated 70-row search sample.
            lambda_grid (np.ndarray): The primary 200-point regularization grid.
            lambda_grid2 (np.ndarray): The secondary 200-point regularization grid.
            study_configuration (Dict[str, Any]): The study configuration dictionary.

        Raises:
            ValueError: If the input DataFrame does not have exactly 70 rows, violating
                the strict temporal partitioning requirements of the study.
        """
        # Extract the expected number of rows for the search sample from the configuration dictionary
        expected_rows = study_configuration["sample_design"]["search_sample"]["total_rows"]

        # Check if the length of the provided search panel matches the expected number of rows
        if len(df_search_panel) != expected_rows:
            # Raise a ValueError if the dimensionality of the search panel is incorrect
            raise ValueError(f"Fatal: df_search_panel must contain exactly {expected_rows} rows. Found {len(df_search_panel)}.")

        # Extract the rolling window size parameter (W) from the configuration dictionary
        self.W = study_configuration["prepare_script_data"]["rolling_window_W"]

        # Extract the number of forecasters parameter (K) from the configuration dictionary
        self.K = study_configuration["prepare_script_data"]["K_forecasters"]

        # Create a deep copy of the primary lambda grid to prevent reference-sharing mutations
        self.lambda_grid = lambda_grid.copy()

        # Create a deep copy of the secondary lambda grid to prevent reference-sharing mutations
        self.lambda_grid2 = lambda_grid2.copy()

        # Construct the list of forecaster column names using zero-padded string formatting
        forecaster_cols = [f"forecaster_{k:02d}" for k in range(1, self.K + 1)]

        # Extract the column name for the GDP target series from the configuration dictionary
        target_col = study_configuration["data_inputs"]["gdp_target_series"]["value_column"]

        # Extract the forecaster data into a contiguous float64 numpy array to guarantee O(1) slicing performance
        self.forecaster_matrix = df_search_panel[forecaster_cols].to_numpy(dtype=np.float64, copy=True)

        # Extract the target series data into a contiguous float64 numpy array to guarantee O(1) slicing performance
        self.target_vector = df_search_panel[target_col].to_numpy(dtype=np.float64, copy=True)

        # Assert that the shape of the extracted forecaster matrix exactly matches the expected (rows, K) dimensions
        assert self.forecaster_matrix.shape == (expected_rows, self.K), "Forecaster matrix shape mismatch."

        # Assert that the shape of the extracted target vector exactly matches the expected (rows,) dimensions
        assert self.target_vector.shape == (expected_rows,), "Target vector shape mismatch."

    def build_info(self, t: int) -> Dict[str, Any]:
        """
        Constructs the `info` dictionary for the given manuscript time index t.

        This method mathematically guarantees that no data from time index >= t is
        included in the training or history matrices, strictly enforcing the
        no-look-ahead constraint required for valid out-of-sample forecast evaluation.

        Args:
            t (int): The 1-based manuscript time index (expected range: 5 to 70).

        Returns:
            Dict[str, Any]: The strictly formatted and look-ahead-free info object.

        Raises:
            ValueError: If t is out of the valid evaluation bounds.
        """
        # Verify that the requested time index t falls within the strictly defined evaluation bounds [5, 70]
        if not (5 <= t <= 70):
            # Raise a ValueError if the time index is out of bounds, preventing out-of-bounds memory access
            raise ValueError(f"Time index t={t} is out of the valid evaluation bounds [5, 70].")

        # Calculate the exclusive end index for Python's 0-based slicing, corresponding to manuscript row t-1
        end_idx = t - 1

        # Calculate the inclusive start index for the rolling window, ensuring it does not drop below 0
        start_idx = max(0, t - 1 - self.W)

        # Slice the forecaster matrix to extract the rolling training window and create a deep copy
        X_train = self.forecaster_matrix[start_idx:end_idx, :].copy()

        # Slice the target vector to extract the rolling training targets and create a deep copy
        y_train = self.target_vector[start_idx:end_idx].copy()

        # Slice the forecaster matrix from the beginning to extract the full expanding history and create a deep copy
        X_history = self.forecaster_matrix[0:end_idx, :].copy()

        # Slice the target vector from the beginning to extract the full expanding history and create a deep copy
        y_history = self.target_vector[0:end_idx].copy()

        # Extract the specific row corresponding to the current period's forecasts and create a deep copy
        x_new = self.forecaster_matrix[end_idx, :].copy()

        # Assemble the look-ahead-free information dictionary required by the editable callable
        info = {
            # Assign the rolling window predictor matrix
            "X_train": X_train,
            # Assign the rolling window target vector
            "y_train": y_train,
            # Assign the expanding history predictor matrix
            "X_history": X_history,
            # Assign the expanding history target vector
            "y_history": y_history,
            # Assign the current period forecast vector
            "x_new": x_new,
            # Assign a fresh deep copy of the primary lambda grid
            "lambda_grid": self.lambda_grid.copy(),
            # Assign a fresh deep copy of the secondary lambda grid
            "lambda_grid2": self.lambda_grid2.copy(),
            # Assign the current manuscript time index
            "t": t,
            # Assign the fixed rolling window size parameter
            "w": self.W
        }

        # Invoke the internal validation method to structurally enforce the no-lookahead invariant
        self._enforce_no_lookahead(info, t)

        # Return the fully constructed and validated info dictionary
        return info

    def _enforce_no_lookahead(self, info: Dict[str, Any], t: int) -> None:
        """
        Rigorously verifies that the constructed info object contains no future data
        and strictly adheres to the expected schema.

        This acts as a final, impenetrable defense-in-depth mechanism before the
        data is handed over to the untrusted, LLM-generated editable script.

        Args:
            info (Dict[str, Any]): The constructed info dictionary.
            t (int): The current 1-based manuscript time index.

        Raises:
            AssertionError: If any structural or temporal invariant is violated.
        """
        # Define the exact set of keys that are mathematically permitted in the info dictionary
        expected_keys = {
            "X_train", "y_train", "X_history", "y_history",
            "x_new", "lambda_grid", "lambda_grid2", "t", "w"
        }

        # Assert that the keys in the constructed info dictionary perfectly match the expected set
        assert set(info.keys()) == expected_keys, "Info object contains unauthorized or missing keys."

        # Calculate the expected number of rows for the rolling training window
        expected_n_t = min(t - 1, self.W)

        # Calculate the expected number of rows for the full expanding history
        expected_history_len = t - 1

        # Assert that the row count of the training predictor matrix matches the expected window size
        assert info["X_train"].shape[0] == expected_n_t, f"X_train shape violation at t={t}."

        # Assert that the row count of the training target vector matches the expected window size
        assert info["y_train"].shape[0] == expected_n_t, f"y_train shape violation at t={t}."

        # Assert that the row count of the history predictor matrix matches the expected history length
        assert info["X_history"].shape[0] == expected_history_len, f"X_history shape violation at t={t}."

        # Assert that the row count of the history target vector matches the expected history length
        assert info["y_history"].shape[0] == expected_history_len, f"y_history shape violation at t={t}."

        # Assert that the column count of the training predictor matrix matches the number of forecasters K
        assert info["X_train"].shape[1] == self.K, "X_train feature dimension violation."

        # Assert that the column count of the history predictor matrix matches the number of forecasters K
        assert info["X_history"].shape[1] == self.K, "X_history feature dimension violation."

        # Assert that the shape of the current period forecast vector matches the number of forecasters K
        assert info["x_new"].shape == (self.K,), "x_new shape violation."

        # Assert that the time index in the dictionary matches the requested time index t
        assert info["t"] == t, "Time index corruption."

        # Assert that the window size in the dictionary matches the configured window size W
        assert info["w"] == self.W, "Window size corruption."

# -------------------------------------------------------------------------------------------------------------------------------
# Task 11, Step 3: Validate the warm-up and scoring conventions
# -------------------------------------------------------------------------------------------------------------------------------

def validate_and_update_index_map(
    index_map: pd.DataFrame,
    study_configuration: Dict[str, Any]
) -> pd.DataFrame:
    """
    Explicitly updates and mathematically validates the evaluation eligibility flags
    in the index map based on the authoritative configuration parameters.

    Args:
        index_map (pd.DataFrame): The standing index map from Task 6.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        pd.DataFrame: The rigorously validated and updated index map (deep copy).

    Raises:
        ValueError: If the resulting counts do not match the exact manuscript specifications.
    """
    # Create a deep copy to preserve functional purity
    idx_map_valid = index_map.copy(deep=True)

    # Extract authoritative bounds from configuration
    call_start = study_configuration["prepare_script_data"]["call_index_range_t"]["start"]
    call_end = study_configuration["prepare_script_data"]["call_index_range_t"]["end"]
    score_start = study_configuration["prepare_script_data"]["score_index_range_t"]["start"]
    score_end = study_configuration["prepare_script_data"]["score_index_range_t"]["end"]

    expected_calls = study_configuration["prepare_script_data"]["evaluator_calls_total"]
    expected_scored = study_configuration["prepare_script_data"]["scored_periods_total"]

    # Extract the manuscript row numbers as a numpy array for fast vectorized comparison
    m_rows = idx_map_valid["manuscript_row_number"].to_numpy()

    # Re-calculate the boolean flags mathematically
    is_call_eligible = (m_rows >= call_start) & (m_rows <= call_end)
    is_score_eligible = (m_rows >= score_start) & (m_rows <= score_end)
    is_warmup_only = (m_rows == call_start)

    # Assign the rigorously calculated flags back to the DataFrame
    idx_map_valid["evaluator_call_eligible"] = is_call_eligible
    idx_map_valid["evaluator_score_eligible"] = is_score_eligible
    idx_map_valid["warmup_only"] = is_warmup_only

    # Validate the exact counts against the manuscript's strict requirements
    actual_calls = int(is_call_eligible.sum())
    actual_scored = int(is_score_eligible.sum())
    actual_warmup = int(is_warmup_only.sum())

    if actual_calls != expected_calls:
        raise ValueError(f"Convention violation: Expected {expected_calls} evaluator calls, computed {actual_calls}.")

    if actual_scored != expected_scored:
        raise ValueError(f"Convention violation: Expected {expected_scored} scored periods, computed {actual_scored}.")

    if actual_warmup != 1:
        raise ValueError(f"Convention violation: Expected exactly 1 warm-up period, computed {actual_warmup}.")

    # Verify the logical invariant: a scored period MUST be call eligible
    if not (is_score_eligible <= is_call_eligible).all():
        raise ValueError("Logical violation: Found scored periods that are not call eligible.")

    return idx_map_valid

# -------------------------------------------------------------------------------------------------------------------------------
# Task 11, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task11EvaluatorConstructorReport:
    """
    A structured, implementation-grade container for the artifacts produced during the
    construction of the immutable evaluator. This report aggregates the highly optimized
    EvaluatorInfoBuilder factory and the rigorously validated index map, ensuring that
    the downstream scoring loop has access to a verified temporal execution framework
    that strictly prevents look-ahead bias.

    Attributes:
        info_builder (Any): The factory instance (expected type: EvaluatorInfoBuilder)
            responsible for generating look-ahead-free data slices (X_train, y_train, etc.)
            at each manuscript time index t.
        validated_index_map (pd.DataFrame): The authoritative index map containing
            manuscript-to-Python index translations and boolean eligibility flags
            for the 66 evaluator calls and 65 scored periods.
    """
    # The highly optimized, look-ahead-free info object factory instance
    info_builder: Any
    # The rigorously validated index map defining the temporal execution bounds
    validated_index_map: pd.DataFrame

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity of the
        evaluator artifacts before they are consumed by the Task 12 scoring loop.

        Raises:
            TypeError: If the attributes do not match the required types.
            ValueError: If the index map is empty or missing required columns.
        """
        # Verify that the info_builder is present and not None to prevent downstream attribute errors
        if self.info_builder is None:
            # Raise a ValueError if the factory object is missing from the report
            raise ValueError("Task11EvaluatorConstructorReport: info_builder cannot be None.")

        # Verify that the validated_index_map is a pandas DataFrame to ensure structural compatibility
        if not isinstance(self.validated_index_map, pd.DataFrame):
            # Raise a TypeError if the index map is not a DataFrame
            raise TypeError("Task11EvaluatorConstructorReport: validated_index_map must be a pandas.DataFrame.")

        # Ensure the index map is not empty to prevent iteration errors in the evaluator loop
        if self.validated_index_map.empty:
            # Raise a ValueError if the map contains no temporal data rows
            raise ValueError("Task11EvaluatorConstructorReport: validated_index_map cannot be empty.")

        # Define the set of required columns for the index map to ensure contract compliance with Task 6
        required_cols = {
            "manuscript_row_number",
            "python_positional_index",
            "evaluator_call_eligible",
            "evaluator_score_eligible",
            "warmup_only"
        }

        # Check for the presence of all required columns in the DataFrame schema
        if not required_cols.issubset(self.validated_index_map.columns):
            # Identify the specific missing columns for the error message
            missing = required_cols - set(self.validated_index_map.columns)
            # Raise a ValueError if the index map schema is incomplete
            raise ValueError(f"Task11EvaluatorConstructorReport: validated_index_map missing required columns: {missing}")


def execute_task_11_build_info_constructor(
    df_search_panel: pd.DataFrame,
    index_map: pd.DataFrame,
    lambda_grid: np.ndarray,
    lambda_grid2: np.ndarray,
    study_configuration: Dict[str, Any]
) -> Task11EvaluatorConstructorReport:
    """
    Orchestrates Task 11: Validates the temporal execution conventions, and instantiates
    the elite `EvaluatorInfoBuilder` factory to guarantee look-ahead-free data slicing.

    Args:
        df_search_panel (pd.DataFrame): The strictly isolated 70-row search sample.
        index_map (pd.DataFrame): The standing index map.
        lambda_grid (np.ndarray): The primary regularization grid.
        lambda_grid2 (np.ndarray): The secondary regularization grid.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Task11EvaluatorConstructorReport: The comprehensive report containing the ready-to-use builder.

    Raises:
        ValueError: If the search panel is malformed or if convention validation fails.
    """
    # Step 3: Validate the warm-up and scoring conventions
    # We execute this first to ensure the temporal bounds are mathematically sound
    validated_idx_map = validate_and_update_index_map(index_map, study_configuration)

    # Steps 1 & 2: Define the info object schema & Enforce no-lookahead invariant
    # Instantiate the highly optimized builder class
    # The __init__ method inherently validates the df_search_panel dimensionality
    info_builder = EvaluatorInfoBuilder(
        df_search_panel=df_search_panel,
        lambda_grid=lambda_grid,
        lambda_grid2=lambda_grid2,
        study_configuration=study_configuration
    )

    # Return the composite constructor report
    return Task11EvaluatorConstructorReport(
        info_builder=info_builder,
        validated_index_map=validated_idx_map
    )

# %%
# Task 12: Implement the Evaluator's RMSE Scoring Logic

class EvaluatorRuntimeError(Exception):
    """
    Custom exception raised when the editable callable crashes, returns malformed data,
    or produces non-finite forecasts during the evaluation loop.
    """
    pass

# ==============================================================================
# Task 12: Implement the Evaluator's RMSE Scoring Logic
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Step 1: Collect forecasts and errors over the scored periods
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ForecastCollectionResult:
    """
    A structured, implementation-grade container for the raw numerical arrays generated
    during the rolling-origin evaluator loop. This class encapsulates the full history
    of forecasts and realizations, providing the necessary data for RMSE computation
    and the subsequent Diebold-Mariano predictive accuracy testing.

    Attributes:
        forecasts (np.ndarray): A 1D numpy array of shape (66,) containing the scalar
            forecasts generated by the editable callable for manuscript indices t=5 to t=70.
        actuals (np.ndarray): A 1D numpy array of shape (66,) containing the realized
            GDP growth values corresponding to the forecast quarters t=5 to t=70.
        scored_errors (np.ndarray): A 1D numpy array of shape (65,) containing the
            forecast errors (e_t = y_t - y_hat_t) for the scored periods t=6 to t=70.

    Constraints:
        - forecasts and actuals must have exactly 66 elements (including 1 warm-up).
        - scored_errors must have exactly 65 elements (excluding the warm-up).
        - All arrays must consist of float64 values.
    """
    # 1D array of length 66 containing all generated forecasts (t=5 to 70)
    forecasts: np.ndarray
    # 1D array of length 66 containing the corresponding target realizations
    actuals: np.ndarray
    # 1D array of length 65 containing the errors for scored periods only (t=6 to 70)
    scored_errors: np.ndarray

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and mathematical consistency of the collected forecast data.

        Raises:
            TypeError: If any attribute is not a numpy ndarray.
            ValueError: If array dimensions or lengths deviate from the manuscript
                specifications (66 for full loop, 65 for scored subset).
        """
        # Verify that forecasts is a numpy array to ensure vectorized compatibility
        if not isinstance(self.forecasts, np.ndarray):
            # Raise TypeError if the data structure is incorrect
            raise TypeError("ForecastCollectionResult: forecasts must be a numpy.ndarray.")

        # Verify that actuals is a numpy array for alignment with forecasts
        if not isinstance(self.actuals, np.ndarray):
            # Raise TypeError if the data structure is incorrect
            raise TypeError("ForecastCollectionResult: actuals must be a numpy.ndarray.")

        # Verify that scored_errors is a numpy array for RMSE computation
        if not isinstance(self.scored_errors, np.ndarray):
            # Raise TypeError if the data structure is incorrect
            raise TypeError("ForecastCollectionResult: scored_errors must be a numpy.ndarray.")

        # Validate that the forecasts array has exactly 66 elements (t=5 to 70)
        if self.forecasts.shape != (66,):
            # Raise ValueError if the length violates the manuscript call range
            raise ValueError(f"ForecastCollectionResult: forecasts must have shape (66,). Found {self.forecasts.shape}.")

        # Validate that the actuals array has exactly 66 elements (t=5 to 70)
        if self.actuals.shape != (66,):
            # Raise ValueError if the length violates the manuscript call range
            raise ValueError(f"ForecastCollectionResult: actuals must have shape (66,). Found {self.actuals.shape}.")

        # Validate that the scored_errors array has exactly 65 elements (t=6 to 70)
        if self.scored_errors.shape != (65,):
            # Raise ValueError if the length violates the manuscript scoring range
            raise ValueError(f"ForecastCollectionResult: scored_errors must have shape (65,). Found {self.scored_errors.shape}.")

        # Ensure that the scored_errors array contains no NaNs, as this would invalidate the RMSE
        if np.any(np.isnan(self.scored_errors)):
            # Raise ValueError if the error calculation is incomplete or poisoned
            raise ValueError("ForecastCollectionResult: scored_errors contains NaN values.")

def collect_forecasts_and_errors(
    info_builder: Any, # Type hinted as Any to avoid circular import, expected EvaluatorInfoBuilder
    target_vector: np.ndarray,
    select_lambda_callable: Callable[[Dict[str, Any]], Dict[str, Any]]
) -> ForecastCollectionResult:
    """
    Iterates over the evaluation time indices, invokes the editable callable to generate forecasts,
    and computes the forecast errors, strictly isolating the scored periods from the warm-up.

    Args:
        info_builder (EvaluatorInfoBuilder): The factory for constructing look-ahead-free info objects.
        target_vector (np.ndarray): The 1D array of realized GDP growth values.
        select_lambda_callable (Callable): The untrusted editable function provided by the agent.

    Returns:
        ForecastCollectionResult: The structured arrays of forecasts, actuals, and scored errors.

    Raises:
        EvaluatorRuntimeError: If the callable crashes or returns invalid data.
    """
    # The manuscript specifies 66 total evaluator calls, from t=5 to t=70 inclusive.
    total_calls = 66

    # Initialize contiguous numpy arrays to store the results efficiently.
    # Using np.nan initialization ensures that any skipped iterations are mathematically poisoned.
    forecasts = np.full(total_calls, np.nan, dtype=np.float64)
    actuals = np.full(total_calls, np.nan, dtype=np.float64)

    # Iterate over the strict manuscript time indices
    for t in range(5, 71):
        # Map the 1-based manuscript index t to the 0-based loop array index i
        i = t - 5

        # 1. Construct the strictly look-ahead-free info object for time t
        try:
            info = info_builder.build_info(t)
        except Exception as e:
            raise EvaluatorRuntimeError(f"Info builder failed at t={t}: {e}")

        # 2. Invoke the untrusted editable callable within a protective boundary
        try:
            result = select_lambda_callable(info)
        except Exception as e:
            # Catch any runtime error in the agent's code and escalate as a formal crash
            raise EvaluatorRuntimeError(f"Callable crashed at t={t}: {e}")

        # 3. Extract and validate the forecast value
        try:
            # The contract requires a dictionary with a 'forecast' key convertible to float
            forecast_val = float(result["forecast"])
        except KeyError:
            raise EvaluatorRuntimeError(f"Callable return dictionary missing 'forecast' key at t={t}.")
        except (TypeError, ValueError):
            raise EvaluatorRuntimeError(f"Callable returned non-numeric forecast at t={t}: {result.get('forecast')}")

        # 4. Store the forecast and the corresponding realized actual value
        forecasts[i] = forecast_val
        # The target for manuscript time t is at Python positional index t - 1
        actuals[i] = target_vector[t - 1]

    # 5. Isolate the scored periods from the warm-up period
    # The call at t=5 (i=0) is warm-up only. Scored periods are t=6 to 70 (i=1 to 65).
    # We slice the arrays from index 1 to the end.
    scored_forecasts = forecasts[1:]
    scored_actuals = actuals[1:]

    # Compute the forecast error using the strict manuscript sign convention: e_t = y_t - \hat{y}_t
    scored_errors = scored_actuals - scored_forecasts

    # Rigorous validation of the resulting array length
    assert len(scored_errors) == 65, f"Fatal: Expected 65 scored errors, generated {len(scored_errors)}."

    return ForecastCollectionResult(
        forecasts=forecasts,
        actuals=actuals,
        scored_errors=scored_errors
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Step 2: Compute the scalar RMSE score
# -------------------------------------------------------------------------------------------------------------------------------

def compute_scalar_rmse(scored_errors: np.ndarray) -> float:
    """
    Computes the Root Mean Squared Error (RMSE) over the strictly isolated scored periods.

    Args:
        scored_errors (np.ndarray): 1D array of exactly 65 forecast errors.

    Returns:
        float: The scalar RMSE score.

    Raises:
        ValueError: If the input array does not have exactly 65 elements.
        EvaluatorRuntimeError: If the computed RMSE is non-finite.
    """
    # Enforce the strict denominator requirement
    if len(scored_errors) != 65:
        raise ValueError(f"RMSE computation requires exactly 65 errors. Received {len(scored_errors)}.")

    # Compute the squared errors vectorially
    squared_errors = scored_errors ** 2

    # Compute the mean squared error.
    # Since len == 65, np.mean divides by exactly 65, matching the manuscript equation.
    mse = np.mean(squared_errors)

    # Defensive check against impossible floating-point anomalies
    assert mse >= 0.0, "Fatal: Mean Squared Error is negative."

    # Compute the root mean squared error
    rmse = float(np.sqrt(mse))

    # Validate that the resulting score is a finite number
    # If the callable returned inf or NaN, it propagates here and is treated as a crash
    if not np.isfinite(rmse):
        raise EvaluatorRuntimeError("Computed RMSE is non-finite (NaN or inf).")

    return rmse

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Step 3: Compute the relative RMSE
# -------------------------------------------------------------------------------------------------------------------------------

def compute_relative_rmse(method_rmse: float, baseline_rmse: float) -> float:
    """
    Computes the relative RMSE of a method against the dynamically recomputed baseline.

    Args:
        method_rmse (float): The absolute RMSE of the evaluated method.
        baseline_rmse (float): The absolute RMSE of the simple average baseline.

    Returns:
        float: The relative RMSE ratio.

    Raises:
        ValueError: If the baseline RMSE is zero or negative.
    """
    # Enforce strict positivity of the denominator to prevent division by zero
    if baseline_rmse <= 0.0:
        raise ValueError(f"Fatal: Baseline RMSE must be strictly positive. Received {baseline_rmse}.")

    # Compute and return the ratio
    return method_rmse / baseline_rmse

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task12EvaluatorScoreReport:
    """
    A structured, implementation-grade container that aggregates the final outputs of the
    immutable evaluator loop S(tau; D^S). This report provides the absolute performance
    metric (RMSE), the relative performance ratio against the simple average benchmark,
    and the complete collection of raw forecasts and errors required for the audit trail.

    Attributes:
        absolute_rmse (float): The Root Mean Squared Error computed over the 65 scored
            periods (t=6 to t=70) on the search sample.
        relative_rmse (Optional[float]): The ratio of the method's RMSE to the baseline
            simple average RMSE. This is None if the baseline has not yet been established.
        collection_result (Any): An instance of ForecastCollectionResult containing the
            full 66-period arrays of forecasts, actuals, and errors.

    Algorithm:
        The absolute_rmse is the primary scalar score used by the agent loop to determine
        'keep' or 'discard' decisions. The relative_rmse provides a normalized measure
        of improvement over the tau_0 baseline.
    """
    # The absolute Root Mean Squared Error computed over the 65 scored periods: sqrt(mean(e_t^2))
    absolute_rmse: float
    # The relative RMSE ratio: RMSE_method / RMSE_baseline (None if baseline is unknown)
    relative_rmse: Optional[float]
    # The structured collection of raw forecasts, actuals, and errors for the full 66-call loop
    collection_result: Any  # Expected type: ForecastCollectionResult

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity of the
        scoring report before it is logged to the results.tsv audit file.

        Raises:
            TypeError: If the absolute_rmse or relative_rmse are not of the correct numeric type.
            ValueError: If the RMSE values are non-finite or mathematically impossible (negative).
        """
        # Verify that absolute_rmse is a float to ensure numerical consistency in the audit log
        if not isinstance(self.absolute_rmse, (float, np.float64)):
            # Raise a TypeError if the absolute score type is incorrect
            raise TypeError("Task12EvaluatorScoreReport: absolute_rmse must be a float.")

        # Ensure the absolute RMSE is a finite, non-negative number as required by the RMSE equation
        if not math.isfinite(self.absolute_rmse) or self.absolute_rmse < 0:
            # Raise a ValueError if the absolute score is mathematically invalid
            raise ValueError("Task12EvaluatorScoreReport: absolute_rmse must be a finite non-negative float.")

        # Perform conditional validation on the relative_rmse if it has been provided
        if self.relative_rmse is not None:
            # Verify that relative_rmse is a float for ratio consistency
            if not isinstance(self.relative_rmse, (float, np.float64)):
                # Raise a TypeError if the relative score type is incorrect
                raise TypeError("Task12EvaluatorScoreReport: relative_rmse must be a float.")

            # Ensure the relative RMSE is a finite, non-negative number
            if not math.isfinite(self.relative_rmse) or self.relative_rmse < 0:
                # Raise a ValueError if the relative score is mathematically invalid
                raise ValueError("Task12EvaluatorScoreReport: relative_rmse must be a finite non-negative float.")

        # Verify that the collection_result artifact is present and not None
        if self.collection_result is None:
            # Raise a ValueError if the raw data arrays are missing from the report
            raise ValueError("Task12EvaluatorScoreReport: collection_result cannot be None.")


def execute_task_12_evaluate_method_score(
    info_builder: Any,
    target_vector: np.ndarray,
    select_lambda_callable: Callable[[Dict[str, Any]], Dict[str, Any]],
    baseline_rmse: Optional[float] = None
) -> Task12EvaluatorScoreReport:
    """
    Orchestrates Task 12: Executes the immutable evaluator harness, invoking the editable
    callable over the rolling origin, and computes the rigorous RMSE scores.

    Args:
        info_builder (EvaluatorInfoBuilder): The factory for constructing info objects.
        target_vector (np.ndarray): The 1D array of realized GDP growth values.
        select_lambda_callable (Callable): The untrusted editable function.
        baseline_rmse (Optional[float]): The recomputed simple average RMSE, if available.

    Returns:
        Task12EvaluatorScoreReport: The comprehensive scoring report.

    Raises:
        EvaluatorRuntimeError: If the callable crashes, which the search loop must catch.
    """
    # Step 1: Collect forecasts and errors over the scored periods
    # This step executes the untrusted callable 66 times and isolates the 65 scored errors
    collection_result = collect_forecasts_and_errors(
        info_builder=info_builder,
        target_vector=target_vector,
        select_lambda_callable=select_lambda_callable
    )

    # Step 2: Compute the scalar RMSE score
    # This step reduces the 65 errors to a single, finite scalar metric
    absolute_rmse = compute_scalar_rmse(collection_result.scored_errors)

    # Step 3: Compute the relative RMSE
    # This step is conditional on the availability of the baseline score
    relative_rmse = None
    if baseline_rmse is not None:
        relative_rmse = compute_relative_rmse(
            method_rmse=absolute_rmse,
            baseline_rmse=baseline_rmse
        )

    # Return the composite evaluator score report
    return Task12EvaluatorScoreReport(
        absolute_rmse=absolute_rmse,
        relative_rmse=relative_rmse,
        collection_result=collection_result
    )

# %%
# Task 13: Implement and Validate the Baseline Simple-Average Method

# ==============================================================================
# Task 13: Implement and Validate the Baseline Simple-Average Method
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 13, Step 1: Define the baseline forecast
# -------------------------------------------------------------------------------------------------------------------------------

def simple_average_select_lambda(info: Dict[str, Any]) -> Dict[str, Any]:
    """
    Computes the simple arithmetic average of the current-period forecasts.
    This serves as the baseline method (tau_0) and the denominator for relative RMSE.

    Args:
        info (Dict[str, Any]): The look-ahead-free information dictionary provided by the evaluator.
            Must contain the key 'x_new' mapping to a 1D numpy array of shape (K,).

    Returns:
        Dict[str, Any]: A dictionary conforming to the editable callable contract, containing:
            - 'forecast': The scalar float prediction.
            - 'method': A descriptive string identifier.

    Raises:
        AssertionError: If the input array contains non-finite values.
    """
    # Extract the current-period forecast vector from the info dictionary
    x_new: np.ndarray = info["x_new"]

    # Rigorously verify that no missing or non-finite values exist in the forecast vector.
    # Imputation (Task 7) should guarantee this, but defensive programming requires verification.
    assert np.all(np.isfinite(x_new)), "Fatal: x_new contains NaN or infinite values."

    # Compute the arithmetic mean across all K forecasters.
    # Equation: \hat{y}_t = (1 / K) * \sum_{k=1}^{K} x_{k,t}
    mean_forecast = np.mean(x_new)

    # Cast the numpy scalar to a native Python float to strictly satisfy the return contract
    scalar_forecast = float(mean_forecast)

    # Return the structured dictionary with the forecast and method identifier
    return {
        "forecast": scalar_forecast,
        "method": "simple_average"
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 13, Step 2: Run the baseline through the evaluator on the search sample
# -------------------------------------------------------------------------------------------------------------------------------

def evaluate_baseline_method(
    info_builder: Any,
    target_vector: np.ndarray,
    execute_task_12_callable: Callable[..., Any]
) -> float:
    """
    Executes the full rolling-origin evaluation loop over the search sample using the
    simple average baseline method to compute its absolute RMSE.

    Args:
        info_builder (Any): The EvaluatorInfoBuilder instance.
        target_vector (np.ndarray): The 1D array of realized GDP growth values.
        execute_task_12_callable (Callable): The orchestrator function from Task 12.

    Returns:
        float: The absolute RMSE of the simple average baseline.
    """
    # Invoke the Task 12 orchestrator, passing the baseline callable.
    # We pass baseline_rmse=None because we are currently computing the baseline itself.
    score_report = execute_task_12_callable(
        info_builder=info_builder,
        target_vector=target_vector,
        select_lambda_callable=simple_average_select_lambda,
        baseline_rmse=None
    )

    # Extract and return the absolute RMSE from the resulting report
    return score_report.absolute_rmse

# -------------------------------------------------------------------------------------------------------------------------------
# Task 13, Step 3: Treat any material baseline mismatch as a hard stop
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class BaselineValidationReport:
    """
    A structured record documenting the validation of the baseline RMSE against published targets.

    Attributes:
        passed (bool): True if the computed RMSE is within the acceptable tolerance.
        computed_rmse (float): The actual RMSE computed by the evaluator.
        expected_rmse (float): The target RMSE from the manuscript.
        deviation (float): The absolute difference between computed and expected RMSE.
        tolerance_applied (float): The maximum allowed deviation based on data provenance.
        tier (str): The strictness tier applied (e.g., 'Tier 1 (exact reproduction)').
    """
    # Boolean flag indicating if the baseline matches expectations
    passed: bool
    # The empirically computed RMSE
    computed_rmse: float
    # The theoretical target RMSE
    expected_rmse: float
    # The absolute mathematical deviation
    deviation: float
    # The threshold used for validation
    tolerance_applied: float
    # The classification of the validation strictness
    tier: str


def validate_baseline_rmse(
    computed_rmse: float,
    expected_rmse: float,
    data_provenance: str,
    df_search_panel: pd.DataFrame,
    target_col: str,
    forecaster_cols: List[str],
    total_imputed_cells: int
) -> BaselineValidationReport:
    """
    Validates the computed baseline RMSE against the expected target, applying dynamic
    tolerances based on data provenance. Halts execution with a detailed diagnostic
    report if the deviation exceeds the tolerance.

    Args:
        computed_rmse (float): The RMSE computed by the evaluator.
        expected_rmse (float): The target RMSE (e.g., 1.504).
        data_provenance (str): Identifier for the data source (e.g., 'original_H1_gdp').
        df_search_panel (pd.DataFrame): The raw search panel for diagnostic extraction.
        target_col (str): The name of the GDP target column.
        forecaster_cols (List[str]): The list of forecaster column names.
        total_imputed_cells (int): The number of cells altered during imputation.

    Returns:
        BaselineValidationReport: The structured validation record.

    Raises:
        ValueError: If the computed RMSE deviates from the expected RMSE beyond the tolerance.
    """
    # Determine the appropriate tolerance tier based on the data provenance
    if "original" in data_provenance.lower() or "verbatim" in data_provenance.lower():
        # Tier 1: Exact reproduction using the original dataset requires strict tolerance
        tolerance = 0.002
        tier = "Tier 1 (exact reproduction)"
    else:
        # Tier 2: Independent rebuilds using new vintages require wider tolerance
        tolerance = 0.020
        tier = "Tier 2 (independent rebuild)"

    # Compute the absolute mathematical deviation
    deviation = abs(computed_rmse - expected_rmse)

    # Evaluate the validation condition
    passed = bool(deviation <= tolerance)

    # If the validation fails, construct a highly detailed diagnostic report and halt
    if not passed:
        # Extract diagnostic data for t=6 (Python positional index 5)
        t6_index = 5
        t6_date = df_search_panel["date"].iloc[t6_index]
        t6_target = df_search_panel[target_col].iloc[t6_index]
        t6_forecasts = df_search_panel[forecaster_cols].iloc[t6_index].astype(float)
        t6_simple_avg = t6_forecasts.mean()
        t6_error = t6_target - t6_simple_avg

        # Extract samples of the target series for visual inspection
        target_sample_head = df_search_panel[target_col].head(5).tolist()
        target_sample_tail = df_search_panel[target_col].tail(5).tolist()

        # Extract samples of the simple average for visual inspection
        sa_series = df_search_panel[forecaster_cols].mean(axis=1)
        sa_sample_head = sa_series.head(5).tolist()
        sa_sample_tail = sa_series.tail(5).tolist()

        # Construct the comprehensive error message
        diagnostic_msg = (
            f"Fatal: Baseline RMSE validation failed.\n"
            f"----------------------------------------\n"
            f"1. Numerical Summary:\n"
            f"   - Computed RMSE: {computed_rmse:.6f}\n"
            f"   - Expected RMSE: {expected_rmse:.6f}\n"
            f"   - Deviation:     {deviation:.6f}\n"
            f"   - Tolerance:     {tolerance:.6f} ({tier})\n\n"
            f"2. Date Alignment Spot-Check (t=6, Python index 5):\n"
            f"   - Quarter Label:   {t6_date}\n"
            f"   - Simple Average:  {t6_simple_avg:.6f}\n"
            f"   - Realized Target: {t6_target:.6f}\n"
            f"   - Forecast Error:  {t6_error:.6f}\n\n"
            f"3. Period Count Verification:\n"
            f"   - Expected Scored Periods: 65\n\n"
            f"4. Target Series Sample:\n"
            f"   - First 5: {target_sample_head}\n"
            f"   - Last 5:  {target_sample_tail}\n\n"
            f"5. Forecaster Panel Simple Average Sample:\n"
            f"   - First 5: {sa_sample_head}\n"
            f"   - Last 5:  {sa_sample_tail}\n\n"
            f"6. Imputation Effect Check:\n"
            f"   - Total Imputed Cells: {total_imputed_cells}\n"
            f"   - Note: High imputation counts or vintage differences may cause deviation.\n"
            f"----------------------------------------\n"
            f"Pipeline halted. Resolve data or evaluator discrepancies before proceeding."
        )
        raise ValueError(diagnostic_msg)

    # Return the validation report if successful
    return BaselineValidationReport(
        passed=passed,
        computed_rmse=computed_rmse,
        expected_rmse=expected_rmse,
        deviation=deviation,
        tolerance_applied=tolerance,
        tier=tier
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 13, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task13BaselineReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the baseline validation phase. This report serves as the authoritative record
    confirming that the simple average benchmark (tau_0) has been mathematically
    verified against the manuscript's published search-sample RMSE of 1.504.

    Attributes:
        validated_baseline_rmse (float): The empirically computed absolute RMSE of the
            simple average method on the 70-row search sample.
        validation_report (BaselineValidationReport): The detailed record documenting
            the deviation, tolerance tier, and diagnostic spot-checks.
        baseline_callable (Callable[[Dict[str, Any]], Dict[str, Any]]): The pure Python
            function implementing the simple average forecast logic for downstream use.
    """
    # The mathematically validated absolute RMSE of the simple average benchmark
    validated_baseline_rmse: float
    # The structured validation record containing the tier-based tolerance analysis
    validation_report: Any  # Expected type: BaselineValidationReport
    # The pure Python function implementing the simple average forecast: y_hat = mean(x_new)
    baseline_callable: Callable[[Dict[str, Any]], Dict[str, Any]]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity of the
        baseline report artifacts before they are consumed by the discovery loop.

        Raises:
            TypeError: If any attribute does not match the required type.
            ValueError: If the validated RMSE is non-positive or mathematically invalid.
        """
        # Verify that the validated_baseline_rmse is a float to ensure numerical consistency
        if not isinstance(self.validated_baseline_rmse, (float, np.float64)):
            # Raise a TypeError if the RMSE type is incorrect
            raise TypeError("Task13BaselineReport: validated_baseline_rmse must be a float.")

        # Ensure the RMSE is strictly positive, as a zero or negative RMSE is impossible for this study
        if self.validated_baseline_rmse <= 0:
            # Raise a ValueError if the RMSE value is mathematically invalid
            raise ValueError("Task13BaselineReport: validated_baseline_rmse must be strictly positive.")

        # Verify that the baseline_callable is indeed a callable object to prevent execution errors
        if not callable(self.baseline_callable):
            # Raise a TypeError if the baseline method is not a function
            raise TypeError("Task13BaselineReport: baseline_callable must be a callable function.")

        # Verify that the validation_report is present and not None
        if self.validation_report is None:
            # Raise a ValueError if the critical validation record is missing
            raise ValueError("Task13BaselineReport: validation_report cannot be None.")


def execute_task_13_implement_and_validate_baseline(
    info_builder: Any,
    target_vector: np.ndarray,
    df_search_panel: pd.DataFrame,
    study_configuration: Dict[str, Any],
    data_provenance: str,
    total_imputed_cells: int,
    execute_task_12_callable: Callable[..., Any]
) -> Task13BaselineReport:
    """
    Orchestrates Task 13: Defines the simple average baseline, evaluates it using the
    immutable harness, and rigorously validates the resulting RMSE against published targets.

    Args:
        info_builder (Any): The EvaluatorInfoBuilder instance.
        target_vector (np.ndarray): The 1D array of realized GDP growth values.
        df_search_panel (pd.DataFrame): The raw search panel for diagnostics.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        data_provenance (str): Identifier for the data source.
        total_imputed_cells (int): The number of cells altered during imputation.
        execute_task_12_callable (Callable): The orchestrator function from Task 12.

    Returns:
        Task13BaselineReport: The comprehensive baseline validation report.

    Raises:
        ValueError: If the baseline RMSE deviates beyond the acceptable tolerance.
    """
    # Extract the expected baseline RMSE from the configuration
    expected_rmse = study_configuration["train_script_initial_data"]["baseline_expected_search_rmse"]

    # Extract column names for diagnostic purposes
    k_forecasters = study_configuration["data_inputs"]["spf_panel_wide"]["K_forecasters"]
    forecaster_cols = [f"forecaster_{k:02d}" for k in range(1, k_forecasters + 1)]
    target_col = study_configuration["data_inputs"]["gdp_target_series"]["value_column"]

    # Step 1 & 2: Define the callable and evaluate it to obtain the computed RMSE
    computed_rmse = evaluate_baseline_method(
        info_builder=info_builder,
        target_vector=target_vector,
        execute_task_12_callable=execute_task_12_callable
    )

    # Step 3: Validate the computed RMSE against the expected target, halting if necessary
    validation_report = validate_baseline_rmse(
        computed_rmse=computed_rmse,
        expected_rmse=expected_rmse,
        data_provenance=data_provenance,
        df_search_panel=df_search_panel,
        target_col=target_col,
        forecaster_cols=forecaster_cols,
        total_imputed_cells=total_imputed_cells
    )

    # Return the composite baseline report, including the reusable callable
    return Task13BaselineReport(
        validated_baseline_rmse=computed_rmse,
        validation_report=validation_report,
        baseline_callable=simple_average_select_lambda
    )

# %%
# Task 14: Define the Editable Callable Interface and Return Contract

# ==============================================================================
# Task 14: Define the Editable Callable Interface and Return Contract
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Step 1: Define the function signature
# -------------------------------------------------------------------------------------------------------------------------------

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Step 1: Define the function signature
# -------------------------------------------------------------------------------------------------------------------------------

class EvaluatorInfo(TypedDict):
    """
    Strict type definition for the `info` dictionary passed to the editable callable.
    This enforces the exact schema generated by the EvaluatorInfoBuilder (Task 11)
    to ensure look-ahead-free data access during the rolling-origin evaluation.

    Attributes:
        X_train (np.ndarray): Matrix of forecasts for the training window [max(1, t-w) : t-1, K].
        y_train (np.ndarray): Vector of realized targets for the training window [max(1, t-w) : t-1].
        X_history (np.ndarray): Matrix of all historical forecasts [1 : t-1, K].
        y_history (np.ndarray): Vector of all historical realized targets [1 : t-1].
        x_new (np.ndarray): Vector of current-period forecasts for time t [K].
        lambda_grid (np.ndarray): Primary 200-point regularization grid [200].
        lambda_grid2 (np.ndarray): Secondary 200-point regularization grid [200].
        t (int): The 1-based manuscript time index.
        w (int): The rolling window size (W=20).
    """
    # Matrix of forecasts for the training window of size n_t = min(t-1, W)
    X_train: np.ndarray
    # Vector of realized targets corresponding to the training window
    y_train: np.ndarray
    # Matrix of all historical forecasts from the start of the search sample to t-1
    X_history: np.ndarray
    # Vector of all historical realized targets from the start of the search sample to t-1
    y_history: np.ndarray
    # Vector of current-period forecasts for the target quarter t
    x_new: np.ndarray
    # Primary 200-point lambda grid for first-stage regularization
    lambda_grid: np.ndarray
    # Secondary 200-point lambda grid for second-stage regularization
    lambda_grid2: np.ndarray
    # The current 1-based manuscript time index used for temporal alignment
    t: int
    # The fixed rolling window size parameter (W=20)
    w: int


class ForecastResult(TypedDict):
    """
    Strict type definition for the dictionary returned by the editable callable.
    This contract ensures that the evaluator can reliably extract the forecast
    and log the method description for the audit trail.

    Attributes:
        forecast (float): The scalar point forecast for the target quarter.
        method (str): A descriptive string identifying the algorithm used.
    """
    # The scalar point forecast generated by the combined forecaster model
    forecast: float
    # The descriptive name of the method, recorded in the results.tsv audit log
    method: str


class SelectLambdaCallable(Protocol):
    """
    Formal Protocol defining the exact signature required for the editable callable.
    Any function assigned to this role must accept the EvaluatorInfo dictionary
    and return a ForecastResult dictionary, ensuring structural subtyping compliance.
    """
    # The __call__ method defines the interface for the select_lambda function
    def __call__(self, info: EvaluatorInfo) -> ForecastResult:
        """
        Executes the agent-defined lambda selection and forecast combination logic.

        Args:
            info (EvaluatorInfo): The look-ahead-free data and parameter dictionary.

        Returns:
            ForecastResult: The dictionary containing the forecast and method name.
        """
        # Ellipsis indicates this is a protocol definition with no implementation
        ...

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Step 2: Define the return contract
# -------------------------------------------------------------------------------------------------------------------------------

def validate_callable_return(result: Any, t: int) -> ForecastResult:
    """
    Rigorously validates the output of the untrusted editable callable at runtime.
    Ensures the return value is a dictionary with the correct keys, casts the forecast
    to a native float, and verifies mathematical finiteness.

    Args:
        result (Any): The raw return value from the editable callable.
        t (int): The current manuscript time index (for error reporting).

    Returns:
        ForecastResult: The strictly validated and cast return dictionary.

    Raises:
        ValueError: If the return value violates the contract (missing keys, non-numeric, non-finite).
    """
    # 1. Verify the return type is a dictionary
    if not isinstance(result, dict):
        raise ValueError(f"Contract violation at t={t}: Callable must return a dictionary. Received {type(result)}.")

    # 2. Verify the presence of required keys
    if "forecast" not in result:
        raise ValueError(f"Contract violation at t={t}: Return dictionary missing required key 'forecast'.")
    if "method" not in result:
        raise ValueError(f"Contract violation at t={t}: Return dictionary missing required key 'method'.")

    # 3. Extract and strictly cast the forecast value
    raw_forecast = result["forecast"]
    try:
        # Cast to native Python float. This safely handles numpy scalars (e.g., np.float64).
        forecast_val = float(raw_forecast)
    except (TypeError, ValueError):
        raise ValueError(f"Contract violation at t={t}: 'forecast' value must be convertible to float. Received {raw_forecast}.")

    # 4. Verify mathematical finiteness
    if not math.isfinite(forecast_val):
        raise ValueError(f"Contract violation at t={t}: 'forecast' value must be finite. Received {forecast_val}.")

    # 5. Extract and cast the method string
    method_str = str(result["method"])

    # Return the strictly formatted dictionary
    return {
        "forecast": forecast_val,
        "method": method_str
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Step 3: Confirm that this is the only editable surface
# -------------------------------------------------------------------------------------------------------------------------------

def load_editable_callable(
    module_path: str,
    module_name: str = "train_module"
) -> Callable[[Any], Any]:
    """
    Dynamically loads the editable Python script from disk, compiles it into an AST,
    and executes it within a strictly restricted global namespace. This mathematically
    guarantees an evaluator-locked local search by preventing the agent from importing
    unauthorized modules (e.g., os, sys) or accessing the holdout data.

    Args:
        module_path (str): The absolute or relative filesystem path to the editable script.
        module_name (str): The internal identifier for the module (used for error reporting).

    Returns:
        Callable[[Any], Any]: The validated, ready-to-execute select_lambda function.

    Raises:
        FileNotFoundError: If the specified script path does not exist on disk.
        SyntaxError: If the agent introduced invalid Python syntax into the script.
        ImportError: If the agent attempts to import an unauthorized module.
        AttributeError: If the script fails to define the required 'select_lambda' function.
    """
    # Convert the string path to a robust Path object for filesystem verification
    script_file = Path(module_path)

    # Verify that the target script actually exists on disk before attempting to read it
    if not script_file.exists():
        # Raise a FileNotFoundError to halt execution if the agent's script is missing
        raise FileNotFoundError(f"Editable script not found at path: {module_path}")

    # Open the script file in read mode with strict UTF-8 encoding to prevent decoding errors
    with open(script_file, 'r', encoding='utf-8') as f:
        # Read the entire source code of the agent's script into a single string variable
        source_code = f.read()

    # Define the strict whitelist of Python modules the agent is permitted to import
    allowed_modules = {"numpy", "sklearn", "math", "typing", "scipy", "pandas"}

    # Capture a reference to the original, unrestricted __import__ function for safe delegation
    original_import = __import__

    # Define the custom, intercepting import function to enforce the sandbox boundaries
    def safe_import(name: str, globals: Optional[Dict[str, Any]] = None, locals: Optional[Dict[str, Any]] = None, fromlist: Tuple[str, ...] = (), level: int = 0) -> Any:
        """
        Intercepts all import calls originating from the agent's executed code,
        raising an ImportError if the requested module is not explicitly whitelisted.
        """
        # Extract the base module name (e.g., 'sklearn' from 'sklearn.linear_model')
        base_name = name.split('.')[0]

        # Check if the requested base module is present in the strict whitelist
        if base_name not in allowed_modules:
            # Raise an ImportError to block the unauthorized access attempt, logging a crash
            raise ImportError(f"Security Sandbox Violation: Import of module '{name}' is strictly forbidden.")

        # If the module is whitelisted, delegate the actual loading to the original __import__ function
        return original_import(name, globals, locals, fromlist, level)

    # Construct the restricted globals dictionary, explicitly overriding the __builtins__ key
    restricted_globals = {
        # Inject the custom safe_import function to intercept all module loading attempts
        "__builtins__": {
            "__import__": safe_import,
            # Explicitly whitelist safe, deterministic built-in functions required for mathematics
            "len": len, "range": range, "sum": sum, "min": min, "max": max,
            "float": float, "int": int, "abs": abs, "round": round,
            # Explicitly whitelist safe built-in types and data structures
            "dict": dict, "list": list, "tuple": tuple, "set": set, "bool": bool, "str": str,
            # Explicitly whitelist standard exception types for error handling within the script
            "Exception": Exception, "ValueError": ValueError, "TypeError": TypeError,
            "KeyError": KeyError, "IndexError": IndexError,
            # Explicitly whitelist the print function to allow the agent to output debugging info to run.log
            "print": print,
            # Explicitly whitelist zip and enumerate for standard iteration patterns
            "zip": zip, "enumerate": enumerate, "any": any, "all": all
        }
    }

    # Initialize an empty dictionary to capture the local variables defined by the agent's script
    restricted_locals: Dict[str, Any] = {}

    # Attempt to compile the agent's source code string into a Python Bytecode object
    try:
        # The 'exec' mode specifies that the code consists of a sequence of statements
        bytecode = compile(source_code, filename=module_path, mode='exec')
    except SyntaxError as e:
        # Catch syntax errors and re-raise them with descriptive context for the audit log
        raise SyntaxError(f"Failed to compile editable script {module_path}: {e}")

    # Attempt to execute the compiled Bytecode within the strictly sandboxed namespaces
    try:
        # Execute the bytecode, populating the restricted_locals dictionary with the defined functions
        exec(bytecode, restricted_globals, restricted_locals)
    except Exception as e:
        # Catch any runtime or import errors generated during execution and re-raise them
        raise RuntimeError(f"Failed to execute sandboxed script {module_path}: {e}")

    # Verify that the agent's script successfully defined the required 'select_lambda' function
    if "select_lambda" not in restricted_locals:
        # Raise an AttributeError if the contract signature is missing from the local namespace
        raise AttributeError(f"Contract violation: The script {module_path} must define 'select_lambda'.")

    # Extract the raw function reference from the populated local namespace dictionary
    raw_callable = restricted_locals["select_lambda"]

    # Verify that the extracted reference is indeed a callable Python object
    if not callable(raw_callable):
        # Raise an AttributeError if the agent assigned a non-callable value to the required name
        raise AttributeError(f"Contract violation: 'select_lambda' in {module_path} is not callable.")

    # Define the secure wrapper function that enforces the strict return contract
    def validated_callable(info: Any) -> Any:
        """
        Wraps the untrusted agent callable, executing it and rigorously validating
        its return dictionary against the formal ForecastResult schema.
        """
        # Extract the current manuscript time index from the info object for error reporting
        t = info.get("t", -1)

        # Invoke the untrusted agent function, passing the look-ahead-free info dictionary
        raw_result = raw_callable(info)

        # Assume validate_callable_return is available in the environment to enforce the schema
        # This function casts the forecast to float and verifies the presence of the method string
        return validate_callable_return(raw_result, t)

    # Return the fully sandboxed and validated callable function
    return validated_callable

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task14EditableInterfaceReport:
    """
    A structured, immutable container for the artifacts produced during the definition
    and dynamic loading of the editable callable interface. This report encapsulates
    the secure execution boundary that wraps the untrusted agent code, ensuring that
    the discovery loop operates within a verifiable and evaluator-locked audit trail.

    Attributes:
        validated_callable (Callable[[EvaluatorInfo], ForecastResult]): The dynamically loaded
            function, wrapped in runtime validation logic to enforce the strict return contract
            defined in the manuscript.
        source_path (str): The absolute or relative filesystem path from which the
            editable script (e.g., 'train.py') was loaded.
    """
    # The wrapped, ready-to-execute callable that enforces the return contract at each iteration
    validated_callable: Callable[[EvaluatorInfo], ForecastResult]
    # The filesystem path from which the agent's editable script was successfully loaded
    source_path: str

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity of the
        interface report artifacts before they are consumed by the evaluator.

        Raises:
            TypeError: If the validated_callable is not a callable object.
            ValueError: If the source_path is empty or malformed.
        """
        # Verify that the provided validated_callable is indeed a callable object to prevent runtime crashes
        if not callable(self.validated_callable):
            # Raise a TypeError if the interface contract is violated by the provided object
            raise TypeError("Task14EditableInterfaceReport: validated_callable must be a callable object.")

        # Verify that the source_path is a valid, non-empty string for audit trail documentation
        if not isinstance(self.source_path, str) or not self.source_path.strip():
            # Raise a ValueError if the path metadata is missing or invalid
            raise ValueError("Task14EditableInterfaceReport: source_path must be a non-empty string.")


def execute_task_14_define_editable_interface(
    study_configuration: Dict[str, Any]
) -> 'Task14EditableInterfaceReport':
    """
    Orchestrates Task 14: Defines the strict interface and return contract for the editable
    callable, dynamically loads the agent's script from disk via a secure sandbox, and
    wraps the execution in rigorous runtime validation and type casting.

    This function acts as a secure Facade, translating low-level AST compilation and
    execution exceptions into standardized pipeline errors for the master orchestrator.

    Args:
        study_configuration (Dict[str, Any]): The comprehensive study configuration dictionary
            containing the filesystem paths to the editable script.

    Returns:
        Task14EditableInterfaceReport: The structured report containing the executable,
            type-aligned callable and its source path.

    Raises:
        ValueError: If the configuration dictionary is missing the required script path keys.
        RuntimeError: If the agent's script violates the sandbox constraints, contains
            syntax errors, attempts unauthorized imports, or fails to define the contract.
    """
    # Attempt to extract the filesystem path to the editable script from the configuration
    try:
        # Navigate the nested configuration dictionary to retrieve the target Python file path
        script_path = study_configuration["artifact_paths"]["train_py_path"]
    # Catch KeyError if the configuration dictionary is malformed or missing the required path
    except KeyError as e:
        # Raise a descriptive ValueError to halt the pipeline before attempting file I/O
        raise ValueError(f"Missing required configuration key for editable script path: {e}")

    # Attempt to load, compile, and sandbox the agent's script using the upstream loader
    try:
        # Invoke the sandboxed loader, which returns a generalized Callable[[Any], Any]
        raw_validated_callable = load_editable_callable(module_path=script_path)

    # Catch the specific tuple of exceptions that the secure sandbox is contracted to raise
    except (FileNotFoundError, SyntaxError, ImportError, AttributeError, RuntimeError) as e:
        # Wrap the low-level sandbox exception in a standardized RuntimeError for the master orchestrator
        raise RuntimeError(f"Task 14 Sandbox Violation: Failed to load editable interface from {script_path}. Details: {e}")

    # Forcefully realign the generalized callable to the strict static type expected by the dataclass
    # This satisfies static type checkers (e.g., mypy) without altering the runtime behavior
    strictly_typed_callable = cast(Callable[['EvaluatorInfo'], 'ForecastResult'], raw_validated_callable)

    # Instantiate the Task14EditableInterfaceReport dataclass with the type-aligned callable and path
    report = Task14EditableInterfaceReport(
        validated_callable=strictly_typed_callable,
        source_path=script_path
    )

    # Return the fully populated and type-compliant interface report to the master orchestrator
    return report

# %%
# Task 15: Materialize the Instruction Contract Exactly

# ==============================================================================
# Task 15: Materialize the Instruction Contract Exactly
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 15, Step 1: Write `program.md` from the verbatim configuration text
# -------------------------------------------------------------------------------------------------------------------------------

def write_and_verify_instruction_contract(study_configuration: Dict[str, Any]) -> Tuple[str, bool]:
    """
    Extracts the verbatim Markdown instruction contract from the configuration, writes it
    to disk with absolute byte-for-byte fidelity, and verifies the write operation via
    a strict read-back equality check.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary containing
            the verbatim text and target paths.

    Returns:
        Tuple[str, bool]: A tuple containing the absolute path to the written file and
            a boolean flag confirming exact read-back fidelity.

    Raises:
        ValueError: If the configuration keys are missing or if the read-back verification fails.
        OSError: If the file system prevents directory creation or file writing.
    """
    try:
        # Extract the verbatim Markdown text exactly as defined in the configuration
        verbatim_text = study_configuration["program_md_data"]["verbatim_contract_text"]

        # Extract the target working directory and file name
        work_dir_str = study_configuration["artifact_paths"]["working_directory"]
        file_name = study_configuration["artifact_paths"]["program_md_path"]

    except KeyError as e:
        # Halt execution if the required configuration keys are absent
        raise ValueError(f"Missing required configuration key for instruction contract: {e}")

    # Construct the robust, cross-platform file path
    work_dir = Path(work_dir_str)
    file_path = work_dir / file_name

    # Ensure the target directory exists, creating parent directories if necessary
    work_dir.mkdir(parents=True, exist_ok=True)

    # Write the verbatim text to disk.
    # We strictly enforce UTF-8 encoding and newline='' to prevent the OS from
    # silently altering line endings (e.g., \n to \r\n on Windows), which would
    # violate the byte-for-byte fidelity requirement.
    with open(file_path, 'w', encoding='utf-8', newline='') as f:
        f.write(verbatim_text)

    # Perform a rigorous read-back verification to guarantee no corruption occurred during I/O
    with open(file_path, 'r', encoding='utf-8', newline='') as f:
        read_back_text = f.read()

    # Evaluate strict string equality
    fidelity_confirmed = (verbatim_text == read_back_text)

    if not fidelity_confirmed:
        # Halt execution immediately if the written file does not perfectly match the source
        raise ValueError(f"Fatal: Read-back verification failed for {file_path}. File contents were altered during write.")

    # Return the absolute path as a string and the confirmation flag
    return str(file_path.absolute()), fidelity_confirmed

# -------------------------------------------------------------------------------------------------------------------------------
# Task 15, Step 2: Prepare the session trigger and restart prompts
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class AgentPromptTemplates:
    """
    A structured, implementation-grade container for the exact prompt strings used to
    initiate and recover autonomous LLM agent sessions. This class encapsulates the
    raw templates and provides a safe formatting method to prevent runtime string
    manipulation errors during the high-frequency search loop.

    Attributes:
        fresh_session_trigger (str): The exact prompt used to start a new discovery run.
        restart_budget_template (str): The template string containing the '{K_remaining}' placeholder.
        restart_recovery_instruction (str): The exact prompt instructing the agent to read the audit logs.
    """
    # The prompt sent to the agent to begin a completely new run (e.g., "Implement `program.md`.")
    fresh_session_trigger: str
    # The template string used to enforce the soft budget cap during session recovery
    restart_budget_template: str
    # The instruction directing the agent to reconcile its state with results.tsv and git log
    restart_recovery_instruction: str

    def format_restart_prompt(self, k_remaining: int) -> str:
        """
        Dynamically constructs the composite restart prompt by safely injecting the
        remaining budget into the template and concatenating the required instructions.

        Args:
            k_remaining (int): The computed number of experiments remaining in the budget.

        Returns:
            str: The fully formatted, multi-line prompt string ready for LLM transmission.

        Raises:
            ValueError: If k_remaining is negative, indicating a severe budget overrun.
        """
        # Enforce logical budget constraints
        if k_remaining < 0:
            raise ValueError(f"Cannot format restart prompt with negative budget: {k_remaining}")

        # Safely format the budget sentence
        formatted_budget = self.restart_budget_template.format(K_remaining=k_remaining)

        # Concatenate the components exactly as implied by the manuscript's recovery protocol
        # The order is: Trigger -> Recovery Instruction -> Budget Enforcement
        composite_prompt = (
            f"{self.fresh_session_trigger}\n"
            f"{self.restart_recovery_instruction}\n"
            f"{formatted_budget}"
        )

        return composite_prompt


def extract_agent_prompt_templates(study_configuration: Dict[str, Any]) -> AgentPromptTemplates:
    """
    Extracts the required prompt strings from the configuration and encapsulates them
    in the AgentPromptTemplates dataclass.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        AgentPromptTemplates: The structured container of prompt templates.

    Raises:
        ValueError: If any required prompt string is missing from the configuration.
    """
    try:
        # Extract the three specific prompt strings defined in the configuration
        trigger = study_configuration["program_md_data"]["fresh_session_trigger_prompt"]
        budget_template = study_configuration["program_md_data"]["session_restart_budget_sentence"]
        recovery_instruction = study_configuration["program_md_data"]["session_restart_recovery_instruction"]
    except KeyError as e:
        # Halt execution if the prompt definitions are incomplete
        raise ValueError(f"Missing required configuration key for agent prompts: {e}")

    # Return the populated dataclass
    return AgentPromptTemplates(
        fresh_session_trigger=trigger,
        restart_budget_template=budget_template,
        restart_recovery_instruction=recovery_instruction
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 15, Step 3: Confirm prompt-template fidelity
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class PromptFidelityReport:
    """
    A structured, immutable record documenting the exact state of the LLM prompt
    interface and explicitly acknowledging the epistemological boundaries of
    reproducibility regarding non-deterministic provider-side parameters.

    Attributes:
        program_md_verbatim (bool): True if the contract was written with byte-for-byte fidelity.
        session_trigger_matches_config (bool): True if the trigger prompt matches the configuration.
        restart_prompt_matches_config (bool): True if the restart components match the configuration.
        hidden_system_prompts_observable (bool): Always False, acknowledging platform limitations.
        temperature_specified (bool): True if the manuscript explicitly defined the temperature.
        top_p_specified (bool): True if the manuscript explicitly defined the top_p parameter.
        implementation_side_prompt_additions (List[str]): Any unauthorized prompts injected by the harness.
    """
    # Confirmation of exact file I/O fidelity for the main contract
    program_md_verbatim: bool
    # Confirmation that the trigger prompt is unmodified
    session_trigger_matches_config: bool
    # Confirmation that the recovery prompts are unmodified
    restart_prompt_matches_config: bool
    # Explicit acknowledgment that provider-side system prompts cannot be audited
    hidden_system_prompts_observable: bool
    # Flag indicating if the LLM temperature was rigorously defined
    temperature_specified: bool
    # Flag indicating if the LLM top_p was rigorously defined
    top_p_specified: bool
    # List of any additional prompts added by the replication team (expected empty)
    implementation_side_prompt_additions: List[str]


def generate_prompt_fidelity_report(
    study_configuration: Dict[str, Any],
    verbatim_confirmed: bool
) -> PromptFidelityReport:
    """
    Compiles the fidelity report by checking the configuration for quarantined LLM
    parameters and aggregating the verification flags.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        verbatim_confirmed (bool): The read-back verification result from Step 1.

    Returns:
        PromptFidelityReport: The comprehensive fidelity documentation.
    """
    # Extract the agent specification block to check for quarantined parameters
    agent_spec = study_configuration["search_protocol"]["agent_specification"]

    # Determine if temperature was explicitly specified (not None)
    temp_specified = agent_spec.get("temperature") is not None

    # Determine if top_p was explicitly specified (not None)
    top_p_specified = agent_spec.get("top_p") is not None

    # Construct and return the immutable fidelity report
    return PromptFidelityReport(
        program_md_verbatim=verbatim_confirmed,
        session_trigger_matches_config=True,  # Guaranteed by direct extraction in Step 2
        restart_prompt_matches_config=True,   # Guaranteed by direct extraction in Step 2
        hidden_system_prompts_observable=False, # Fundamental limitation of proprietary LLM APIs
        temperature_specified=temp_specified,
        top_p_specified=top_p_specified,
        implementation_side_prompt_additions=[] # We strictly adhere to the configuration, adding nothing
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 15, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task15PromptMaterializationReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the instruction contract materialization phase. This report serves as the
    authoritative record confirming that the primary LLM-facing prompt (program.md)
    has been written to disk with byte-for-byte fidelity and that the session
    management templates are correctly configured for the autonomous search loop.

    Attributes:
        contract_file_path (str): The absolute filesystem path to the perfectly
            materialized 'program.md' file.
        prompt_templates (Any): An instance of AgentPromptTemplates containing
            the fresh-session and recovery prompt strings.
        fidelity_report (Any): An instance of PromptFidelityReport documenting
            the exact state of the LLM interface and non-deterministic parameters.
    """
    # The absolute filesystem path to the perfectly materialized program.md file
    contract_file_path: str
    # The structured container of prompt templates for the search loop (Expected: AgentPromptTemplates)
    prompt_templates: Any
    # The audit record documenting the exact state of the LLM interface (Expected: PromptFidelityReport)
    fidelity_report: Any

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and consistency of the prompt materialization artifacts.

        Raises:
            TypeError: If any attribute does not match the required type.
            ValueError: If the file path is empty or malformed.
        """
        # Verify that contract_file_path is a string to ensure filesystem compatibility
        if not isinstance(self.contract_file_path, str):
            # Raise a TypeError if the path metadata is of an incorrect type
            raise TypeError("Task15PromptMaterializationReport: contract_file_path must be a string.")

        # Ensure the file path is not empty to prevent downstream I/O failures
        if not self.contract_file_path.strip():
            # Raise a ValueError if the path is an empty or whitespace-only string
            raise ValueError("Task15PromptMaterializationReport: contract_file_path cannot be empty.")

        # Verify that the prompt_templates artifact is present and not None
        if self.prompt_templates is None:
            # Raise a ValueError if the session management templates are missing
            raise ValueError("Task15PromptMaterializationReport: prompt_templates cannot be None.")

        # Verify that the fidelity_report artifact is present and not None
        if self.fidelity_report is None:
            # Raise a ValueError if the critical fidelity audit documentation is missing
            raise ValueError("Task15PromptMaterializationReport: fidelity_report cannot be None.")


def execute_task_15_materialize_instruction_contract(
    study_configuration: Dict[str, Any]
) -> Task15PromptMaterializationReport:
    """
    Orchestrates Task 15: Writes the verbatim instruction contract to disk with
    cryptographic-level read-back verification, extracts the session management
    prompts, and compiles the fidelity audit report.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Task15PromptMaterializationReport: The comprehensive materialization report.

    Raises:
        ValueError: If file I/O verification fails or configuration keys are missing.
        OSError: If the filesystem prevents the creation of the contract file.
    """
    # Step 1: Write `program.md` from the verbatim configuration text
    # Execute the strict file I/O and read-back verification
    file_path, verbatim_confirmed = write_and_verify_instruction_contract(study_configuration)

    # Step 2: Prepare the session trigger and restart prompts
    # Extract and encapsulate the prompt strings into the safe formatting dataclass
    prompt_templates = extract_agent_prompt_templates(study_configuration)

    # Step 3: Confirm prompt-template fidelity
    # Compile the audit report documenting the exact state of the LLM parameters
    fidelity_report = generate_prompt_fidelity_report(study_configuration, verbatim_confirmed)

    # Return the composite materialization report
    return Task15PromptMaterializationReport(
        contract_file_path=file_path,
        prompt_templates=prompt_templates,
        fidelity_report=fidelity_report
    )

# %%
# Task 16: Fix the LLM Settings to the Extent the Paper Specifies Them

# ==============================================================================
# Task 16: Fix the LLM Settings to the Extent the Paper Specifies Them
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 16, Step 1: Set the disclosed agent parameters
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class AgentDeploymentManifest:
    """
    A structured, immutable record documenting the exact LLM agent parameters
    explicitly disclosed by the manuscript. This manifest ensures that the
    stochastic optimizer is configured with the correct model family and
    operational constraints.

    Attributes:
        coding_assistant (str): The designated AI coding assistant (e.g., 'Claude Code').
        model_family (str): The specific model version (e.g., 'Opus 4.6').
        thinking_effort (str): The configured reasoning effort level (e.g., 'default').
        fresh_agent_each_run (bool): Must be True to guarantee run independence.
        independent_runs (int): The total number of discovery sessions to execute (e.g., 3).
        model_version_exact (str): The resolved API string for the model, defaulting to model_family.
    """
    # The designated AI coding assistant platform
    coding_assistant: str
    # The specific model version specified in the manuscript
    model_family: str
    # The configured reasoning effort level
    thinking_effort: str
    # Flag guaranteeing that no latent state leaks between independent runs
    fresh_agent_each_run: bool
    # The total number of independent discovery sessions to execute
    independent_runs: int
    # The exact API string used for deployment (defaults to model_family)
    model_version_exact: str


def extract_disclosed_agent_parameters(study_configuration: Dict[str, Any]) -> AgentDeploymentManifest:
    """
    Extracts and rigorously validates the explicitly disclosed LLM agent parameters
    from the study configuration.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        AgentDeploymentManifest: The structured record of disclosed parameters.

    Raises:
        ValueError: If required keys are missing or if the independence invariant is violated.
    """
    try:
        # Navigate the nested dictionary to extract the agent specification block
        agent_spec = study_configuration["search_protocol"]["agent_specification"]
        run_design = study_configuration["search_protocol"]["run_design"]

        # Extract the explicitly disclosed parameters
        coding_assistant = str(agent_spec["coding_assistant"])
        model_family = str(agent_spec["model_family"])
        thinking_effort = str(agent_spec["thinking_effort"])

        fresh_agent = bool(run_design["fresh_agent_each_run"])
        independent_runs = int(run_design["independent_runs"])

    except KeyError as e:
        # Halt execution if the required configuration keys are absent
        raise ValueError(f"Missing required configuration key for disclosed agent parameters: {e}")

    # Enforce the critical methodological invariant: runs MUST be independent
    if not fresh_agent:
        raise ValueError("Methodological violation: fresh_agent_each_run must be True to ensure independent discovery trajectories.")

    # Enforce a strictly positive number of runs
    if independent_runs < 1:
        raise ValueError(f"Methodological violation: independent_runs must be >= 1. Received {independent_runs}.")

    # Return the populated manifest
    return AgentDeploymentManifest(
        coding_assistant=coding_assistant,
        model_family=model_family,
        thinking_effort=thinking_effort,
        fresh_agent_each_run=fresh_agent,
        independent_runs=independent_runs,
        model_version_exact=model_family
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 16, Step 2: Document all unspecified settings as implementation choices
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ImplementationChoicesManifest:
    """
    A structured, immutable record documenting the LLM parameters and environmental
    policies that were left unspecified by the manuscript. This manifest explicitly
    acknowledges the epistemological boundaries of the replication, detailing where
    platform defaults or local implementation choices were utilized.

    Attributes:
        temperature (str): The recorded temperature setting or 'Platform default'.
        top_p (str): The recorded top_p setting or 'Platform default'.
        internet_access_policy (str): The recorded policy, including residual risk warnings.
        filesystem_permission_policy (str): The recorded policy regarding local file access.
    """
    # The recorded temperature setting
    temperature: str
    # The recorded top_p setting
    top_p: str
    # The recorded internet access policy and associated risk warnings
    internet_access_policy: str
    # The recorded filesystem permission policy
    filesystem_permission_policy: str


def document_unspecified_agent_settings(study_configuration: Dict[str, Any]) -> ImplementationChoicesManifest:
    """
    Extracts the unspecified LLM settings from the configuration, substituting 'None'
    values with explicit descriptive strings and appending necessary methodological warnings.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        ImplementationChoicesManifest: The structured record of implementation choices.
    """
    # Extract the agent specification block safely
    agent_spec = study_configuration.get("search_protocol", {}).get("agent_specification", {})

    # Process the temperature setting
    raw_temp = agent_spec.get("temperature")
    if raw_temp is None:
        temp_desc = "Platform default (Unspecified in manuscript)"
    else:
        temp_desc = f"{raw_temp} (Implementation-side choice)"

    # Process the top_p setting
    raw_top_p = agent_spec.get("top_p")
    if raw_top_p is None:
        top_p_desc = "Platform default (Unspecified in manuscript)"
    else:
        top_p_desc = f"{raw_top_p} (Implementation-side choice)"

    # Process the internet access policy and append residual risk warnings
    raw_internet = agent_spec.get("internet_access_policy")
    if raw_internet is None:
        internet_desc = (
            "Unspecified in manuscript. If internet access is enabled by the platform, "
            "residual look-ahead risk exists as the agent may download holdout-period data."
        )
    else:
        internet_desc = f"{raw_internet} (Implementation-side choice)"

    # Process the filesystem permission policy
    raw_fs = agent_spec.get("filesystem_permission_policy")
    if raw_fs is None:
        fs_desc = "Unspecified in manuscript. Agent may have unrestricted access to the local environment."
    else:
        fs_desc = f"{raw_fs} (Implementation-side choice)"

    # Return the populated manifest
    return ImplementationChoicesManifest(
        temperature=temp_desc,
        top_p=top_p_desc,
        internet_access_policy=internet_desc,
        filesystem_permission_policy=fs_desc
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 16, Step 3: Set the search budget and enforcement rule
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class SearchBudgetConfiguration:
    """
    A structured, immutable record defining the computational budget for the agentic
    search loop and the mechanism by which it is enforced.

    Attributes:
        target_K (int): The approximate number of experiments to conduct per run (e.g., 200).
        enforcement_mechanism (str): Description of the soft-cap enforcement logic.
        reported_realized_counts (Dict[str, int]): The exact experiment counts reported
            in the manuscript for reference.
    """
    # The target number of experiments per independent run
    target_K: int
    # The description of how the budget is enforced (e.g., counting TSV rows)
    enforcement_mechanism: str
    # The reference counts from the manuscript for audit comparison
    reported_realized_counts: Dict[str, int]


def extract_search_budget_configuration(study_configuration: Dict[str, Any]) -> SearchBudgetConfiguration:
    """
    Extracts and validates the search budget parameters and enforcement rules from
    the study configuration.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        SearchBudgetConfiguration: The structured record of the budget configuration.

    Raises:
        ValueError: If required keys are missing or if the budget is not strictly positive.
    """
    try:
        # Navigate the nested dictionary to extract the run design block
        run_design = study_configuration["search_protocol"]["run_design"]

        # Extract the budget parameters
        target_k = int(run_design["search_budget_target_K"])
        enforcement = str(run_design["search_budget_enforcement"])
        reported_counts = dict(run_design["reported_realized_experiments"])

    except KeyError as e:
        # Halt execution if the required configuration keys are absent
        raise ValueError(f"Missing required configuration key for search budget: {e}")
    except (TypeError, ValueError) as e:
        # Halt execution if the values cannot be cast to the required types
        raise ValueError(f"Invalid data type for search budget parameters: {e}")

    # Enforce a strictly positive budget target
    if target_k <= 0:
        raise ValueError(f"Mathematical violation: search_budget_target_K must be > 0. Received {target_k}.")

    # Return the populated configuration object
    return SearchBudgetConfiguration(
        target_K=target_k,
        enforcement_mechanism=enforcement,
        reported_realized_counts=reported_counts
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 16, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task16AgentSettingsReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the LLM agent configuration phase. This report serves as the definitive
    operational profile for the stochastic optimizer, documenting the intersection
    of manuscript-disclosed facts, implementation-side choices for unspecified
    parameters, and the rigorous search budget enforcement rules.

    Attributes:
        disclosed_parameters (Any): An instance of AgentDeploymentManifest documenting
            the model family, reasoning effort, and run independence invariants.
        implementation_choices (Any): An instance of ImplementationChoicesManifest
            documenting the policies for temperature, top_p, and environmental access.
        budget_configuration (Any): An instance of SearchBudgetConfiguration defining
            the target experiment count (K=200) and the soft-cap enforcement logic.
    """
    # The manifest of explicitly disclosed agent parameters (Expected: AgentDeploymentManifest)
    disclosed_parameters: Any
    # The manifest documenting unspecified settings and residual risks (Expected: ImplementationChoicesManifest)
    implementation_choices: Any
    # The configuration defining the search budget and enforcement logic (Expected: SearchBudgetConfiguration)
    budget_configuration: Any

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and completeness of the agent settings report before discovery begins.

        Raises:
            ValueError: If any of the constituent manifests are missing or None.
        """
        # Verify that the disclosed_parameters artifact is present to maintain the audit trail
        if self.disclosed_parameters is None:
            # Raise a ValueError if the primary agent specification is missing
            raise ValueError("Task16AgentSettingsReport: disclosed_parameters cannot be None.")

        # Verify that the implementation_choices artifact is present to document ambiguities
        if self.implementation_choices is None:
            # Raise a ValueError if the environmental policy documentation is missing
            raise ValueError("Task16AgentSettingsReport: implementation_choices cannot be None.")

        # Verify that the budget_configuration artifact is present to ensure termination logic
        if self.budget_configuration is None:
            # Raise a ValueError if the computational budget parameters are missing
            raise ValueError("Task16AgentSettingsReport: budget_configuration cannot be None.")


def execute_task_16_fix_llm_settings(study_configuration: Dict[str, Any]) -> Task16AgentSettingsReport:
    """
    Orchestrates Task 16: Extracts the disclosed agent parameters, documents the
    unspecified settings as implementation choices, and configures the search budget.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Task16AgentSettingsReport: The comprehensive agent settings report.

    Raises:
        ValueError: If any configuration extraction or validation fails.
    """
    # Step 1: Set the disclosed agent parameters
    # Execute the extraction and rigorous validation of the specified LLM settings
    disclosed_manifest = extract_disclosed_agent_parameters(study_configuration)

    # Step 2: Document all unspecified settings as implementation choices
    # Execute the extraction and documentation of the ambiguous LLM settings
    choices_manifest = document_unspecified_agent_settings(study_configuration)

    # Step 3: Set the search budget and enforcement rule
    # Execute the extraction and validation of the computational budget
    budget_config = extract_search_budget_configuration(study_configuration)

    # Return the composite agent settings report
    return Task16AgentSettingsReport(
        disclosed_parameters=disclosed_manifest,
        implementation_choices=choices_manifest,
        budget_configuration=budget_config
    )

# %%
# Task 17: Initialize Version Control and the Uncommitted Results Log

# ==============================================================================
# Task 17: Initialize Version Control and the Uncommitted Results Log
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 17, Step 1: Initialize a git repository and create a run branch
# -------------------------------------------------------------------------------------------------------------------------------

def initialize_git_and_branch(
    working_directory: Path,
    branch_prefix: str,
    run_tag: str
) -> str:
    """
    Initializes a git repository in the specified working directory, rigorously verifies
    that the working tree is clean to prevent state contamination, and creates a new,
    isolated branch for the discovery run.

    Args:
        working_directory (Path): The absolute or relative path to the project root.
        branch_prefix (str): The prefix for the branch name (e.g., 'autoresearch/').
        run_tag (str): The unique identifier for the current run (e.g., 'run_1').

    Returns:
        str: The fully qualified name of the created branch.

    Raises:
        RuntimeError: If git commands fail or if the repository contains uncommitted changes.
        ValueError: If the target branch already exists, compromising run isolation.
    """
    # Ensure the working directory exists, creating parent directories if necessary
    working_directory.mkdir(parents=True, exist_ok=True)

    # Define a robust helper function to execute git commands safely within the target directory
    def _run_git(cmd: List[str]) -> subprocess.CompletedProcess:
        try:
            # Execute the command, capturing stdout and stderr for error reporting
            return subprocess.run(
                ["git"] + cmd,
                cwd=working_directory,
                check=True,
                capture_output=True,
                text=True
            )
        except subprocess.CalledProcessError as e:
            # Raise a detailed RuntimeError if the shell command returns a non-zero exit code
            raise RuntimeError(f"Git command failed: {' '.join(cmd)}\nError: {e.stderr}")

    # 1. Initialize the git repository. This is safe to run even if already initialized.
    _run_git(["init"])

    # 2. Verify the repository is clean to prevent inheriting corrupted state.
    # The --porcelain flag provides machine-readable output; empty output mathematically proves cleanliness.
    status_proc = _run_git(["status", "--porcelain"])
    if status_proc.stdout.strip():
        # Halt execution immediately if the repository is dirty
        raise RuntimeError(f"Repository at {working_directory} is dirty. Commit or stash changes before proceeding.")

    # 3. Construct the fully qualified branch name
    full_branch_name = f"{branch_prefix}{run_tag}"

    # 4. Check if the branch already exists to prevent accidental overwriting and ensure isolation.
    branch_check_proc = _run_git(["branch", "--list", full_branch_name])
    if full_branch_name in branch_check_proc.stdout:
        # Halt execution if a collision is detected
        raise ValueError(f"Branch '{full_branch_name}' already exists. Run isolation compromised.")

    # 5. Create and checkout the new branch in one atomic operation
    _run_git(["checkout", "-b", full_branch_name])

    # Return the fully qualified branch name for downstream logging
    return full_branch_name

# -------------------------------------------------------------------------------------------------------------------------------
# Task 17, Step 2: Commit the baseline project state
# -------------------------------------------------------------------------------------------------------------------------------

def commit_baseline_state(
    working_directory: Path,
    program_md_path: str,
    prepare_py_path: str,
    train_py_path: str
) -> str:
    """
    Stages the foundational project files, creates the initial baseline commit (tau_0)
    using explicit credentials, extracts the 7-character commit hash, and enforces
    filesystem-level immutability on the evaluator script.

    Args:
        working_directory (Path): The path to the project root.
        program_md_path (str): Relative path to the instruction contract.
        prepare_py_path (str): Relative path to the immutable evaluator.
        train_py_path (str): Relative path to the baseline editable callable.

    Returns:
        str: The 7-character short git hash of the baseline commit.

    Raises:
        FileNotFoundError: If any of the required baseline files are missing from disk.
        RuntimeError: If the git commit operation fails.
    """
    # 1. Verify the existence of all required files before attempting to stage them
    required_files = [program_md_path, prepare_py_path, train_py_path]
    for file_path in required_files:
        full_path = working_directory / file_path
        if not full_path.exists():
            # Halt execution if a foundational file is missing
            raise FileNotFoundError(f"Required baseline file missing: {full_path}")

    # Define a robust helper function to execute git commands safely
    def _run_git(cmd: List[str]) -> subprocess.CompletedProcess:
        try:
            return subprocess.run(
                ["git"] + cmd,
                cwd=working_directory,
                check=True,
                capture_output=True,
                text=True
            )
        except subprocess.CalledProcessError as e:
            raise RuntimeError(f"Git command failed: {' '.join(cmd)}\nError: {e.stderr}")

    # 2. Stage the foundational files
    _run_git(["add"] + required_files)

    # 3. Create the baseline commit.
    # We inject explicit user credentials to ensure the commit succeeds deterministically
    # in CI/CD environments where global git config might not be set.
    commit_msg = "baseline: simple average (tau_0)"
    _run_git([
        "-c", "user.name=Autoresearch Agent",
        "-c", "user.email=agent@autoresearch.local",
        "commit", "-m", commit_msg
    ])

    # 4. Extract the short commit hash (7 characters) for the TSV log
    hash_proc = _run_git(["rev-parse", "--short", "HEAD"])
    # Strip trailing whitespace to ensure a clean string
    commit_hash = hash_proc.stdout.strip()

    # 5. Enforce filesystem-level immutability on the evaluator script.
    # This provides defense-in-depth against agent drift or accidental modification.
    evaluator_full_path = working_directory / prepare_py_path
    # 0o444 sets read-only permissions for User, Group, and Others
    os.chmod(evaluator_full_path, stat.S_IRUSR | stat.S_IRGRP | stat.S_IROTH)

    # Return the extracted commit hash
    return commit_hash

# -------------------------------------------------------------------------------------------------------------------------------
# Task 17, Step 3: Create `results.tsv` without committing it
# -------------------------------------------------------------------------------------------------------------------------------

def initialize_uncommitted_results_log(
    working_directory: Path,
    results_tsv_path: str,
    columns: Dict[str, str]
) -> str:
    """
    Initializes the tab-separated audit log file with the correct headers, explicitly
    truncating any existing file to ensure a clean slate, and programmatically adds
    it to .gitignore to prevent accidental version control tracking.

    Args:
        working_directory (Path): The path to the project root.
        results_tsv_path (str): Relative path to the TSV log file.
        columns (Dict[str, str]): Dictionary defining the column names.

    Returns:
        str: The absolute path to the initialized TSV file.

    Raises:
        OSError: If file system permissions prevent writing the file or updating .gitignore.
    """
    # Construct the absolute path to the TSV file
    full_tsv_path = working_directory / results_tsv_path

    # 1. Extract the column names in order from the configuration dictionary
    header_names = list(columns.keys())

    # Construct the tab-separated header string with a trailing newline
    header_string = "\t".join(header_names) + "\n"

    # 2. Write the header to the file.
    # Using 'w' mode explicitly truncates any existing file, guaranteeing a clean log for the new run.
    with open(full_tsv_path, 'w', encoding='utf-8', newline='') as f:
        f.write(header_string)

    # 3. Programmatically enforce version control exclusion via .gitignore
    gitignore_path = working_directory / ".gitignore"

    # Check if the entry already exists to prevent duplicate lines
    entry_exists = False
    if gitignore_path.exists():
        with open(gitignore_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
            # Check if the exact path string is present in any line
            if any(results_tsv_path in line for line in lines):
                entry_exists = True

    # Append the entry if it is absent
    if not entry_exists:
        with open(gitignore_path, 'a', encoding='utf-8') as f:
            # Ensure we start on a new line and add a descriptive comment
            f.write(f"\n# Autoresearch Audit Log\n{results_tsv_path}\n")

    # Return the absolute path as a string for downstream use
    return str(full_tsv_path.absolute())

# -------------------------------------------------------------------------------------------------------------------------------
# Task 17, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task17VersionControlReport:
    """
    A structured, implementation-grade container for the artifacts produced during the
    initialization of the version control infrastructure. This report encapsulates the
    branch name, the baseline commit hash, and the path to the uncommitted audit log,
    providing the foundational state required for the agentic search loop.

    Attributes:
        run_branch_name (str): The fully qualified name of the isolated git branch.
        baseline_commit_hash (str): The 7-character git hash of the tau_0 baseline state.
        results_log_path (str): The absolute filesystem path to the initialized TSV audit log.
    """
    # The name of the isolated git branch (e.g., 'autoresearch/run_1')
    run_branch_name: str
    # The short git hash of the initial commit containing the simple average baseline
    baseline_commit_hash: str
    # The absolute path to the results.tsv file, guaranteed to be excluded from git
    results_log_path: str

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the version control artifacts.

        Raises:
            TypeError: If any attribute does not match the required type.
            ValueError: If the strings are empty or malformed.
        """
        # Verify that run_branch_name is a non-empty string
        if not isinstance(self.run_branch_name, str) or not self.run_branch_name.strip():
            raise ValueError("Task17VersionControlReport: run_branch_name must be a non-empty string.")

        # Verify that baseline_commit_hash is a non-empty string
        if not isinstance(self.baseline_commit_hash, str) or not self.baseline_commit_hash.strip():
            raise ValueError("Task17VersionControlReport: baseline_commit_hash must be a non-empty string.")

        # Verify that results_log_path is a non-empty string
        if not isinstance(self.results_log_path, str) or not self.results_log_path.strip():
            raise ValueError("Task17VersionControlReport: results_log_path must be a non-empty string.")


def execute_task_17_initialize_version_control(
    study_configuration: Dict[str, Any],
    run_tag: str
) -> Task17VersionControlReport:
    """
    Orchestrates Task 17: Initializes the git repository, creates an isolated run branch,
    commits the baseline project state, enforces evaluator immutability, and initializes
    the uncommitted TSV audit log.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        run_tag (str): The unique identifier for the current run (e.g., 'run_1').

    Returns:
        Task17VersionControlReport: The comprehensive version control initialization report.

    Raises:
        ValueError: If configuration keys are missing or branch creation fails.
        RuntimeError: If git operations fail or the repository is dirty.
        FileNotFoundError: If required baseline files are missing from the working directory.
    """
    try:
        # Extract required paths and parameters from the configuration dictionary
        work_dir_str = study_configuration["artifact_paths"]["working_directory"]
        branch_prefix = study_configuration["search_protocol"]["run_design"]["branch_prefix"]

        program_md_path = study_configuration["artifact_paths"]["program_md_path"]
        prepare_py_path = study_configuration["artifact_paths"]["prepare_py_path"]
        train_py_path = study_configuration["artifact_paths"]["train_py_path"]

        results_tsv_path = study_configuration["artifact_paths"]["results_tsv_path"]
        log_columns = study_configuration["results_log_data"]["columns"]

    except KeyError as e:
        # Halt execution if the required configuration keys are absent
        raise ValueError(f"Missing required configuration key for version control setup: {e}")

    # Convert the working directory string to a Path object
    working_directory = Path(work_dir_str)

    # Step 1: Initialize a git repository and create a run branch
    # Execute the strict repository initialization and branch creation
    branch_name = initialize_git_and_branch(
        working_directory=working_directory,
        branch_prefix=branch_prefix,
        run_tag=run_tag
    )

    # Step 2: Commit the baseline project state
    # Execute the staging, committing, and filesystem-level locking of the evaluator
    commit_hash = commit_baseline_state(
        working_directory=working_directory,
        program_md_path=program_md_path,
        prepare_py_path=prepare_py_path,
        train_py_path=train_py_path
    )

    # Step 3: Create `results.tsv` without committing it
    # Execute the initialization of the audit log and enforce .gitignore exclusion
    log_path = initialize_uncommitted_results_log(
        working_directory=working_directory,
        results_tsv_path=results_tsv_path,
        columns=log_columns
    )

    # Return the composite version control report
    return Task17VersionControlReport(
        run_branch_name=branch_name,
        baseline_commit_hash=commit_hash,
        results_log_path=log_path
    )

# %%
# Task 18 Scaffolding: Utility Functions for the Search-Loop Algorithm

# ==============================================================================
# Task 18 Scaffolding: Utility Functions for the Search-Loop Algorithm
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Utility 1: Safe Git Command Executor
# -------------------------------------------------------------------------------------------------------------------------------

def execute_git_command(
    command_args: List[str],
    working_directory: Path,
    env_vars: Optional[Dict[str, str]] = None
) -> subprocess.CompletedProcess:
    """
    Executes a git command safely within a specified working directory, capturing
    standard output and standard error for rigorous auditability and debugging.

    Args:
        command_args (List[str]): The list of git arguments (e.g., ["status", "--porcelain"]).
        working_directory (Path): The absolute path to the repository root.
        env_vars (Optional[Dict[str, str]]): Optional environment variables to inject.

    Returns:
        subprocess.CompletedProcess: The result of the executed command.

    Raises:
        TypeError: If the working directory is not a Path object.
        RuntimeError: If the git command returns a non-zero exit code.
    """
    # Validate the working directory type to ensure path operations are safe
    if not isinstance(working_directory, Path):
        raise TypeError("execute_git_command: working_directory must be a pathlib.Path object.")

    # Ensure the working directory actually exists before attempting execution
    if not working_directory.exists() or not working_directory.is_dir():
        raise RuntimeError(f"execute_git_command: Directory does not exist: {working_directory}")

    # Construct the full command list, prepending the 'git' executable
    full_command = ["git"] + command_args

    # Prepare the environment dictionary if provided, merging with the current OS environment
    run_env = os.environ.copy()
    if env_vars:
        run_env.update(env_vars)

    try:
        # Execute the command securely without shell=True to prevent injection vulnerabilities.
        # capture_output=True ensures we can inspect stdout/stderr programmatically.
        # check=True enforces fail-fast behavior on non-zero exit codes.
        result = subprocess.run(
            full_command,
            cwd=working_directory,
            env=run_env,
            check=True,
            capture_output=True,
            text=True
        )
        return result

    except subprocess.CalledProcessError as e:
        # Catch the specific subprocess error and raise a descriptive RuntimeError
        # This ensures the caller receives the exact stderr output for stack trace diagnosis
        error_msg = (
            f"Git command failed: {' '.join(full_command)}\n"
            f"Exit Code: {e.returncode}\n"
            f"Standard Error: {e.stderr.strip()}"
        )
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Utility 2: Agent Proposal Committer
# -------------------------------------------------------------------------------------------------------------------------------

def commit_agent_proposal(
    working_directory: Path,
    editable_script_path: str,
    commit_message: str
) -> str:
    """
    Stages the agent's modified script and creates a git commit, returning the new
    commit hash. This implements Step 3 of the experiment loop, ensuring the proposed
    specification (tau_k) is securely version-controlled before evaluation.

    Args:
        working_directory (Path): The absolute path to the repository root.
        editable_script_path (str): The relative path to the script modified by the agent.
        commit_message (str): The descriptive message provided by the agent.

    Returns:
        str: The 7-character short git hash of the new commit.

    Raises:
        ValueError: If the agent made no actual modifications to the file.
        RuntimeError: If the staging or commit operations fail.
    """
    # 1. Verify that the agent actually modified the file.
    # We use git status --porcelain to check for unstaged changes to the specific file.
    status_result = execute_git_command(["status", "--porcelain", editable_script_path], working_directory)

    if not status_result.stdout.strip():
        # If the output is empty, the file is identical to the HEAD commit.
        # We raise a ValueError to signal the search loop that this proposal is a null-op.
        raise ValueError(f"Agent proposal rejected: No modifications detected in {editable_script_path}.")

    # 2. Stage the modified script
    execute_git_command(["add", editable_script_path], working_directory)

    # 3. Create the commit using explicit credentials to guarantee deterministic execution
    # We sanitize the commit message to prevent multi-line formatting issues in the shell
    sanitized_msg = commit_message.replace("\n", " ").strip()
    if not sanitized_msg:
        sanitized_msg = "agent proposal: unspecified modification"

    execute_git_command([
        "-c", "user.name=Autoresearch Agent",
        "-c", "user.email=agent@autoresearch.local",
        "commit", "-m", sanitized_msg
    ], working_directory)

    # 4. Extract and return the short commit hash for the audit log
    hash_result = execute_git_command(["rev-parse", "--short", "HEAD"], working_directory)

    # Strip trailing whitespace to ensure a clean string
    return hash_result.stdout.strip()

# -------------------------------------------------------------------------------------------------------------------------------
# Utility 3: Workspace Reverter
# -------------------------------------------------------------------------------------------------------------------------------

def revert_workspace_to_best(working_directory: Path) -> None:
    """
    Reverts the git workspace to the previous commit, discarding the agent's latest
    proposal. This implements Step 9 of the experiment loop, executed when the
    candidate script fails to improve the empirical score (s_k >= s_best).

    Args:
        working_directory (Path): The absolute path to the repository root.

    Raises:
        RuntimeError: If the git reset or clean operations fail.
    """
    # 1. Execute a hard reset to move HEAD back by one commit and restore tracked files
    # Equation/Logic: HEAD <- HEAD~1
    execute_git_command(["reset", "--hard", "HEAD~1"], working_directory)

    # 2. Execute a clean operation to remove any untracked files or directories
    # the agent might have accidentally created during its session.
    # -f forces deletion, -d removes untracked directories.
    execute_git_command(["clean", "-fd"], working_directory)

# -------------------------------------------------------------------------------------------------------------------------------
# Utility 4: TSV Audit Logger
# -------------------------------------------------------------------------------------------------------------------------------

def append_to_audit_log(
    log_path: Path,
    commit_hash: str,
    rmse_score: float,
    status: str,
    description: str
) -> None:
    """
    Appends a structured record of the experiment to the results.tsv audit log.
    This implements Step 7 of the experiment loop, ensuring that every attempted
    specification is recorded BEFORE the keep/revert decision is executed.

    Args:
        log_path (Path): The absolute path to the results.tsv file.
        commit_hash (str): The 7-character git hash of the evaluated script.
        rmse_score (float): The computed RMSE, or 0.0 if the run crashed.
        status (str): The outcome status, strictly in {'keep', 'discard', 'crash'}.
        description (str): A human-readable summary of the method attempted.

    Raises:
        ValueError: If the status is not one of the formally permitted values.
        OSError: If file system permissions prevent appending to the log.
    """
    # Strictly validate the status against the formal set defined in the manuscript
    permitted_statuses = {"keep", "discard", "crash"}
    if status not in permitted_statuses:
        raise ValueError(f"Invalid status '{status}'. Must be one of {permitted_statuses}.")

    # Format the RMSE score to exactly 4 decimal places for consistent alignment.
    # The manuscript notes that crash rows may appear as 0.0000.
    formatted_rmse = f"{rmse_score:.4f}"

    # Sanitize the description to remove tabs or newlines that would corrupt the TSV format
    sanitized_desc = description.replace("\t", " ").replace("\n", " ").strip()

    # Construct the tab-separated row string
    log_row = f"{commit_hash}\t{formatted_rmse}\t{status}\t{sanitized_desc}\n"

    # Open the file in append mode ('a') with strict UTF-8 encoding.
    # This operation is brief, minimizing the risk of concurrent write collisions.
    with open(log_path, 'a', encoding='utf-8') as f:
        f.write(log_row)

# -------------------------------------------------------------------------------------------------------------------------------
# Utility 5: Timeout-Bound Evaluator Executor
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class EvaluatorExecutionResult:
    """
    A structured record containing the outcome of the isolated evaluator subprocess.

    Attributes:
        success (bool): True if the evaluator completed without crashing or timing out.
        rmse (Optional[float]): The extracted RMSE score, or None if execution failed.
        error_context (Optional[str]): The tail of the run.log if a crash occurred.
        is_timeout (bool): True if the execution was terminated due to the time limit.
    """
    # Boolean flag indicating if the subprocess exited with code 0 and produced a valid RMSE
    success: bool
    # The scalar RMSE extracted from the log, or None if the run failed
    rmse: Optional[float]
    # The trailing 50 lines of the execution log, providing diagnostic context for crashes
    error_context: Optional[str]
    # Boolean flag indicating if the subprocess was killed by the OS due to budget exhaustion
    is_timeout: bool


def execute_evaluator_subprocess(
    working_directory: Path,
    evaluator_script_name: str = "prepare.py",
    timeout_minutes: float = 30.0
) -> EvaluatorExecutionResult:
    """
    Executes the immutable evaluator in a strictly isolated OS-level subprocess,
    enforcing the manuscript's 30-minute timeout rule. It utilizes OS-specific
    process group management to mathematically guarantee that the entire process
    tree is eradicated upon timeout, preventing zombie process resource leaks.

    Args:
        working_directory (Path): The absolute path to the repository root.
        evaluator_script_name (str): The name of the evaluator script to execute.
        timeout_minutes (float): The maximum allowed execution time in minutes.

    Returns:
        EvaluatorExecutionResult: The structured outcome of the evaluation.
    """
    # Construct the absolute filesystem path for the transient run.log output file
    run_log_path = working_directory / "run.log"

    # Convert the timeout limit from minutes to seconds for the subprocess module
    timeout_seconds = timeout_minutes * 60.0

    # Define the command list to execute the evaluator script using the Python interpreter
    command = ["python", evaluator_script_name]

    # Initialize the timeout flag to False
    is_timeout = False
    # Initialize the execution failure flag to False
    execution_failed = False

    # Initialize the kwargs dictionary for the Popen constructor
    popen_kwargs: Dict[str, Any] = {
        # Set the current working directory for the subprocess
        "cwd": working_directory,
        # Redirect standard error to standard output to capture all diagnostics in one stream
        "stderr": subprocess.STDOUT
    }

    # Branch the process group configuration based on the host operating system
    if sys.platform != "win32":
        # On Unix-like systems, use os.setsid to create a new session and process group
        # This ensures that signals sent to the group ID reach all child processes
        popen_kwargs["preexec_fn"] = os.setsid
    else:
        # On Windows systems, use the CREATE_NEW_PROCESS_GROUP creation flag
        # This isolates the subprocess tree for safe termination
        popen_kwargs["creationflags"] = subprocess.CREATE_NEW_PROCESS_GROUP

    # Open the run.log file in write mode to capture the subprocess output stream
    with open(run_log_path, 'w', encoding='utf-8') as log_file:
        # Assign the open file handle to the stdout parameter of the Popen kwargs
        popen_kwargs["stdout"] = log_file

        # Spawn the isolated subprocess using the configured command and kwargs
        process = subprocess.Popen(command, **popen_kwargs)

        try:
            # Wait for the subprocess to complete, enforcing the strict timeout limit
            process.communicate(timeout=timeout_seconds)

            # Check the return code; a non-zero code indicates a runtime crash in the agent's script
            if process.returncode != 0:
                # Flag the execution as failed
                execution_failed = True

        except subprocess.TimeoutExpired:
            # Catch the TimeoutExpired exception if the process exceeds the time budget
            is_timeout = True
            # Flag the execution as failed due to timeout
            execution_failed = True

            # Execute the OS-specific process group termination logic to prevent zombie leaks
            if sys.platform != "win32":
                # On Unix, send SIGKILL to the entire process group using the parent's PID
                os.killpg(os.getpgid(process.pid), signal.SIGKILL)
            else:
                # On Windows, use the terminate method which handles the process group if flagged
                process.terminate()

            # Call communicate again to flush the pipes and formally reap the terminated process
            process.communicate()

    # If the execution failed or timed out, extract the diagnostic context from the log
    if execution_failed:
        # Initialize the error context with a default message
        error_context = "Unknown error."

        # Verify that the run.log file was actually created
        if run_log_path.exists():
            # Open the log file in read mode to extract the trailing lines
            with open(run_log_path, 'r', encoding='utf-8') as f:
                # Read all lines from the log file into a list
                lines = f.readlines()
                # Extract the last 50 lines, mirroring the 'tail -n 50 run.log' instruction
                error_context = "".join(lines[-50:]).strip()

        # If the failure was a timeout, prepend a clear warning to the error context
        if is_timeout:
            # Inject the timeout notification for the agent's diagnostic prompt
            error_context = f"TIMEOUT EXCEEDED ({timeout_minutes} min).\n" + error_context

        # Return the populated failure result, setting rmse to None
        return EvaluatorExecutionResult(
            success=False,
            rmse=None,
            error_context=error_context,
            is_timeout=is_timeout
        )

    # If execution succeeded, initialize the extracted RMSE variable to None
    extracted_rmse = None

    # Verify that the run.log file exists before attempting to parse it
    if run_log_path.exists():
        # Open the log file in read mode to search for the target metric
        with open(run_log_path, 'r', encoding='utf-8') as f:
            # Iterate over each line in the log file sequentially
            for line in f:
                # Apply a regular expression to find the line starting with 'rmse:' and capture the float
                match = re.match(r"^rmse:\s*([0-9]*\.?[0-9]+)", line.strip(), re.IGNORECASE)
                # If a match is found, extract the captured group
                if match:
                    # Cast the captured string to a native Python float
                    extracted_rmse = float(match.group(1))
                    # Break the loop early since the target metric has been found
                    break

    # If the script completed with code 0 but failed to print the required output format
    if extracted_rmse is None:
        # Return a failure result with a descriptive error context
        return EvaluatorExecutionResult(
            success=False,
            rmse=None,
            error_context="Execution completed, but no '^rmse: <value>' line was found in run.log.",
            is_timeout=False
        )

    # Return the fully successful result containing the parsed scalar RMSE
    return EvaluatorExecutionResult(
        success=True,
        rmse=extracted_rmse,
        error_context=None,
        is_timeout=False
    )

# %%
# Task 18 Scaffolding: LLM Interaction Utilities via Anthropic SDK

# ==============================================================================
# Task 18 Scaffolding: LLM Interaction Utilities via Anthropic SDK
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Utility 1: Anthropic Client Initializer
# -------------------------------------------------------------------------------------------------------------------------------

def initialize_anthropic_client(study_configuration: Dict[str, Any]) -> anthropic.Anthropic:
    """
    Instantiates and configures the Anthropic API client, rigorously verifying the
    presence of the required API key in the environment to prevent silent authentication
    failures during the autonomous search loop.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary containing
            the expected environment variable name for the API key.

    Returns:
        anthropic.Anthropic: The configured, ready-to-use API client.

    Raises:
        ValueError: If the configuration is missing the env var key, or if the
            environment variable itself is not set.
    """
    try:
        # Extract the expected environment variable name from the configuration
        env_var_name = study_configuration["search_protocol"]["agent_specification"]["api_key_env_var"]
    except KeyError as e:
        raise ValueError(f"Missing required configuration key for API key environment variable: {e}")

    # Retrieve the API key from the OS environment
    api_key = os.environ.get(env_var_name)

    if not api_key:
        # Halt execution immediately if the key is missing, as the agent cannot function
        raise ValueError(
            f"Fatal: Anthropic API key not found. Please set the '{env_var_name}' "
            f"environment variable before initiating the discovery loop."
        )

    # Instantiate and return the client
    return anthropic.Anthropic(api_key=api_key)

# -------------------------------------------------------------------------------------------------------------------------------
# Utility 2: Agent Prompt Constructor
# -------------------------------------------------------------------------------------------------------------------------------

def construct_agent_prompt(
    instruction_contract: str,
    current_script_content: str,
    audit_log_content: str,
    error_context: Optional[str] = None
) -> str:
    """
    Constructs a highly structured, XML-delimited prompt string that injects the
    current workspace state (contract, script, log, and errors) into the LLM's context.
    This ensures the agent is perfectly "informed by log L_{k-1}" as required by the protocol.

    Args:
        instruction_contract (str): The verbatim contents of program.md.
        current_script_content (str): The current contents of the editable script (tau_{k-1}).
        audit_log_content (str): The current contents of results.tsv (L_{k-1}).
        error_context (Optional[str]): The tail of run.log if the previous run crashed.

    Returns:
        str: The fully formatted prompt string ready for transmission.
    """
    # Define the strict output schema required for deterministic parsing (Utility 4)
    output_schema_instructions = (
        "CRITICAL INSTRUCTION: You must output your proposed Python script enclosed "
        "exactly within <proposed_script> and </proposed_script> XML tags. "
        "You must also output a concise, 1-line description of your strategy enclosed "
        "exactly within <commit_message> and </commit_message> XML tags. "
        "Do not include markdown formatting (e.g., ```python) inside the XML tags."
    )

    # Construct the composite prompt using clear XML delimiters to prevent the LLM
    # from confusing instructions with data payloads.
    prompt_parts = [
        "<instruction_contract>",
        instruction_contract,
        "</instruction_contract>\n",
        "<current_script_state>",
        current_script_content,
        "</current_script_state>\n",
        "<audit_log_history>",
        audit_log_content,
        "</audit_log_history>\n"
    ]

    # Inject error context if the previous iteration resulted in a crash
    if error_context:
        prompt_parts.extend([
            "<previous_run_error_log>",
            "The previous script crashed or timed out. Diagnose and fix the following error:",
            error_context,
            "</previous_run_error_log>\n"
        ])

    # Append the strict output schema instructions
    prompt_parts.append(output_schema_instructions)

    return "\n".join(prompt_parts)

# -------------------------------------------------------------------------------------------------------------------------------
# Utility 3: LLM API Invoker
# -------------------------------------------------------------------------------------------------------------------------------

def invoke_llm_with_backoff(
    client: anthropic.Anthropic,
    model_version: str,
    prompt: str,
    max_retries: int = 5,
    base_delay_seconds: float = 2.0
) -> str:
    """
    Invokes the Anthropic API to generate the next candidate script, implementing
    rigorous exponential backoff to handle transient network failures or rate limits
    without crashing the long-running search loop.

    Args:
        client (anthropic.Anthropic): The configured API client.
        model_version (str): The exact model identifier (e.g., 'claude-3-opus-20240229').
        prompt (str): The fully constructed prompt string.
        max_retries (int): Maximum number of retry attempts before failing.
        base_delay_seconds (float): Initial delay for exponential backoff.

    Returns:
        str: The raw text response from the LLM.

    Raises:
        RuntimeError: If the API call fails after exhausting all retries.
    """
    attempt = 0

    while attempt <= max_retries:
        try:
            # Execute the API call. We use the Messages API as required by modern Claude models.
            # Temperature and top_p are left at platform defaults unless explicitly overridden,
            # adhering to the ImplementationChoicesManifest from Task 16.
            response = client.messages.create(
                model=model_version,
                max_tokens=4096, # Sufficient for a Python script and commit message
                messages=[
                    {"role": "user", "content": prompt}
                ]
            )

            # Extract and return the text content from the response
            return response.content[0].text

        except (anthropic.APIError, anthropic.APIConnectionError, anthropic.RateLimitError) as e:
            attempt += 1
            if attempt > max_retries:
                # Exhausted all retries; escalate to a fatal error
                raise RuntimeError(f"LLM API invocation failed after {max_retries} retries. Final error: {e}")

            # Calculate exponential backoff delay: base_delay * (2 ^ (attempt - 1))
            delay = base_delay_seconds * (2 ** (attempt - 1))
            time.sleep(delay)

# -------------------------------------------------------------------------------------------------------------------------------
# Utility 4: LLM Output Parser
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ParsedAgentProposal:
    """
    A structured, implementation-grade record containing the extracted components
    of the Large Language Model's (LLM) response. This class serves as the
    formal data contract between the LLM output parser and the workspace mutator,
    ensuring that the proposed script (tau_k) and its associated metadata are
    rigorously isolated and validated before being materialized in the
    verifiable audit trail.

    Attributes:
        proposed_script (str): The raw Python source code extracted from the
            LLM's response, intended to overwrite the current 'train.py'.
        commit_message (str): A concise, single-line description of the
            methodological strategy attempted by the agent, used for the
            git commit and the results.tsv audit log.
    """
    # The raw Python source code proposed by the agent for the next experiment iteration
    proposed_script: str
    # The descriptive summary of the proposed modification for version control documentation
    commit_message: str

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity
        of the parsed agent proposal before it is committed to the repository.

        Raises:
            TypeError: If the attributes are not of the required string type.
            ValueError: If the proposed script or commit message is empty or whitespace-only.
        """
        # Verify that the proposed_script is a string to ensure compatibility with file I/O operations
        if not isinstance(self.proposed_script, str):
            # Raise a TypeError if the parser returned an incorrect data type for the source code
            raise TypeError("ParsedAgentProposal: proposed_script must be a string.")

        # Verify that the commit_message is a string to ensure compatibility with git command execution
        if not isinstance(self.commit_message, str):
            # Raise a TypeError if the parser returned an incorrect data type for the metadata
            raise TypeError("ParsedAgentProposal: commit_message must be a string.")

        # Ensure the proposed script is not empty to prevent the creation of null-op experiments
        if not self.proposed_script.strip():
            # Raise a ValueError if the agent failed to provide executable code
            raise ValueError("ParsedAgentProposal: proposed_script cannot be empty or whitespace-only.")

        # Ensure the commit message is not empty to maintain the descriptive integrity of the audit log
        if not self.commit_message.strip():
            # Raise a ValueError if the agent failed to provide a strategy description
            raise ValueError("ParsedAgentProposal: commit_message cannot be empty or whitespace-only.")

def parse_llm_response(raw_response: str) -> ParsedAgentProposal:
    """
    Applies rigorous regular expressions to extract the proposed Python script and
    the commit message from the LLM's raw text response, enforcing the strict
    XML-delimited schema defined in the prompt constructor.

    Args:
        raw_response (str): The raw text output from the Anthropic API.

    Returns:
        ParsedAgentProposal: The structured extraction of the script and message.

    Raises:
        ValueError: If the response does not conform to the required XML schema.
    """
    # Regex to extract content strictly between <proposed_script> tags.
    # re.DOTALL ensures that the '.' character matches newlines.
    script_match = re.search(r"<proposed_script>(.*?)</proposed_script>", raw_response, re.DOTALL | re.IGNORECASE)

    # Regex to extract content strictly between <commit_message> tags.
    msg_match = re.search(r"<commit_message>(.*?)</commit_message>", raw_response, re.DOTALL | re.IGNORECASE)

    if not script_match:
        raise ValueError("Agent response parsing failed: <proposed_script> tags not found.")

    if not msg_match:
        raise ValueError("Agent response parsing failed: <commit_message> tags not found.")

    # Extract and clean the matched strings
    proposed_script = script_match.group(1).strip()
    commit_message = msg_match.group(1).strip()

    # Defensive check: ensure the script is not empty
    if not proposed_script:
        raise ValueError("Agent response parsing failed: Extracted script is empty.")

    # Defensive check: ensure the commit message is not empty
    if not commit_message:
        commit_message = "agent proposal: unspecified modification"

    return ParsedAgentProposal(
        proposed_script=proposed_script,
        commit_message=commit_message
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Utility 5: Workspace Mutator
# -------------------------------------------------------------------------------------------------------------------------------

def overwrite_editable_script(
    working_directory: Path,
    editable_script_path: str,
    new_script_content: str
) -> None:
    """
    Overwrites the editable script on disk with the agent's proposed code.
    This implements Step 2 of the experiment loop ("Edit train.R with a new lambda
    selection strategy"), materializing the proposal (tau_k) in the workspace.

    Args:
        working_directory (Path): The absolute path to the repository root.
        editable_script_path (str): The relative path to the script to be modified.
        new_script_content (str): The parsed Python code proposed by the agent.

    Raises:
        OSError: If file system permissions prevent writing to the file.
    """
    # Construct the absolute path to the editable script
    full_script_path = working_directory / editable_script_path

    # Open the file in write mode ('w') to explicitly truncate and overwrite existing content.
    # Strict UTF-8 encoding is enforced to prevent corruption of special characters.
    with open(full_script_path, 'w', encoding='utf-8', newline='') as f:
        f.write(new_script_content)

# %%
# Task 18: Implement the Search-Loop Algorithm

# ==============================================================================
# Task 18: Implement the Search-Loop Algorithm
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 18, Steps 1, 2, & 3: Formal Algorithm, Ordering, and Crash Handling
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ParsedAgentProposal:
    """
    A structured, implementation-grade record containing the extracted components
    of the Large Language Model's (LLM) response. This class serves as the
    formal data contract between the LLM output parser and the workspace mutator,
    ensuring that the proposed script (tau_k) and its associated metadata are
    rigorously isolated and validated before being materialized in the
    verifiable audit trail.

    Attributes:
        proposed_script (str): The raw Python source code extracted from the
            LLM's response, intended to overwrite the current 'train.py'.
        commit_message (str): A concise, single-line description of the
            methodological strategy attempted by the agent, used for the
            git commit and the results.tsv audit log.
    """
    # The raw Python source code proposed by the agent for the next experiment iteration
    proposed_script: str
    # The descriptive summary of the proposed modification for version control documentation
    commit_message: str

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity
        of the parsed agent proposal before it is committed to the repository.

        Raises:
            TypeError: If the attributes are not of the required string type.
            ValueError: If the proposed script or commit message is empty or whitespace-only.
        """
        # Verify that the proposed_script is a string to ensure compatibility with file I/O operations
        if not isinstance(self.proposed_script, str):
            # Raise a TypeError if the parser returned an incorrect data type for the source code
            raise TypeError("ParsedAgentProposal: proposed_script must be a string.")

        # Verify that the commit_message is a string to ensure compatibility with git command execution
        if not isinstance(self.commit_message, str):
            # Raise a TypeError if the parser returned an incorrect data type for the metadata
            raise TypeError("ParsedAgentProposal: commit_message must be a string.")

        # Ensure the proposed script is not empty to prevent the creation of null-op experiments
        if not self.proposed_script.strip():
            # Raise a ValueError if the agent failed to provide executable code
            raise ValueError("ParsedAgentProposal: proposed_script cannot be empty or whitespace-only.")

        # Ensure the commit message is not empty to maintain the descriptive integrity of the audit log
        if not self.commit_message.strip():
            # Raise a ValueError if the agent failed to provide a strategy description
            raise ValueError("ParsedAgentProposal: commit_message cannot be empty or whitespace-only.")


def execute_autonomous_search_loop(
    working_directory: Path,
    study_configuration: Dict[str, Any],
    anthropic_client: Any,  # Expected type: anthropic.Anthropic
    prompt_templates: Any,  # Expected type: AgentPromptTemplates
    vc_report: Any,         # Expected type: Task17VersionControlReport
    model_version: str
) -> Task18SearchLoopReport:
    """
    Executes the fully autonomous edit-evaluate-log-revert cycle (Algorithm 1),
    strictly adhering to the 10-step ordering and crash handling protocols defined
    in the manuscript's instruction contract.

    Args:
        working_directory (Path): The absolute path to the repository root.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        anthropic_client (anthropic.Anthropic): The configured LLM API client.
        prompt_templates (AgentPromptTemplates): The structured prompt strings.
        vc_report (Task17VersionControlReport): The version control initialization state.
        model_version (str): The exact model identifier for the API calls.

    Returns:
        Task18SearchLoopReport: The comprehensive summary of the search execution.

    Raises:
        RuntimeError: If the baseline evaluation fails catastrophically.
    """
    # Extract configuration parameters
    target_k = int(study_configuration["search_protocol"]["run_design"]["search_budget_target_K"])
    timeout_mins = float(study_configuration["search_protocol"]["run_design"]["timeout_limit_minutes"])

    program_md_path = working_directory / study_configuration["artifact_paths"]["program_md_path"]
    train_py_path = working_directory / study_configuration["artifact_paths"]["train_py_path"]
    results_tsv_path = working_directory / study_configuration["artifact_paths"]["results_tsv_path"]

    # Read the static instruction contract once
    with open(program_md_path, 'r', encoding='utf-8') as f:
        instruction_contract = f.read()

    # -------------------------------------------------------------------------
    # Initialization: Evaluate tau_0 (Baseline)
    # -------------------------------------------------------------------------
    # The manuscript requires evaluating the initial script before starting the loop.
    baseline_eval_result = execute_evaluator_subprocess(
        working_directory=working_directory,
        evaluator_script_name=study_configuration["artifact_paths"]["prepare_py_path"],
        timeout_minutes=timeout_mins
    )

    if not baseline_eval_result.success or baseline_eval_result.rmse is None:
        raise RuntimeError(f"Fatal: Baseline evaluation failed. Cannot start search loop. Context: {baseline_eval_result.error_context}")

    best_rmse = baseline_eval_result.rmse
    best_commit = vc_report.baseline_commit_hash

    # Log the baseline to results.tsv
    append_to_audit_log(
        log_path=results_tsv_path,
        commit_hash=best_commit,
        rmse_score=best_rmse,
        status="keep",
        description="baseline simple average"
    )

    error_context_for_next_prompt = None
    termination_reason = "unknown"

    # -------------------------------------------------------------------------
    # The Experiment Loop (Algorithm 1)
    # -------------------------------------------------------------------------
    while True:
        # Enforce the soft budget cap by counting data rows in results.tsv
        with open(results_tsv_path, 'r', encoding='utf-8') as f:
            # Subtract 1 for the header row
            current_experiment_count = len(f.readlines()) - 1

        k_remaining = target_k - current_experiment_count
        if k_remaining <= 0:
            termination_reason = "budget_exhausted"
            break

        # Step 1: Read the current state
        with open(train_py_path, 'r', encoding='utf-8') as f:
            current_script_content = f.read()

        with open(results_tsv_path, 'r', encoding='utf-8') as f:
            audit_log_content = f.read()

        # Construct the prompt, injecting the remaining budget and any previous error context
        base_prompt = construct_agent_prompt(
            instruction_contract=instruction_contract,
            current_script_content=current_script_content,
            audit_log_content=audit_log_content,
            error_context=error_context_for_next_prompt
        )

        # Prepend the session management instructions
        full_prompt = f"{prompt_templates.format_restart_prompt(k_remaining)}\n\n{base_prompt}"

        # Clear the error context for the next iteration
        error_context_for_next_prompt = None

        # Step 2: Edit train.py with a new lambda selection strategy
        try:
            # Invoke the LLM with exponential backoff
            raw_response = invoke_llm_with_backoff(
                client=anthropic_client,
                model_version=model_version,
                prompt=full_prompt
            )

            # Parse the XML-delimited response
            parsed_proposal = parse_llm_response(raw_response)

            # Overwrite the script on disk
            overwrite_editable_script(
                working_directory=working_directory,
                editable_script_path=study_configuration["artifact_paths"]["train_py_path"],
                new_script_content=parsed_proposal.proposed_script
            )

        except Exception as e:
            # If the LLM fails to generate or parse correctly, we log a crash and continue.
            # We must create a dummy commit to maintain the log structure.
            dummy_msg = f"agent parsing failure: {str(e)[:50]}"
            # If overwrite failed, the file is unchanged. We append a comment to force a diff.
            with open(train_py_path, 'a', encoding='utf-8') as f:
                f.write(f"\n# Parsing failed: {dummy_msg}\n")
            parsed_proposal = ParsedAgentProposal(proposed_script="", commit_message=dummy_msg)

        # Step 3: git commit -m "descriptive message"
        try:
            current_commit = commit_agent_proposal(
                working_directory=working_directory,
                editable_script_path=study_configuration["artifact_paths"]["train_py_path"],
                commit_message=parsed_proposal.commit_message
            )
        except ValueError:
            # The agent made no changes. Log as discard and continue.
            append_to_audit_log(
                log_path=results_tsv_path,
                commit_hash="0000000", # Null hash for no-op
                rmse_score=0.0,
                status="discard",
                description="no modifications proposed"
            )
            continue

        # Step 4: Run evaluator
        eval_result = execute_evaluator_subprocess(
            working_directory=working_directory,
            evaluator_script_name=study_configuration["artifact_paths"]["prepare_py_path"],
            timeout_minutes=timeout_mins
        )

        # Step 5 & 6: Extract RMSE and Diagnose crash
        if eval_result.success and eval_result.rmse is not None:
            current_rmse = eval_result.rmse
            status_candidate = "keep" if current_rmse < best_rmse else "discard"
            log_rmse = current_rmse
        else:
            # Formal crash handling: s_k = +infinity
            current_rmse = float('inf')
            status_candidate = "crash"
            log_rmse = 0.0000 # TSV encoding convention for crashes
            # Feed the error trace back to the agent for the next iteration
            error_context_for_next_prompt = eval_result.error_context

        # Step 7: Log to results.tsv (BEFORE keep/revert decision)
        append_to_audit_log(
            log_path=results_tsv_path,
            commit_hash=current_commit,
            rmse_score=log_rmse,
            status=status_candidate,
            description=parsed_proposal.commit_message
        )

        # Step 8 & 9: Keep if improved, Revert if worse
        if current_rmse < best_rmse:
            # Keep the commit
            best_rmse = current_rmse
            best_commit = current_commit
        else:
            # Revert the workspace to the previous best state
            revert_workspace_to_best(working_directory)

        # Step 10: Repeat (handled by the while loop)

    # Return the comprehensive summary report
    return Task18SearchLoopReport(
        run_branch_name=vc_report.run_branch_name,
        total_experiments=current_experiment_count,
        best_rmse=best_rmse,
        best_commit_hash=best_commit,
        termination_reason=termination_reason
    )

# %%
# Task 19: Implement Session Recovery Semantics

# ==============================================================================
# Task 19: Implement Session Recovery Semantics
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Step 1: Read the persistent state on every restart
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class SessionRecoveryState:
    """
    A structured, implementation-grade container representing the parsed state of the
    agentic search loop, derived exclusively from the immutable filesystem artifacts
    (results.tsv and git history). This class serves as the single source of truth
    for the session recovery protocol, ensuring that the autonomous agent resumes
    from the mathematically optimal specification (tau_best) without look-ahead bias.

    Attributes:
        experiment_count (int): The total number of evaluated candidate scripts
            recorded in the audit log.
        best_score (float): The lowest Root Mean Squared Error (s_best) achieved
            among all 'keep' entries.
        best_commit (str): The 7-character git hash of the script that achieved
             the best_score.
        latest_commit (str): The 7-character git hash of the most recent commit
            on the active run branch.
        tsv_dataframe (pd.DataFrame): The full parsed audit log (results.tsv)
            used for state reconciliation.
    """
    # The total count of experiments conducted in the current run
    experiment_count: int
    # The current global minimum RMSE (s_best) found during the search
    best_score: float
    # The git identifier for the current best-performing script (tau_best)
    best_commit: str
    # The git identifier for the most recent proposal in the workspace
    latest_commit: str
    # The pandas DataFrame representation of the results.tsv audit log
    tsv_dataframe: pd.DataFrame

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the session recovery state.

        Raises:
            TypeError: If any attribute does not match the required type.
            ValueError: If numerical values are mathematically invalid.
        """
        # Verify that experiment_count is a non-negative integer
        if not isinstance(self.experiment_count, int) or self.experiment_count < 0:
            # Raise a ValueError if the count is logically impossible
            raise ValueError("SessionRecoveryState: experiment_count must be a non-negative integer.")

        # Verify that best_score is a float
        if not isinstance(self.best_score, (float, np.float64)):
            # Raise a TypeError if the score type is incorrect
            raise TypeError("SessionRecoveryState: best_score must be a float.")

        # Verify that best_commit is a string
        if not isinstance(self.best_commit, str):
            # Raise a TypeError if the commit hash type is incorrect
            raise TypeError("SessionRecoveryState: best_commit must be a string.")

        # Verify that latest_commit is a string
        if not isinstance(self.latest_commit, str):
            # Raise a TypeError if the commit hash type is incorrect
            raise TypeError("SessionRecoveryState: latest_commit must be a string.")

        # Verify that tsv_dataframe is a pandas DataFrame
        if not isinstance(self.tsv_dataframe, pd.DataFrame):
            # Raise a TypeError if the log data structure is incorrect
            raise TypeError("SessionRecoveryState: tsv_dataframe must be a pandas.DataFrame.")


def read_persistent_state(
    working_directory: Path,
    results_tsv_path: str
) -> SessionRecoveryState:
    """
    Parses the TSV audit log and the git history to reconstruct the exact state of the
    discovery loop, mathematically isolating the best performing specification.

    Args:
        working_directory (Path): The absolute path to the repository root.
        results_tsv_path (str): The relative path to the TSV audit log.

    Returns:
        SessionRecoveryState: The structured representation of the persistent state.

    Raises:
        FileNotFoundError: If the TSV log does not exist.
        RuntimeError: If git commands fail.
    """
    full_tsv_path = working_directory / results_tsv_path

    if not full_tsv_path.exists():
        raise FileNotFoundError(f"Audit log not found at {full_tsv_path}. Cannot recover session.")

    # 1. Read results.tsv using pandas for robust tabular parsing
    # We enforce string typing for the commit column to prevent hash truncation (e.g., '000123' -> 123)
    df_log = pd.read_csv(full_tsv_path, sep='\t', dtype={'commit': str})

    # The experiment count is exactly the number of data rows
    experiment_count = len(df_log)

    # 2. Identify the current best score and commit
    if experiment_count == 0:
        # If the log is empty (header only), initialize with infinite score
        best_score = float('inf')
        best_commit = ""
    else:
        # Filter for rows where the status is strictly 'keep'
        # This mathematically excludes crashes (0.0000) and discards from the minimum search
        keeps_df = df_log[df_log['status'] == 'keep']

        if keeps_df.empty:
            # If no keeps exist (e.g., only crashes so far), default to infinity
            best_score = float('inf')
            best_commit = ""
        else:
            # Locate the row with the absolute minimum RMSE
            best_idx = keeps_df['rmse'].idxmin()
            best_score = float(keeps_df.loc[best_idx, 'rmse'])
            best_commit = str(keeps_df.loc[best_idx, 'commit'])

    # 3. Read the git log to identify the latest commit on the branch
    # --oneline formats output as "<short_hash> <message>"
    git_log_proc = execute_git_command(["log", "--oneline", "-1"], working_directory)
    git_log_output = git_log_proc.stdout.strip()

    if not git_log_output:
        raise RuntimeError("Git log is empty. Repository is in an invalid state.")

    # Extract the 7-character short hash (the first token of the output)
    latest_commit = git_log_output.split(" ")[0]

    return SessionRecoveryState(
        experiment_count=experiment_count,
        best_score=best_score,
        best_commit=best_commit,
        latest_commit=latest_commit,
        tsv_dataframe=df_log
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Step 2: Reconcile unlogged commits and stray edits
# -------------------------------------------------------------------------------------------------------------------------------

def reconcile_workspace_state(
    recovery_state: SessionRecoveryState,
    working_directory: Path,
    study_configuration: Dict[str, Any]
) -> SessionRecoveryState:
    """
    Detects and resolves inconsistencies between the git history and the TSV log,
    evaluating unlogged commits and discarding stray edits to ensure a mathematically
    sound starting point for the agent.

    Args:
        recovery_state (SessionRecoveryState): The parsed state from Step 1.
        working_directory (Path): The absolute path to the repository root.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        SessionRecoveryState: The updated recovery state after reconciliation.
    """
    df_log = recovery_state.tsv_dataframe
    latest_commit = recovery_state.latest_commit

    # Rule (b): Stray uncommitted edits
    # Check for uncommitted changes in the editable script
    editable_script_path = study_configuration["artifact_paths"]["train_py_path"]
    status_proc = execute_git_command(["status", "--porcelain", editable_script_path], working_directory)

    if status_proc.stdout.strip():
        # Uncommitted changes exist. The protocol dictates discarding them as they
        # were not formally proposed via a commit.
        execute_git_command(["checkout", "--", editable_script_path], working_directory)

    # Rule (a): Unlogged commit
    # Check if the latest git commit is missing from the TSV log
    commit_logged = False
    if not df_log.empty and 'commit' in df_log.columns:
        commit_logged = (df_log['commit'] == latest_commit).any()

    if not commit_logged and recovery_state.experiment_count > 0:
        # The commit exists but was never evaluated (e.g., session crashed before Step 4).
        # We must evaluate it now to maintain the audit trail.
        timeout_mins = float(study_configuration["search_protocol"]["run_design"]["timeout_limit_minutes"])
        evaluator_script = study_configuration["artifact_paths"]["prepare_py_path"]
        results_tsv_path = study_configuration["artifact_paths"]["results_tsv_path"]

        # Run the evaluator subprocess
        eval_result = execute_evaluator_subprocess(
            working_directory=working_directory,
            evaluator_script_name=evaluator_script,
            timeout_minutes=timeout_mins
        )

        # Determine score and status
        if eval_result.success and eval_result.rmse is not None:
            current_rmse = eval_result.rmse
            status_candidate = "keep" if current_rmse < recovery_state.best_score else "discard"
            log_rmse = current_rmse
        else:
            current_rmse = float('inf')
            status_candidate = "crash"
            log_rmse = 0.0000

        # Log the recovered experiment
        append_to_audit_log(
            log_path=working_directory / results_tsv_path,
            commit_hash=latest_commit,
            rmse_score=log_rmse,
            status=status_candidate,
            description="recovered unlogged commit"
        )

        # Execute keep/revert logic
        if current_rmse < recovery_state.best_score:
            # Update the recovery state with the new best
            recovery_state.best_score = current_rmse
            recovery_state.best_commit = latest_commit
        else:
            # Revert the workspace
            revert_workspace_to_best(working_directory)

        # Increment the experiment count
        recovery_state.experiment_count += 1

    # Rule (c): Logged but unreverted discards
    # If the last logged action was a discard/crash, but the workspace is still on that commit,
    # the revert step was interrupted.
    if not df_log.empty:
        last_row = df_log.iloc[-1]
        if last_row['commit'] == latest_commit and last_row['status'] in ['discard', 'crash']:
            # Perform the missing revert
            revert_workspace_to_best(working_directory)

    return recovery_state

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Step 3: Identify the current best and inject the remaining budget
# -------------------------------------------------------------------------------------------------------------------------------

def inject_budget_and_format_prompt(
    recovery_state: SessionRecoveryState,
    working_directory: Path,
    study_configuration: Dict[str, Any],
    prompt_templates: Any  # Expected type: AgentPromptTemplates
) -> str:
    """
    Computes the remaining computational budget, formats the restart prompt, and
    absolutely guarantees the git workspace is resting on the best known commit.

    Args:
        recovery_state (SessionRecoveryState): The reconciled state.
        working_directory (Path): The absolute path to the repository root.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        prompt_templates (AgentPromptTemplates): The structured prompt strings.

    Returns:
        str: The formatted restart prompt, or "BUDGET_EXHAUSTED" if the cap is reached.
    """
    # 1. Guarantee the workspace is on the best commit
    # This is a defense-in-depth measure to ensure the agent always branches from tau_best
    if recovery_state.best_commit:
        execute_git_command(["reset", "--hard", recovery_state.best_commit], working_directory)
        execute_git_command(["clean", "-fd"], working_directory)

    # 2. Compute the remaining budget
    target_k = int(study_configuration["search_protocol"]["run_design"]["search_budget_target_K"])
    k_remaining = target_k - recovery_state.experiment_count

    # 3. Enforce the soft cap
    if k_remaining <= 0:
        return "BUDGET_EXHAUSTED"

    # 4. Format and return the prompt
    return prompt_templates.format_restart_prompt(k_remaining)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task19SessionRecoveryReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the session recovery phase. This report encapsulates the mathematically
    reconciled state of the search loop and the budget-aware restart prompt,
    providing the exact context required to resume the autonomous discovery
    process after a context-window reset or system interruption.

    Attributes:
        reconciled_state (Any): An instance of SessionRecoveryState representing
            the current experiment count, best score, and best commit hash.
        restart_prompt (str): The fully formatted prompt string to be transmitted
            to the LLM, or the sentinel 'BUDGET_EXHAUSTED'.
    """
    # The mathematically reconciled state of the search loop derived from persistent logs
    reconciled_state: Any  # Expected type: SessionRecoveryState
    # The formatted prompt string ready for LLM transmission or budget termination signal
    restart_prompt: str

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity
        of the session recovery artifacts before they are consumed by the search loop.

        Raises:
            TypeError: If the attributes do not match the required types.
            ValueError: If the restart_prompt is empty or malformed.
        """
        # Verify that the reconciled_state artifact is present and not None to maintain the audit trail
        if self.reconciled_state is None:
            # Raise a ValueError if the critical state metadata is missing
            raise ValueError("Task19SessionRecoveryReport: reconciled_state cannot be None.")

        # Verify that the restart_prompt is a string to ensure compatibility with the LLM API
        if not isinstance(self.restart_prompt, str):
            # Raise a TypeError if the prompt metadata is of an incorrect type
            raise TypeError("Task19SessionRecoveryReport: restart_prompt must be a string.")

        # Ensure the restart_prompt is not empty to prevent sending null instructions to the agent
        if not self.restart_prompt.strip():
            # Raise a ValueError if the prompt is an empty or whitespace-only string
            raise ValueError("Task19SessionRecoveryReport: restart_prompt cannot be empty.")


def execute_task_19_recover_session_state(
    working_directory: Path,
    study_configuration: Dict[str, Any],
    prompt_templates: Any  # Expected type: AgentPromptTemplates
) -> Task19SessionRecoveryReport:
    """
    Orchestrates Task 19: Reads the persistent artifacts, reconciles any inconsistencies
    between the git history and the audit log, and generates the budget-aware restart prompt.

    Args:
        working_directory (Path): The absolute path to the repository root.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        prompt_templates (AgentPromptTemplates): The structured prompt strings.

    Returns:
        Task19SessionRecoveryReport: The comprehensive session recovery report.

    Raises:
        FileNotFoundError: If the audit log is missing.
        RuntimeError: If git reconciliation fails.
    """
    results_tsv_path = study_configuration["artifact_paths"]["results_tsv_path"]

    # Step 1: Read the persistent state on every restart
    raw_state = read_persistent_state(
        working_directory=working_directory,
        results_tsv_path=results_tsv_path
    )

    # Step 2: Reconcile unlogged commits and stray edits
    reconciled_state = reconcile_workspace_state(
        recovery_state=raw_state,
        working_directory=working_directory,
        study_configuration=study_configuration
    )

    # Step 3: Identify the current best and inject the remaining budget
    restart_prompt = inject_budget_and_format_prompt(
        recovery_state=reconciled_state,
        working_directory=working_directory,
        study_configuration=study_configuration,
        prompt_templates=prompt_templates
    )

    # Return the composite recovery report
    return Task19SessionRecoveryReport(
        reconciled_state=reconciled_state,
        restart_prompt=restart_prompt
    )

# %%
# Task 20: Reproduce the Benchmark Helper Functions

# ==============================================================================
# Task 20: Reproduce the Benchmark Helper Functions
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 20, Step 1: Identify the required helpers
# -------------------------------------------------------------------------------------------------------------------------------

def identify_required_helpers(study_configuration: Dict[str, Any]) -> Dict[str, str]:
    """
    Extracts the list of required helper functions from the configuration and maps
    each to its inferred econometric purpose based on the peLASSO framework.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Dict[str, str]: A dictionary mapping function names to their theoretical definitions.

    Raises:
        ValueError: If the required configuration key is missing.
    """
    try:
        helper_names = study_configuration["prepare_script_data"]["helper_functions_in_scope_from_prepare"]
    except KeyError as e:
        raise ValueError(f"Missing required configuration key for helper functions: {e}")

    # Define the theoretical specification for each expected helper
    specifications = {
        "pelasso_lasso_avg": "Two-step: LASSO selection -> equal-weight average of active set.",
        "pelasso_lasso_eridge": "Two-step: LASSO selection -> egalitarian ridge on active set.",
        "pelasso_lasso_elasso": "Two-step: LASSO selection -> egalitarian LASSO on active set.",
        "fit_lasso": "Standard LASSO regression: min ||y - Xb||^2 + lambda||b||_1.",
        "fit_ridge": "Standard Ridge regression: min ||y - Xb||^2 + lambda||b||_2^2.",
        "fit_elasso": "Egalitarian LASSO: LASSO on transformed target y_tilde = y - mean(X).",
        "fit_eridge": "Egalitarian Ridge: Ridge on transformed target y_tilde = y - mean(X).",
        "cv_loo_bandwidth": "Leave-one-out CV for a single regularization parameter.",
        "cv_loo_bandwidth_2step": "Leave-one-out CV over a 2D grid (lambda_1, lambda_2)."
    }

    # Verify all configured helpers have a known specification
    for name in helper_names:
        if name not in specifications:
            specifications[name] = "Unknown helper function."

    return specifications

# -------------------------------------------------------------------------------------------------------------------------------
# Task 20, Step 2: Port from the reference implementation
# -------------------------------------------------------------------------------------------------------------------------------

def _egalitarian_transform(X: np.ndarray, y: np.ndarray) -> np.ndarray:
    """
    Applies the egalitarian transformation to the target vector by subtracting the
    simple cross-sectional average of the forecasters' predictions. This centers
    the target variable around the egalitarian benchmark (1/K).

    Args:
        X (np.ndarray): A 2D array of shape (n_samples, K_forecasters) containing the predictions.
        y (np.ndarray): A 1D array of shape (n_samples,) containing the realized targets.

    Returns:
        np.ndarray: A 1D array of shape (n_samples,) containing the transformed targets.

    Raises:
        TypeError: If X or y are not numpy arrays.
        ValueError: If the dimensions of X and y do not align.
    """
    # Validate that X is a numpy array to ensure vectorized operations are supported
    if not isinstance(X, np.ndarray):
        # Raise a TypeError if X is not the expected data structure
        raise TypeError("_egalitarian_transform: X must be a numpy.ndarray.")

    # Validate that y is a numpy array to ensure vectorized operations are supported
    if not isinstance(y, np.ndarray):
        # Raise a TypeError if y is not the expected data structure
        raise TypeError("_egalitarian_transform: y must be a numpy.ndarray.")

    # Ensure the number of samples in X matches the number of samples in y
    if X.shape[0] != y.shape[0]:
        # Raise a ValueError if the temporal dimensions are misaligned
        raise ValueError(f"_egalitarian_transform: X rows ({X.shape[0]}) must match y length ({y.shape[0]}).")

    # Compute the simple average forecast for each row across all K forecasters
    # Equation: \bar{x}_s = (1/K) * \sum_{k=1}^K x_{k,s}
    simple_avg = np.mean(X, axis=1)

    # Subtract the simple average from the realized target to create the egalitarian-transformed target
    # Equation: \tilde{y}_s = y_s - \bar{x}_s
    y_tilde = y - simple_avg

    # Return the transformed target vector
    return y_tilde


def fit_lasso(X: np.ndarray, y: np.ndarray, lambda_val: float) -> np.ndarray:
    """
    Fits a standard LASSO regression model using coordinate descent, strictly adhering
    to the 1/(2n) objective function scaling convention used by glmnet.

    Args:
        X (np.ndarray): A 2D array of shape (n_samples, n_features) containing the predictors.
        y (np.ndarray): A 1D array of shape (n_samples,) containing the target variable.
        lambda_val (float): The L1 regularization penalty parameter.

    Returns:
        np.ndarray: A 1D array of shape (n_features,) containing the estimated coefficients.

    Raises:
        TypeError: If inputs are not of the expected types.
        ValueError: If lambda_val is negative or dimensions mismatch.
    """
    # Validate that X is a numpy array
    if not isinstance(X, np.ndarray):
        # Raise a TypeError if X is invalid
        raise TypeError("fit_lasso: X must be a numpy.ndarray.")

    # Validate that y is a numpy array
    if not isinstance(y, np.ndarray):
        # Raise a TypeError if y is invalid
        raise TypeError("fit_lasso: y must be a numpy.ndarray.")

    # Validate that lambda_val is a non-negative float
    if not isinstance(lambda_val, (float, int)) or lambda_val < 0:
        # Raise a ValueError if the regularization parameter is mathematically invalid
        raise ValueError("fit_lasso: lambda_val must be a non-negative float.")

    # Handle the edge case where lambda is exactly 0 (unpenalized Ordinary Least Squares)
    if lambda_val == 0.0:
        # Use the Moore-Penrose pseudo-inverse for robust OLS estimation to avoid singular matrix errors
        # Equation: \hat{\beta} = (X^T X)^+ X^T y
        return np.linalg.pinv(X.T @ X) @ X.T @ y

    # Initialize the sklearn Lasso model. sklearn's 'alpha' corresponds directly to 'lambda'
    # when using the 1/(2n) objective. We set fit_intercept=False assuming data is pre-centered.
    # Equation: \min_{\beta} (1/(2n)) ||y - X\beta||_2^2 + \lambda ||\beta||_1
    model = Lasso(alpha=float(lambda_val), fit_intercept=False, tol=1e-6, max_iter=10000)

    # Fit the LASSO model to the provided data
    model.fit(X, y)

    # Return the estimated coefficient vector
    return model.coef_


def fit_ridge(X: np.ndarray, y: np.ndarray, lambda_val: float) -> np.ndarray:
    """
    Fits a standard Ridge regression model, explicitly scaling the penalty parameter
    to match the 1/(2n) objective function scaling convention used by glmnet.

    Args:
        X (np.ndarray): A 2D array of shape (n_samples, n_features) containing the predictors.
        y (np.ndarray): A 1D array of shape (n_samples,) containing the target variable.
        lambda_val (float): The L2 regularization penalty parameter.

    Returns:
        np.ndarray: A 1D array of shape (n_features,) containing the estimated coefficients.

    Raises:
        TypeError: If inputs are not of the expected types.
        ValueError: If lambda_val is negative or dimensions mismatch.
    """
    # Validate that X is a numpy array
    if not isinstance(X, np.ndarray):
        # Raise a TypeError if X is invalid
        raise TypeError("fit_ridge: X must be a numpy.ndarray.")

    # Validate that y is a numpy array
    if not isinstance(y, np.ndarray):
        # Raise a TypeError if y is invalid
        raise TypeError("fit_ridge: y must be a numpy.ndarray.")

    # Validate that lambda_val is a non-negative float
    if not isinstance(lambda_val, (float, int)) or lambda_val < 0:
        # Raise a ValueError if the regularization parameter is mathematically invalid
        raise ValueError("fit_ridge: lambda_val must be a non-negative float.")

    # Extract the number of samples (n) to scale the penalty parameter
    n_samples = X.shape[0]

    # Scale lambda by n_samples to match glmnet's 1/(2n) objective scaling.
    # sklearn Ridge objective: ||y - Xw||^2_2 + alpha * ||w||^2_2
    # glmnet Ridge objective: (1/(2n)) ||y - Xw||^2_2 + lambda * ||w||^2_2
    alpha_scaled = float(lambda_val) * n_samples

    # Initialize the sklearn Ridge model using the Cholesky solver for exact analytical solutions
    model = Ridge(alpha=alpha_scaled, fit_intercept=False, solver='cholesky')

    # Fit the Ridge model to the provided data
    model.fit(X, y)

    # Return the estimated coefficient vector
    return model.coef_


def fit_elasso(X: np.ndarray, y: np.ndarray, lambda_val: float) -> np.ndarray:
    """
    Fits an Egalitarian LASSO regression model by applying the egalitarian transformation
    to the target variable, fitting a standard LASSO, and adding back the egalitarian benchmark.

    Args:
        X (np.ndarray): A 2D array of shape (n_samples, K_forecasters) containing the predictors.
        y (np.ndarray): A 1D array of shape (n_samples,) containing the target variable.
        lambda_val (float): The L1 regularization penalty parameter.

    Returns:
        np.ndarray: A 1D array of shape (K_forecasters,) containing the egalitarian coefficients.

    Raises:
        TypeError: If inputs are not of the expected types.
    """
    # Validate that X is a numpy array
    if not isinstance(X, np.ndarray):
        # Raise a TypeError if X is invalid
        raise TypeError("fit_elasso: X must be a numpy.ndarray.")

    # Extract the number of forecasters (K) from the feature dimension of X
    K = X.shape[1]

    # Apply the egalitarian transformation to the target vector
    # Equation: \tilde{y}_s = y_s - (1/K) \sum_{k=1}^K x_{k,s}
    y_tilde = _egalitarian_transform(X, y)

    # Fit a standard LASSO regression on the transformed target
    beta_tilde = fit_lasso(X, y_tilde, lambda_val)

    # Add back the egalitarian benchmark weight (1/K) to each coefficient to recover the final weights
    # Equation: \hat{\beta}_k^{\text{eLASSO}} = \tilde{\beta}_k + \frac{1}{K}
    return beta_tilde + (1.0 / K)


def fit_eridge(X: np.ndarray, y: np.ndarray, lambda_val: float) -> np.ndarray:
    """
    Fits an Egalitarian Ridge regression model by applying the egalitarian transformation
    to the target variable, fitting a standard Ridge, and adding back the egalitarian benchmark.

    Args:
        X (np.ndarray): A 2D array of shape (n_samples, K_forecasters) containing the predictors.
        y (np.ndarray): A 1D array of shape (n_samples,) containing the target variable.
        lambda_val (float): The L2 regularization penalty parameter.

    Returns:
        np.ndarray: A 1D array of shape (K_forecasters,) containing the egalitarian coefficients.

    Raises:
        TypeError: If inputs are not of the expected types.
    """
    # Validate that X is a numpy array
    if not isinstance(X, np.ndarray):
        # Raise a TypeError if X is invalid
        raise TypeError("fit_eridge: X must be a numpy.ndarray.")

    # Extract the number of forecasters (K) from the feature dimension of X
    K = X.shape[1]

    # Apply the egalitarian transformation to the target vector
    y_tilde = _egalitarian_transform(X, y)

    # Fit a standard Ridge regression on the transformed target
    beta_tilde = fit_ridge(X, y_tilde, lambda_val)

    # Add back the egalitarian benchmark weight (1/K) to each coefficient to recover the final weights
    # Equation: \hat{\beta}_k^{\text{eRidge}} = \tilde{\beta}_k + \frac{1}{K}
    return beta_tilde + (1.0 / K)


def pelasso_lasso_avg(X_train: np.ndarray, y_train: np.ndarray, x_new: np.ndarray, lambda_1: float) -> float:
    """
    Executes the two-step peLASSO(LASSO, Avg) method: performs variable selection via LASSO
    and aggregates the selected forecasters using an equal-weight average.

    Args:
        X_train (np.ndarray): The training window predictor matrix.
        y_train (np.ndarray): The training window target vector.
        x_new (np.ndarray): The current-period forecast vector.
        lambda_1 (float): The L1 penalty parameter for the first-stage selection.

    Returns:
        float: The combined scalar forecast.

    Raises:
        TypeError: If inputs are not of the expected types.
    """
    # Validate that x_new is a numpy array
    if not isinstance(x_new, np.ndarray):
        # Raise a TypeError if x_new is invalid
        raise TypeError("pelasso_lasso_avg: x_new must be a numpy.ndarray.")

    # Step 1: Selection - Fit LASSO to obtain the first-stage coefficients
    beta_lasso = fit_lasso(X_train, y_train, lambda_1)

    # Define the active set A = {k : \hat{\beta}_k \neq 0}
    # We use a strict tolerance (1e-7) to handle floating-point near-zeros inherent to numerical solvers
    active_set = np.where(np.abs(beta_lasso) > 1e-7)[0]

    # Step 2: Aggregation - Check if the active set is empty
    if len(active_set) == 0:
        # Fallback: if no variables are selected, return the simple average of all forecasters
        return float(np.mean(x_new))

    # Compute and return the equal-weight average of the selected forecasters' predictions
    # Equation: \hat{y}_t = |\mathcal{A}|^{-1} \sum_{k \in \mathcal{A}} x_{k,t}
    return float(np.mean(x_new[active_set]))


def pelasso_lasso_eridge(X_train: np.ndarray, y_train: np.ndarray, x_new: np.ndarray, lambda_1: float, lambda_2: float) -> float:
    """
    Executes the two-step peLASSO(LASSO, eRidge) method: performs variable selection via LASSO
    and aggregates the selected forecasters using an egalitarian Ridge regression.

    Args:
        X_train (np.ndarray): The training window predictor matrix.
        y_train (np.ndarray): The training window target vector.
        x_new (np.ndarray): The current-period forecast vector.
        lambda_1 (float): The L1 penalty parameter for the first-stage selection.
        lambda_2 (float): The L2 penalty parameter for the second-stage egalitarian Ridge.

    Returns:
        float: The combined scalar forecast.

    Raises:
        TypeError: If inputs are not of the expected types.
    """
    # Validate that x_new is a numpy array
    if not isinstance(x_new, np.ndarray):
        # Raise a TypeError if x_new is invalid
        raise TypeError("pelasso_lasso_eridge: x_new must be a numpy.ndarray.")

    # Step 1: Selection - Fit LASSO to obtain the first-stage coefficients
    beta_lasso = fit_lasso(X_train, y_train, lambda_1)

    # Define the active set A = {k : \hat{\beta}_k \neq 0} using a strict tolerance
    active_set = np.where(np.abs(beta_lasso) > 1e-7)[0]

    # Check if the active set is empty
    if len(active_set) == 0:
        # Fallback: if no variables are selected, return the simple average of all forecasters
        return float(np.mean(x_new))

    # Subset the training predictor matrix to include only the active set
    X_train_sub = X_train[:, active_set]

    # Subset the current-period forecast vector to include only the active set
    x_new_sub = x_new[active_set]

    # Step 2: Aggregation - Fit egalitarian ridge on the subsetted training data
    beta_eridge_sub = fit_eridge(X_train_sub, y_train, lambda_2)

    # Compute and return the combined forecast via the dot product of weights and predictions
    # Equation: \hat{y}_t = \sum_{k \in \mathcal{A}} \hat{\beta}_k^{\text{eRidge}} x_{k,t}
    return float(np.dot(x_new_sub, beta_eridge_sub))


def pelasso_lasso_elasso(X_train: np.ndarray, y_train: np.ndarray, x_new: np.ndarray, lambda_1: float, lambda_2: float) -> float:
    """
    Executes the two-step peLASSO(LASSO, eLASSO) method: performs variable selection via LASSO
    and aggregates the selected forecasters using an egalitarian LASSO regression.

    Args:
        X_train (np.ndarray): The training window predictor matrix.
        y_train (np.ndarray): The training window target vector.
        x_new (np.ndarray): The current-period forecast vector.
        lambda_1 (float): The L1 penalty parameter for the first-stage selection.
        lambda_2 (float): The L1 penalty parameter for the second-stage egalitarian LASSO.

    Returns:
        float: The combined scalar forecast.

    Raises:
        TypeError: If inputs are not of the expected types.
    """
    # Validate that x_new is a numpy array
    if not isinstance(x_new, np.ndarray):
        # Raise a TypeError if x_new is invalid
        raise TypeError("pelasso_lasso_elasso: x_new must be a numpy.ndarray.")

    # Step 1: Selection - Fit LASSO to obtain the first-stage coefficients
    beta_lasso = fit_lasso(X_train, y_train, lambda_1)

    # Define the active set A = {k : \hat{\beta}_k \neq 0} using a strict tolerance
    active_set = np.where(np.abs(beta_lasso) > 1e-7)[0]

    # Check if the active set is empty
    if len(active_set) == 0:
        # Fallback: if no variables are selected, return the simple average of all forecasters
        return float(np.mean(x_new))

    # Subset the training predictor matrix to include only the active set
    X_train_sub = X_train[:, active_set]

    # Subset the current-period forecast vector to include only the active set
    x_new_sub = x_new[active_set]

    # Step 2: Aggregation - Fit egalitarian LASSO on the subsetted training data
    beta_elasso_sub = fit_elasso(X_train_sub, y_train, lambda_2)

    # Compute and return the combined forecast via the dot product of weights and predictions
    # Equation: \hat{y}_t = \sum_{k \in \mathcal{A}} \hat{\beta}_k^{\text{eLASSO}} x_{k,t}
    return float(np.dot(x_new_sub, beta_elasso_sub))


def cv_loo_bandwidth(X: np.ndarray, y: np.ndarray, lambda_grid: np.ndarray, method: str = 'lasso') -> float:
    """
    Performs Leave-One-Out Cross-Validation (LOO-CV) to select the optimal regularization
    parameter for a single-step penalized regression method.

    Args:
        X (np.ndarray): The training predictor matrix.
        y (np.ndarray): The training target vector.
        lambda_grid (np.ndarray): The 1D array of candidate lambda values.
        method (str): The regression method to evaluate ('lasso', 'ridge', or 'elasso').

    Returns:
        float: The lambda value that minimizes the LOO-CV mean squared error.

    Raises:
        ValueError: If an unsupported method string is provided.
    """
    # Initialize the sklearn LeaveOneOut cross-validator
    loo = LeaveOneOut()

    # Initialize the best lambda to the first element of the grid
    best_lambda = float(lambda_grid[0])

    # Initialize the minimum MSE to positive infinity
    min_mse = float('inf')

    # Iterate over each candidate lambda in the grid
    for lam in lambda_grid:
        # Initialize the sum of squared errors for the current lambda
        mse_sum = 0.0

        # Iterate over each train/test split generated by LOO
        for train_idx, test_idx in loo.split(X):
            # Partition the predictors into training and holdout sets
            X_tr, X_te = X[train_idx], X[test_idx]
            # Partition the targets into training and holdout sets
            y_tr, y_te = y[train_idx], y[test_idx]

            # Fit the specified model on the training fold
            if method == 'lasso':
                beta = fit_lasso(X_tr, y_tr, float(lam))
            elif method == 'ridge':
                beta = fit_ridge(X_tr, y_tr, float(lam))
            elif method == 'elasso':
                beta = fit_elasso(X_tr, y_tr, float(lam))
            else:
                # Raise a ValueError if the method is not recognized
                raise ValueError(f"Unknown method: {method}")

            # Generate the prediction for the single holdout observation
            pred = np.dot(X_te, beta)

            # Accumulate the squared error for this fold
            mse_sum += float((y_te[0] - pred[0])**2)

        # If the accumulated MSE for this lambda is strictly less than the current minimum
        if mse_sum < min_mse:
            # Update the minimum MSE
            min_mse = mse_sum
            # Update the best lambda
            best_lambda = float(lam)

    # Return the optimal lambda value
    return best_lambda


def cv_loo_bandwidth_2step(X: np.ndarray, y: np.ndarray, lambda_grid1: np.ndarray, lambda_grid2: np.ndarray, method: str = 'eridge') -> Tuple[float, float]:
    """
    Performs Leave-One-Out Cross-Validation (LOO-CV) over a 2D grid to select the optimal
    pair of regularization parameters for two-step peLASSO methods.

    Args:
        X (np.ndarray): The training predictor matrix.
        y (np.ndarray): The training target vector.
        lambda_grid1 (np.ndarray): The 1D array of candidate lambda_1 values (first stage).
        lambda_grid2 (np.ndarray): The 1D array of candidate lambda_2 values (second stage).
        method (str): The second-stage aggregation method ('eridge', 'elasso', or 'avg').

    Returns:
        Tuple[float, float]: The (lambda_1, lambda_2) pair that minimizes the LOO-CV MSE.

    Raises:
        ValueError: If an unsupported method string is provided.
    """
    # Initialize the sklearn LeaveOneOut cross-validator
    loo = LeaveOneOut()

    # Initialize the best lambda pair to the first elements of the grids
    best_lam1, best_lam2 = float(lambda_grid1[0]), float(lambda_grid2[0])

    # Initialize the minimum MSE to positive infinity
    min_mse = float('inf')

    # Iterate over each candidate lambda_1 in the first-stage grid
    for lam1 in lambda_grid1:
        # Iterate over each candidate lambda_2 in the second-stage grid
        for lam2 in lambda_grid2:
            # Initialize the sum of squared errors for the current lambda pair
            mse_sum = 0.0

            # Iterate over each train/test split generated by LOO
            for train_idx, test_idx in loo.split(X):
                # Partition the predictors into training and holdout sets
                X_tr, X_te = X[train_idx], X[test_idx]
                # Partition the targets into training and holdout sets
                y_tr, y_te = y[train_idx], y[test_idx]

                # Execute the specified two-step method on the training fold to predict the holdout
                if method == 'eridge':
                    pred = pelasso_lasso_eridge(X_tr, y_tr, X_te[0], float(lam1), float(lam2))
                elif method == 'elasso':
                    pred = pelasso_lasso_elasso(X_tr, y_tr, X_te[0], float(lam1), float(lam2))
                elif method == 'avg':
                    # The 'avg' method only utilizes lambda_1, but we evaluate it within the grid structure
                    pred = pelasso_lasso_avg(X_tr, y_tr, X_te[0], float(lam1))
                else:
                    # Raise a ValueError if the two-step method is not recognized
                    raise ValueError(f"Unknown 2-step method: {method}")

                # Accumulate the squared error for this fold
                mse_sum += float((y_te[0] - pred)**2)

            # If the accumulated MSE for this lambda pair is strictly less than the current minimum
            if mse_sum < min_mse:
                # Update the minimum MSE
                min_mse = mse_sum
                # Update the best lambda_1
                best_lam1 = float(lam1)
                # Update the best lambda_2
                best_lam2 = float(lam2)

    # Return the optimal lambda pair
    return best_lam1, best_lam2

# -------------------------------------------------------------------------------------------------------------------------------
# Task 20, Step 3: Validate each helper against the reference implementation's output
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class HelperValidationReport:
    """
    A structured, implementation-grade record documenting the validation of the Python
    helper functions. This report confirms internal mathematical consistency and explicitly
    acknowledges the epistemological boundary regarding cross-language parity with the
    original R implementation.

    Attributes:
        passed_internal_consistency (bool): True if all internal mathematical invariants
            (e.g., coefficient summation, shrinkage to zero) hold.
        cross_language_parity_verified (bool): True if the outputs were verified against
            external R reference data (typically False in isolated environments).
        notes (str): Detailed diagnostic notes regarding the validation outcomes.
    """
    # Flag indicating if internal mathematical invariants are satisfied
    passed_internal_consistency: bool
    # Flag indicating if cross-language parity was empirically verified
    cross_language_parity_verified: bool
    # Diagnostic notes and caveats regarding the validation process
    notes: str

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the integrity
        of the helper validation report.

        Raises:
            TypeError: If the attributes do not match the required types.
        """
        # Verify that passed_internal_consistency is a boolean
        if not isinstance(self.passed_internal_consistency, bool):
            raise TypeError("HelperValidationReport: passed_internal_consistency must be a boolean.")

        # Verify that cross_language_parity_verified is a boolean
        if not isinstance(self.cross_language_parity_verified, bool):
            raise TypeError("HelperValidationReport: cross_language_parity_verified must be a boolean.")

        # Verify that notes is a string
        if not isinstance(self.notes, str):
            raise TypeError("HelperValidationReport: notes must be a string.")


def validate_helpers_internal_consistency() -> HelperValidationReport:
    """
    Performs rigorous internal mathematical consistency checks on the helper functions.
    This serves as a proxy for cross-language validation when external R reference
    data is unavailable, ensuring the fundamental properties of penalized regression hold.

    Returns:
        HelperValidationReport: The structured validation record.
    """
    # Generate synthetic data for testing to ensure deterministic execution
    np.random.seed(42)
    # Create a 20x23 predictor matrix mimicking the rolling window
    X_test = np.random.randn(20, 23)
    # Create a 20-element target vector
    y_test = np.random.randn(20)
    # Define a standard lambda value for testing
    lam = 0.1

    # Initialize validation state
    passed = True
    notes = "Internal consistency checks passed. "

    try:
        # Check 1: Egalitarian Ridge Dimensionality
        # Ensure the egalitarian ridge function returns exactly K coefficients
        b_eridge = fit_eridge(X_test, y_test, lam)
        if len(b_eridge) != 23:
            passed = False
            notes += "fit_eridge dimension mismatch. "

        # Check 2: LASSO Shrinkage Property
        # A sufficiently large lambda should shrink all LASSO coefficients to exactly zero
        b_lasso_large = fit_lasso(X_test, y_test, 1000.0)
        if not np.allclose(b_lasso_large, 0.0):
            passed = False
            notes += "fit_lasso failed to shrink to zero at large lambda. "

    except Exception as e:
        # Catch any unexpected runtime errors during validation and mark as failed
        passed = False
        notes += f"Exception during validation: {e}"

    # Return the comprehensive validation report
    return HelperValidationReport(
        passed_internal_consistency=passed,
        cross_language_parity_verified=False, # True only if R CSVs are loaded
        notes=notes + "Cross-language parity requires R reference CSVs."
    )


# -------------------------------------------------------------------------------------------------------------------------------
# Task 20, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task20BenchmarkHelpersReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the benchmark helper reproduction phase. This report serves as the authoritative
    registry of ported econometric callables (e.g., fit_lasso, pelasso_lasso_avg,
    cv_loo_bandwidth) required to replicate the Diebold and Shin (2019) benchmarks
    and provide a rigorous mathematical foundation for the agentic discovery loop.

    Attributes:
        helper_functions (Dict[str, Callable]): A dictionary mapping function names
            (as strings) to their respective Python callable implementations.
        validation_report (Any): An instance of HelperValidationReport documenting
            the internal mathematical consistency and cross-language parity status
            of the ported suite.
    """
    # Dictionary mapping function identifiers to the actual Python callable objects for injection
    helper_functions: Dict[str, Callable]
    # The structured validation record confirming the mathematical integrity of the ported suite
    validation_report: Any  # Expected type: HelperValidationReport

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and completeness of the benchmark helper artifacts.

        Raises:
            TypeError: If the attributes do not match the required types.
            ValueError: If the helper functions dictionary is empty or the report is missing.
        """
        # Verify that helper_functions is a dictionary to ensure O(1) lookup compatibility
        if not isinstance(self.helper_functions, dict):
            # Raise a TypeError if the data structure is incorrect for a registry
            raise TypeError("Task20BenchmarkHelpersReport: helper_functions must be a dictionary.")

        # Ensure the dictionary contains at least one helper to prevent downstream execution failures
        if not self.helper_functions:
            # Raise a ValueError if the registry is empty, indicating a failed porting phase
            raise ValueError("Task20BenchmarkHelpersReport: helper_functions dictionary cannot be empty.")

        # Verify that every value in the dictionary is indeed a callable object
        for name, func in self.helper_functions.items():
            # Check if the object can be called as a function
            if not callable(func):
                # Raise a TypeError if the registry contains a non-callable artifact
                raise TypeError(f"Task20BenchmarkHelpersReport: Helper '{name}' is not a callable object.")

        # Verify that the validation_report is present and not None to maintain the audit trail
        if self.validation_report is None:
            # Raise a ValueError if the critical validation metadata is missing from the report
            raise ValueError("Task20BenchmarkHelpersReport: validation_report cannot be None.")


def execute_task_20_reproduce_benchmark_helpers(study_configuration: Dict[str, Any]) -> Task20BenchmarkHelpersReport:
    """
    Orchestrates Task 20: Identifies required helpers, ports them to Python using
    rigorous penalized regression theory, and validates their internal consistency.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Task20BenchmarkHelpersReport: The comprehensive report containing the callables.
    """
    # Step 1: Identify the required helpers
    specifications = identify_required_helpers(study_configuration)

    # Step 2: Port from the reference implementation
    # Bundle the implemented functions into a dictionary
    helpers = {
        "pelasso_lasso_avg": pelasso_lasso_avg,
        "pelasso_lasso_eridge": pelasso_lasso_eridge,
        "pelasso_lasso_elasso": pelasso_lasso_elasso,
        "fit_lasso": fit_lasso,
        "fit_ridge": fit_ridge,
        "fit_elasso": fit_elasso,
        "fit_eridge": fit_eridge,
        "cv_loo_bandwidth": cv_loo_bandwidth,
        "cv_loo_bandwidth_2step": cv_loo_bandwidth_2step
    }

    # Verify all required helpers were implemented
    for name in specifications.keys():
        if name not in helpers:
            raise NotImplementedError(f"Required helper '{name}' was not implemented.")

    # Step 3: Validate each helper
    validation_report = validate_helpers_internal_consistency()

    if not validation_report.passed_internal_consistency:
        raise ValueError(f"Task 20 Step 3 Failed: Helper internal consistency error. {validation_report.notes}")

    return Task20BenchmarkHelpersReport(
        helper_functions=helpers,
        validation_report=validation_report
    )

# %%
# Task 21: Reproduce the Benchmark Methods and Validate Against Published Targets

# ===============================================================================
# Task 21: Reproduce the Benchmark Methods and Validate Against Published Targets
# ===============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 21, Step 1: Evaluate the simple average, peLASSO ex post, and original-paper benchmarks
# -------------------------------------------------------------------------------------------------------------------------------

def evaluate_pelasso_ex_post_original(
    info_builder: Any,
    target_vector: np.ndarray,
    lambda_grid: np.ndarray
) -> float:
    """
    Evaluates the 'peLASSO ex post (original)' benchmark. This oracle method selects
    a single regularization parameter lambda that minimizes the RMSE over the ENTIRE
    65-period search sample simultaneously, violating the no-look-ahead constraint
    to establish a theoretical upper bound on performance.

    Args:
        info_builder (Any): The EvaluatorInfoBuilder instance.
        target_vector (np.ndarray): The 1D array of realized GDP growth values.
        lambda_grid (np.ndarray): The 1D array of candidate lambda values.

    Returns:
        float: The globally optimal RMSE achieved by the ex-post peLASSO method.
    """
    best_global_rmse = float('inf')

    # Iterate over every candidate lambda in the grid
    for lam in lambda_grid:
        forecasts = np.full(66, np.nan, dtype=np.float64)
        actuals = np.full(66, np.nan, dtype=np.float64)

        # Evaluate this specific lambda over all 66 time steps
        for t in range(5, 71):
            i = t - 5
            info = info_builder.build_info(t)

            # Execute the first-stage LASSO selection and equal-weight averaging
            # Equation: \hat{y}_t = |\mathcal{A}(\lambda)|^{-1} \sum_{k \in \mathcal{A}(\lambda)} x_{k,t}
            pred = pelasso_lasso_avg(
                X_train=info["X_train"],
                y_train=info["y_train"],
                x_new=info["x_new"],
                lambda_1=float(lam)
            )

            forecasts[i] = pred
            actuals[i] = target_vector[t - 1]

        # Isolate the 65 scored periods (excluding the t=5 warm-up)
        scored_errors = actuals[1:] - forecasts[1:]

        # Compute the scalar RMSE for this specific lambda across the entire sample
        current_rmse = compute_scalar_rmse(scored_errors)

        # Update the global minimum RMSE
        if current_rmse < best_global_rmse:
            best_global_rmse = current_rmse

    return best_global_rmse


def evaluate_pelasso_ex_post_per_window(
    info_builder: Any,
    target_vector: np.ndarray,
    lambda_grid: np.ndarray
) -> float:
    """
    Evaluates the 'peLASSO ex post (per window)' benchmark. This method re-optimizes
    the regularization parameter lambda at each forecast origin t using Leave-One-Out
    Cross-Validation (LOO-CV) on the rolling training window.

    Args:
        info_builder (Any): The EvaluatorInfoBuilder instance.
        target_vector (np.ndarray): The 1D array of realized GDP growth values.
        lambda_grid (np.ndarray): The 1D array of candidate lambda values.

    Returns:
        float: The RMSE achieved by the per-window optimized peLASSO method.
    """
    forecasts = np.full(66, np.nan, dtype=np.float64)
    actuals = np.full(66, np.nan, dtype=np.float64)

    for t in range(5, 71):
        i = t - 5
        info = info_builder.build_info(t)

        # Step 1: Re-optimize lambda on the current rolling window using LOO-CV
        # This selects the lambda that minimizes in-sample LOO error
        optimal_lam = cv_loo_bandwidth(
            X=info["X_train"],
            y=info["y_train"],
            lambda_grid=lambda_grid,
            method='lasso'
        )

        # Step 2: Generate the forecast using the window-specific optimal lambda
        pred = pelasso_lasso_avg(
            X_train=info["X_train"],
            y_train=info["y_train"],
            x_new=info["x_new"],
            lambda_1=optimal_lam
        )

        forecasts[i] = pred
        actuals[i] = target_vector[t - 1]

    # Isolate the 65 scored periods and compute the final RMSE
    scored_errors = actuals[1:] - forecasts[1:]
    return compute_scalar_rmse(scored_errors)


def evaluate_best_avg_flex(
    info_builder: Any,
    target_vector: np.ndarray,
    k_forecasters: int = 23,
    n_max: int = 6
) -> float:
    """
    Evaluates the 'Best avg flex (N_max=6)' benchmark. At each forecast origin, this
    method exhaustively searches all subsets of up to 6 forecasters, selecting the
    subset that minimizes the Mean Squared Error over the recent training window.

    Utilizes a highly optimized, vectorized matrix multiplication approach to evaluate
    all 145,498 combinations simultaneously without Python-level loops.

    Args:
        info_builder (Any): The EvaluatorInfoBuilder instance.
        target_vector (np.ndarray): The 1D array of realized GDP growth values.
        k_forecasters (int): The total number of forecasters (K=23).
        n_max (int): The maximum subset size to consider (N_max=6).

    Returns:
        float: The RMSE achieved by the Best avg flex method.
    """
    # 1. Pre-compute the combinatorial mask matrix M
    # Generate all combinations of indices from size 1 to n_max
    combinations = []
    for n in range(1, n_max + 1):
        combinations.extend(list(itertools.combinations(range(k_forecasters), n)))

    num_combinations = len(combinations)

    # Construct a dense matrix M of shape (K, num_combinations)
    # Each column represents a subset. The non-zero elements are set to 1/|S|
    # so that X @ M directly computes the simple average of the subset.
    M = np.zeros((k_forecasters, num_combinations), dtype=np.float64)
    for idx, combo in enumerate(combinations):
        weight = 1.0 / len(combo)
        for forecaster_idx in combo:
            M[forecaster_idx, idx] = weight

    forecasts = np.full(66, np.nan, dtype=np.float64)
    actuals = np.full(66, np.nan, dtype=np.float64)

    for t in range(5, 71):
        i = t - 5
        info = info_builder.build_info(t)
        X_train = info["X_train"]
        y_train = info["y_train"]
        x_new = info["x_new"]

        # 2. Vectorized evaluation of all 145,498 subsets on the training window
        # subset_preds shape: (n_t, num_combinations)
        subset_preds = X_train @ M

        # Compute squared errors against the training targets
        # Broadcasting y_train[:, None] aligns the targets with the predictions
        squared_errors = (subset_preds - y_train[:, None]) ** 2

        # Compute the Mean Squared Error for each subset over the training window
        # subset_mse shape: (num_combinations,)
        subset_mse = np.mean(squared_errors, axis=0)

        # 3. Select the optimal subset
        best_subset_idx = int(np.argmin(subset_mse))

        # 4. Generate the forecast using the optimal subset
        # x_new @ M[:, best_subset_idx] computes the simple average of the selected forecasters
        pred = np.dot(x_new, M[:, best_subset_idx])

        forecasts[i] = pred
        actuals[i] = target_vector[t - 1]

    scored_errors = actuals[1:] - forecasts[1:]
    return compute_scalar_rmse(scored_errors)


def evaluate_best_nw_avg(
    info_builder: Any,
    target_vector: np.ndarray,
    k_forecasters: int = 23,
    max_w: int = 20
) -> float:
    """
    Evaluates the 'Best (N,W) avg adaptive' benchmark. At each forecast origin, this
    method searches over window sizes W and subset sizes N. For a given W, it ranks
    forecasters by RMSE, selects the top N, and computes their combined RMSE. The
    (N,W) pair that minimizes this combined RMSE is used to generate the forecast.

    Args:
        info_builder (Any): The EvaluatorInfoBuilder instance.
        target_vector (np.ndarray): The 1D array of realized GDP growth values.
        k_forecasters (int): The total number of forecasters (K=23).
        max_w (int): The maximum rolling window size (W=20).

    Returns:
        float: The RMSE achieved by the Best (N,W) avg method.
    """
    forecasts = np.full(66, np.nan, dtype=np.float64)
    actuals = np.full(66, np.nan, dtype=np.float64)

    for t in range(5, 71):
        i = t - 5
        info = info_builder.build_info(t)
        X_history = info["X_history"]
        y_history = info["y_history"]
        x_new = info["x_new"]

        # The maximum available history at time t is t-1
        available_history = X_history.shape[0]

        best_combined_rmse = float('inf')
        best_N = 1
        best_W = 1
        best_ranking = []

        # Search over all feasible window sizes W
        feasible_max_w = min(max_w, available_history)
        # Ensure we have at least 1 observation to evaluate
        if feasible_max_w < 1:
            # Fallback for extreme edge cases (should not occur given t>=5)
            forecasts[i] = np.mean(x_new)
            actuals[i] = target_vector[t - 1]
            continue

        for w in range(1, feasible_max_w + 1):
            # Extract the specific window of history
            X_w = X_history[-w:, :]
            y_w = y_history[-w:]

            # Compute RMSE for each individual forecaster over window w
            # individual_squared_errors shape: (w, K)
            individual_squared_errors = (X_w - y_w[:, None]) ** 2
            individual_rmse = np.sqrt(np.mean(individual_squared_errors, axis=0))

            # Rank forecasters by RMSE (ascending)
            # argsort returns the indices that would sort the array
            ranking = np.argsort(individual_rmse)

            # Search over all subset sizes N
            for n in range(1, k_forecasters + 1):
                # Select the top N forecasters
                top_n_indices = ranking[:n]

                # Compute the simple average forecast of the top N over window w
                # X_w[:, top_n_indices] shape: (w, n)
                combined_preds_w = np.mean(X_w[:, top_n_indices], axis=1)

                # Compute the RMSE of this combined forecast
                combined_rmse = np.sqrt(np.mean((combined_preds_w - y_w) ** 2))

                # Update the optimal (N,W) pair
                if combined_rmse < best_combined_rmse:
                    best_combined_rmse = combined_rmse
                    best_N = n
                    best_W = w
                    best_ranking = top_n_indices

        # Generate the forecast using the optimal N and W
        # The optimal ranking was computed over the optimal W
        pred = np.mean(x_new[best_ranking])

        forecasts[i] = pred
        actuals[i] = target_vector[t - 1]

    scored_errors = actuals[1:] - forecasts[1:]
    return compute_scalar_rmse(scored_errors)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 21, Step 2: Validate each benchmark to close tolerance
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class BenchmarkValidationRecord:
    """
    A structured record documenting the validation of a single benchmark method against
    its published target RMSE.

    Attributes:
        method_name (str): The identifier of the benchmark method.
        computed_rmse (float): The empirically computed absolute RMSE.
        target_rmse (float): The theoretical target RMSE from the manuscript.
        deviation (float): The absolute mathematical deviation.
        tolerance (float): The maximum allowed deviation based on data provenance.
        passed (bool): True if the deviation is within the acceptable tolerance.
    """
    method_name: str
    computed_rmse: float
    target_rmse: float
    deviation: float
    tolerance: float
    passed: bool


def validate_benchmark_tolerances(
    computed_rmses: Dict[str, float],
    study_configuration: Dict[str, Any],
    data_provenance: str
) -> List[BenchmarkValidationRecord]:
    """
    Compares the computed benchmark RMSEs against the published targets, applying
    dynamic tolerance tiers based on the data provenance (exact vs. independent rebuild).

    Args:
        computed_rmses (Dict[str, float]): Mapping of method names to computed RMSEs.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        data_provenance (str): Identifier for the data source.

    Returns:
        List[BenchmarkValidationRecord]: A list of structured validation records.
    """
    # Extract the target RMSEs from the configuration
    targets = study_configuration["econometric_setup"]["benchmark_targets"]["search_sample"]

    # Define the base tolerances for exact reproduction (Tier 1)
    base_tolerances = {
        "peLASSO ex post (original)": 0.005,
        "peLASSO ex post (per window)": 0.005,
        "Best avg flex": 0.010,
        "Best (N,W) avg": 0.010
    }

    # Determine if an independent rebuild penalty applies (Tier 2)
    is_independent_rebuild = not ("original" in data_provenance.lower() or "verbatim" in data_provenance.lower())
    vintage_penalty = 0.025 if is_independent_rebuild else 0.000

    validation_records = []

    # Map the computed keys to the configuration target keys
    key_mapping = {
        "peLASSO ex post (original)": "peLASSO_ex_post_original_rmse",
        "peLASSO ex post (per window)": "peLASSO_ex_post_per_window_rmse",
        "Best avg flex": "best_avg_flex_rmse",
        "Best (N,W) avg": "best_NW_avg_rmse"
    }

    for method_name, computed_val in computed_rmses.items():
        if method_name == "Simple average":
            # Simple average is validated separately in Task 13, but we include it here for completeness
            target_val = study_configuration["econometric_setup"]["simple_average_baseline"]["search_sample_rmse"]
            tolerance = 0.002 + vintage_penalty
        else:
            target_key = key_mapping[method_name]
            target_val = targets[target_key]
            tolerance = base_tolerances[method_name] + vintage_penalty

        deviation = abs(computed_val - target_val)
        passed = bool(deviation <= tolerance)

        record = BenchmarkValidationRecord(
            method_name=method_name,
            computed_rmse=computed_val,
            target_rmse=target_val,
            deviation=deviation,
            tolerance=tolerance,
            passed=passed
        )
        validation_records.append(record)

    return validation_records

# -------------------------------------------------------------------------------------------------------------------------------
# Task 21, Step 3: Store benchmark results for downstream comparison
# -------------------------------------------------------------------------------------------------------------------------------

def compile_benchmark_registry(
    validation_records: List[BenchmarkValidationRecord],
    baseline_rmse: float,
    data_provenance: str
) -> pd.DataFrame:
    """
    Aggregates the benchmark validation records into a structured pandas DataFrame,
    computing the relative RMSE for each method against the dynamically evaluated baseline.

    Args:
        validation_records (List[BenchmarkValidationRecord]): The list of validation records.
        baseline_rmse (float): The recomputed simple average RMSE.
        data_provenance (str): Identifier for the data source.

    Returns:
        pd.DataFrame: The comprehensive benchmark registry table.
    """
    # Initialize lists to construct the DataFrame columns
    data = {
        "method_name": [],
        "search_sample_rmse": [],
        "search_sample_relative_rmse": [],
        "validation_target": [],
        "deviation": [],
        "within_tolerance": [],
        "data_provenance": []
    }

    for record in validation_records:
        data["method_name"].append(record.method_name)
        data["search_sample_rmse"].append(record.computed_rmse)

        # Compute the relative RMSE dynamically
        relative_rmse = compute_relative_rmse(record.computed_rmse, baseline_rmse)
        data["search_sample_relative_rmse"].append(relative_rmse)

        data["validation_target"].append(record.target_rmse)
        data["deviation"].append(record.deviation)
        data["within_tolerance"].append(record.passed)
        data["data_provenance"].append(data_provenance)

    # Construct and return the DataFrame
    df_registry = pd.DataFrame(data)
    return df_registry

# -------------------------------------------------------------------------------------------------------------------------------
# Task 21, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task21BenchmarkReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the benchmark reproduction phase. This report encapsulates the empirically
    computed RMSEs for the original Diebold and Shin (2019) methods, their rigorous
    validation against published targets, and the structured registry DataFrame
    required for downstream comparative analysis.

    Attributes:
        benchmark_registry (pd.DataFrame): The comprehensive table containing absolute
            and relative RMSEs, deviations, and tolerance checks for all benchmarks.
        all_benchmarks_passed (bool): A global flag indicating whether all reproduced
            benchmarks fell within the acceptable methodological tolerance bounds.
    """
    # The structured pandas DataFrame containing the benchmark evaluation results
    benchmark_registry: pd.DataFrame
    # Boolean flag confirming the overall success of the reproduction phase
    all_benchmarks_passed: bool

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the benchmark report before it is consumed by the orchestrator.

        Raises:
            TypeError: If the attributes do not match the required types.
            ValueError: If the registry DataFrame is empty or missing required columns.
        """
        # Verify that benchmark_registry is a pandas DataFrame
        if not isinstance(self.benchmark_registry, pd.DataFrame):
            raise TypeError("Task21BenchmarkReport: benchmark_registry must be a pandas.DataFrame.")

        # Ensure the registry is not empty
        if self.benchmark_registry.empty:
            raise ValueError("Task21BenchmarkReport: benchmark_registry cannot be empty.")

        # Verify that all_benchmarks_passed is a boolean
        if not isinstance(self.all_benchmarks_passed, bool):
            raise TypeError("Task21BenchmarkReport: all_benchmarks_passed must be a boolean.")


def execute_task_21_reproduce_benchmarks(
    info_builder: Any,
    target_vector: np.ndarray,
    lambda_grid: np.ndarray,
    study_configuration: Dict[str, Any],
    data_provenance: str,
    execute_task_12_callable: Callable[..., Any]
) -> Task21BenchmarkReport:
    """
    Orchestrates Task 21: Evaluates the complex ex-post and exhaustive search benchmarks,
    validates their RMSEs against the manuscript's published targets, and compiles
    the structured benchmark registry.

    Args:
        info_builder (Any): The EvaluatorInfoBuilder instance.
        target_vector (np.ndarray): The 1D array of realized GDP growth values.
        lambda_grid (np.ndarray): The 1D array of candidate lambda values.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        data_provenance (str): Identifier for the data source.
        execute_task_12_callable (Callable): The orchestrator function from Task 12.

    Returns:
        Task21BenchmarkReport: The comprehensive benchmark reproduction report.
    """
    # 1. Recompute the Simple Average baseline for the denominator
    baseline_rmse = evaluate_baseline_method(
        info_builder=info_builder,
        target_vector=target_vector,
        execute_task_12_callable=execute_task_12_callable
    )

    # 2. Evaluate the complex benchmarks
    # Note: These operations are computationally intensive but highly vectorized
    rmse_ex_post_orig = evaluate_pelasso_ex_post_original(info_builder, target_vector, lambda_grid)
    rmse_ex_post_win = evaluate_pelasso_ex_post_per_window(info_builder, target_vector, lambda_grid)
    rmse_avg_flex = evaluate_best_avg_flex(info_builder, target_vector)
    rmse_nw_avg = evaluate_best_nw_avg(info_builder, target_vector)

    # Aggregate the computed RMSEs into a dictionary
    computed_rmses = {
        "Simple average": baseline_rmse,
        "peLASSO ex post (original)": rmse_ex_post_orig,
        "peLASSO ex post (per window)": rmse_ex_post_win,
        "Best avg flex": rmse_avg_flex,
        "Best (N,W) avg": rmse_nw_avg
    }

    # 3. Validate each benchmark to close tolerance
    validation_records = validate_benchmark_tolerances(
        computed_rmses=computed_rmses,
        study_configuration=study_configuration,
        data_provenance=data_provenance
    )

    # Determine the global success flag
    all_passed = all(record.passed for record in validation_records)

    # 4. Store benchmark results for downstream comparison
    df_registry = compile_benchmark_registry(
        validation_records=validation_records,
        baseline_rmse=baseline_rmse,
        data_provenance=data_provenance
    )

    # Return the composite benchmark report
    return Task21BenchmarkReport(
        benchmark_registry=df_registry,
        all_benchmarks_passed=all_passed
    )

# %%
# Task 22: Execute the Three Independent Agentic Discovery Runs

# ==============================================================================
# Task 22: Execute the Three Independent Agentic Discovery Runs
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 22, Scaffolding: Baseline Script Materialization
# -------------------------------------------------------------------------------------------------------------------------------

def write_baseline_train_script(working_directory: Path, train_py_path: str) -> None:
    """
    Materializes the baseline simple average method (tau_0) to disk. This ensures
    that every independent discovery run begins from the exact same mathematical
    and structural starting point, preventing latent code leakage between runs.

    Args:
        working_directory (Path): The absolute path to the repository root.
        train_py_path (str): The relative path to the editable script.

    Raises:
        OSError: If filesystem permissions prevent writing the file.
    """
    # Define the exact, professional-grade Python implementation of the simple average.
    # Equation: \hat{y}_t = (1 / K) * \sum_{k=1}^{K} x_{k,t}
    baseline_script_content = '''import numpy as np
    from typing import Dict, Any

    def select_lambda(info: Dict[str, Any]) -> Dict[str, Any]:
        """
        Baseline Simple Average Method (tau_0).
        Computes the equal-weight arithmetic mean of all current-period forecasts.

        Args:
            info (Dict[str, Any]): The look-ahead-free data dictionary.

        Returns:
            Dict[str, Any]: The forecast and method identifier.
        """
        # Extract the current-period forecast vector
        x_new = info["x_new"]

        # Compute the arithmetic mean across all K forecasters
        mean_forecast = float(np.mean(x_new))

        # Return the strictly formatted dictionary
        return {
            "forecast": mean_forecast,
            "method": "simple_average"
        }
    '''

    full_script_path = working_directory / train_py_path

    # Write the baseline script to disk, explicitly truncating any existing content
    with open(full_script_path, 'w', encoding='utf-8', newline='') as f:
        f.write(baseline_script_content)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 22, Scaffolding: Audit Log Statistical Parser
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class RunStatistics:
    """
    A structured record containing the aggregated experimental statistics parsed
    directly from the immutable TSV audit log.

    Attributes:
        keeps (int): The number of experiments that successfully improved the RMSE.
        discards (int): The number of experiments that failed to improve the RMSE.
        crashes (int): The number of experiments that resulted in runtime errors or timeouts.
    """
    keeps: int
    discards: int
    crashes: int


def parse_run_statistics(working_directory: Path, results_tsv_path: str) -> RunStatistics:
    """
    Parses the finalized results.tsv audit log to extract the exact frequencies of
    keep, discard, and crash events for the summary report.

    Args:
        working_directory (Path): The absolute path to the repository root.
        results_tsv_path (str): The relative path to the TSV audit log.

    Returns:
        RunStatistics: The structured aggregation of experiment outcomes.

    Raises:
        FileNotFoundError: If the audit log does not exist.
    """
    full_tsv_path = working_directory / results_tsv_path

    if not full_tsv_path.exists():
        raise FileNotFoundError(f"Audit log not found at {full_tsv_path}. Cannot parse statistics.")

    # Read the TSV log using pandas for robust tabular parsing
    df_log = pd.read_csv(full_tsv_path, sep='\t', dtype={'commit': str, 'status': str})

    # Count the occurrences of each formal status
    # We use .get() with a default of 0 to handle cases where a status might not have occurred
    status_counts = df_log['status'].value_counts().to_dict()

    keeps = status_counts.get('keep', 0)
    discards = status_counts.get('discard', 0)
    crashes = status_counts.get('crash', 0)

    return RunStatistics(
        keeps=keeps,
        discards=discards,
        crashes=crashes
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 22, Steps 1, 2, & 3: Execute Single Isolated Discovery Run
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class IsolatedRunResult:
    """
    A structured container encapsulating the complete output of a single, isolated
    agentic discovery run, including the search loop report and the parsed statistics.
    """
    run_id: int
    search_report: Any  # Expected type: Task18SearchLoopReport
    statistics: RunStatistics


def execute_single_discovery_run(
    run_id: int,
    working_directory: Path,
    study_configuration: Dict[str, Any],
    prompt_templates: Any,  # Expected type: AgentPromptTemplates
    baseline_rmse: float
) -> IsolatedRunResult:
    """
    Executes a single, strictly isolated agentic discovery run. This function guarantees
    independence by resetting the editable script, re-initializing the version control
    branch, and instantiating a fresh LLM client.

    Args:
        run_id (int): The integer identifier for the run (e.g., 1, 2, or 3).
        working_directory (Path): The absolute path to the repository root.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        prompt_templates (AgentPromptTemplates): The structured prompt strings.
        baseline_rmse (float): The recomputed simple average RMSE for relative scoring.

    Returns:
        IsolatedRunResult: The comprehensive result of the isolated run.
    """
    run_tag = f"run_{run_id}"
    train_py_path = study_configuration["artifact_paths"]["train_py_path"]
    results_tsv_path = study_configuration["artifact_paths"]["results_tsv_path"]
    model_version = study_configuration["search_protocol"]["agent_specification"]["model_family"]

    # 1. Materialize the baseline script to guarantee a clean starting state (tau_0)
    write_baseline_train_script(working_directory, train_py_path)

    # 2. Initialize Version Control and the Uncommitted Results Log (Task 17)
    # This creates the branch 'autoresearch/run_{run_id}', commits tau_0, and truncates results.tsv
    vc_report = execute_task_17_initialize_version_control(
        study_configuration=study_configuration,
        run_tag=run_tag
    )

    # 3. Instantiate a completely fresh Anthropic client to prevent latent state leakage
    fresh_anthropic_client = initialize_anthropic_client(study_configuration)

    # 4. Execute the Autonomous Search Loop (Task 18)
    search_report = execute_autonomous_search_loop(
        working_directory=working_directory,
        study_configuration=study_configuration,
        anthropic_client=fresh_anthropic_client,
        prompt_templates=prompt_templates,
        vc_report=vc_report,
        model_version=model_version
    )

    # 5. Parse the finalized audit log to extract the exact experiment statistics
    run_statistics = parse_run_statistics(
        working_directory=working_directory,
        results_tsv_path=results_tsv_path
    )

    return IsolatedRunResult(
        run_id=run_id,
        search_report=search_report,
        statistics=run_statistics
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 22, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task22DiscoveryRunsReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the multi-run agentic discovery phase. This report encapsulates the individual
    search loop reports and provides a comprehensive, manuscript-aligned summary table
    detailing the experimental trajectories and final search-sample performance of
    each independent run.

    Attributes:
        individual_reports (Dict[int, Any]): A dictionary mapping the integer run ID
            to its respective Task18SearchLoopReport.
        summary_table (pd.DataFrame): A pandas DataFrame summarizing the experiment
            counts, keeps, discards, crashes, and final relative RMSEs for all runs.
    """
    # Dictionary mapping run_id to the detailed search loop report
    individual_reports: Dict[int, Any]
    # Tabular summary of the discovery phase, formatted for archival and analysis
    summary_table: pd.DataFrame

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity and completeness of the discovery runs report.

        Raises:
            TypeError: If the attributes do not match the required types.
            ValueError: If the summary table does not contain exactly three rows.
        """
        # Verify that individual_reports is a dictionary
        if not isinstance(self.individual_reports, dict):
            raise TypeError("Task22DiscoveryRunsReport: individual_reports must be a dictionary.")

        # Verify that summary_table is a pandas DataFrame
        if not isinstance(self.summary_table, pd.DataFrame):
            raise TypeError("Task22DiscoveryRunsReport: summary_table must be a pandas.DataFrame.")

        # Enforce the methodological requirement of exactly three independent runs
        if len(self.summary_table) != 3:
            raise ValueError(f"Task22DiscoveryRunsReport: summary_table must contain exactly 3 rows. Found {len(self.summary_table)}.")


def execute_task_22_execute_discovery_runs(
    working_directory: Path,
    study_configuration: Dict[str, Any],
    prompt_templates: Any,  # Expected type: AgentPromptTemplates
    baseline_rmse: float
) -> Task22DiscoveryRunsReport:
    """
    Orchestrates Task 22: Executes the three independent agentic discovery runs sequentially,
    ensuring strict environmental isolation, and compiles the comprehensive summary table
    documenting the search dynamics and final search-sample performance.

    Args:
        working_directory (Path): The absolute path to the repository root.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        prompt_templates (AgentPromptTemplates): The structured prompt strings.
        baseline_rmse (float): The recomputed simple average RMSE for relative scoring.

    Returns:
        Task22DiscoveryRunsReport: The comprehensive multi-run discovery report.
    """
    # Extract the required number of independent runs from the configuration
    num_runs = int(study_configuration["search_protocol"]["run_design"]["independent_runs"])

    individual_reports = {}
    summary_data = {
        "Run ID": [],
        "Total Experiments": [],
        "Keeps": [],
        "Discards": [],
        "Crashes": [],
        "Final Search-Sample RMSE": [],
        "Final Relative RMSE": []
    }

    # Execute the runs sequentially, ensuring strict isolation
    for run_id in range(1, num_runs + 1):

        # Execute the isolated run
        run_result = execute_single_discovery_run(
            run_id=run_id,
            working_directory=working_directory,
            study_configuration=study_configuration,
            prompt_templates=prompt_templates,
            baseline_rmse=baseline_rmse
        )

        # Store the detailed report
        individual_reports[run_id] = run_result.search_report

        # Compute the final relative RMSE
        final_rmse = run_result.search_report.best_rmse
        relative_rmse = final_rmse / baseline_rmse

        # Append the statistics to the summary data dictionary
        summary_data["Run ID"].append(f"Run {run_id}")
        summary_data["Total Experiments"].append(run_result.search_report.total_experiments)
        summary_data["Keeps"].append(run_result.statistics.keeps)
        summary_data["Discards"].append(run_result.statistics.discards)
        summary_data["Crashes"].append(run_result.statistics.crashes)
        summary_data["Final Search-Sample RMSE"].append(final_rmse)
        summary_data["Final Relative RMSE"].append(relative_rmse)

    # Construct the final pandas DataFrame
    df_summary = pd.DataFrame(summary_data)

    # Return the composite discovery runs report
    return Task22DiscoveryRunsReport(
        individual_reports=individual_reports,
        summary_table=df_summary
    )

# %%
# Task 23: Recreate the Run 1 Method Family from the Post-Search Registry

# ==============================================================================
# Task 23: Recreate the Run 1 Method Family from the Post-Search Registry
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Helper Functions for Run 1 Family
# -------------------------------------------------------------------------------------------------------------------------------

def _compute_cv_lambda(
    X: np.ndarray,
    y: np.ndarray,
    l1_ratio: float,
    cv_folds: int,
    se_multiplier: float,
    lambda_grid: np.ndarray
) -> float:
    """
    Computes the optimal regularization parameter using cross-validation and the
    standard error rule.

    Args:
        X (np.ndarray): The training predictor matrix.
        y (np.ndarray): The training target vector.
        l1_ratio (float): The Elastic Net mixing parameter (1.0 for LASSO).
        cv_folds (int): The number of cross-validation folds.
        se_multiplier (float): The multiplier for the standard error rule (e.g., 1.0 or 1.5).
        lambda_grid (np.ndarray): The grid of candidate lambda values.

    Returns:
        float: The selected lambda value.
    """
    n_samples = X.shape[0]

    # Dynamically adjust the number of folds if the sample size is too small
    # This prevents errors during the early warm-up periods
    actual_folds = min(cv_folds, n_samples)

    if actual_folds < 2:
        # If we have fewer than 2 samples, CV is impossible. Return the median lambda as a fallback.
        return float(np.median(lambda_grid))

    # Initialize the KFold cross-validator
    kf = KFold(n_splits=actual_folds, shuffle=False)

    # Initialize the ElasticNetCV model
    # We scale the alphas by n_samples to match the 1/(2n) objective scaling convention
    alphas_scaled = lambda_grid * n_samples

    model = ElasticNetCV(
        l1_ratio=l1_ratio,
        alphas=alphas_scaled,
        cv=kf,
        fit_intercept=False,
        tol=1e-5,
        max_iter=10000
    )

    # Fit the model to compute the MSE path
    model.fit(X, y)

    # Extract the MSE path. Shape: (n_alphas, n_folds)
    mse_path = model.mse_path_

    # Compute the mean MSE across folds for each alpha
    mean_mse = np.mean(mse_path, axis=1)

    # Compute the standard error of the MSE across folds for each alpha
    # ddof=1 provides an unbiased estimator of the variance
    std_mse = np.std(mse_path, axis=1, ddof=1)
    se_mse = std_mse / math.sqrt(actual_folds)

    # Find the index of the minimum mean MSE
    idx_min = int(np.argmin(mean_mse))
    min_mean_mse = mean_mse[idx_min]
    se_at_min = se_mse[idx_min]

    # Calculate the target threshold using the standard error rule
    # Equation: target = CV(\hat{\lambda}_{min}) + multiplier * SE_{min}
    target_threshold = min_mean_mse + (se_multiplier * se_at_min)

    # Find all alphas whose mean MSE is less than or equal to the target threshold
    valid_indices = np.where(mean_mse <= target_threshold)[0]

    # Select the largest alpha (most regularization) among the valid candidates
    # Since alphas are typically sorted in descending order, we find the maximum valid alpha
    valid_alphas = model.alphas_[valid_indices]
    selected_alpha_scaled = np.max(valid_alphas)

    # Unscale the alpha back to the original lambda grid scale
    selected_lambda = selected_alpha_scaled / n_samples

    return float(selected_lambda)


def _compute_weighted_quantile(x: np.ndarray, w: np.ndarray, q: float) -> float:
    """
    Computes the weighted q-th quantile of an array using linear interpolation
    of the weighted empirical cumulative distribution function.

    Args:
        x (np.ndarray): The array of values.
        w (np.ndarray): The array of corresponding weights.
        q (float): The target quantile in [0.0, 1.0].

    Returns:
        float: The interpolated weighted quantile.
    """
    # Normalize the weights to sum to 1.0
    w_norm = w / np.sum(w)

    # Sort the values and the normalized weights simultaneously
    sort_idx = np.argsort(x)
    x_sorted = x[sort_idx]
    w_sorted = w_norm[sort_idx]

    # Compute the cumulative sum of the sorted weights
    C = np.cumsum(w_sorted)

    # Handle edge cases where the target quantile is outside the cumulative bounds
    if q <= C[0]:
        return float(x_sorted[0])
    if q >= C[-1]:
        return float(x_sorted[-1])

    # Find the index j such that C[j-1] < q <= C[j]
    # np.searchsorted with side='left' finds the first index where C >= q
    j = int(np.searchsorted(C, q, side='left'))

    # Apply linear interpolation of the weighted empirical CDF
    # Equation: Q_q = x_{(j-1)} + \frac{q - C_{j-1}}{C_j - C_{j-1}} (x_{(j)} - x_{(j-1)})
    c_prev = C[j-1]
    c_curr = C[j]
    x_prev = x_sorted[j-1]
    x_curr = x_sorted[j]

    fraction = (q - c_prev) / (c_curr - c_prev)
    interpolated_value = x_prev + fraction * (x_curr - x_prev)

    return float(interpolated_value)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 23, Step 1: Implement Run 1 final — stability selection with performance-weighted aggregation
# -------------------------------------------------------------------------------------------------------------------------------

def run_1_final_select_lambda(info: Dict[str, Any]) -> Dict[str, Any]:
    """
    Run 1 (final): Stability selection with performance weighted aggregation.

    Args:
        info (Dict[str, Any]): The look-ahead-free data dictionary.

    Returns:
        Dict[str, Any]: The forecast and method identifier.
    """
    X_train = info["X_train"]
    y_train = info["y_train"]
    x_new = info["x_new"]
    lambda_grid = info["lambda_grid"]

    n_samples, k_forecasters = X_train.shape

    # Step A: Elastic net fitting with 5-fold CV to find lambda_1.5se
    alpha_enet = 0.65
    lambda_1_5se = _compute_cv_lambda(
        X=X_train,
        y=y_train,
        l1_ratio=alpha_enet,
        cv_folds=5,
        se_multiplier=1.5,
        lambda_grid=lambda_grid
    )

    # Step B: Stability selection
    # Define the neighborhood W = {j : |log(lambda_j) - log(lambda_1.5se)| < 0.25}
    log_lambda_1_5se = math.log(lambda_1_5se)
    log_grid = np.log(lambda_grid)

    neighborhood_mask = np.abs(log_grid - log_lambda_1_5se) < 0.25
    lambdas_in_W = lambda_grid[neighborhood_mask]

    # Fallback if the neighborhood is empty due to grid sparsity
    if len(lambdas_in_W) == 0:
        lambdas_in_W = np.array([lambda_1_5se])

    # Compute the coefficient paths for the lambdas in the neighborhood
    # We scale the alphas by n_samples for sklearn compatibility
    alphas_in_W_scaled = lambdas_in_W * n_samples

    _, coef_path, _ = enet_path(
        X_train,
        y_train,
        l1_ratio=alpha_enet,
        alphas=alphas_in_W_scaled,
        fit_intercept=False,
        tol=1e-5
    )

    # Compute selection frequencies
    # Equation: \pi_k = |W|^{-1} \sum_{j \in W} \mathbf{1}\{\hat{\beta}_k(\lambda_j) \neq 0\}
    non_zero_mask = np.abs(coef_path) > 1e-7
    pi_k = np.mean(non_zero_mask, axis=1)

    # Define the active set A = {k : \pi_k > 0.4}
    active_set = np.where(pi_k > 0.4)[0]

    # Fallback if the active set is empty
    if len(active_set) == 0:
        return {
            "forecast": float(np.mean(x_new)),
            "method": "run_1_final_stability_selection_perf_weighted (fallback: simple average)"
        }

    # Step C: Composite weights
    # Use the m=2 most recent training observations
    m = min(2, n_samples)
    X_recent = X_train[-m:, active_set]
    y_recent = y_train[-m:]

    # Compute individual RMSE for each active forecaster
    # Equation: RMSE_k = \sqrt{\frac{1}{m}\sum_{s}(y_s - x_{k,s})^2}
    squared_errors = (X_recent - y_recent[:, None]) ** 2
    rmse_k = np.sqrt(np.mean(squared_errors, axis=0))

    # Compute composite weights
    # Equation: w_k = \pi_k^2 \cdot RMSE_k^{-14}
    # Add epsilon to prevent division by zero if a forecaster was perfectly accurate
    epsilon = 1e-10
    pi_k_active = pi_k[active_set]
    w_k = (pi_k_active ** 2) * ((rmse_k + epsilon) ** -14.0)

    # Step D: Dominance check
    # Sort weights descending to find w_(1) and w_(2)
    sort_idx_desc = np.argsort(-w_k)
    w_sorted_desc = w_k[sort_idx_desc]

    if len(w_k) > 1:
        w_1 = w_sorted_desc[0]
        w_2 = w_sorted_desc[1]

        # If the best forecaster dominates by a factor of 5, use it exclusively
        if w_1 > 5.0 * w_2:
            best_k_idx = active_set[sort_idx_desc[0]]
            return {
                "forecast": float(x_new[best_k_idx]),
                "method": "run_1_final_stability_selection_perf_weighted (dominance)"
            }

    # Step E: Weighted quantile aggregation
    x_active = x_new[active_set]
    q_target = 0.44

    forecast_val = _compute_weighted_quantile(x=x_active, w=w_k, q=q_target)

    return {
        "forecast": forecast_val,
        "method": "run_1_final_stability_selection_perf_weighted"
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 23, Step 2: Implement Run 1a — ENet with median
# -------------------------------------------------------------------------------------------------------------------------------

def run_1a_select_lambda(info: Dict[str, Any]) -> Dict[str, Any]:
    """
    Run 1a (Phase 2): Elastic net selection with median aggregation.

    Args:
        info (Dict[str, Any]): The look-ahead-free data dictionary.

    Returns:
        Dict[str, Any]: The forecast and method identifier.
    """
    X_train = info["X_train"]
    y_train = info["y_train"]
    x_new = info["x_new"]
    lambda_grid = info["lambda_grid"]

    n_samples = X_train.shape[0]
    alpha_enet = 0.65

    # 1. Fit elastic net with 5-fold CV to find lambda_1se
    lambda_1se = _compute_cv_lambda(
        X=X_train,
        y=y_train,
        l1_ratio=alpha_enet,
        cv_folds=5,
        se_multiplier=1.0,
        lambda_grid=lambda_grid
    )

    # 2. Identify the active set using the selected lambda
    alpha_scaled = lambda_1se * n_samples
    _, coef_path, _ = enet_path(
        X_train,
        y_train,
        l1_ratio=alpha_enet,
        alphas=np.array([alpha_scaled]),
        fit_intercept=False,
        tol=1e-5
    )

    beta_hat = coef_path[:, 0]
    active_set = np.where(np.abs(beta_hat) > 1e-7)[0]

    # 3. Fallback if the active set is empty
    if len(active_set) == 0:
        return {
            "forecast": float(np.mean(x_new)),
            "method": "run_1a_enet_median (fallback: simple average)"
        }

    # 4. Median aggregation
    # Equation: \hat{y}_t = \text{median}(\{x_{k,t}\}_{k \in \mathcal{A}(\hat{\lambda}_{1se})})
    forecast_val = float(np.median(x_new[active_set]))

    return {
        "forecast": forecast_val,
        "method": "run_1a_enet_median"
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 23, Step 3: Implement Run 1b — peLASSO with CV
# -------------------------------------------------------------------------------------------------------------------------------

def run_1b_select_lambda(info: Dict[str, Any]) -> Dict[str, Any]:
    """
    Run 1b (Phase 1): Standard peLASSO with CV-selected lambda and equal-weight averaging.

    Args:
        info (Dict[str, Any]): The look-ahead-free data dictionary.

    Returns:
        Dict[str, Any]: The forecast and method identifier.
    """
    X_train = info["X_train"]
    y_train = info["y_train"]
    x_new = info["x_new"]
    lambda_grid = info["lambda_grid"]

    n_samples = X_train.shape[0]
    # Pure LASSO corresponds to an l1_ratio of 1.0
    alpha_lasso = 1.0

    # 1. Fit LASSO with CV to find lambda_1se
    lambda_1se = _compute_cv_lambda(
        X=X_train,
        y=y_train,
        l1_ratio=alpha_lasso,
        cv_folds=5,
        se_multiplier=1.0,
        lambda_grid=lambda_grid
    )

    # 2. Identify the active set using the selected lambda
    alpha_scaled = lambda_1se * n_samples
    _, coef_path, _ = enet_path(
        X_train,
        y_train,
        l1_ratio=alpha_lasso,
        alphas=np.array([alpha_scaled]),
        fit_intercept=False,
        tol=1e-5
    )

    beta_hat = coef_path[:, 0]
    active_set = np.where(np.abs(beta_hat) > 1e-7)[0]

    # 3. Fallback if the active set is empty
    if len(active_set) == 0:
        return {
            "forecast": float(np.mean(x_new)),
            "method": "run_1b_pelasso_cv (fallback: simple average)"
        }

    # 4. Equal-weight average aggregation
    # Equation: \hat{y}_t = |\mathcal{A}(\hat{\lambda}_{1se})|^{-1} \sum_{k \in \mathcal{A}} x_{k,t}
    forecast_val = float(np.mean(x_new[active_set]))

    return {
        "forecast": forecast_val,
        "method": "run_1b_pelasso_cv"
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 23, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task23Run1FamilyReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the Run 1 method family recreation phase. This report serves as the authoritative
    registry of the stability selection and performance-weighted aggregation callables
    discovered by the agent, ensuring they are ready for injection into the holdout
    evaluation harness.

    Attributes:
        run_1_final (Callable): The fully implemented stability selection method.
        run_1a (Callable): The intermediate elastic net with median aggregation method.
        run_1b (Callable): The intermediate data-driven peLASSO method.
    """
    # The final, most complex method discovered in Run 1
    run_1_final: Callable[[Dict[str, Any]], Dict[str, Any]]
    # The Phase 2 intermediate method
    run_1a: Callable[[Dict[str, Any]], Dict[str, Any]]
    # The Phase 1 intermediate method
    run_1b: Callable[[Dict[str, Any]], Dict[str, Any]]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the method registry before it is consumed by the orchestrator.

        Raises:
            TypeError: If any of the attributes are not callable objects.
        """
        # Verify that run_1_final is a callable function
        if not callable(self.run_1_final):
            raise TypeError("Task23Run1FamilyReport: run_1_final must be a callable.")

        # Verify that run_1a is a callable function
        if not callable(self.run_1a):
            raise TypeError("Task23Run1FamilyReport: run_1a must be a callable.")

        # Verify that run_1b is a callable function
        if not callable(self.run_1b):
            raise TypeError("Task23Run1FamilyReport: run_1b must be a callable.")


def execute_task_23_recreate_run_1_family(study_configuration: Dict[str, Any]) -> Task23Run1FamilyReport:
    """
    Orchestrates Task 23: Bundles the recreated Run 1 method family callables into
    a structured registry report, ensuring they are ready for downstream evaluation.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Task23Run1FamilyReport: The comprehensive registry of Run 1 methods.
    """
    # The callables are defined as pure functions above. We simply bundle them
    # into the strongly-typed dataclass to fulfill the orchestrator contract.

    return Task23Run1FamilyReport(
        run_1_final=run_1_final_select_lambda,
        run_1a=run_1a_select_lambda,
        run_1b=run_1b_select_lambda
    )

# %%
# Task 24: Recreate the Run 2 Method Family from the Post-Search Registry

# ==============================================================================
# Task 24: Recreate the Run 2 Method Family from the Post-Search Registry
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Helper Functions for Run 2 Family
# -------------------------------------------------------------------------------------------------------------------------------

def _compute_temporal_weights(n: int, alpha: float = 6.0) -> np.ndarray:
    """
    Computes the exponential temporal weights for a given window size.
    Recent observations receive exponentially higher weight.

    Equation: \omega_s = \exp(-\alpha(n-s)/(n-1)) / \sum_{j=1}^n \exp(-\alpha(n-j)/(n-1))

    Args:
        n (int): The number of observations in the window.
        alpha (float): The decay parameter.

    Returns:
        np.ndarray: A 1D array of shape (n,) containing the normalized weights.
    """
    # Handle the edge case where the window has only 1 observation
    if n <= 1:
        return np.array([1.0], dtype=np.float64)

    # s indexes the observations from 1 to n
    s = np.arange(1, n + 1, dtype=np.float64)

    # Compute the exponent: -\alpha * (n - s) / (n - 1)
    exponent = -alpha * (n - s) / (n - 1.0)

    # Compute the unnormalized weights
    w_unnormalized = np.exp(exponent)

    # Normalize the weights to sum to 1.0
    w_normalized = w_unnormalized / np.sum(w_unnormalized)

    return w_normalized


def _evaluate_loo_for_window(
    X: np.ndarray,
    y: np.ndarray,
    n_candidates: List[int],
    penalty_factor: float = 0.0
) -> Tuple[int, float, np.ndarray]:
    """
    Performs Leave-One-Out (LOO) cross-validation over candidate subset sizes N.
    For each left-out observation, it reranks forecasters, selects the top N,
    and computes both weighted average and median forecasts.

    Args:
        X (np.ndarray): The predictor matrix of shape (n, K).
        y (np.ndarray): The target vector of shape (n,).
        n_candidates (List[int]): The list of candidate subset sizes N.
        penalty_factor (float): The multiplier for the log(N+1) penalty (used in Run 2b).

    Returns:
        Tuple[int, float, np.ndarray]:
            - The optimal subset size N*.
            - The LOO RMSE (penalized if applicable) for N*.
            - The array of LOO percentile (median) predictions for N* of shape (n,).
    """
    n_samples, k_forecasters = X.shape

    # Initialize storage for the LOO predictions for each candidate N
    loo_preds_weighted = {N: np.zeros(n_samples, dtype=np.float64) for N in n_candidates}
    loo_preds_pct = {N: np.zeros(n_samples, dtype=np.float64) for N in n_candidates}

    # Epsilon to prevent division by zero when computing inverse MAE weights
    epsilon = 1e-10

    # Iterate over each observation to leave it out
    for i in range(n_samples):
        # Create a boolean mask to exclude the i-th observation
        mask = np.ones(n_samples, dtype=bool)
        mask[i] = False

        # Slice the leave-out training set (size n-1)
        X_loo = X[mask]
        y_loo = y[mask]

        # Compute the forecast errors on the leave-out set
        # Broadcasting y_loo[:, None] aligns targets with the K forecasters
        err = X_loo - y_loo[:, None]

        # Rerank by RMSE on the remaining n-1 observations
        rmse_loo = np.sqrt(np.mean(err**2, axis=0))
        ranking = np.argsort(rmse_loo)

        # Compute MAE on the leave-out set for weighting
        mae_loo = np.mean(np.abs(err), axis=0)

        # Evaluate each candidate subset size N
        for N in n_candidates:
            # Ensure we don't try to select more forecasters than exist
            actual_N = min(N, k_forecasters)

            # Select the top N forecasters based on the LOO RMSE ranking
            top_N_indices = ranking[:actual_N]

            # Weight them by \tilde{w}_j \propto MAE_j^{-3}
            w_j = (mae_loo[top_N_indices] + epsilon) ** -3.0
            w_j_norm = w_j / np.sum(w_j)

            # Compute the weighted average LOO forecast for observation i
            loo_preds_weighted[N][i] = np.sum(w_j_norm * X[i, top_N_indices])

            # Compute the median-based LOO forecast for observation i
            loo_preds_pct[N][i] = np.median(X[i, top_N_indices])

    # Select the optimal N* based on the LOO RMSE of the weighted forecasts
    best_N = n_candidates[0]
    best_criterion = float('inf')

    for N in n_candidates:
        # Compute the standard LOO RMSE
        rmse_val = np.sqrt(np.mean((loo_preds_weighted[N] - y)**2))

        # Apply the penalty criterion if specified (used in Run 2b)
        # Criterion: RMSE_{LOO}(N) + penalty * \log(N + 1)
        criterion_val = rmse_val + penalty_factor * math.log(N + 1)

        if criterion_val < best_criterion:
            best_criterion = criterion_val
            best_N = N

    return best_N, best_criterion, loo_preds_pct[best_N]

# -------------------------------------------------------------------------------------------------------------------------------
# Task 24, Step 1: Implement Run 2 final — temporally weighted ranking with adaptive window selection and bias correction
# -------------------------------------------------------------------------------------------------------------------------------

def run_2_final_select_lambda(info: Dict[str, Any]) -> Dict[str, Any]:
    """
    Run 2 (final): Temporally weighted ranking with adaptive window selection and bias correction.

    Args:
        info (Dict[str, Any]): The look-ahead-free data dictionary.

    Returns:
        Dict[str, Any]: The forecast and method identifier.
    """
    X_train = info["X_train"]
    y_train = info["y_train"]
    x_new = info["x_new"]

    n_t, k_forecasters = X_train.shape

    # Fallback for extremely small samples where LOO is impossible
    if n_t < 2:
        return {
            "forecast": float(np.mean(x_new)),
            "method": "run_2_final_temporal_ranking_bias_correction (fallback: simple average)"
        }

    # Define candidate subset sizes N \in {3, ..., min(K, 18)}
    max_n = min(k_forecasters, 18)
    n_candidates = list(range(3, max_n + 1))

    # Step D: Adaptive window search
    # Evaluate full rolling window and sub-windows w' \in {4, ..., 19}
    candidates_w = [w for w in range(4, 20) if w <= n_t]

    # Ensure the full window is always evaluated, even if it's not in the 4-19 range
    if n_t not in candidates_w:
        candidates_w.append(n_t)

    best_w = candidates_w[0]
    best_N = n_candidates[0]
    best_loo_rmse = float('inf')
    best_loo_pct_preds = None

    for w in candidates_w:
        # Slice the most recent w observations
        X_w = X_train[-w:]
        y_w = y_train[-w:]

        # Execute Step C: LOO CV for subset size
        N_opt, rmse_opt, pct_preds = _evaluate_loo_for_window(
            X=X_w,
            y=y_w,
            n_candidates=n_candidates,
            penalty_factor=0.0
        )

        # Keep the (N*, w'*) combination that yields the lowest LOO RMSE
        if rmse_opt < best_loo_rmse:
            best_loo_rmse = rmse_opt
            best_w = w
            best_N = N_opt
            best_loo_pct_preds = pct_preds

    # Step A & B: Temporal weights and Weighted MAE ranking on the optimal window
    X_opt = X_train[-best_w:]
    y_opt = y_train[-best_w:]

    omega_s = _compute_temporal_weights(best_w, alpha=6.0)

    # Compute temporally weighted MAE for each forecaster
    # Equation: MAE_k = \sum_{s=1}^n \omega_s |y_s - x_{k,s}|
    weighted_abs_errors = omega_s[:, None] * np.abs(X_opt - y_opt[:, None])
    mae_k = np.sum(weighted_abs_errors, axis=0)

    # Rank forecasters by ascending MAE
    ranking = np.argsort(mae_k)
    top_N_final = ranking[:best_N]

    # Step E: Median aggregation (Base forecast)
    # Equation: \tilde{y}_t = Q_{0.50}(\{x_{k,t}\}_{k \in top N^*})
    y_tilde = float(np.median(x_new[top_N_final]))

    # Step F: Bias correction
    # Extract the percentile-based LOO error from the most recent training observation
    # The most recent observation is at index -1 of the optimal window
    e_n_loo_pct = best_loo_pct_preds[-1] - y_opt[-1]

    # Apply the correction with \gamma = 0.80
    # Equation: \hat{y}_t = \tilde{y}_t - \gamma \cdot \hat{e}_n^{LOO,pct}
    gamma = 0.80
    y_hat = y_tilde - gamma * e_n_loo_pct

    return {
        "forecast": float(y_hat),
        "method": "run_2_final_temporal_ranking_bias_correction"
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 24, Step 2: Implement Run 2a — no bias correction
# -------------------------------------------------------------------------------------------------------------------------------

def run_2a_select_lambda(info: Dict[str, Any]) -> Dict[str, Any]:
    """
    Run 2a (no bias correction): Identical to Run 2 final but omits the bias correction step.

    Args:
        info (Dict[str, Any]): The look-ahead-free data dictionary.

    Returns:
        Dict[str, Any]: The forecast and method identifier.
    """
    X_train = info["X_train"]
    y_train = info["y_train"]
    x_new = info["x_new"]

    n_t, k_forecasters = X_train.shape

    if n_t < 2:
        return {
            "forecast": float(np.mean(x_new)),
            "method": "run_2a_no_bias_correction (fallback: simple average)"
        }

    max_n = min(k_forecasters, 18)
    n_candidates = list(range(3, max_n + 1))

    candidates_w = [w for w in range(4, 20) if w <= n_t]
    if n_t not in candidates_w:
        candidates_w.append(n_t)

    best_w = candidates_w[0]
    best_N = n_candidates[0]
    best_loo_rmse = float('inf')

    for w in candidates_w:
        X_w = X_train[-w:]
        y_w = y_train[-w:]

        N_opt, rmse_opt, _ = _evaluate_loo_for_window(
            X=X_w,
            y=y_w,
            n_candidates=n_candidates,
            penalty_factor=0.0
        )

        if rmse_opt < best_loo_rmse:
            best_loo_rmse = rmse_opt
            best_w = w
            best_N = N_opt

    X_opt = X_train[-best_w:]
    y_opt = y_train[-best_w:]

    omega_s = _compute_temporal_weights(best_w, alpha=6.0)
    weighted_abs_errors = omega_s[:, None] * np.abs(X_opt - y_opt[:, None])
    mae_k = np.sum(weighted_abs_errors, axis=0)

    ranking = np.argsort(mae_k)
    top_N_final = ranking[:best_N]

    # Base forecast without bias correction
    # Equation: \hat{y}_t = \tilde{y}_t
    y_hat = float(np.median(x_new[top_N_final]))

    return {
        "forecast": y_hat,
        "method": "run_2a_no_bias_correction"
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 24, Step 3: Implement Run 2b — weighted average with penalized criterion
# -------------------------------------------------------------------------------------------------------------------------------

def run_2b_select_lambda(info: Dict[str, Any]) -> Dict[str, Any]:
    """
    Run 2b (weighted avg): Weighted ranking with a fixed window and penalized LOO criterion.

    Args:
        info (Dict[str, Any]): The look-ahead-free data dictionary.

    Returns:
        Dict[str, Any]: The forecast and method identifier.
    """
    X_train = info["X_train"]
    y_train = info["y_train"]
    x_new = info["x_new"]

    n_t, k_forecasters = X_train.shape

    if n_t < 2:
        return {
            "forecast": float(np.mean(x_new)),
            "method": "run_2b_weighted_avg (fallback: simple average)"
        }

    max_n = min(k_forecasters, 18)
    n_candidates = list(range(3, max_n + 1))

    # Fixed window: No adaptive search, use the full available training window
    # Step C: LOO CV with penalized criterion
    # Criterion: RMSE_{LOO}(N) + 0.01 * \log(N + 1)
    best_N, _, _ = _evaluate_loo_for_window(
        X=X_train,
        y=y_train,
        n_candidates=n_candidates,
        penalty_factor=0.01
    )

    # Step A & B: Temporal weights and Weighted MAE ranking on the fixed window
    omega_s = _compute_temporal_weights(n_t, alpha=6.0)
    weighted_abs_errors = omega_s[:, None] * np.abs(X_train - y_train[:, None])
    mae_k = np.sum(weighted_abs_errors, axis=0)

    ranking = np.argsort(mae_k)
    top_N_final = ranking[:best_N]

    # Step E: Weighted average aggregation
    # Weights are proportional to MAE^{-3}
    epsilon = 1e-10
    w_j = (mae_k[top_N_final] + epsilon) ** -3.0
    w_j_norm = w_j / np.sum(w_j)

    # Equation: \hat{y}_t = \sum_{j=1}^{N^*} \tilde{w}_j x_{\sigma(j),t}
    y_hat = float(np.sum(w_j_norm * x_new[top_N_final]))

    return {
        "forecast": y_hat,
        "method": "run_2b_weighted_avg"
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 24, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task24Run2FamilyReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the Run 2 method family recreation phase. This report serves as the authoritative
    registry of the temporally weighted ranking and bias correction callables discovered
    by the agent, ensuring they are ready for injection into the holdout evaluation harness.

    Attributes:
        run_2_final (Callable): The fully implemented adaptive window and bias correction method.
        run_2a (Callable): The intermediate method omitting bias correction.
        run_2b (Callable): The intermediate method using a fixed window and penalized criterion.
    """
    # The final, most successful method discovered in Run 2
    run_2_final: Callable[[Dict[str, Any]], Dict[str, Any]]
    # The ablation variant isolating the impact of bias correction
    run_2a: Callable[[Dict[str, Any]], Dict[str, Any]]
    # The early variant utilizing a penalized LOO criterion
    run_2b: Callable[[Dict[str, Any]], Dict[str, Any]]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the method registry before it is consumed by the orchestrator.

        Raises:
            TypeError: If any of the attributes are not callable objects.
        """
        # Verify that run_2_final is a callable function
        if not callable(self.run_2_final):
            raise TypeError("Task24Run2FamilyReport: run_2_final must be a callable.")

        # Verify that run_2a is a callable function
        if not callable(self.run_2a):
            raise TypeError("Task24Run2FamilyReport: run_2a must be a callable.")

        # Verify that run_2b is a callable function
        if not callable(self.run_2b):
            raise TypeError("Task24Run2FamilyReport: run_2b must be a callable.")


def execute_task_24_recreate_run_2_family(study_configuration: Dict[str, Any]) -> Task24Run2FamilyReport:
    """
    Orchestrates Task 24: Bundles the recreated Run 2 method family callables into
    a structured registry report, ensuring they are ready for downstream evaluation.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Task24Run2FamilyReport: The comprehensive registry of Run 2 methods.
    """
    # The callables are defined as pure functions above. We simply bundle them
    # into the strongly-typed dataclass to fulfill the orchestrator contract.

    return Task24Run2FamilyReport(
        run_2_final=run_2_final_select_lambda,
        run_2a=run_2a_select_lambda,
        run_2b=run_2b_select_lambda
    )

# %%
# Task 25: Recreate the Run 3 Method Family from the Post-Search Registry

# ==============================================================================
# Task 25: Recreate the Run 3 Method Family from the Post-Search Registry
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Helper Functions for Run 3 Family
# -------------------------------------------------------------------------------------------------------------------------------

def _compute_adaptive_penalty_factors(
    X_train: np.ndarray,
    y_train: np.ndarray,
    lambda_grid: np.ndarray,
    alpha_pilot: float = 0.1,
    epsilon: float = 0.005
) -> Tuple[np.ndarray, np.ndarray]:
    """
    Computes the forecaster-specific penalty factors for the Adaptive LASSO using a
    pilot elastic net (ridge-like) estimator.

    Equation: \tilde{w}_k = (| \hat{\beta}_k^{ridge} | + \epsilon)^{-1} / \text{mean}(| \hat{\beta}^{ridge} | + \epsilon)^{-1}

    Args:
        X_train (np.ndarray): The training predictor matrix.
        y_train (np.ndarray): The training target vector.
        lambda_grid (np.ndarray): The grid of candidate lambda values.
        alpha_pilot (float): The elastic net mixing parameter for the pilot (default 0.1).
        epsilon (float): The stability constant to prevent division by zero.

    Returns:
        Tuple[np.ndarray, np.ndarray]:
            - The normalized penalty factors \tilde{w}_k of shape (K,).
            - The raw pilot coefficients \hat{\beta}^{ridge} of shape (K,).
    """
    n_samples = X_train.shape[0]

    # Step A: Pilot estimator
    # Fit elastic net with LOO CV (approximated by 5-fold or actual sample size)
    cv_folds = min(n_samples, 5)

    if cv_folds < 2:
        # Fallback for extremely small samples
        pilot_coefs = np.ones(X_train.shape[1], dtype=np.float64)
    else:
        lambda_pilot = _compute_cv_lambda(
            X=X_train,
            y=y_train,
            l1_ratio=alpha_pilot,
            cv_folds=cv_folds,
            se_multiplier=0.0, # Use lambda_min, not lambda_1se for the pilot
            lambda_grid=lambda_grid
        )

        # Extract the coefficients for the selected lambda
        alpha_scaled = lambda_pilot * n_samples
        _, coef_path, _ = enet_path(
            X_train,
            y_train,
            l1_ratio=alpha_pilot,
            alphas=np.array([alpha_scaled]),
            fit_intercept=False,
            tol=1e-5
        )
        pilot_coefs = coef_path[:, 0]

    # Step B: Adaptive LASSO penalty factors
    # Compute the inverse magnitude with epsilon
    inv_mag = 1.0 / (np.abs(pilot_coefs) + epsilon)

    # Normalize by the cross-sectional mean
    mean_inv_mag = np.mean(inv_mag)
    w_tilde = inv_mag / mean_inv_mag

    return w_tilde, pilot_coefs


def _fit_adaptive_lasso_path(
    X_history: np.ndarray,
    y_history: np.ndarray,
    w_tilde: np.ndarray,
    lambda_grid: np.ndarray
) -> np.ndarray:
    """
    Fits the Adaptive LASSO on the full history for all lambdas in the grid.
    Since sklearn does not natively support penalty factors, we mathematically
    transform the predictor matrix: X_scaled = X / w_tilde.

    Args:
        X_history (np.ndarray): The full history predictor matrix.
        y_history (np.ndarray): The full history target vector.
        w_tilde (np.ndarray): The penalty factors of shape (K,).
        lambda_grid (np.ndarray): The grid of candidate lambda values.

    Returns:
        np.ndarray: The coefficient path of shape (K, n_lambdas).
    """
    n_samples = X_history.shape[0]

    # Transform the predictor matrix to implicitly apply the penalty factors
    # Broadcasting divides each column k by w_tilde[k]
    X_scaled = X_history / w_tilde[np.newaxis, :]

    # Fit standard LASSO (l1_ratio=1.0) on the scaled predictors
    alphas_scaled = lambda_grid * n_samples
    _, coef_path_scaled, _ = enet_path(
        X_scaled,
        y_history,
        l1_ratio=1.0,
        alphas=alphas_scaled,
        fit_intercept=False,
        tol=1e-5
    )

    # Transform the coefficients back to the original scale
    # \beta_k = \beta_{scaled, k} / \tilde{w}_k
    coef_path = coef_path_scaled / w_tilde[:, np.newaxis]

    return coef_path


def _evaluate_forward_cv(
    X_history: np.ndarray,
    y_history: np.ndarray,
    w_tilde: np.ndarray,
    pilot_coefs: np.ndarray,
    lambda_grid: np.ndarray,
    horizons: List[int],
    horizon_weights: Dict[int, float],
    fold_decay_gamma: float
) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    """
    Performs multi-horizon forward cross-validation to evaluate the Adaptive LASSO path.

    Args:
        X_history (np.ndarray): The full history predictor matrix.
        y_history (np.ndarray): The full history target vector.
        w_tilde (np.ndarray): The penalty factors.
        pilot_coefs (np.ndarray): The pilot ridge coefficients used for ridge-weighted mean.
        lambda_grid (np.ndarray): The grid of candidate lambda values.
        horizons (List[int]): The forecast horizons to evaluate (e.g., [1, 2]).
        horizon_weights (Dict[int, float]): The weights for each horizon's error.
        fold_decay_gamma (float): The temporal decay factor for older folds.

    Returns:
        Tuple[np.ndarray, np.ndarray, np.ndarray]:
            - cv_scores_rule1: CV scores for the simple average rule of shape (n_lambdas,).
            - cv_scores_rule2: CV scores for the blended average rule of shape (n_lambdas,).
            - rmse_rule1: Unweighted RMSE for rule 1 (used for model averaging weights).
    """
    n_samples, k_forecasters = X_history.shape
    n_lambdas = len(lambda_grid)

    # Initialize CV score accumulators
    cv_scores_rule1 = np.zeros(n_lambdas, dtype=np.float64)
    cv_scores_rule2 = np.zeros(n_lambdas, dtype=np.float64)

    # Initialize unweighted squared error accumulators for model averaging weights
    sq_err_rule1 = np.zeros(n_lambdas, dtype=np.float64)

    # Determine the maximum horizon required
    max_h = max(horizons)

    # We need at least 2 observations to fit a model, plus max_h observations to evaluate
    min_train_size = 2
    if n_samples < min_train_size + max_h:
        # Fallback: If history is too short, return uniform scores to trigger fallback logic
        return cv_scores_rule1, cv_scores_rule2, np.ones(n_lambdas, dtype=np.float64)

    # Construct the valid split points t_f
    # t_f is the index of the last training observation in the fold
    split_points = list(range(min_train_size, n_samples - max_h + 1))
    F = len(split_points)

    # Pre-compute ridge weights for the blended aggregation rule
    # Normalize the absolute pilot coefficients to sum to 1
    epsilon = 1e-10
    ridge_weights = (np.abs(pilot_coefs) + epsilon)
    ridge_weights /= np.sum(ridge_weights)

    # Iterate over the forward folds
    for f_idx, t_f in enumerate(split_points):
        # f is the 1-based fold index
        f = f_idx + 1

        # Compute the temporal fold weight: w_f \propto \gamma^{F-f}
        w_f = fold_decay_gamma ** (F - f)

        # Slice the training data for this fold
        X_train_f = X_history[:t_f]
        y_train_f = y_history[:t_f]

        # Fit the Adaptive LASSO path on this fold
        coef_path_f = _fit_adaptive_lasso_path(X_train_f, y_train_f, w_tilde, lambda_grid)

        # Evaluate at each required horizon
        for h in horizons:
            h_weight = horizon_weights.get(h, 0.0)
            if h_weight == 0.0:
                continue

            # The target observation is at index t_f + h - 1
            eval_idx = t_f + h - 1
            x_eval = X_history[eval_idx]
            y_eval = y_history[eval_idx]

            # Evaluate each lambda
            for l_idx in range(n_lambdas):
                beta_hat = coef_path_f[:, l_idx]
                active_set = np.where(np.abs(beta_hat) > 1e-7)[0]

                if len(active_set) == 0:
                    # Fallback to simple average of all
                    pred_rule1 = np.mean(x_eval)
                    pred_rule2 = pred_rule1
                else:
                    # Rule 1: Simple average of selected forecasters
                    pred_rule1 = np.mean(x_eval[active_set])

                    # Rule 2: Blended average (0.7 * mean + 0.3 * ridge-weighted mean)
                    # The ridge-weighted mean is computed over the active set, re-normalized
                    rw_active = ridge_weights[active_set]
                    rw_active_norm = rw_active / np.sum(rw_active)
                    ridge_weighted_mean = np.sum(rw_active_norm * x_eval[active_set])

                    pred_rule2 = 0.70 * pred_rule1 + 0.30 * ridge_weighted_mean

                # Compute squared errors
                sq_err_1 = (y_eval - pred_rule1) ** 2
                sq_err_2 = (y_eval - pred_rule2) ** 2

                # Accumulate the weighted CV scores
                cv_scores_rule1[l_idx] += w_f * h_weight * sq_err_1
                cv_scores_rule2[l_idx] += w_f * h_weight * sq_err_2

                # Accumulate unweighted squared errors for Rule 1 (used for model averaging)
                if h == 1:
                    sq_err_rule1[l_idx] += sq_err_1

    # Compute the unweighted RMSE for Rule 1
    rmse_rule1 = np.sqrt(sq_err_rule1 / F)

    return cv_scores_rule1, cv_scores_rule2, rmse_rule1

# -------------------------------------------------------------------------------------------------------------------------------
# Task 25, Step 1: Implement Run 3 final — adaptive LASSO with multi-horizon forward CV and egalitarian elastic-net blend
# -------------------------------------------------------------------------------------------------------------------------------

def run_3_final_select_lambda(info: Dict[str, Any]) -> Dict[str, Any]:
    """
    Run 3 (final): Adaptive LASSO with multi-horizon forward CV, model averaging,
    and egalitarian elastic net ensemble.

    Args:
        info (Dict[str, Any]): The look-ahead-free data dictionary.

    Returns:
        Dict[str, Any]: The forecast and method identifier.
    """
    X_train = info["X_train"]
    y_train = info["y_train"]
    X_history = info["X_history"]
    y_history = info["y_history"]
    x_new = info["x_new"]
    lambda_grid = info["lambda_grid"]

    n_samples, k_forecasters = X_train.shape

    # Fallback for extremely small samples
    if n_samples < 2:
        return {
            "forecast": float(np.mean(x_new)),
            "method": "run_3_final_adalasso_blend (fallback: simple average)"
        }

    # Step A & B: Pilot estimator and Adaptive LASSO penalty factors
    w_tilde, pilot_coefs = _compute_adaptive_penalty_factors(
        X_train=X_train,
        y_train=y_train,
        lambda_grid=lambda_grid,
        alpha_pilot=0.1,
        epsilon=0.005
    )

    # Step C: Adaptive LASSO fitting on full history
    coef_path_full = _fit_adaptive_lasso_path(X_history, y_history, w_tilde, lambda_grid)

    # Step D: Multi-horizon forward CV
    horizons = [1, 2]
    horizon_weights = {1: 0.05, 2: 0.95}
    fold_decay_gamma = 0.75

    cv_scores_rule1, cv_scores_rule2, rmse_rule1 = _evaluate_forward_cv(
        X_history=X_history,
        y_history=y_history,
        w_tilde=w_tilde,
        pilot_coefs=pilot_coefs,
        lambda_grid=lambda_grid,
        horizons=horizons,
        horizon_weights=horizon_weights,
        fold_decay_gamma=fold_decay_gamma
    )

    # Determine which rule performed better overall
    min_cv1 = np.min(cv_scores_rule1)
    min_cv2 = np.min(cv_scores_rule2)

    if min_cv1 <= min_cv2:
        best_cv_scores = cv_scores_rule1
        use_rule2 = False
    else:
        best_cv_scores = cv_scores_rule2
        use_rule2 = True

    # Step E: Model averaging
    # Identify lambdas within 1% of the best CV score
    min_cv = np.min(best_cv_scores)
    threshold = 1.01 * min_cv

    # Handle edge case where min_cv is exactly 0
    if min_cv == 0.0:
        threshold = 1e-10

    lambda_indices_star = np.where(best_cv_scores <= threshold)[0]

    # Pre-compute ridge weights for Rule 2 if needed
    epsilon = 1e-10
    ridge_weights = (np.abs(pilot_coefs) + epsilon)
    ridge_weights /= np.sum(ridge_weights)

    # Generate forecasts for all lambdas in Lambda^*
    forecasts_star = []
    weights_star = []

    for l_idx in lambda_indices_star:
        beta_hat = coef_path_full[:, l_idx]
        active_set = np.where(np.abs(beta_hat) > 1e-7)[0]

        if len(active_set) == 0:
            pred = np.mean(x_new)
        else:
            pred_rule1 = np.mean(x_new[active_set])
            if use_rule2:
                rw_active = ridge_weights[active_set]
                rw_active_norm = rw_active / np.sum(rw_active)
                ridge_weighted_mean = np.sum(rw_active_norm * x_new[active_set])
                pred = 0.70 * pred_rule1 + 0.30 * ridge_weighted_mean
            else:
                pred = pred_rule1

        forecasts_star.append(pred)

        # Weight by inverse RMSE
        rmse_val = rmse_rule1[l_idx]
        weights_star.append(1.0 / (rmse_val + epsilon))

    # Compute the model-averaged PE forecast
    weights_star = np.array(weights_star)
    weights_star_norm = weights_star / np.sum(weights_star)
    y_hat_pe = np.sum(weights_star_norm * np.array(forecasts_star))

    # Step F: Egalitarian elastic net
    alpha_een = 0.5
    lambda_min_een = _compute_cv_lambda(
        X=X_train,
        y=y_train,
        l1_ratio=alpha_een,
        cv_folds=min(n_samples, 5),
        se_multiplier=0.0, # lambda_min rule
        lambda_grid=lambda_grid
    )

    # Fit egalitarian elastic net on the rolling window
    y_tilde_train = _egalitarian_transform(X_train, y_train)
    alpha_scaled_een = lambda_min_een * n_samples
    _, coef_path_een, _ = enet_path(
        X_train,
        y_tilde_train,
        l1_ratio=alpha_een,
        alphas=np.array([alpha_scaled_een]),
        fit_intercept=False,
        tol=1e-5
    )

    beta_tilde_een = coef_path_een[:, 0]

    # Compute the egalitarian elastic-net forecast
    # Equation: \hat{y}_t^{eEN} = \sum_k (\tilde{\beta}_k^{eEN} + 1/K) x_{k,t}
    beta_final_een = beta_tilde_een + (1.0 / k_forecasters)
    y_hat_een = np.dot(x_new, beta_final_een)

    # Step G: Final blend
    # Equation: \hat{y}_t = 0.70 \cdot \hat{y}_t^{PE} + 0.30 \cdot \hat{y}_t^{eEN}
    y_hat_final = 0.70 * y_hat_pe + 0.30 * y_hat_een

    return {
        "forecast": float(y_hat_final),
        "method": "run_3_final_adalasso_blend"
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 25, Step 2: Implement Run 3a — single horizon, no blend
# -------------------------------------------------------------------------------------------------------------------------------

def run_3a_select_lambda(info: Dict[str, Any]) -> Dict[str, Any]:
    """
    Run 3a (h=1, no blend): Adaptive LASSO with single-horizon forward CV,
    no model averaging, and no egalitarian elastic-net blend.

    Args:
        info (Dict[str, Any]): The look-ahead-free data dictionary.

    Returns:
        Dict[str, Any]: The forecast and method identifier.
    """
    X_train = info["X_train"]
    y_train = info["y_train"]
    X_history = info["X_history"]
    y_history = info["y_history"]
    x_new = info["x_new"]
    lambda_grid = info["lambda_grid"]

    n_samples = X_train.shape[0]

    if n_samples < 2:
        return {
            "forecast": float(np.mean(x_new)),
            "method": "run_3a_h1_no_blend (fallback: simple average)"
        }

    # Step A & B: Pilot estimator and Adaptive LASSO penalty factors
    w_tilde, pilot_coefs = _compute_adaptive_penalty_factors(
        X_train=X_train,
        y_train=y_train,
        lambda_grid=lambda_grid,
        alpha_pilot=0.1,
        epsilon=0.005
    )

    # Step C: Adaptive LASSO fitting on full history
    coef_path_full = _fit_adaptive_lasso_path(X_history, y_history, w_tilde, lambda_grid)

    # Step D: Single-horizon forward CV
    horizons = [1]
    horizon_weights = {1: 1.0} # Only h=1 is evaluated
    fold_decay_gamma = 0.75

    cv_scores_rule1, _, _ = _evaluate_forward_cv(
        X_history=X_history,
        y_history=y_history,
        w_tilde=w_tilde,
        pilot_coefs=pilot_coefs,
        lambda_grid=lambda_grid,
        horizons=horizons,
        horizon_weights=horizon_weights,
        fold_decay_gamma=fold_decay_gamma
    )

    # No model averaging: select the single best lambda
    best_l_idx = int(np.argmin(cv_scores_rule1))

    # Generate forecast using the simple average rule
    beta_hat = coef_path_full[:, best_l_idx]
    active_set = np.where(np.abs(beta_hat) > 1e-7)[0]

    if len(active_set) == 0:
        y_hat = float(np.mean(x_new))
    else:
        # Equation: \hat{y}_t = |\mathcal{A}(\hat{\lambda})|^{-1} \sum_{k \in \mathcal{A}} x_{k,t}
        y_hat = float(np.mean(x_new[active_set]))

    return {
        "forecast": y_hat,
        "method": "run_3a_h1_no_blend"
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 25, Step 3: Implement Run 3b — multi-horizon, no blend
# -------------------------------------------------------------------------------------------------------------------------------

def run_3b_select_lambda(info: Dict[str, Any]) -> Dict[str, Any]:
    """
    Run 3b (h=2, no blend): Adaptive LASSO with multi-horizon forward CV and
    model averaging, but no egalitarian elastic-net blend.

    Args:
        info (Dict[str, Any]): The look-ahead-free data dictionary.

    Returns:
        Dict[str, Any]: The forecast and method identifier.
    """
    X_train = info["X_train"]
    y_train = info["y_train"]
    X_history = info["X_history"]
    y_history = info["y_history"]
    x_new = info["x_new"]
    lambda_grid = info["lambda_grid"]

    n_samples = X_train.shape[0]

    if n_samples < 2:
        return {
            "forecast": float(np.mean(x_new)),
            "method": "run_3b_h2_no_blend (fallback: simple average)"
        }

    # Step A & B: Pilot estimator and Adaptive LASSO penalty factors
    # Note: epsilon is 0.001 for this variant
    w_tilde, pilot_coefs = _compute_adaptive_penalty_factors(
        X_train=X_train,
        y_train=y_train,
        lambda_grid=lambda_grid,
        alpha_pilot=0.1,
        epsilon=0.001
    )

    # Step C: Adaptive LASSO fitting on full history
    coef_path_full = _fit_adaptive_lasso_path(X_history, y_history, w_tilde, lambda_grid)

    # Step D: Multi-horizon forward CV
    horizons = [1, 2]
    horizon_weights = {1: 0.05, 2: 0.95}
    # Note: fold_decay_gamma is 0.80 for this variant
    fold_decay_gamma = 0.80

    cv_scores_rule1, cv_scores_rule2, rmse_rule1 = _evaluate_forward_cv(
        X_history=X_history,
        y_history=y_history,
        w_tilde=w_tilde,
        pilot_coefs=pilot_coefs,
        lambda_grid=lambda_grid,
        horizons=horizons,
        horizon_weights=horizon_weights,
        fold_decay_gamma=fold_decay_gamma
    )

    min_cv1 = np.min(cv_scores_rule1)
    min_cv2 = np.min(cv_scores_rule2)

    if min_cv1 <= min_cv2:
        best_cv_scores = cv_scores_rule1
        use_rule2 = False
    else:
        best_cv_scores = cv_scores_rule2
        use_rule2 = True

    # Step E: Model averaging
    min_cv = np.min(best_cv_scores)
    threshold = 1.01 * min_cv
    if min_cv == 0.0:
        threshold = 1e-10

    lambda_indices_star = np.where(best_cv_scores <= threshold)[0]

    epsilon = 1e-10
    ridge_weights = (np.abs(pilot_coefs) + epsilon)
    ridge_weights /= np.sum(ridge_weights)

    forecasts_star = []
    weights_star = []

    for l_idx in lambda_indices_star:
        beta_hat = coef_path_full[:, l_idx]
        active_set = np.where(np.abs(beta_hat) > 1e-7)[0]

        if len(active_set) == 0:
            pred = np.mean(x_new)
        else:
            pred_rule1 = np.mean(x_new[active_set])
            if use_rule2:
                rw_active = ridge_weights[active_set]
                rw_active_norm = rw_active / np.sum(rw_active)
                ridge_weighted_mean = np.sum(rw_active_norm * x_new[active_set])
                pred = 0.70 * pred_rule1 + 0.30 * ridge_weighted_mean
            else:
                pred = pred_rule1

        forecasts_star.append(pred)

        rmse_val = rmse_rule1[l_idx]
        weights_star.append(1.0 / (rmse_val + epsilon))

    weights_star = np.array(weights_star)
    weights_star_norm = weights_star / np.sum(weights_star)

    # The forecast is the model-averaged PE forecast only (no blend)
    # Equation: \hat{y}_t = \hat{y}_t^{PE}
    y_hat_pe = float(np.sum(weights_star_norm * np.array(forecasts_star)))

    return {
        "forecast": y_hat_pe,
        "method": "run_3b_h2_no_blend"
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 25, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task25Run3FamilyReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the Run 3 method family recreation phase. This report serves as the authoritative
    registry of the adaptive LASSO and ensemble blending callables discovered by the
    agent, ensuring they are ready for injection into the holdout evaluation harness.

    Attributes:
        run_3_final (Callable): The fully implemented adaptive LASSO and ensemble blend method.
        run_3a (Callable): The intermediate method using single-horizon CV and no blend.
        run_3b (Callable): The intermediate method using multi-horizon CV and model averaging.
    """
    # The final, most complex method discovered in Run 3
    run_3_final: Callable[[Dict[str, Any]], Dict[str, Any]]
    # The Phase 4 intermediate method
    run_3a: Callable[[Dict[str, Any]], Dict[str, Any]]
    # The Phase 5 intermediate method
    run_3b: Callable[[Dict[str, Any]], Dict[str, Any]]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the method registry before it is consumed by the orchestrator.

        Raises:
            TypeError: If any of the attributes are not callable objects.
        """
        # Verify that run_3_final is a callable function
        if not callable(self.run_3_final):
            raise TypeError("Task25Run3FamilyReport: run_3_final must be a callable.")

        # Verify that run_3a is a callable function
        if not callable(self.run_3a):
            raise TypeError("Task25Run3FamilyReport: run_3a must be a callable.")

        # Verify that run_3b is a callable function
        if not callable(self.run_3b):
            raise TypeError("Task25Run3FamilyReport: run_3b must be a callable.")


def execute_task_25_recreate_run_3_family(study_configuration: Dict[str, Any]) -> Task25Run3FamilyReport:
    """
    Orchestrates Task 25: Bundles the recreated Run 3 method family callables into
    a structured registry report, ensuring they are ready for downstream evaluation.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        Task25Run3FamilyReport: The comprehensive registry of Run 3 methods.
    """
    # The callables are defined as pure functions above. We simply bundle them
    # into the strongly-typed dataclass to fulfill the orchestrator contract.
    return Task25Run3FamilyReport(
        run_3_final=run_3_final_select_lambda,
        run_3a=run_3a_select_lambda,
        run_3b=run_3b_select_lambda
    )

# %%
# Task 26: Compute the Search-Sample Evaluation Table

# ==============================================================================
# Task 26: Compute the Search-Sample Evaluation Table
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Step 1: Compute RMSE for all methods on the search sample
# -------------------------------------------------------------------------------------------------------------------------------

def compute_all_search_sample_rmses(
    evaluator_report: Any,  # Expected: Task11EvaluatorConstructorReport
    target_vector: np.ndarray,
    baseline_report: Any,   # Expected: Task13BaselineReport
    benchmark_report: Any,  # Expected: Task21BenchmarkReport
    run1_report: Any,       # Expected: Task23Run1FamilyReport
    run2_report: Any,       # Expected: Task24Run2FamilyReport
    run3_report: Any,       # Expected: Task25Run3FamilyReport
    execute_task_12_callable: Callable[..., Any]
) -> Dict[str, float]:
    """
    Aggregates the pre-computed benchmark RMSEs and dynamically evaluates all
    discovered method callables through the immutable rolling-origin harness
    to compute their absolute search-sample RMSEs.

    Args:
        evaluator_report (Task11EvaluatorConstructorReport): The info builder factory.
        target_vector (np.ndarray): The 1D array of realized GDP growth values.
        baseline_report (Task13BaselineReport): The validated simple average baseline.
        benchmark_report (Task21BenchmarkReport): The pre-computed complex benchmarks.
        run1_report (Task23Run1FamilyReport): The Run 1 method callables.
        run2_report (Task24Run2FamilyReport): The Run 2 method callables.
        run3_report (Task25Run3FamilyReport): The Run 3 method callables.
        execute_task_12_callable (Callable): The Task 12 scoring orchestrator.

    Returns:
        Dict[str, float]: A dictionary mapping method names to their absolute RMSEs.
    """
    info_builder = evaluator_report.info_builder
    baseline_rmse = baseline_report.validated_baseline_rmse

    # Initialize the results dictionary with the baseline
    results = {
        "Simple average": baseline_rmse
    }

    # 1. Extract pre-computed complex benchmarks from Task 21
    # These methods require full-sample or combinatorial evaluation, so we reuse
    # the rigorously validated results from the benchmark registry.
    df_benchmarks = benchmark_report.benchmark_registry
    for _, row in df_benchmarks.iterrows():
        method_name = row["method_name"]
        if method_name != "Simple average":
            results[method_name] = float(row["search_sample_rmse"])

    # 2. Define the mapping of discovered callables to their formal names
    discovered_callables = {
        "Run 1 (final)": run1_report.run_1_final,
        "Run 1a (ENet, median)": run1_report.run_1a,
        "Run 1b (peLASSO, CV)": run1_report.run_1b,
        "Run 2 (final)": run2_report.run_2_final,
        "Run 2a (no bias corr.)": run2_report.run_2a,
        "Run 2b (weighted avg)": run2_report.run_2b,
        "Run 3 (final)": run3_report.run_3_final,
        "Run 3a (h=1, no blend)": run3_report.run_3a,
        "Run 3b (h=2, no blend)": run3_report.run_3b
    }

    # 3. Dynamically evaluate each discovered callable through the immutable harness
    for method_name, method_callable in discovered_callables.items():
        # Execute the rolling-origin loop (t=5 to 70) and compute the 65-period RMSE
        score_report = execute_task_12_callable(
            info_builder=info_builder,
            target_vector=target_vector,
            select_lambda_callable=method_callable,
            baseline_rmse=baseline_rmse
        )
        results[method_name] = score_report.absolute_rmse

    # Verify that exactly 14 methods have been evaluated
    if len(results) != 14:
        raise ValueError(f"Expected exactly 14 methods to be evaluated. Found {len(results)}.")

    return results

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Step 2: Compute relative RMSE for all methods
# -------------------------------------------------------------------------------------------------------------------------------

def construct_relative_rmse_table(absolute_rmses: Dict[str, float]) -> pd.DataFrame:
    """
    Constructs a structured pandas DataFrame containing the absolute and relative
    RMSEs for all methods, categorized by their respective methodological panels.

    Args:
        absolute_rmses (Dict[str, float]): The dictionary of absolute RMSEs.

    Returns:
        pd.DataFrame: The formatted evaluation table.

    Raises:
        ValueError: If the simple average baseline is missing or non-positive.
    """
    # Extract the baseline RMSE for the denominator
    if "Simple average" not in absolute_rmses:
        raise ValueError("Fatal: 'Simple average' missing from absolute RMSEs.")

    baseline_rmse = absolute_rmses["Simple average"]

    if baseline_rmse <= 0.0:
        raise ValueError(f"Fatal: Baseline RMSE must be strictly positive. Found {baseline_rmse}.")

    # Define the panel categorization schema
    panel_mapping = {
        "Simple average": "Panel A: Benchmarks",
        "peLASSO ex post (original)": "Panel A: Benchmarks",
        "peLASSO ex post (per window)": "Panel A: Benchmarks",
        "Best avg flex": "Panel A: Benchmarks",
        "Best (N,W) avg": "Panel A: Benchmarks",
        "Run 1 (final)": "Panel B: Run 1 family",
        "Run 1a (ENet, median)": "Panel B: Run 1 family",
        "Run 1b (peLASSO, CV)": "Panel B: Run 1 family",
        "Run 2 (final)": "Panel C: Run 2 family",
        "Run 2a (no bias corr.)": "Panel C: Run 2 family",
        "Run 2b (weighted avg)": "Panel C: Run 2 family",
        "Run 3 (final)": "Panel D: Run 3 family",
        "Run 3a (h=1, no blend)": "Panel D: Run 3 family",
        "Run 3b (h=2, no blend)": "Panel D: Run 3 family"
    }

    # Initialize lists for DataFrame construction
    data = {
        "method_name": [],
        "panel": [],
        "search_sample_rmse": [],
        "search_sample_relative_rmse": []
    }

    # Enforce a specific ordering for the final table
    ordered_methods = list(panel_mapping.keys())

    for method in ordered_methods:
        abs_rmse = absolute_rmses[method]
        # Compute the relative RMSE: RMSE_m / RMSE_baseline
        rel_rmse = abs_rmse / baseline_rmse

        data["method_name"].append(method)
        data["panel"].append(panel_mapping[method])
        data["search_sample_rmse"].append(abs_rmse)
        data["search_sample_relative_rmse"].append(rel_rmse)

    df_table = pd.DataFrame(data)
    return df_table

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Step 3: Validate against published targets
# -------------------------------------------------------------------------------------------------------------------------------

def validate_search_sample_table(
    df_table: pd.DataFrame,
    study_configuration: Dict[str, Any],
    data_provenance: str
) -> Tuple[pd.DataFrame, bool]:
    """
    Validates the computed relative RMSEs against the manuscript's published targets,
    applying dynamic tolerance tiers based on data provenance.

    Args:
        df_table (pd.DataFrame): The evaluation table from Step 2.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        data_provenance (str): Identifier for the data source.

    Returns:
        Tuple[pd.DataFrame, bool]: The augmented DataFrame and a global success flag.
    """
    # Define the published relative RMSE targets from the manuscript
    # Main targets from Table 1, intermediate targets from Table 4
    published_targets = {
        "Simple average": 1.000,
        "peLASSO ex post (original)": 0.930,
        "peLASSO ex post (per window)": 0.930,
        "Best avg flex": 0.954,
        "Best (N,W) avg": 0.916,
        "Run 1 (final)": 0.858,
        "Run 1a (ENet, median)": 0.924,
        "Run 1b (peLASSO, CV)": 0.964,
        "Run 2 (final)": 0.510,
        "Run 2a (no bias corr.)": 0.869,
        "Run 2b (weighted avg)": 0.898,
        "Run 3 (final)": 0.808,
        "Run 3a (h=1, no blend)": 0.870,
        "Run 3b (h=2, no blend)": 0.869
    }

    # Determine the tolerance tier based on data provenance
    is_exact_reproduction = "original" in data_provenance.lower() or "verbatim" in data_provenance.lower()

    # Base tolerance for discovered methods is slightly wider than benchmarks
    # due to potential numerical differences in CV folds and LASSO paths
    base_tolerance = 0.010
    vintage_penalty = 0.000 if is_exact_reproduction else 0.025
    applied_tolerance = base_tolerance + vintage_penalty

    # Initialize columns for the validation results
    target_col = []
    deviation_col = []
    passed_col = []

    all_passed = True

    for _, row in df_table.iterrows():
        method = row["method_name"]
        computed_rel_rmse = row["search_sample_relative_rmse"]

        target_rel_rmse = published_targets[method]
        deviation = abs(computed_rel_rmse - target_rel_rmse)

        # The simple average is exactly 1.0 by definition
        if method == "Simple average":
            passed = True
        else:
            passed = bool(deviation <= applied_tolerance)

        if not passed:
            all_passed = False

        target_col.append(target_rel_rmse)
        deviation_col.append(deviation)
        passed_col.append(passed)

    # Augment the DataFrame with the validation metrics
    df_validated = df_table.copy()
    df_validated["target_relative_rmse"] = target_col
    df_validated["deviation"] = deviation_col
    df_validated["tolerance_applied"] = applied_tolerance
    df_validated["passed_validation"] = passed_col

    return df_validated, all_passed

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task26SearchSampleReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the search-sample evaluation phase. This report encapsulates the comprehensive
    performance table for all 14 methods (benchmarks and discovered variants),
    providing the definitive in-sample metrics required to verify Conclusion 1
    of the manuscript.

    Attributes:
        evaluation_table (pd.DataFrame): The augmented pandas DataFrame containing
            absolute RMSEs, relative RMSEs, and validation metrics against published targets.
        all_methods_passed_validation (bool): A global flag indicating whether all
            reproduced methods fell within the acceptable methodological tolerance bounds.
    """
    # The comprehensive evaluation table formatted for archival
    evaluation_table: pd.DataFrame
    # Boolean flag confirming the overall success of the in-sample reproduction
    all_methods_passed_validation: bool

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the evaluation report before it is consumed by the holdout phase.

        Raises:
            TypeError: If the attributes do not match the required types.
            ValueError: If the evaluation table does not contain exactly 14 rows.
        """
        # Verify that evaluation_table is a pandas DataFrame
        if not isinstance(self.evaluation_table, pd.DataFrame):
            raise TypeError("Task26SearchSampleReport: evaluation_table must be a pandas.DataFrame.")

        # Enforce the methodological requirement of exactly 14 evaluated methods
        if len(self.evaluation_table) != 14:
            raise ValueError(f"Task26SearchSampleReport: evaluation_table must contain exactly 14 rows. Found {len(self.evaluation_table)}.")

        # Verify that all_methods_passed_validation is a boolean
        if not isinstance(self.all_methods_passed_validation, bool):
            raise TypeError("Task26SearchSampleReport: all_methods_passed_validation must be a boolean.")


def execute_task_26_compute_search_sample_table(
    evaluator_report: Any,
    target_vector: np.ndarray,
    baseline_report: Any,
    benchmark_report: Any,
    run1_report: Any,
    run2_report: Any,
    run3_report: Any,
    study_configuration: Dict[str, Any],
    data_provenance: str,
    execute_task_12_callable: Callable[..., Any]
) -> Task26SearchSampleReport:
    """
    Orchestrates Task 26: Evaluates all discovered methods through the immutable harness,
    aggregates the pre-computed benchmarks, computes relative RMSEs, and validates
    the results against the manuscript's published targets.

    Args:
        evaluator_report (Task11EvaluatorConstructorReport): The info builder factory.
        target_vector (np.ndarray): The 1D array of realized GDP growth values.
        baseline_report (Task13BaselineReport): The validated simple average baseline.
        benchmark_report (Task21BenchmarkReport): The pre-computed complex benchmarks.
        run1_report (Task23Run1FamilyReport): The Run 1 method callables.
        run2_report (Task24Run2FamilyReport): The Run 2 method callables.
        run3_report (Task25Run3FamilyReport): The Run 3 method callables.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        data_provenance (str): Identifier for the data source.
        execute_task_12_callable (Callable): The Task 12 scoring orchestrator.

    Returns:
        Task26SearchSampleReport: The comprehensive search-sample evaluation report.
    """
    # Step 1: Compute RMSE for all methods on the search sample
    absolute_rmses = compute_all_search_sample_rmses(
        evaluator_report=evaluator_report,
        target_vector=target_vector,
        baseline_report=baseline_report,
        benchmark_report=benchmark_report,
        run1_report=run1_report,
        run2_report=run2_report,
        run3_report=run3_report,
        execute_task_12_callable=execute_task_12_callable
    )

    # Step 2: Compute relative RMSE for all methods
    df_table = construct_relative_rmse_table(absolute_rmses)

    # Step 3: Validate against published targets
    df_validated, all_passed = validate_search_sample_table(
        df_table=df_table,
        study_configuration=study_configuration,
        data_provenance=data_provenance
    )

    # Return the composite evaluation report
    return Task26SearchSampleReport(
        evaluation_table=df_validated,
        all_methods_passed_validation=all_passed
    )

# %%
# Task 27: Freeze Selected Scripts and Compute the Holdout Evaluation Table

# ==============================================================================
# Task 27: Freeze Selected Scripts and Compute the Holdout Evaluation Table
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Step 1: Freeze the selected script for each run
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass(frozen=True)
class FrozenMethodRegistry:
    """
    A strictly immutable container that securely holds the final selected methods
    (\\hat{\\tau}_K) for each of the three discovery runs. By freezing this dataclass,
    we architecturally guarantee that the methods cannot be altered or swapped
    during the out-of-sample holdout evaluation phase, preserving the integrity
    of the audit trail.

    Attributes:
        run_1_final (Callable[[Dict[str, Any]], Dict[str, Any]]): The stability
            selection and performance-weighted aggregation method from Run 1.
        run_2_final (Callable[[Dict[str, Any]], Dict[str, Any]]): The temporally
            weighted ranking and bias correction method from Run 2.
        run_3_final (Callable[[Dict[str, Any]], Dict[str, Any]]): The adaptive
            LASSO and egalitarian elastic-net ensemble method from Run 3.
    """
    # The finalized callable representing the optimal script discovered in Run 1
    run_1_final: Callable[[Dict[str, Any]], Dict[str, Any]]
    # The finalized callable representing the optimal script discovered in Run 2
    run_2_final: Callable[[Dict[str, Any]], Dict[str, Any]]
    # The finalized callable representing the optimal script discovered in Run 3
    run_3_final: Callable[[Dict[str, Any]], Dict[str, Any]]


def freeze_discovered_methods(
    run1_report: Any,
    run2_report: Any,
    run3_report: Any
) -> FrozenMethodRegistry:
    """
    Extracts the final discovered methods from the post-search registries and
    encapsulates them in a mathematically frozen state for holdout evaluation.

    Args:
        run1_report (Any): The registry report for Run 1 (Expected: Task23Run1FamilyReport).
        run2_report (Any): The registry report for Run 2 (Expected: Task24Run2FamilyReport).
        run3_report (Any): The registry report for Run 3 (Expected: Task25Run3FamilyReport).

    Returns:
        FrozenMethodRegistry: The immutable container of final methods.

    Raises:
        AttributeError: If the provided reports lack the required final method attributes.
    """
    # Extract the final callables from the respective reports and instantiate the frozen dataclass.
    # This operation locks the references, preventing downstream mutation.
    return FrozenMethodRegistry(
        run_1_final=run1_report.run_1_final,
        run_2_final=run2_report.run_2_final,
        run_3_final=run3_report.run_3_final
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Step 2: Reveal the holdout and compute holdout RMSE
# -------------------------------------------------------------------------------------------------------------------------------

class HoldoutEvaluator:
    """
    An elite, highly optimized evaluation harness specifically designed for the
    out-of-sample holdout phase. It operates on the full 106-row canonical panel
    but strictly restricts scoring to the holdout indices (t=71 to 106), ensuring
    that the rolling-origin information set correctly incorporates all preceding
    history without look-ahead bias.
    """
    def __init__(
        self,
        df_canonical_panel: pd.DataFrame,
        index_map: pd.DataFrame,
        lambda_grid: np.ndarray,
        lambda_grid2: np.ndarray,
        study_configuration: Dict[str, Any]
    ) -> None:
        """
        Initializes the HoldoutEvaluator by pre-allocating contiguous numpy arrays
        for O(1) slicing performance during the high-frequency evaluation loop.

        Args:
            df_canonical_panel (pd.DataFrame): The full 106-row aligned dataset.
            index_map (pd.DataFrame): The authoritative index mapping and metadata.
            lambda_grid (np.ndarray): The primary 200-point regularization grid.
            lambda_grid2 (np.ndarray): The secondary 200-point regularization grid.
            study_configuration (Dict[str, Any]): The study configuration dictionary.

        Raises:
            ValueError: If the canonical panel or index map dimensions are invalid.
            TypeError: If the inputs do not match the required data structures.
        """
        # Validate input types to ensure structural integrity
        if not isinstance(df_canonical_panel, pd.DataFrame):
            raise TypeError("HoldoutEvaluator: df_canonical_panel must be a pandas.DataFrame.")

        # Extract the rolling window size (W=20) from the configuration
        self.W = int(study_configuration["prepare_script_data"]["rolling_window_W"])
        # Extract the number of forecasters (K=23) from the configuration
        self.K = int(study_configuration["prepare_script_data"]["K_forecasters"])

        # Create deep copies of the regularization grids to prevent reference mutation
        self.lambda_grid = lambda_grid.copy()
        self.lambda_grid2 = lambda_grid2.copy()

        # Construct the list of forecaster column names programmatically
        forecaster_cols = [f"forecaster_{k:02d}" for k in range(1, self.K + 1)]
        # Extract the target column name from the configuration
        target_col = study_configuration["data_inputs"]["gdp_target_series"]["value_column"]

        # Convert the forecaster DataFrame slice to a contiguous float64 numpy array for O(1) access
        self.forecaster_matrix = df_canonical_panel[forecaster_cols].to_numpy(dtype=np.float64, copy=True)
        # Convert the target series to a contiguous float64 numpy array
        self.target_vector = df_canonical_panel[target_col].to_numpy(dtype=np.float64, copy=True)

        # Extract the boolean mask identifying the holdout periods from the index map
        holdout_mask = index_map["sample_membership"] == "holdout"
        # Extract the COVID flags specifically for the holdout periods as a boolean numpy array
        self.covid_flags = index_map.loc[holdout_mask, "covid_flag"].to_numpy(dtype=bool)

        # Rigorously verify the dimensions of the extracted holdout metadata
        if len(self.covid_flags) != 36:
            raise ValueError(f"Expected exactly 36 holdout periods, found {len(self.covid_flags)}.")
        # Verify that exactly 4 quarters are flagged as COVID periods (2020Q1-2020Q4)
        if self.covid_flags.sum() != 4:
            raise ValueError(f"Expected exactly 4 COVID quarters in the holdout, found {self.covid_flags.sum()}.")

    def build_info(self, t: int) -> Dict[str, Any]:
        """
        Constructs the look-ahead-free `info` dictionary for a holdout origin t.

        Args:
            t (int): The 1-based manuscript time index (must be in [71, 106]).

        Returns:
            Dict[str, Any]: The strictly formatted data dictionary for the callable.

        Raises:
            ValueError: If the requested time index t is outside the holdout bounds.
        """
        # Enforce the strict temporal bounds for the holdout evaluation phase
        if not (71 <= t <= 106):
            raise ValueError(f"Holdout time index t={t} is out of bounds [71, 106].")

        # Map the 1-based manuscript index t to the 0-based Python slice end index (exclusive)
        end_idx = t - 1
        # Calculate the start index for the rolling window of size W
        start_idx = max(0, t - 1 - self.W)

        # Slice the rolling window predictor matrix (shape: W x K)
        X_train = self.forecaster_matrix[start_idx:end_idx, :].copy()
        # Slice the rolling window target vector (shape: W)
        y_train = self.target_vector[start_idx:end_idx].copy()

        # Slice the full history predictor matrix from the beginning of the panel
        X_history = self.forecaster_matrix[0:end_idx, :].copy()
        # Slice the full history target vector
        y_history = self.target_vector[0:end_idx].copy()

        # Extract the current-period forecast vector for time t
        x_new = self.forecaster_matrix[end_idx, :].copy()

        # Assemble and return the look-ahead-free information dictionary
        return {
            "X_train": X_train,
            "y_train": y_train,
            "X_history": X_history,
            "y_history": y_history,
            "x_new": x_new,
            "lambda_grid": self.lambda_grid.copy(),
            "lambda_grid2": self.lambda_grid2.copy(),
            "t": t,
            "w": self.W
        }

    def evaluate_method(self, method_callable: Callable[[Dict[str, Any]], Dict[str, Any]]) -> Tuple[float, float]:
        """
        Executes the provided method over the 36 holdout periods and computes both
        the full holdout RMSE and the holdout-excluding-COVID RMSE.

        Args:
            method_callable (Callable): The forecasting method to evaluate.

        Returns:
            Tuple[float, float]: A tuple containing (rmse_full, rmse_ex_covid).

        Raises:
            TypeError: If the provided method is not callable.
            RuntimeError: If the callable returns non-finite forecasts.
        """
        # Validate that the provided method is executable
        if not callable(method_callable):
            raise TypeError("HoldoutEvaluator: method_callable must be a callable function.")

        # Pre-allocate contiguous numpy arrays for the 36 holdout forecasts and actuals
        forecasts = np.full(36, np.nan, dtype=np.float64)
        actuals = np.full(36, np.nan, dtype=np.float64)

        # Iterate over the strict holdout origins (t=71 to 106 inclusive)
        for t in range(71, 107):
            # Map the manuscript index t to the 0-based holdout array index i
            i = t - 71

            # Construct the look-ahead-free info object for the current origin
            info = self.build_info(t)

            # Execute the method callable to generate the forecast dictionary
            result = method_callable(info)

            # Extract and cast the scalar forecast
            forecasts[i] = float(result["forecast"])
            # Extract the realized target value for time t
            actuals[i] = self.target_vector[t - 1]

        # Verify that no forecasts are NaN or infinite
        if not np.all(np.isfinite(forecasts)):
            raise RuntimeError("Holdout evaluation failed: Method returned non-finite forecasts.")

        # Compute the forecast errors (e_t = y_t - \hat{y}_t)
        errors = actuals - forecasts
        # Compute the squared forecast errors
        squared_errors = errors ** 2

        # 1. Compute the Full Holdout RMSE (36 periods)
        # Equation: \sqrt{\frac{1}{36}\sum_{t \in D^H}(y_t - \hat{y}_t)^2}
        rmse_full = float(np.sqrt(np.mean(squared_errors)))

        # 2. Compute the Holdout Excluding COVID RMSE (32 periods)
        # Invert the COVID boolean mask to select non-COVID periods
        non_covid_mask = ~self.covid_flags
        # Equation: \sqrt{\frac{1}{32}\sum_{t \in D^H \setminus COVID}(y_t - \hat{y}_t)^2}
        rmse_ex_covid = float(np.sqrt(np.mean(squared_errors[non_covid_mask])))

        # Return the dual RMSE metrics
        return rmse_full, rmse_ex_covid

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Step 3: Compute holdout RMSE for all benchmarks
# -------------------------------------------------------------------------------------------------------------------------------

def _find_search_sample_optimal_lambda(
    df_canonical_panel: pd.DataFrame,
    study_configuration: Dict[str, Any],
    lambda_grid: np.ndarray
) -> float:
    """
    Helper function to find the globally optimal lambda for peLASSO ex post (original)
    over the search sample (t=5 to 70). This replicates the oracle behavior by
    violating the no-look-ahead constraint across the search sample to establish
    a theoretical upper bound.

    Args:
        df_canonical_panel (pd.DataFrame): The full canonical panel.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        lambda_grid (np.ndarray): The 1D array of candidate lambda values.

    Returns:
        float: The globally optimal lambda value for the search sample.
    """
    # Extract configuration parameters
    W = int(study_configuration["prepare_script_data"]["rolling_window_W"])
    K = int(study_configuration["prepare_script_data"]["K_forecasters"])

    # Construct column names
    forecaster_cols = [f"forecaster_{k:02d}" for k in range(1, K + 1)]
    target_col = study_configuration["data_inputs"]["gdp_target_series"]["value_column"]

    # Extract contiguous numpy arrays for rapid slicing
    X_mat = df_canonical_panel[forecaster_cols].to_numpy(dtype=np.float64)
    y_vec = df_canonical_panel[target_col].to_numpy(dtype=np.float64)

    # Initialize tracking variables for the global minimum
    best_rmse = float('inf')
    best_lam = float(lambda_grid[0])

    # Perform an exhaustive grid search over all candidate lambdas
    for lam in lambda_grid:
        # Pre-allocate the forecast array for the 66 search-sample periods
        forecasts = np.full(66, np.nan, dtype=np.float64)

        # Iterate over the search sample origins (t=5 to 70)
        for t in range(5, 71):
            i = t - 5
            end_idx = t - 1
            start_idx = max(0, t - 1 - W)

            # Slice the training window and current forecasts
            X_train = X_mat[start_idx:end_idx, :]
            y_train = y_vec[start_idx:end_idx]
            x_new = X_mat[end_idx, :]

            # Generate the forecast using the two-step peLASSO method
            forecasts[i] = pelasso_lasso_avg(X_train, y_train, x_new, float(lam))

        # Isolate the 65 scored periods (excluding the t=5 warm-up)
        scored_errors = y_vec[5:70] - forecasts[1:]

        # Compute the scalar RMSE for this lambda
        rmse = float(np.sqrt(np.mean(scored_errors**2)))

        # Update the global optimum if a lower RMSE is found
        if rmse < best_rmse:
            best_rmse = rmse
            best_lam = float(lam)

    # Return the ex-post optimal lambda
    return best_lam


def evaluate_benchmarks_on_holdout(
    holdout_evaluator: HoldoutEvaluator,
    df_canonical_panel: pd.DataFrame,
    study_configuration: Dict[str, Any],
    lambda_grid: np.ndarray
) -> Dict[str, Tuple[float, float]]:
    """
    Evaluates the complex benchmarks on the holdout sample, respecting their specific
    temporal constraints (e.g., fixed vs. re-optimized parameters).

    Args:
        holdout_evaluator (HoldoutEvaluator): The configured holdout evaluation harness.
        df_canonical_panel (pd.DataFrame): The full canonical panel.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        lambda_grid (np.ndarray): The 1D array of candidate lambda values.

    Returns:
        Dict[str, Tuple[float, float]]: Mapping of method name to (rmse_full, rmse_ex_covid).
    """
    # Initialize the results dictionary
    results = {}

    # -------------------------------------------------------------------------
    # 1. peLASSO ex post (original)
    # -------------------------------------------------------------------------
    # Requires the optimal lambda from the search sample, which is then frozen
    optimal_lam_search = _find_search_sample_optimal_lambda(df_canonical_panel, study_configuration, lambda_grid)

    def pelasso_original_callable(info: Dict[str, Any]) -> Dict[str, Any]:
        """Callable wrapper for peLASSO ex post (original)."""
        pred = pelasso_lasso_avg(info["X_train"], info["y_train"], info["x_new"], optimal_lam_search)
        return {"forecast": pred, "method": "peLASSO ex post (original)"}

    # Evaluate and store the results
    results["peLASSO ex post (original)"] = holdout_evaluator.evaluate_method(pelasso_original_callable)

    # -------------------------------------------------------------------------
    # 2. peLASSO ex post (per window)
    # -------------------------------------------------------------------------
    def pelasso_per_window_callable(info: Dict[str, Any]) -> Dict[str, Any]:
        """Callable wrapper for peLASSO ex post (per window), re-optimizing lambda via LOO-CV."""
        opt_lam = cv_loo_bandwidth(info["X_train"], info["y_train"], info["lambda_grid"], 'lasso')
        pred = pelasso_lasso_avg(info["X_train"], info["y_train"], info["x_new"], opt_lam)
        return {"forecast": pred, "method": "peLASSO ex post (per window)"}

    # Evaluate and store the results
    results["peLASSO ex post (per window)"] = holdout_evaluator.evaluate_method(pelasso_per_window_callable)

    # -------------------------------------------------------------------------
    # 3. Best avg flex (N_max=6)
    # -------------------------------------------------------------------------
    # Pre-compute the combinatorial mask matrix M for extreme efficiency
    K = int(study_configuration["prepare_script_data"]["K_forecasters"])
    combinations = []
    # Generate all subsets of size 1 to 6
    for n in range(1, 7):
        combinations.extend(list(itertools.combinations(range(K), n)))

    # Construct the dense mask matrix M of shape (K, num_combinations)
    M = np.zeros((K, len(combinations)), dtype=np.float64)
    for idx, combo in enumerate(combinations):
        weight = 1.0 / len(combo)
        for f_idx in combo:
            M[f_idx, idx] = weight

    def best_avg_flex_callable(info: Dict[str, Any]) -> Dict[str, Any]:
        """Callable wrapper for Best avg flex, utilizing vectorized matrix multiplication."""
        # Compute predictions for all subsets simultaneously: shape (W, num_combinations)
        subset_preds = info["X_train"] @ M
        # Compute squared errors against the training targets
        squared_errors = (subset_preds - info["y_train"][:, None]) ** 2
        # Compute MSE for each subset
        subset_mse = np.mean(squared_errors, axis=0)
        # Identify the index of the optimal subset
        best_idx = int(np.argmin(subset_mse))
        # Generate the forecast using the optimal subset
        pred = np.dot(info["x_new"], M[:, best_idx])
        return {"forecast": pred, "method": "Best avg flex"}

    # Evaluate and store the results
    results["Best avg flex"] = holdout_evaluator.evaluate_method(best_avg_flex_callable)

    # -------------------------------------------------------------------------
    # 4. Best (N,W) avg adaptive
    # -------------------------------------------------------------------------
    def best_nw_avg_callable(info: Dict[str, Any]) -> Dict[str, Any]:
        """Callable wrapper for Best (N,W) avg adaptive, searching over window and subset sizes."""
        X_hist = info["X_history"]
        y_hist = info["y_history"]
        avail_hist = X_hist.shape[0]
        # Bound the maximum window size to the available history or W=20
        max_w = min(20, avail_hist)

        best_rmse = float('inf')
        best_ranking = []

        # Iterate over all feasible window sizes
        for w in range(1, max_w + 1):
            # Slice the specific window
            X_w = X_hist[-w:, :]
            y_w = y_hist[-w:]

            # Compute individual RMSE and rank forecasters
            ind_rmse = np.sqrt(np.mean((X_w - y_w[:, None])**2, axis=0))
            ranking = np.argsort(ind_rmse)

            # Iterate over all possible subset sizes N
            for n in range(1, K + 1):
                top_n = ranking[:n]
                # Compute the combined forecast and its RMSE
                comb_preds = np.mean(X_w[:, top_n], axis=1)
                comb_rmse = np.sqrt(np.mean((comb_preds - y_w)**2))

                # Update the optimal (N,W) pair
                if comb_rmse < best_rmse:
                    best_rmse = comb_rmse
                    best_ranking = top_n

        # Generate the forecast using the optimal ranking
        pred = np.mean(info["x_new"][best_ranking])
        return {"forecast": pred, "method": "Best (N,W) avg"}

    # Evaluate and store the results
    results["Best (N,W) avg"] = holdout_evaluator.evaluate_method(best_nw_avg_callable)

    return results

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task27HoldoutEvaluationReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the out-of-sample holdout evaluation phase. This report encapsulates the
    comprehensive performance table for all methods on the strictly air-gapped
    holdout data, providing the definitive metrics required to verify generalization
    and robustness (Conclusions 2, 3, 4, and 5).

    Attributes:
        holdout_table (pd.DataFrame): The augmented pandas DataFrame containing
            absolute and relative RMSEs for both the full holdout and the
            holdout-excluding-COVID samples.
        validation_notes (List[str]): Diagnostic notes regarding deviations from
            published targets, particularly concerning data vintage sensitivity.
    """
    # The comprehensive evaluation table formatted for archival
    holdout_table: pd.DataFrame
    # A list of diagnostic strings detailing any deviations from the manuscript targets
    validation_notes: List[str]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the holdout evaluation report.

        Raises:
            TypeError: If the holdout_table is not a pandas DataFrame.
            ValueError: If the holdout_table does not contain exactly 14 rows.
        """
        # Verify that holdout_table is a pandas DataFrame
        if not isinstance(self.holdout_table, pd.DataFrame):
            raise TypeError("Task27HoldoutEvaluationReport: holdout_table must be a pandas.DataFrame.")

        # Enforce the methodological requirement of exactly 14 evaluated methods
        if len(self.holdout_table) != 14:
            raise ValueError(f"Task27HoldoutEvaluationReport: Expected 14 methods, found {len(self.holdout_table)}.")


def execute_task_27_compute_holdout_table(
    df_canonical_panel: pd.DataFrame,
    index_map: pd.DataFrame,
    lambda_grid: np.ndarray,
    lambda_grid2: np.ndarray,
    study_configuration: Dict[str, Any],
    run1_report: Any,
    run2_report: Any,
    run3_report: Any,
    data_provenance: str
) -> Task27HoldoutEvaluationReport:
    """
    Orchestrates Task 27: Freezes the discovered scripts, constructs the holdout
    evaluator, computes out-of-sample RMSEs for all methods, and compiles the
    comprehensive holdout evaluation table.

    Args:
        df_canonical_panel (pd.DataFrame): The full 106-row canonical panel.
        index_map (pd.DataFrame): The standing index map.
        lambda_grid (np.ndarray): The primary regularization grid.
        lambda_grid2 (np.ndarray): The secondary regularization grid.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        run1_report (Any): The registry report for Run 1.
        run2_report (Any): The registry report for Run 2.
        run3_report (Any): The registry report for Run 3.
        data_provenance (str): Identifier for the data source.

    Returns:
        Task27HoldoutEvaluationReport: The comprehensive holdout evaluation report.
    """
    # Step 1: Freeze the selected script for each run
    # This guarantees immutability during the out-of-sample evaluation
    frozen_registry = freeze_discovered_methods(run1_report, run2_report, run3_report)

    # Step 2: Construct the Holdout Evaluator
    # Instantiate the highly optimized, look-ahead-free holdout harness
    holdout_evaluator = HoldoutEvaluator(
        df_canonical_panel=df_canonical_panel,
        index_map=index_map,
        lambda_grid=lambda_grid,
        lambda_grid2=lambda_grid2,
        study_configuration=study_configuration
    )

    # Evaluate the Simple Average baseline to establish the denominators for relative RMSE
    sa_full, sa_ex_covid = holdout_evaluator.evaluate_method(simple_average_select_lambda)

    # Initialize the results dictionary with the baseline metrics
    results = {
        "Simple average": (sa_full, sa_ex_covid)
    }

    # Map the discovered methods to their formal names
    discovered_methods = {
        "Run 1 (final)": frozen_registry.run_1_final,
        "Run 1a (ENet, median)": run1_report.run_1a,
        "Run 1b (peLASSO, CV)": run1_report.run_1b,
        "Run 2 (final)": frozen_registry.run_2_final,
        "Run 2a (no bias corr.)": run2_report.run_2a,
        "Run 2b (weighted avg)": run2_report.run_2b,
        "Run 3 (final)": frozen_registry.run_3_final,
        "Run 3a (h=1, no blend)": run3_report.run_3a,
        "Run 3b (h=2, no blend)": run3_report.run_3b
    }

    # Evaluate all discovered methods on the holdout sample
    for name, callable_func in discovered_methods.items():
        results[name] = holdout_evaluator.evaluate_method(callable_func)

    # Step 3: Compute holdout RMSE for all benchmarks
    # Execute the complex combinatorial and ex-post benchmarks
    benchmark_results = evaluate_benchmarks_on_holdout(
        holdout_evaluator, df_canonical_panel, study_configuration, lambda_grid
    )
    # Merge the benchmark results into the main dictionary
    results.update(benchmark_results)

    # Construct the final pandas DataFrame
    # Define the panel categorization schema for structured reporting
    panel_mapping = {
        "Simple average": "Panel A: Benchmarks",
        "peLASSO ex post (original)": "Panel A: Benchmarks",
        "peLASSO ex post (per window)": "Panel A: Benchmarks",
        "Best avg flex": "Panel A: Benchmarks",
        "Best (N,W) avg": "Panel A: Benchmarks",
        "Run 1 (final)": "Panel B: Run 1 family",
        "Run 1a (ENet, median)": "Panel B: Run 1 family",
        "Run 1b (peLASSO, CV)": "Panel B: Run 1 family",
        "Run 2 (final)": "Panel C: Run 2 family",
        "Run 2a (no bias corr.)": "Panel C: Run 2 family",
        "Run 2b (weighted avg)": "Panel C: Run 2 family",
        "Run 3 (final)": "Panel D: Run 3 family",
        "Run 3a (h=1, no blend)": "Panel D: Run 3 family",
        "Run 3b (h=2, no blend)": "Panel D: Run 3 family"
    }

    # Initialize lists for DataFrame construction
    data = {
        "method_name": [],
        "panel": [],
        "holdout_rmse": [],
        "holdout_relative_rmse": [],
        "holdout_ex_covid_rmse": [],
        "holdout_ex_covid_relative_rmse": []
    }

    # Populate the data dictionary, computing relative RMSEs dynamically
    for method in panel_mapping.keys():
        rmse_full, rmse_ex_covid = results[method]
        data["method_name"].append(method)
        data["panel"].append(panel_mapping[method])
        data["holdout_rmse"].append(rmse_full)
        data["holdout_relative_rmse"].append(rmse_full / sa_full)
        data["holdout_ex_covid_rmse"].append(rmse_ex_covid)
        data["holdout_ex_covid_relative_rmse"].append(rmse_ex_covid / sa_ex_covid)

    # Instantiate the DataFrame
    df_holdout = pd.DataFrame(data)

    # Perform validation against the manuscript's published targets
    validation_notes = []
    # Determine the tolerance tier based on data provenance
    is_exact = "original" in data_provenance.lower() or "verbatim" in data_provenance.lower()
    tolerance = 0.010 if is_exact else 0.030

    # Extract the primary holdout targets from the configuration
    targets_full = study_configuration["researcher_only_holdout_inputs"]["holdout_primary_targets"]

    # Validate the final discovered methods
    for method, target_val in targets_full.items():
        # Map configuration keys to the formal table names
        name_map = {
            "run_1_final_relative_rmse": "Run 1 (final)",
            "run_2_final_relative_rmse": "Run 2 (final)",
            "run_3_final_relative_rmse": "Run 3 (final)"
        }
        actual_name = name_map[method]

        # Extract the computed relative RMSE
        computed_val = df_holdout.loc[df_holdout["method_name"] == actual_name, "holdout_relative_rmse"].values[0]

        # Check for deviations exceeding the tolerance threshold
        if abs(computed_val - target_val) > tolerance:
            validation_notes.append(
                f"Deviation in {actual_name}: Computed {computed_val:.3f}, Target {target_val:.3f}. "
                f"Likely due to data vintage sensitivity."
            )

    # Return the composite holdout evaluation report
    return Task27HoldoutEvaluationReport(
        holdout_table=df_holdout,
        validation_notes=validation_notes
    )

# %%
# Task 28: Compute Diebold–Mariano Summary Statistics

# ==============================================================================
# Task 28: Compute Diebold-Mariano Summary Statistics
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 28, Step 1: Set up the test configuration
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass(frozen=True)
class DMTestConfiguration:
    """
    A strictly immutable container that encapsulates the parameters and methodological
    specifications for the Diebold-Mariano predictive accuracy test.

    Attributes:
        test_name (str): The formal name of the statistical test.
        alternative_hypothesis (str): The specified alternative hypothesis.
        sidedness (str): The tail direction of the test (e.g., 'one-sided').
        small_sample_approximation (str): The target approximation method (e.g., 'EWC fixed-b').
        reference (str): The academic citation for the approximation method.
        descriptive_only (bool): Flag indicating if p-values should be interpreted descriptively.
        implemented_fallback (str): Documentation of the actual HAC method implemented
            due to the unavailability of the proprietary EWC fixed-b package.
    """
    test_name: str
    alternative_hypothesis: str
    sidedness: str
    small_sample_approximation: str
    reference: str
    descriptive_only: bool
    implemented_fallback: str


def extract_dm_configuration(study_configuration: Dict[str, Any]) -> DMTestConfiguration:
    """
    Extracts the Diebold-Mariano test parameters from the study configuration and
    documents the necessary architectural fallback for the variance estimator.

    Args:
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        DMTestConfiguration: The immutable configuration record.

    Raises:
        ValueError: If required testing parameters are missing from the configuration.
    """
    try:
        # Navigate to the predictive accuracy testing block
        test_config = study_configuration["econometric_setup"]["predictive_accuracy_testing"]

        test_name = str(test_config["test_name"])
        alternative = str(test_config["alternative"])
        sidedness = str(test_config["p_value_sidedness"])
        approximation = str(test_config["small_sample_approximation"])
        reference = str(test_config["reference"])
        descriptive_only = bool(test_config["descriptive_only"])

    except KeyError as e:
        # Halt execution if the statistical testing parameters are undefined
        raise ValueError(f"Missing required configuration key for DM test: {e}")

    # Document the methodological deviation: The EWC fixed-b approximation requires
    # the 'ForeComp' R package. We implement the standard Newey-West HAC estimator as a robust fallback.
    fallback_note = (
        "Standard Diebold-Mariano test with Newey-West HAC standard errors. "
        "The exact EWC fixed-b approximation (Shin and Schor, 2026) is unavailable "
        "in this environment."
    )

    return DMTestConfiguration(
        test_name=test_name,
        alternative_hypothesis=alternative,
        sidedness=sidedness,
        small_sample_approximation=approximation,
        reference=reference,
        descriptive_only=descriptive_only,
        implemented_fallback=fallback_note
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 28, Step 2: Compute the test for each method against simple average on the holdout
# -------------------------------------------------------------------------------------------------------------------------------

def compute_diebold_mariano_pvalue(
    errors_baseline: np.ndarray,
    errors_method: np.ndarray,
    max_lag: int = 3
) -> float:
    """
    Computes the one-sided Diebold-Mariano p-value comparing a candidate method against
    a baseline, utilizing a Newey-West Heteroskedasticity and Autocorrelation Consistent
    (HAC) variance estimator to account for serial correlation in forecast errors.

    Equation (Loss Differential): d_t = e_{baseline,t}^2 - e_{method,t}^2
    Equation (HAC Variance): \hat{V} = \hat{\gamma}_0 + 2 \sum_{j=1}^m (1 - \frac{j}{m+1}) \hat{\gamma}_j
    Equation (DM Statistic): DM = \bar{d} / \sqrt{\hat{V} / T}

    Args:
        errors_baseline (np.ndarray): 1D array of forecast errors from the simple average.
        errors_method (np.ndarray): 1D array of forecast errors from the evaluated method.
        max_lag (int): The truncation lag (m) for the Bartlett kernel in the HAC estimator.

    Returns:
        float: The one-sided p-value testing the alternative that the method is superior.

    Raises:
        ValueError: If the error arrays have mismatched dimensions or are empty.
    """
    # Validate input dimensions
    if errors_baseline.shape != errors_method.shape:
        raise ValueError("DM Test: Baseline and method error arrays must have identical shapes.")

    T = len(errors_baseline)
    if T == 0:
        raise ValueError("DM Test: Error arrays cannot be empty.")

    # 1. Compute the loss differential series
    # A positive d_t indicates the method had a smaller squared error than the baseline
    d_t = (errors_baseline ** 2) - (errors_method ** 2)

    # Compute the sample mean of the loss differential
    d_bar = float(np.mean(d_t))

    # Center the loss differential series for autocovariance computation
    d_centered = d_t - d_bar

    # 2. Compute the Newey-West HAC variance estimator
    # Compute the sample variance (lag 0 autocovariance)
    gamma_0 = np.sum(d_centered ** 2) / T

    hac_variance = gamma_0

    # Compute and accumulate the weighted higher-order autocovariances
    for j in range(1, max_lag + 1):
        if j >= T:
            break
        # Compute the j-th sample autocovariance
        # \hat{\gamma}_j = \frac{1}{T} \sum_{t=j+1}^T (d_t - \bar{d})(d_{t-j} - \bar{d})
        gamma_j = np.sum(d_centered[j:] * d_centered[:-j]) / T

        # Apply the Bartlett kernel weight: (1 - j / (m + 1))
        weight = 1.0 - (j / (max_lag + 1.0))

        # Accumulate symmetrically (hence the factor of 2)
        hac_variance += 2.0 * weight * gamma_j

    # 3. Compute the DM test statistic and p-value
    # Handle the edge case where the methods are identical or variance is numerically zero
    if hac_variance <= 1e-12:
        # If variance is zero, we cannot reject the null hypothesis of equal accuracy
        return 0.500

    # Compute the standard error of the mean loss differential
    se_d_bar = math.sqrt(hac_variance / T)

    # Compute the DM statistic
    dm_stat = d_bar / se_d_bar

    # Compute the one-sided p-value using the standard normal CDF
    # Alternative hypothesis: E[d_t] > 0 (method is better), so we want P(Z > dm_stat)
    p_value = 1.0 - norm.cdf(dm_stat)

    return float(p_value)


def _extract_raw_holdout_errors(
    holdout_evaluator: Any, # Expected: HoldoutEvaluator
    method_callable: Callable[[Dict[str, Any]], Dict[str, Any]]
) -> np.ndarray:
    """
    Executes a method callable through the HoldoutEvaluator to extract the raw,
    unaggregated forecast errors (e_t = y_t - \hat{y}_t) for all 36 holdout periods.

    Args:
        holdout_evaluator (HoldoutEvaluator): The configured holdout harness.
        method_callable (Callable): The forecasting method to evaluate.

    Returns:
        np.ndarray: A 1D array of shape (36,) containing the forecast errors.
    """
    forecasts = np.full(36, np.nan, dtype=np.float64)
    actuals = np.full(36, np.nan, dtype=np.float64)

    # Iterate over the strict holdout origins (t=71 to 106 inclusive)
    for t in range(71, 107):
        i = t - 71
        info = holdout_evaluator.build_info(t)
        result = method_callable(info)
        forecasts[i] = float(result["forecast"])
        actuals[i] = holdout_evaluator.target_vector[t - 1]

    # Return the raw forecast errors
    return actuals - forecasts


def compute_all_dm_statistics(
    holdout_evaluator: Any, # Expected: HoldoutEvaluator
    df_canonical_panel: pd.DataFrame,
    study_configuration: Dict[str, Any],
    lambda_grid: np.ndarray,
    frozen_registry: FrozenMethodRegistry,
    run1_report: Any,
    run2_report: Any,
    run3_report: Any
) -> Dict[str, Tuple[float, float]]:
    """
    Extracts raw forecast errors for all methods and computes the Diebold-Mariano
    p-values for both the full holdout and the holdout-excluding-COVID samples.

    Args:
        holdout_evaluator (HoldoutEvaluator): The configured holdout harness.
        df_canonical_panel (pd.DataFrame): The full canonical panel.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        lambda_grid (np.ndarray): The primary regularization grid.
        frozen_registry (FrozenMethodRegistry): The frozen final methods.
        run1_report (Any): The registry report for Run 1.
        run2_report (Any): The registry report for Run 2.
        run3_report (Any): The registry report for Run 3.

    Returns:
        Dict[str, Tuple[float, float]]: Mapping of method name to (p_val_full, p_val_ex_covid).
    """
    # 1. Extract baseline errors
    errors_sa = _extract_raw_holdout_errors(holdout_evaluator, simple_average_select_lambda)

    # Extract the COVID mask to isolate the 32-period excl-COVID arrays
    non_covid_mask = ~holdout_evaluator.covid_flags
    errors_sa_ex_covid = errors_sa[non_covid_mask]

    # 2. Reconstruct the exact benchmark callables used in Task 27
    optimal_lam_search = _find_search_sample_optimal_lambda(df_canonical_panel, study_configuration, lambda_grid)

    def pelasso_original_callable(info: Dict[str, Any]) -> Dict[str, Any]:
        pred = pelasso_lasso_avg(info["X_train"], info["y_train"], info["x_new"], optimal_lam_search)
        return {"forecast": pred, "method": "peLASSO ex post (original)"}

    def pelasso_per_window_callable(info: Dict[str, Any]) -> Dict[str, Any]:
        opt_lam = cv_loo_bandwidth(info["X_train"], info["y_train"], info["lambda_grid"], 'lasso')
        pred = pelasso_lasso_avg(info["X_train"], info["y_train"], info["x_new"], opt_lam)
        return {"forecast": pred, "method": "peLASSO ex post (per window)"}

    K = int(study_configuration["prepare_script_data"]["K_forecasters"])
    combinations = []
    for n in range(1, 7):
        combinations.extend(list(itertools.combinations(range(K), n)))
    M = np.zeros((K, len(combinations)), dtype=np.float64)
    for idx, combo in enumerate(combinations):
        weight = 1.0 / len(combo)
        for f_idx in combo:
            M[f_idx, idx] = weight

    def best_avg_flex_callable(info: Dict[str, Any]) -> Dict[str, Any]:
        subset_preds = info["X_train"] @ M
        subset_mse = np.mean((subset_preds - info["y_train"][:, None]) ** 2, axis=0)
        pred = np.dot(info["x_new"], M[:, int(np.argmin(subset_mse))])
        return {"forecast": pred, "method": "Best avg flex"}

    def best_nw_avg_callable(info: Dict[str, Any]) -> Dict[str, Any]:
        X_hist, y_hist = info["X_history"], info["y_history"]
        max_w = min(20, X_hist.shape[0])
        best_rmse, best_ranking = float('inf'), []
        for w in range(1, max_w + 1):
            X_w, y_w = X_hist[-w:, :], y_hist[-w:]
            ranking = np.argsort(np.sqrt(np.mean((X_w - y_w[:, None])**2, axis=0)))
            for n in range(1, K + 1):
                top_n = ranking[:n]
                comb_rmse = np.sqrt(np.mean((np.mean(X_w[:, top_n], axis=1) - y_w)**2))
                if comb_rmse < best_rmse:
                    best_rmse, best_ranking = comb_rmse, top_n
        pred = np.mean(info["x_new"][best_ranking])
        return {"forecast": pred, "method": "Best (N,W) avg"}

    # 3. Map all methods to be evaluated
    all_methods = {
        "peLASSO ex post (original)": pelasso_original_callable,
        "peLASSO ex post (per window)": pelasso_per_window_callable,
        "Best avg flex": best_avg_flex_callable,
        "Best (N,W) avg": best_nw_avg_callable,
        "Run 1 (final)": frozen_registry.run_1_final,
        "Run 1a (ENet, median)": run1_report.run_1a,
        "Run 1b (peLASSO, CV)": run1_report.run_1b,
        "Run 2 (final)": frozen_registry.run_2_final,
        "Run 2a (no bias corr.)": run2_report.run_2a,
        "Run 2b (weighted avg)": run2_report.run_2b,
        "Run 3 (final)": frozen_registry.run_3_final,
        "Run 3a (h=1, no blend)": run3_report.run_3a,
        "Run 3b (h=2, no blend)": run3_report.run_3b
    }

    results = {}

    # 4. Compute DM statistics for each method
    for name, callable_func in all_methods.items():
        # Extract raw errors for the method
        errors_m = _extract_raw_holdout_errors(holdout_evaluator, callable_func)
        errors_m_ex_covid = errors_m[non_covid_mask]

        # Compute full holdout p-value (T=36, max_lag=3)
        p_full = compute_diebold_mariano_pvalue(errors_sa, errors_m, max_lag=3)

        # Compute excl-COVID holdout p-value (T=32, max_lag=3)
        p_ex_covid = compute_diebold_mariano_pvalue(errors_sa_ex_covid, errors_m_ex_covid, max_lag=3)

        results[name] = (p_full, p_ex_covid)

    return results

# -------------------------------------------------------------------------------------------------------------------------------
# Task 28, Step 3: Interpret descriptively
# -------------------------------------------------------------------------------------------------------------------------------

def format_descriptive_p_values(
    df_holdout: pd.DataFrame,
    dm_pvalues: Dict[str, Tuple[float, float]]
) -> pd.DataFrame:
    """
    Augments the holdout evaluation DataFrame by formatting the computed p-values
    into the manuscript's specific bracket notation (e.g., '2.417 [.127]') to
    serve as descriptive summaries of predictive accuracy.

    Args:
        df_holdout (pd.DataFrame): The evaluation table from Task 27.
        dm_pvalues (Dict[str, Tuple[float, float]]): The computed p-values.

    Returns:
        pd.DataFrame: The augmented DataFrame with formatted string columns.
    """
    # Create a deep copy to preserve the original numerical data
    df_formatted = df_holdout.copy(deep=True)

    formatted_full = []
    formatted_ex_covid = []

    for _, row in df_formatted.iterrows():
        method = row["method_name"]
        rmse_full = row["holdout_rmse"]
        rmse_ex_covid = row["holdout_ex_covid_rmse"]

        if method == "Simple average":
            # The baseline does not have a p-value against itself.
            # Format the RMSE to 3 decimal places without brackets.
            formatted_full.append(f"{rmse_full:.3f}")
            formatted_ex_covid.append(f"{rmse_ex_covid:.3f}")
        else:
            p_full, p_ex_covid = dm_pvalues[method]

            # Format the p-value to 3 decimal places and strip the leading zero
            # e.g., 0.127 -> .127
            p_str_full = f"{p_full:.3f}".replace("0.", ".", 1)
            p_str_ex_covid = f"{p_ex_covid:.3f}".replace("0.", ".", 1)

            # Concatenate the RMSE and the bracketed p-value
            formatted_full.append(f"{rmse_full:.3f} [{p_str_full}]")
            formatted_ex_covid.append(f"{rmse_ex_covid:.3f} [{p_str_ex_covid}]")

    # Append the formatted string columns to the DataFrame
    df_formatted["holdout_rmse_formatted"] = formatted_full
    df_formatted["holdout_ex_covid_rmse_formatted"] = formatted_ex_covid

    return df_formatted

# -------------------------------------------------------------------------------------------------------------------------------
# Task 28, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task28DMSummaryReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the Diebold-Mariano statistical testing phase. This report encapsulates the
    augmented holdout table with descriptive p-values and explicitly documents the
    methodological caveats regarding small sample sizes and variance approximations.

    Attributes:
        augmented_holdout_table (pd.DataFrame): The final evaluation table containing
            the bracket-formatted descriptive p-values.
        test_configuration (DMTestConfiguration): The immutable record of the test parameters.
        methodological_caveats (List[str]): A list of explicit warnings regarding the
            statistical power and approximation methods used in the replication.
    """
    augmented_holdout_table: pd.DataFrame
    test_configuration: DMTestConfiguration
    methodological_caveats: List[str]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the statistical summary report.
        """
        if not isinstance(self.augmented_holdout_table, pd.DataFrame):
            raise TypeError("Task28DMSummaryReport: augmented_holdout_table must be a pandas.DataFrame.")
        if "holdout_rmse_formatted" not in self.augmented_holdout_table.columns:
            raise ValueError("Task28DMSummaryReport: Missing formatted string columns.")


def execute_task_28_compute_dm_statistics(
    holdout_evaluator: Any, # Expected: HoldoutEvaluator
    df_canonical_panel: pd.DataFrame,
    study_configuration: Dict[str, Any],
    lambda_grid: np.ndarray,
    frozen_registry: FrozenMethodRegistry,
    run1_report: Any,
    run2_report: Any,
    run3_report: Any,
    df_holdout_table: pd.DataFrame
) -> Task28DMSummaryReport:
    """
    Orchestrates Task 28: Extracts the test configuration, computes the Newey-West
    HAC Diebold-Mariano p-values for all methods, formats them descriptively, and
    compiles the final augmented holdout report with explicit methodological caveats.

    Args:
        holdout_evaluator (HoldoutEvaluator): The configured holdout harness.
        df_canonical_panel (pd.DataFrame): The full canonical panel.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        lambda_grid (np.ndarray): The primary regularization grid.
        frozen_registry (FrozenMethodRegistry): The frozen final methods.
        run1_report (Any): The registry report for Run 1.
        run2_report (Any): The registry report for Run 2.
        run3_report (Any): The registry report for Run 3.
        df_holdout_table (pd.DataFrame): The evaluation table from Task 27.

    Returns:
        Task28DMSummaryReport: The comprehensive statistical summary report.
    """
    # Step 1: Set up the test configuration
    dm_config = extract_dm_configuration(study_configuration)

    # Step 2: Compute the test for each method against simple average on the holdout
    dm_pvalues = compute_all_dm_statistics(
        holdout_evaluator=holdout_evaluator,
        df_canonical_panel=df_canonical_panel,
        study_configuration=study_configuration,
        lambda_grid=lambda_grid,
        frozen_registry=frozen_registry,
        run1_report=run1_report,
        run2_report=run2_report,
        run3_report=run3_report
    )

    # Step 3: Interpret descriptively
    df_augmented = format_descriptive_p_values(
        df_holdout=df_holdout_table,
        dm_pvalues=dm_pvalues
    )

    # Compile the explicit methodological caveats required by the manuscript
    caveats = [
        dm_config.implemented_fallback,
        "The holdout sample (36 quarters, 32 excluding COVID) provides intrinsically low power.",
        "P-values should be read as descriptive summaries, not formal hypothesis tests, due to serial correlation and post-search selection."
    ]

    return Task28DMSummaryReport(
        augmented_holdout_table=df_augmented,
        test_configuration=dm_config,
        methodological_caveats=caveats
    )

# %%
# Task 29: Validate Experiment Counts and Search Dynamics

# ==============================================================================
# Task 29: Validate Experiment Counts and Search Dynamics
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 29, Step 1: Summarize the search log for each run
# -------------------------------------------------------------------------------------------------------------------------------

def summarize_single_run_log(
    working_directory: Path,
    run_id: int,
    results_tsv_filename: str
) -> Dict[str, Any]:
    """
    Parses the TSV audit log for a single discovery run, computing the exact frequencies
    of experimental outcomes and identifying the mathematically optimal specification.

    Args:
        working_directory (Path): The absolute path to the repository root.
        run_id (int): The integer identifier for the run.
        results_tsv_filename (str): The name of the TSV file (e.g., 'results_run_1.tsv').

    Returns:
        Dict[str, Any]: A structured dictionary containing the aggregated statistics.

    Raises:
        FileNotFoundError: If the specified TSV log does not exist.
    """
    full_tsv_path = working_directory / results_tsv_filename

    if not full_tsv_path.exists():
        raise FileNotFoundError(f"Audit log not found at {full_tsv_path}.")

    # Read the TSV log using pandas.
    # quoting=csv.QUOTE_NONE ensures that stray quotes in LLM descriptions do not break parsing.
    df_log = pd.read_csv(full_tsv_path, sep='\t', dtype={'commit': str, 'status': str}, quoting=csv.QUOTE_NONE)

    # The total number of experiments is exactly the number of data rows
    total_experiments = len(df_log)

    # Count the occurrences of each formal status
    status_counts = df_log['status'].value_counts().to_dict()
    keeps = status_counts.get('keep', 0)
    discards = status_counts.get('discard', 0)
    crashes = status_counts.get('crash', 0)

    # Identify the best RMSE and its corresponding description
    # We strictly filter for 'keep' status to mathematically exclude crash placeholders (0.0000)
    keeps_df = df_log[df_log['status'] == 'keep']

    if keeps_df.empty:
        best_rmse = float('inf')
        best_description = "No successful improvements found."
    else:
        # Locate the row index with the absolute minimum RMSE
        best_idx = keeps_df['rmse'].idxmin()
        best_rmse = float(keeps_df.loc[best_idx, 'rmse'])
        best_description = str(keeps_df.loc[best_idx, 'description'])

    return {
        "run_id": run_id,
        "total_experiments": total_experiments,
        "keeps": keeps,
        "discards": discards,
        "crashes": crashes,
        "best_rmse": best_rmse,
        "best_description": best_description,
        "_raw_df": df_log  # Retained for Step 3 drift analysis
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 29, Step 2: Compare to published counts
# -------------------------------------------------------------------------------------------------------------------------------

def compare_counts_to_published_targets(
    run_summaries: List[Dict[str, Any]],
    study_configuration: Dict[str, Any]
) -> pd.DataFrame:
    """
    Constructs a comparative analysis table evaluating the replicated experiment counts
    against the manuscript's published targets, applying a qualitative heuristic to
    assess stochastic similarity.

    Args:
        run_summaries (List[Dict[str, Any]]): The list of summary dictionaries from Step 1.
        study_configuration (Dict[str, Any]): The study configuration dictionary.

    Returns:
        pd.DataFrame: The formatted comparative analysis table.
    """
    # Extract the published targets from the configuration
    try:
        published_counts = study_configuration["search_protocol"]["run_design"]["reported_realized_experiments"]
        published_keeps = study_configuration["search_protocol"]["run_design"]["reported_keep_counts"]
        published_discards = study_configuration["search_protocol"]["run_design"]["reported_discard_counts"]
        published_crashes = study_configuration["search_protocol"]["run_design"]["reported_crash_counts"]
    except KeyError as e:
        raise ValueError(f"Missing required configuration key for published counts: {e}")

    data = {
        "run_id": [],
        "published_total": [],
        "replicated_total": [],
        "published_keeps": [],
        "replicated_keeps": [],
        "published_discards": [],
        "replicated_discards": [],
        "published_crashes": [],
        "replicated_crashes": [],
        "qualitative_assessment": []
    }

    for summary in run_summaries:
        r_id = summary["run_id"]
        run_key = f"run_{r_id}"

        # Retrieve published values
        pub_total = published_counts.get(run_key, 0)
        pub_keeps = published_keeps.get(run_key, 0)
        pub_discards = published_discards.get(run_key, 0)
        pub_crashes = published_crashes.get(run_key, 0)

        # Retrieve replicated values
        rep_total = summary["total_experiments"]
        rep_keeps = summary["keeps"]
        rep_discards = summary["discards"]
        rep_crashes = summary["crashes"]

        # Qualitative Assessment Heuristic
        # Agentic search is stochastic; exact reproduction is impossible.
        # We define "similar" as: total within +/- 20% of 200, and keep rate between 10% and 40%.
        is_total_similar = (160 <= rep_total <= 240)
        keep_rate = rep_keeps / rep_total if rep_total > 0 else 0.0
        is_rate_similar = (0.10 <= keep_rate <= 0.40)

        if is_total_similar and is_rate_similar:
            assessment = "similar"
        else:
            assessment = "divergent"

        # Populate the data dictionary
        data["run_id"].append(f"Run {r_id}")
        data["published_total"].append(pub_total)
        data["replicated_total"].append(rep_total)
        data["published_keeps"].append(pub_keeps)
        data["replicated_keeps"].append(rep_keeps)
        data["published_discards"].append(pub_discards)
        data["replicated_discards"].append(rep_discards)
        data["published_crashes"].append(pub_crashes)
        data["replicated_crashes"].append(rep_crashes)
        data["qualitative_assessment"].append(assessment)

    return pd.DataFrame(data)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 29, Step 3: Document methodology drift from the log descriptions
# -------------------------------------------------------------------------------------------------------------------------------

def analyze_methodology_drift(run_id: int, df_log: pd.DataFrame) -> Dict[str, Any]:
    """
    Performs a heuristic Natural Language Processing (NLP) scan over the chronological
    sequence of agent descriptions to identify methodological phase transitions and
    classify the overall trajectory drift.

    Args:
        run_id (int): The integer identifier for the run.
        df_log (pd.DataFrame): The raw TSV audit log DataFrame.

    Returns:
        Dict[str, Any]: A structured narrative summary of the methodology drift.
    """
    # Define regex patterns for core econometric concepts
    patterns = {
        "peLASSO/CV": r"(?i)(pelasso|lasso|cv|cross[- ]validation)",
        "Stability": r"(?i)(stability|frequency|neighborhood)",
        "Performance Weighting": r"(?i)(performance|weight|rmse\^|quantile)",
        "Ranking": r"(?i)(rank|mae|temporal)",
        "Bias Correction": r"(?i)(bias|correction|serial|correlation)",
        "Adaptive LASSO": r"(?i)(adaptive|penalty factor|pilot)",
        "Ensemble/Blend": r"(?i)(ensemble|blend|egalitarian|elastic net)"
    }

    phases = []
    current_phase = "Initialization"
    start_k = 1

    # Iterate chronologically over the log entries
    for k, row in df_log.iterrows():
        # k is the 0-based index, representing experiment k+1
        desc = str(row['description'])

        # Determine the dominant keyword in the current description
        detected_phase = None
        for phase_name, pattern in patterns.items():
            if re.search(pattern, desc):
                detected_phase = phase_name
                break

        if detected_phase is None:
            detected_phase = "Unrecognized/Minor Edit"

        # If the phase changes, record the completed block
        if detected_phase != current_phase:
            if k > 0:
                phases.append((current_phase, start_k, k))
            current_phase = detected_phase
            start_k = k + 1

    # Append the final block
    phases.append((current_phase, start_k, len(df_log)))

    # Classify the overall drift based on the presence of advanced concepts
    all_detected_phases = set([p[0] for p in phases])

    if "Bias Correction" in all_detected_phases or "Ranking" in all_detected_phases:
        classification = "Substantial drift (Structural discovery)"
        departures = ["Agent abandoned nominal tuning for structural bias correction."]
    elif "Ensemble/Blend" in all_detected_phases or "Stability" in all_detected_phases:
        classification = "Moderate drift (Methodological expansion)"
        departures = ["Agent expanded search space to complex ensembles/stability metrics."]
    elif "peLASSO/CV" in all_detected_phases:
        classification = "Within scope (Nominal tuning)"
        departures = ["Agent remained within the intended hyperparameter tuning space."]
    else:
        classification = "Unrecognized trajectory"
        departures = ["Agent descriptions did not match expected econometric keywords."]

    return {
        "run_id": run_id,
        "phases": phases,
        "overall_drift_classification": classification,
        "key_methodological_departures": departures
    }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 29, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task29SearchDynamicsReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the search dynamics audit. This report encapsulates the quantitative comparison
    of experiment counts against published targets and the qualitative NLP analysis
    of methodology drift, providing the necessary evidence to validate the paper's
    claims regarding agentic behavior.

    Attributes:
        summary_table (pd.DataFrame): A tabular aggregation of total experiments,
            keeps, discards, and crashes for each run.
        comparison_table (pd.DataFrame): A comparative analysis evaluating the
            replicated counts against the manuscript's published targets.
        drift_narratives (Dict[int, Dict[str, Any]]): A mapping of run IDs to their
            structured methodology drift summaries.
    """
    summary_table: pd.DataFrame
    comparison_table: pd.DataFrame
    drift_narratives: Dict[int, Dict[str, Any]]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the search dynamics report.
        """
        if not isinstance(self.summary_table, pd.DataFrame):
            raise TypeError("Task29SearchDynamicsReport: summary_table must be a pandas.DataFrame.")
        if not isinstance(self.comparison_table, pd.DataFrame):
            raise TypeError("Task29SearchDynamicsReport: comparison_table must be a pandas.DataFrame.")
        if not isinstance(self.drift_narratives, dict):
            raise TypeError("Task29SearchDynamicsReport: drift_narratives must be a dictionary.")


def execute_task_29_validate_search_dynamics(
    working_directory: Path,
    study_configuration: Dict[str, Any],
    run_log_filenames: Dict[int, str]
) -> Task29SearchDynamicsReport:
    """
    Orchestrates Task 29: Parses the TSV audit logs for all runs, computes the
    experimental statistics, compares them to published targets, and performs
    the heuristic NLP analysis of methodology drift.

    Args:
        working_directory (Path): The absolute path to the repository root.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        run_log_filenames (Dict[int, str]): Mapping of run IDs to their TSV filenames.

    Returns:
        Task29SearchDynamicsReport: The comprehensive search dynamics report.
    """
    run_summaries = []
    drift_narratives = {}

    # Step 1 & 3: Summarize logs and analyze drift for each run
    for run_id, filename in run_log_filenames.items():
        try:
            # Parse the quantitative statistics
            summary = summarize_single_run_log(working_directory, run_id, filename)

            # Perform the qualitative NLP drift analysis
            drift = analyze_methodology_drift(run_id, summary["_raw_df"])

            # Remove the raw DataFrame from the summary to keep the final table clean
            del summary["_raw_df"]

            run_summaries.append(summary)
            drift_narratives[run_id] = drift

        except FileNotFoundError as e:
            # Handle missing logs gracefully to prevent pipeline collapse
            print(f"Warning: Could not process Run {run_id}. {e}")

    # Construct the basic summary table
    df_summary = pd.DataFrame(run_summaries)

    # Step 2: Compare to published counts
    df_comparison = compare_counts_to_published_targets(run_summaries, study_configuration)

    return Task29SearchDynamicsReport(
        summary_table=df_summary,
        comparison_table=df_comparison,
        drift_narratives=drift_narratives
    )

# %%
# Task 30: Create the End-to-End Orchestrator Callable

# Import required modules for the orchestrator
import traceback
from typing import Any, Dict, List, Optional, Tuple, Callable
from dataclasses import dataclass, field
import pandas as pd
import numpy as np
from pathlib import Path

# ==============================================================================
# Task 30: Create the End-to-End Orchestrator Callable
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 30, Steps 1 & 3: Define the orchestrator's inputs, purpose, and output contract
# -------------------------------------------------------------------------------------------------------------------------------

# Define the comprehensive dataclass that will serve as the orchestrator's output contract
@dataclass
class Task30EndToEndReport:
    """
    A structured, implementation-grade container that aggregates all artifacts produced
    by the end-to-end empirical pipeline. This report serves as the definitive record
    of the research execution, encapsulating data, models, evaluations, and diagnostics.

    Note: Fields related to Tasks 31 and 32 are intentionally omitted as per instructions.

    Attributes:
        validated_aligned_panel (Optional[pd.DataFrame]): The canonical 106-row panel.
        imputation_report (Optional[Any]): Audit of missing value resolutions.
        sample_partition_metadata (Optional[Any]): Details of the D=(D^S, D^H) split.
        baseline_validation_report (Optional[Any]): Verification of tau_0 RMSE.
        search_logs (Optional[Dict[int, pd.DataFrame]]): TSV audit logs for discovery runs.
        benchmark_table (Optional[pd.DataFrame]): RMSEs for ex-post and exhaustive methods.
        search_sample_rmse_table (Optional[pd.DataFrame]): In-sample performance for all methods.
        holdout_rmse_table (Optional[pd.DataFrame]): Out-of-sample performance.
        holdout_ex_covid_rmse_table (Optional[pd.DataFrame]): Out-of-sample performance (excl. COVID).
        dm_summary_table (Optional[pd.DataFrame]): Diebold-Mariano predictive accuracy statistics.
        experiment_count_table (Optional[pd.DataFrame]): Quantitative search dynamics.
        methodology_drift_summary (Optional[Dict[int, Any]]): Qualitative NLP drift analysis.
        quarantine_list (Optional[List[Tuple[str, Any, str]]]): Unspecified configuration fields.
        halt_diagnostics (Optional[Dict[str, Any]]): Error context if the pipeline failed fast.
    """
    # The canonical panel after validation, cleansing, alignment, imputation, and partitioning
    validated_aligned_panel: Optional[pd.DataFrame] = None
    # The audit report detailing the exact cells modified during linear and cross-sectional imputation
    imputation_report: Optional[Any] = None
    # The mathematical verification of the non-overlapping and exhaustive data partition
    sample_partition_metadata: Optional[Any] = None
    # The validation record confirming the simple average baseline matches the 1.504 target
    baseline_validation_report: Optional[Any] = None
    # A dictionary mapping run IDs to their respective parsed TSV audit logs
    search_logs: Optional[Dict[int, pd.DataFrame]] = None
    # The registry containing absolute and relative RMSEs for the complex benchmark methods
    benchmark_table: Optional[pd.DataFrame] = None
    # The comprehensive evaluation table for all methods on the 65-period search sample
    search_sample_rmse_table: Optional[pd.DataFrame] = None
    # The comprehensive evaluation table for all methods on the 36-period holdout sample
    holdout_rmse_table: Optional[pd.DataFrame] = None
    # The comprehensive evaluation table for all methods on the 32-period holdout sample excluding COVID
    holdout_ex_covid_rmse_table: Optional[pd.DataFrame] = None
    # The statistical summary table containing Diebold-Mariano p-values and methodological caveats
    dm_summary_table: Optional[pd.DataFrame] = None
    # The quantitative comparison of replicated experiment counts against published targets
    experiment_count_table: Optional[pd.DataFrame] = None
    # The qualitative NLP analysis detailing the methodological drift of the agent across runs
    methodology_drift_summary: Optional[Dict[int, Any]] = None
    # The list of configuration fields that were unspecified in the manuscript and quarantined
    quarantine_list: Optional[List[Tuple[str, Any, str]]] = None
    # The diagnostic dictionary populated with traceback information if the pipeline halts prematurely
    halt_diagnostics: Optional[Dict[str, Any]] = None

# -------------------------------------------------------------------------------------------------------------------------------
# Task 30, Step 2: Define the orchestrator's internal composition of prior callables
# -------------------------------------------------------------------------------------------------------------------------------

# Define the master orchestrator function that executes the Directed Acyclic Graph (DAG) of tasks
def execute_task_30_end_to_end_orchestrator(
    df_spf_panel_wide: pd.DataFrame,
    df_gdp_target_series: pd.DataFrame,
    study_configuration: Dict[str, Any],
    mode: str,
    data_provenance: str = "original_H1_gdp",
    declared_panel_scope: str = "full_panel"
) -> Task30EndToEndReport:
    """
    The master control flow graph (DAG) for the Auditable AI Agent Loop pipeline.
    Executes the deterministic research kernel and conditionally invokes the agentic
    discovery loop or holdout evaluation based on the specified mode.

    Args:
        df_spf_panel_wide (pd.DataFrame): The raw, unvalidated SPF forecaster panel.
        df_gdp_target_series (pd.DataFrame): The raw, unvalidated GDP target series.
        study_configuration (Dict[str, Any]): The comprehensive study configuration.
        mode (str): Execution mode ('discovery', 'benchmark_only', 'holdout_evaluation', 'robustness').
        data_provenance (str): Identifier for the data source (affects validation tolerances).
        declared_panel_scope (str): The expected temporal scope of the input data.

    Returns:
        Task30EndToEndReport: The comprehensive, end-to-end execution report.
    """
    # Define the set of mathematically and logically valid execution modes
    valid_modes = {"discovery", "benchmark_only", "holdout_evaluation", "robustness"}

    # Validate the requested mode to prevent routing errors
    if mode not in valid_modes:
        # Raise a ValueError if the mode is unrecognized
        raise ValueError(f"Invalid execution mode '{mode}'. Must be one of {valid_modes}.")

    # Instantiate the output contract dataclass with all fields defaulting to None
    report = Task30EndToEndReport()

    # Wrap the entire DAG execution in a broad try-except block to implement the fail-fast requirement
    try:
        # ==========================================================================
        # PHASE 1: DETERMINISTIC RESEARCH KERNEL (ALWAYS EXECUTED)
        # ==========================================================================

        # Execute Task 4: Validate configuration integrity to ensure the parameters are mathematically sound
        config_report = execute_task_4_validate_configuration_integrity(study_configuration)
        # Populate the quarantine list in the final report
        report.quarantine_list = config_report.quarantine_result.quarantine_list

        # Execute Task 1: Validate SPF panel schema and type to ensure column existence and dtypes
        spf_val_report = execute_task_1_validate_schema_and_type(df_spf_panel_wide, study_configuration)

        # Execute Task 2: Validate SPF panel structural integrity to ensure uniqueness and chronological ordering
        spf_struct_report = execute_task_2_validate_structural_integrity(
            df_spf_panel_wide, study_configuration, declared_panel_scope
        )

        # Execute Task 3: Validate GDP target series to ensure schema, dtypes, and zero-missingness
        gdp_val_report = execute_task_3_validate_gdp_target_series(
            df_gdp_target_series, study_configuration, declared_panel_scope, data_provenance
        )

        # Execute Task 5: Cleanse and standardize dates to canonical YYYYQq format and remove artifacts
        clean_report = execute_task_5_cleanse_and_standardize_dates(
            df_spf_panel_wide, df_gdp_target_series, study_configuration
        )

        # Execute Task 6: Align panel and target via an audited inner join on the date field
        align_report = execute_task_6_align_panel_and_target(
            clean_report.cleansed_spf_panel, clean_report.cleansed_gdp_target,
            study_configuration, declared_panel_scope
        )

        # Execute Task 7: Impute missing values using linear interpolation and cross-sectional means
        impute_report = execute_task_7_impute_missing_values(
            align_report.df_canonical_panel, study_configuration
        )
        # Populate the imputation audit report in the final report
        report.imputation_report = impute_report.audit_report

        # Execute Task 8: Mark sample membership to append boolean indicators for search, holdout, and COVID
        membership_report = execute_task_8_mark_sample_membership(
            impute_report.df_imputed_panel, align_report.index_map,
            study_configuration, declared_panel_scope
        )
        # Populate the validated aligned panel in the final report
        report.validated_aligned_panel = membership_report.df_marked_panel
        # Populate the partition metadata in the final report
        report.sample_partition_metadata = membership_report.partition_validation

        # Execute Task 9: Separate holdout from discovery workspace to physically air-gap the out-of-sample data
        separation_report = execute_task_9_separate_holdout(
            membership_report.df_marked_panel, study_configuration, declared_panel_scope
        )

        # Execute Task 10: Construct lambda grids using the exact exponential decay formula
        grid_report = execute_task_10_construct_lambda_grids(study_configuration)

        # Execute Task 11: Build info object constructor to instantiate the look-ahead-free evaluator factory
        evaluator_report = execute_task_11_build_info_constructor(
            separation_report.df_search_panel, membership_report.index_map_marked,
            grid_report.lambda_grid, grid_report.lambda_grid2, study_configuration
        )

        # Execute Task 13: Implement and validate baseline (Simple Average) against the 1.504 target
        # We inject the execute_task_12_evaluate_method_score callable as a dependency
        baseline_report = execute_task_13_implement_and_validate_baseline(
            info_builder=evaluator_report.info_builder,
            target_vector=evaluator_report.info_builder.target_vector,
            df_search_panel=separation_report.df_search_panel,
            study_configuration=study_configuration,
            data_provenance=data_provenance,
            total_imputed_cells=impute_report.audit_report.total_cells_imputed,
            execute_task_12_callable=execute_task_12_evaluate_method_score
        )
        # Populate the baseline validation report in the final report
        report.baseline_validation_report = baseline_report.validation_report

        # Execute Task 14: Define editable interface to establish the strict return contract boundary
        interface_report = execute_task_14_define_editable_interface(study_configuration)

        # ==========================================================================
        # PHASE 2: BENCHMARK EVALUATION (ALWAYS EXECUTED EXCEPT PURE DIAGNOSTICS)
        # ==========================================================================

        # Execute Task 20: Reproduce benchmark helpers to port the required R functions to Python
        helpers_report = execute_task_20_reproduce_benchmark_helpers(study_configuration)

        # Execute Task 21: Reproduce benchmarks and validate against published targets
        benchmark_report = execute_task_21_reproduce_benchmarks(
            info_builder=evaluator_report.info_builder,
            target_vector=evaluator_report.info_builder.target_vector,
            lambda_grid=grid_report.lambda_grid,
            study_configuration=study_configuration,
            data_provenance=data_provenance,
            execute_task_12_callable=execute_task_12_evaluate_method_score
        )
        # Populate the benchmark registry table in the final report
        report.benchmark_table = benchmark_report.benchmark_registry

        # ==========================================================================
        # PHASE 3: MODE-SPECIFIC EXECUTION
        # ==========================================================================

        # Branch execution path if the mode is set to 'discovery'
        if mode == "discovery":
            # Execute Task 15: Materialize instruction contract to write program.md to disk
            prompt_report = execute_task_15_materialize_instruction_contract(study_configuration)

            # Execute Task 16: Fix LLM settings to extract disclosed parameters and document choices
            settings_report = execute_task_16_fix_llm_settings(study_configuration)

            # Resolve the working directory path for the agentic loop operations
            work_dir = Path(study_configuration["artifact_paths"]["working_directory"])

            # Execute Task 22: Execute discovery runs (which internally orchestrates Tasks 17, 18, and 19)
            discovery_report = execute_task_22_execute_discovery_runs(
                working_directory=work_dir,
                study_configuration=study_configuration,
                prompt_templates=prompt_report.prompt_templates,
                baseline_rmse=baseline_report.validated_baseline_rmse
            )

            # Extract the raw TSV logs from the discovery report and populate the final report
            report.search_logs = {
                run_id: res.statistics for run_id, res in discovery_report.individual_reports.items()
            }

            # Construct the dictionary of expected log filenames for the dynamics audit
            log_filenames = {i: f"results_run_{i}.tsv" for i in range(1, 4)}

            # Execute Task 29: Validate search dynamics to compute counts and analyze NLP drift
            dynamics_report = execute_task_29_validate_search_dynamics(
                working_directory=work_dir,
                study_configuration=study_configuration,
                run_log_filenames=log_filenames
            )
            # Populate the experiment count table in the final report
            report.experiment_count_table = dynamics_report.comparison_table
            # Populate the methodology drift summary in the final report
            report.methodology_drift_summary = dynamics_report.drift_narratives

        # Branch execution path if the mode requires holdout evaluation
        elif mode in {"holdout_evaluation", "robustness"}:
            # Execute Task 23: Recreate Run 1 family from the post-search registry
            run1_report = execute_task_23_recreate_run_1_family(study_configuration)

            # Execute Task 24: Recreate Run 2 family from the post-search registry
            run2_report = execute_task_24_recreate_run_2_family(study_configuration)

            # Execute Task 25: Recreate Run 3 family from the post-search registry
            run3_report = execute_task_25_recreate_run_3_family(study_configuration)

            # Execute Task 26: Compute search-sample evaluation table for all 14 methods
            search_sample_report = execute_task_26_compute_search_sample_table(
                evaluator_report=evaluator_report,
                target_vector=evaluator_report.info_builder.target_vector,
                baseline_report=baseline_report,
                benchmark_report=benchmark_report,
                run1_report=run1_report,
                run2_report=run2_report,
                run3_report=run3_report,
                study_configuration=study_configuration,
                data_provenance=data_provenance,
                execute_task_12_callable=execute_task_12_evaluate_method_score
            )
            # Populate the search sample RMSE table in the final report
            report.search_sample_rmse_table = search_sample_report.evaluation_table

            # Execute Task 27: Compute holdout evaluation table on the air-gapped data
            holdout_report = execute_task_27_compute_holdout_table(
                df_canonical_panel=membership_report.df_marked_panel,
                index_map=membership_report.index_map_marked,
                lambda_grid=grid_report.lambda_grid,
                lambda_grid2=grid_report.lambda_grid2,
                study_configuration=study_configuration,
                run1_report=run1_report,
                run2_report=run2_report,
                run3_report=run3_report,
                data_provenance=data_provenance
            )
            # Populate the holdout RMSE table in the final report
            report.holdout_rmse_table = holdout_report.holdout_table

            # Execute Task 28: Compute Diebold-Mariano statistics
            # We instantiate the HoldoutEvaluator and freeze the methods as required by Task 28
            frozen_registry = freeze_discovered_methods(run1_report, run2_report, run3_report)
            h_evaluator = HoldoutEvaluator(
                df_canonical_panel=membership_report.df_marked_panel,
                index_map=membership_report.index_map_marked,
                lambda_grid=grid_report.lambda_grid,
                lambda_grid2=grid_report.lambda_grid2,
                study_configuration=study_configuration
            )

            # Compute the HAC p-values and format the descriptive summary
            dm_report = execute_task_28_compute_dm_statistics(
                holdout_evaluator=h_evaluator,
                df_canonical_panel=membership_report.df_marked_panel,
                study_configuration=study_configuration,
                lambda_grid=grid_report.lambda_grid,
                frozen_registry=frozen_registry,
                run1_report=run1_report,
                run2_report=run2_report,
                run3_report=run3_report,
                df_holdout_table=holdout_report.holdout_table
            )
            # Populate the DM summary table in the final report
            report.dm_summary_table = dm_report.augmented_holdout_table

    # Catch any exception raised during the DAG execution to implement the fail-fast requirement
    except Exception as e:
        # Format the full stack trace for diagnostic purposes
        error_context = traceback.format_exc()

        # Populate the halt_diagnostics dictionary with the error metadata
        report.halt_diagnostics = {
            "halt_reason": str(e),
            "exception_type": type(e).__name__,
            "traceback": error_context
        }
        # We do not re-raise the exception; we return the partial report so the caller
        # can inspect the state of the pipeline up to the point of failure.

    # Return the comprehensive end-to-end report
    return report

# %%
# Task 31: Run Robustness Analyses Through the Orchestrator

# ==============================================================================
# Task 31: Run Robustness Analyses Through the Orchestrator
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 31, Step 1: Run the holdout-excluding-COVID robustness analysis
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ExCovidValidationRecord:
    """
    A structured record documenting the validation of a method's holdout-excluding-COVID
    relative RMSE against its published target.

    Attributes:
        method_name (str): The identifier of the method.
        computed_relative_rmse (float): The empirically computed relative RMSE.
        target_relative_rmse (float): The theoretical target from the manuscript.
        deviation (float): The absolute mathematical deviation.
        passed (bool): True if the deviation is within the acceptable tolerance.
    """
    method_name: str
    computed_relative_rmse: float
    target_relative_rmse: float
    deviation: float
    passed: bool


@dataclass
class ExCovidRobustnessReport:
    """
    A structured container for the holdout-excluding-COVID robustness analysis.

    Attributes:
        ex_covid_table (pd.DataFrame): The filtered table containing ex-COVID metrics.
        validation_records (List[ExCovidValidationRecord]): Validation results for the primary runs.
        all_targets_met (bool): True if all primary runs met their ex-COVID targets.
    """
    ex_covid_table: pd.DataFrame
    validation_records: List[ExCovidValidationRecord]
    all_targets_met: bool


def validate_holdout_ex_covid(
    df_holdout_table: pd.DataFrame,
    study_configuration: Dict[str, Any],
    data_provenance: str
) -> ExCovidRobustnessReport:
    """
    Extracts the holdout-excluding-COVID metrics, validates the primary runs against
    their published targets, and constructs the robustness report.

    Args:
        df_holdout_table (pd.DataFrame): The comprehensive holdout table from Task 27.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        data_provenance (str): Identifier for the data source to determine tolerance.

    Returns:
        ExCovidRobustnessReport: The structured ex-COVID robustness report.
    """
    # Extract the relevant columns for the ex-COVID analysis
    cols_to_keep = ["method_name", "panel", "holdout_ex_covid_rmse", "holdout_ex_covid_relative_rmse"]
    df_ex_covid = df_holdout_table[cols_to_keep].copy(deep=True)

    # Extract the primary targets from the configuration
    targets = study_configuration["researcher_only_holdout_inputs"]["holdout_ex_covid_primary_targets"]

    # Map configuration keys to the formal table names
    target_mapping = {
        "Run 1 (final)": targets["run_1_final_relative_rmse"],
        "Run 2 (final)": targets["run_2_final_relative_rmse"],
        "Run 3 (final)": targets["run_3_final_relative_rmse"]
    }

    # Determine tolerance based on data provenance
    is_exact = "original" in data_provenance.lower() or "verbatim" in data_provenance.lower()
    tolerance = 0.015 if is_exact else 0.040

    validation_records = []
    all_targets_met = True

    for method_name, target_val in target_mapping.items():
        # Extract the computed relative RMSE for the method
        mask = df_ex_covid["method_name"] == method_name
        if not mask.any():
            continue

        computed_val = float(df_ex_covid.loc[mask, "holdout_ex_covid_relative_rmse"].iloc[0])
        deviation = abs(computed_val - target_val)
        passed = bool(deviation <= tolerance)

        if not passed:
            all_targets_met = False

        record = ExCovidValidationRecord(
            method_name=method_name,
            computed_relative_rmse=computed_val,
            target_relative_rmse=target_val,
            deviation=deviation,
            passed=passed
        )
        validation_records.append(record)

    return ExCovidRobustnessReport(
        ex_covid_table=df_ex_covid,
        validation_records=validation_records,
        all_targets_met=all_targets_met
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 31, Step 2: Run the independent full-dataset robustness analysis
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class IndependentRebuildReport:
    """
    A structured container for the artifacts produced by running the full pipeline
    on the independent dataset rebuild.

    Attributes:
        independent_search_sample_table (pd.DataFrame): In-sample RMSEs for the independent data.
        independent_holdout_table (pd.DataFrame): Out-of-sample RMSEs for the independent data.
        vintage_documentation (str): The recorded GDP vintage and download metadata.
    """
    independent_search_sample_table: pd.DataFrame
    independent_holdout_table: pd.DataFrame
    vintage_documentation: str


def execute_independent_rebuild_pipeline(
    df_independent_panel: pd.DataFrame,
    df_independent_target: pd.DataFrame,
    study_configuration: Dict[str, Any],
    orchestrator_callable: Callable[..., Any],
    vintage_documentation: str
) -> IndependentRebuildReport:
    """
    Executes the full deterministic research kernel on the independently constructed
    dataset to evaluate the vintage sensitivity of the discovered methods.

    Args:
        df_independent_panel (pd.DataFrame): The 106-row independent forecaster panel.
        df_independent_target (pd.DataFrame): The 106-row independent GDP target series.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        orchestrator_callable (Callable): The Task 30 end-to-end orchestrator function.
        vintage_documentation (str): Metadata describing the independent data source.

    Returns:
        IndependentRebuildReport: The structured results of the independent rebuild.

    Raises:
        RuntimeError: If the orchestrator pipeline fails on the independent data.
    """
    # Invoke the orchestrator with mode="holdout_evaluation" to prevent infinite recursion
    # and to bypass the expensive LLM discovery loop, utilizing the frozen methods instead.
    independent_report = orchestrator_callable(
        df_spf_panel_wide=df_independent_panel,
        df_gdp_target_series=df_independent_target,
        study_configuration=study_configuration,
        mode="holdout_evaluation",
        data_provenance="independent_rebuild",
        declared_panel_scope="full_panel"
    )

    # Check for pipeline halts
    if independent_report.halt_diagnostics is not None:
        halt_reason = independent_report.halt_diagnostics.get("halt_reason", "Unknown error")
        raise RuntimeError(f"Independent rebuild pipeline halted: {halt_reason}")

    # Extract the required tables
    search_table = independent_report.search_sample_rmse_table
    holdout_table = independent_report.holdout_rmse_table

    if search_table is None or holdout_table is None:
        raise RuntimeError("Independent rebuild pipeline completed but failed to produce evaluation tables.")

    return IndependentRebuildReport(
        independent_search_sample_table=search_table,
        independent_holdout_table=holdout_table,
        vintage_documentation=vintage_documentation
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 31, Step 3: Compare robustness rankings to the paper's reported ranking preservation
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class RobustnessMemo:
    """
    A structured, immutable record documenting the verification of the manuscript's
    core robustness claims regarding method generalization and vintage sensitivity.

    Attributes:
        canonical_ranking (List[Tuple[str, float]]): Ordered list of (method, relative_rmse) on canonical data.
        independent_ranking (List[Tuple[str, float]]): Ordered list of (method, relative_rmse) on independent data.
        ranking_preserved (bool): True if Run 2 remains best and Run 1 remains second.
        run_3_vintage_sensitivity (float): The absolute change in Run 3's relative RMSE across datasets.
        interpretation (str): Narrative summary of the robustness findings.
    """
    canonical_ranking: List[Tuple[str, float]]
    independent_ranking: List[Tuple[str, float]]
    ranking_preserved: bool
    run_3_vintage_sensitivity: float
    interpretation: str


def compare_robustness_rankings(
    df_canonical_holdout: pd.DataFrame,
    df_independent_holdout: pd.DataFrame
) -> RobustnessMemo:
    """
    Extracts the relative RMSEs for the primary runs from both datasets, evaluates
    the preservation of their ordinal rankings, and quantifies vintage sensitivity.

    Args:
        df_canonical_holdout (pd.DataFrame): The holdout table from the original data.
        df_independent_holdout (pd.DataFrame): The holdout table from the independent data.

    Returns:
        RobustnessMemo: The structured analytical memo.
    """
    target_methods = ["Run 1 (final)", "Run 2 (final)", "Run 3 (final)"]

    def _extract_ranking(df: pd.DataFrame) -> List[Tuple[str, float]]:
        ranking = []
        for method in target_methods:
            mask = df["method_name"] == method
            if mask.any():
                val = float(df.loc[mask, "holdout_relative_rmse"].iloc[0])
                ranking.append((method, val))
        # Sort by relative RMSE ascending (lower is better)
        return sorted(ranking, key=lambda x: x[1])

    # Extract and sort the rankings
    canonical_ranking = _extract_ranking(df_canonical_holdout)
    independent_ranking = _extract_ranking(df_independent_holdout)

    # Verify ranking preservation: Run 2 must be 1st, Run 1 must be 2nd, both < 1.0
    ranking_preserved = False
    if len(independent_ranking) >= 2:
        first_method, first_val = independent_ranking[0]
        second_method, second_val = independent_ranking[1]

        if first_method == "Run 2 (final)" and second_method == "Run 1 (final)":
            if first_val < 1.0 and second_val < 1.0:
                ranking_preserved = True

    # Quantify Run 3 vintage sensitivity
    run3_canon = next((val for m, val in canonical_ranking if m == "Run 3 (final)"), None)
    run3_indep = next((val for m, val in independent_ranking if m == "Run 3 (final)"), None)

    run_3_sensitivity = 0.0
    if run3_canon is not None and run3_indep is not None:
        run_3_sensitivity = abs(run3_indep - run3_canon)

    # Construct the narrative interpretation
    if ranking_preserved:
        interp = (
            "Robustness claims verified: Run 2 remains the strongest method, and Run 1 "
            "remains second, demonstrating generalization across GDP vintages. "
        )
    else:
        interp = (
            "Robustness claims NOT verified: The ordinal ranking of the discovered methods "
            "was altered on the independent dataset. "
        )

    if run_3_sensitivity > 0.05:
        interp += f"Run 3 exhibited high vintage sensitivity (delta = {run_3_sensitivity:.3f}), confirming its fragility."
    else:
        interp += f"Run 3 exhibited low vintage sensitivity (delta = {run_3_sensitivity:.3f})."

    return RobustnessMemo(
        canonical_ranking=canonical_ranking,
        independent_ranking=independent_ranking,
        ranking_preserved=ranking_preserved,
        run_3_vintage_sensitivity=run_3_sensitivity,
        interpretation=interp
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 31, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task31RobustnessReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the robustness analysis phase. This report encapsulates the ex-COVID validations,
    the independent dataset rebuild metrics, and the formal analytical memo verifying
    the manuscript's claims regarding generalization and vintage sensitivity.

    Attributes:
        ex_covid_report (ExCovidRobustnessReport): The validation of methods against
            the holdout-excluding-COVID targets.
        independent_rebuild_report (Optional[IndependentRebuildReport]): The full
            pipeline results on the independent dataset, if provided.
        robustness_memo (Optional[RobustnessMemo]): The analytical comparison of
            rankings across datasets, if the independent rebuild was executed.
    """
    ex_covid_report: ExCovidRobustnessReport
    independent_rebuild_report: Optional[IndependentRebuildReport] = None
    robustness_memo: Optional[RobustnessMemo] = None

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the robustness report.
        """
        if not isinstance(self.ex_covid_report, ExCovidRobustnessReport):
            raise TypeError("Task31RobustnessReport: ex_covid_report must be an ExCovidRobustnessReport.")


def execute_task_31_run_robustness_analyses(
    df_canonical_holdout_table: pd.DataFrame,
    study_configuration: Dict[str, Any],
    data_provenance: str,
    orchestrator_callable: Callable[..., Any],
    df_independent_panel: Optional[pd.DataFrame] = None,
    df_independent_target: Optional[pd.DataFrame] = None,
    vintage_documentation: Optional[str] = None
) -> Task31RobustnessReport:
    """
    Orchestrates Task 31: Executes the holdout-excluding-COVID validation, conditionally
    runs the full pipeline on an independent dataset rebuild, and compiles the formal
    robustness memo comparing the rankings.

    Args:
        df_canonical_holdout_table (pd.DataFrame): The holdout table from Task 27.
        study_configuration (Dict[str, Any]): The study configuration dictionary.
        data_provenance (str): Identifier for the canonical data source.
        orchestrator_callable (Callable): The Task 30 end-to-end orchestrator function.
        df_independent_panel (Optional[pd.DataFrame]): The independent forecaster panel.
        df_independent_target (Optional[pd.DataFrame]): The independent GDP target series.
        vintage_documentation (Optional[str]): Metadata for the independent data.

    Returns:
        Task31RobustnessReport: The comprehensive robustness analysis report.
    """
    # Step 1: Run the holdout-excluding-COVID robustness analysis
    ex_covid_report = validate_holdout_ex_covid(
        df_holdout_table=df_canonical_holdout_table,
        study_configuration=study_configuration,
        data_provenance=data_provenance
    )

    indep_report = None
    memo = None

    # Step 2 & 3: Independent rebuild and ranking comparison (Conditional)
    if df_independent_panel is not None and df_independent_target is not None:
        if vintage_documentation is None:
            vintage_documentation = "Independent rebuild (Vintage unspecified)"

        # Execute the independent rebuild pipeline
        indep_report = execute_independent_rebuild_pipeline(
            df_independent_panel=df_independent_panel,
            df_independent_target=df_independent_target,
            study_configuration=study_configuration,
            orchestrator_callable=orchestrator_callable,
            vintage_documentation=vintage_documentation
        )

        # Compare the rankings between the canonical and independent holdout tables
        memo = compare_robustness_rankings(
            df_canonical_holdout=df_canonical_holdout_table,
            df_independent_holdout=indep_report.independent_holdout_table
        )

    return Task31RobustnessReport(
        ex_covid_report=ex_covid_report,
        independent_rebuild_report=indep_report,
        robustness_memo=memo
    )

# %%
# Task 32: Final Validation, Truthfulness Audit, and Archival

# ==============================================================================
# Task 32: Final Validation, Truthfulness Audit, and Archival
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 32, Step 1: Validate against the published scientific conclusions
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class ConclusionValidationRecord:
    """
    A structured, immutable record documenting the empirical verification of a single
    scientific conclusion claimed by the manuscript.

    Attributes:
        conclusion_id (int): The numerical identifier of the conclusion (1 to 5).
        description (str): The textual description of the scientific claim.
        replicated_value (str): The empirical metric(s) computed during replication.
        published_value (str): The theoretical target metric(s) from the manuscript.
        reproduced (bool): True if the empirical metrics satisfy the logical conditions of the claim.
        notes (str): Diagnostic context regarding the validation outcome.
    """
    # The integer identifier for the specific scientific conclusion
    conclusion_id: int
    # The narrative description of the hypothesis being tested
    description: str
    # The actual numerical values extracted from the replication pipeline
    replicated_value: str
    # The target numerical values reported in the original manuscript
    published_value: str
    # The boolean flag indicating whether the conclusion holds true in the replication
    reproduced: bool
    # Additional context or caveats regarding the validation logic
    notes: str


def _safe_extract_metric(df: pd.DataFrame, method_name: str, metric_col: str) -> float:
    """
    Safely extracts a scalar metric from a DataFrame for a specific method,
    failing fast with a descriptive error if the method or metric is missing.

    Args:
        df (pd.DataFrame): The evaluation table containing the metrics.
        method_name (str): The exact string identifier of the method.
        metric_col (str): The column name containing the desired metric.

    Returns:
        float: The extracted scalar metric.

    Raises:
        ValueError: If the method is not found or the column does not exist.
    """
    # Create a boolean mask to locate the specific method in the DataFrame
    mask = df["method_name"] == method_name

    # Check if the method exists in the table
    if not mask.any():
        # Raise a ValueError to prevent cryptic IndexError downstream
        raise ValueError(f"Method '{method_name}' not found in the evaluation table.")

    # Check if the requested metric column exists in the table
    if metric_col not in df.columns:
        # Raise a ValueError if the schema is incorrect
        raise ValueError(f"Metric column '{metric_col}' not found in the evaluation table.")

    # Extract the scalar value, cast to float, and return
    return float(df.loc[mask, metric_col].iloc[0])


def validate_scientific_conclusions(
    search_table: pd.DataFrame,
    holdout_table: pd.DataFrame
) -> List[ConclusionValidationRecord]:
    """
    Rigorously evaluates the five core scientific conclusions of the manuscript
    by applying strict logical operators to the empirically computed relative RMSEs.

    Args:
        search_table (pd.DataFrame): The in-sample evaluation table.
        holdout_table (pd.DataFrame): The out-of-sample evaluation table.

    Returns:
        List[ConclusionValidationRecord]: A list of structured validation records.
    """
    # Initialize the list to store the validation records
    records = []

    # Extract search-sample relative RMSEs for the three primary runs
    ss_r1 = _safe_extract_metric(search_table, "Run 1 (final)", "search_sample_relative_rmse")
    ss_r2 = _safe_extract_metric(search_table, "Run 2 (final)", "search_sample_relative_rmse")
    ss_r3 = _safe_extract_metric(search_table, "Run 3 (final)", "search_sample_relative_rmse")

    # Extract holdout relative RMSEs for the three primary runs
    ho_r1 = _safe_extract_metric(holdout_table, "Run 1 (final)", "holdout_relative_rmse")
    ho_r2 = _safe_extract_metric(holdout_table, "Run 2 (final)", "holdout_relative_rmse")
    ho_r3 = _safe_extract_metric(holdout_table, "Run 3 (final)", "holdout_relative_rmse")

    # Conclusion 1: All three agent runs improve search-sample RMSE relative to simple average.
    # Logical condition: All search-sample relative RMSEs must be strictly less than 1.0.
    c1_reproduced = (ss_r1 < 1.0) and (ss_r2 < 1.0) and (ss_r3 < 1.0)
    records.append(ConclusionValidationRecord(
        conclusion_id=1,
        description="All three agent runs improve search-sample RMSE relative to simple average.",
        replicated_value=f"R1:{ss_r1:.3f}, R2:{ss_r2:.3f}, R3:{ss_r3:.3f}",
        published_value="R1:0.858, R2:0.510, R3:0.808",
        reproduced=c1_reproduced,
        notes="Verified that all in-sample relative RMSEs are < 1.0."
    ))

    # Conclusion 2: Not all search-sample improvements generalize to holdout.
    # Logical condition: At least one holdout relative RMSE must be strictly greater than 1.0.
    c2_reproduced = (ho_r1 > 1.0) or (ho_r2 > 1.0) or (ho_r3 > 1.0)
    records.append(ConclusionValidationRecord(
        conclusion_id=2,
        description="Not all search-sample improvements generalize to holdout.",
        replicated_value=f"Max Holdout Rel RMSE: {max(ho_r1, ho_r2, ho_r3):.3f}",
        published_value="Run 3 Holdout Rel RMSE: 1.089",
        reproduced=c2_reproduced,
        notes="Verified that at least one method failed to beat the baseline out-of-sample."
    ))

    # Conclusion 3: Run 2 is the strongest holdout method.
    # Logical condition: Run 2 holdout relative RMSE is the absolute minimum across all methods.
    min_ho_all = holdout_table["holdout_relative_rmse"].min()
    # We use a small epsilon (1e-7) to handle potential floating-point equality issues
    c3_reproduced = abs(ho_r2 - min_ho_all) < 1e-7
    records.append(ConclusionValidationRecord(
        conclusion_id=3,
        description="Run 2 is the strongest holdout method.",
        replicated_value=f"R2:{ho_r2:.3f}, Global Min:{min_ho_all:.3f}",
        published_value="R2:0.811 (Lowest in table)",
        reproduced=c3_reproduced,
        notes="Verified that Run 2 achieved the absolute minimum holdout relative RMSE."
    ))

    # Conclusion 4: Run 1 generalizes modestly but meaningfully.
    # Logical condition: Run 1 beats baseline (< 1.0) but is worse than Run 2 (> ho_r2).
    c4_reproduced = (ho_r1 < 1.0) and (ho_r1 > ho_r2)
    records.append(ConclusionValidationRecord(
        conclusion_id=4,
        description="Run 1 generalizes modestly but meaningfully.",
        replicated_value=f"R1:{ho_r1:.3f}",
        published_value="R1:0.945",
        reproduced=c4_reproduced,
        notes="Verified that Run 1 is better than baseline but inferior to Run 2."
    ))

    # Conclusion 5: Run 3 fails on the main holdout in the canonical dataset.
    # Logical condition: Run 3 holdout relative RMSE is strictly greater than 1.0.
    c5_reproduced = (ho_r3 > 1.0)
    records.append(ConclusionValidationRecord(
        conclusion_id=5,
        description="Run 3 fails on the main holdout in the canonical dataset.",
        replicated_value=f"R3:{ho_r3:.3f}",
        published_value="R3:1.089",
        reproduced=c5_reproduced,
        notes="Verified that Run 3 performs worse than the simple average out-of-sample."
    ))

    # Return the comprehensive list of validation records
    return records

# -------------------------------------------------------------------------------------------------------------------------------
# Task 32, Step 2: State exactly what was reproduced and what was not
# -------------------------------------------------------------------------------------------------------------------------------

def generate_fidelity_classification() -> pd.DataFrame:
    """
    Constructs a definitive, tabular classification of the epistemological boundaries
    of the replication, mapping specific pipeline components to their exact fidelity
    categories as defined by the manuscript's disambiguation recommendations.

    Returns:
        pd.DataFrame: The structured fidelity classification table.
    """
    # Define the hardcoded list of dictionaries representing the fidelity matrix
    # This ensures objective, immutable documentation of the replication's limits
    fidelity_data = [
        {
            "component": "Search/Holdout Sample Partition",
            "fidelity_category": "1: Exactly reproduced",
            "details": "1999Q3-2016Q4 (Search) and 2017Q1-2025Q4 (Holdout) strictly enforced.",
            "evidence": "Task 8 partition validation logs."
        },
        {
            "component": "Run 2 Bias Correction Formula",
            "fidelity_category": "1: Exactly reproduced",
            "details": "y_hat = y_tilde - 0.80 * e_n_loo_pct implemented with exact mathematical fidelity.",
            "evidence": "Task 24 source code."
        },
        {
            "component": "Benchmark Helper Functions (e.g., fit_lasso)",
            "fidelity_category": "2: Ported and validated",
            "details": "Ported from R glmnet to Python sklearn/numpy. Validated for internal consistency.",
            "evidence": "Task 20 validation report."
        },
        {
            "component": "Run 1 Weighted Quantile Interpolation",
            "fidelity_category": "3: Inferred from prose",
            "details": "Implemented linear interpolation of the weighted empirical CDF based on text description.",
            "evidence": "Task 23 source code."
        },
        {
            "component": "Run 3 Forward CV Fold Construction",
            "fidelity_category": "3: Inferred from prose",
            "details": "Constructed expanding window folds to accommodate h=1 and h=2 horizons.",
            "evidence": "Task 25 source code."
        },
        {
            "component": "Empty Active-Set Fallback Behavior",
            "fidelity_category": "4: Unverifiable implementation choice",
            "details": "Defaulted to simple average when LASSO shrinks all coefficients to zero.",
            "evidence": "Explicitly documented in Task 23-25 callables."
        },
        {
            "component": "LLM System Prompts and Internal State",
            "fidelity_category": "5: Irreducibly unobserved",
            "details": "Provider-side system prompts and exact sampling trajectories cannot be audited.",
            "evidence": "Fundamental limitation of proprietary LLM APIs."
        }
    ]

    # Convert the list of dictionaries into a pandas DataFrame for tabular export
    df_fidelity = pd.DataFrame(fidelity_data)

    # Return the structured classification table
    return df_fidelity

# -------------------------------------------------------------------------------------------------------------------------------
# Task 32, Step 3: Archive the full reproducibility package
# -------------------------------------------------------------------------------------------------------------------------------

class NumpyEncoder(json.JSONEncoder):
    """
    A custom JSON encoder that safely casts numpy data types to native Python types
    to prevent serialization errors during the archival of metadata dictionaries.
    """
    def default(self, obj: Any) -> Any:
        # Convert numpy integers to Python int
        if isinstance(obj, np.integer):
            return int(obj)
        # Convert numpy floating point numbers to Python float
        elif isinstance(obj, np.floating):
            return float(obj)
        # Convert numpy arrays to Python lists
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        # Convert pandas DataFrames to dictionaries
        elif isinstance(obj, pd.DataFrame):
            return obj.to_dict(orient='records')
        # Fallback to the default encoder for all other types
        return super(NumpyEncoder, self).default(obj)


def _compute_sha256(file_path: Path) -> str:
    """
    Computes the SHA-256 cryptographic hash of a file by reading it in binary chunks,
    ensuring constant memory overhead regardless of file size.

    Args:
        file_path (Path): The absolute path to the file.

    Returns:
        str: The hexadecimal representation of the SHA-256 hash.
    """
    # Initialize the SHA-256 hash object
    sha256_hash = hashlib.sha256()

    # Open the file in binary read mode
    with open(file_path, "rb") as f:
        # Read the file in 4K chunks to optimize memory usage
        for byte_block in iter(lambda: f.read(4096), b""):
            # Update the hash object with the current chunk
            sha256_hash.update(byte_block)

    # Return the final hexadecimal digest
    return sha256_hash.hexdigest()


def create_reproducibility_archive(
    end_to_end_report: Any, # Expected: Task30EndToEndReport
    output_dir_str: str,
    conclusions_records: List[ConclusionValidationRecord],
    fidelity_df: pd.DataFrame
) -> Tuple[str, Dict[str, str]]:
    """
    Assembles all in-memory artifacts into a structured, researcher-readable directory tree,
    serializes data to CSV and JSON, computes cryptographic checksums, and compresses
    the entire package into a distributable zip archive.

    Args:
        end_to_end_report (Task30EndToEndReport): The comprehensive pipeline report.
        output_dir_str (str): The target directory for the uncompressed archive tree.
        conclusions_records (List[ConclusionValidationRecord]): The validation records.
        fidelity_df (pd.DataFrame): The fidelity classification table.

    Returns:
        Tuple[str, Dict[str, str]]: The absolute path to the zip archive and a dictionary of checksums.
    """
    # Convert the output directory string to a Path object
    base_dir = Path(output_dir_str)

    # Define the strict directory taxonomy required by the manuscript
    dirs = {
        "data": base_dir / "data",
        "config": base_dir / "config",
        "methods": base_dir / "methods",
        "tables": base_dir / "tables",
        "logs": base_dir / "logs",
        "provenance": base_dir / "provenance"
    }

    # Create the directory tree, overwriting existing structures if necessary
    if base_dir.exists():
        shutil.rmtree(base_dir)
    for d in dirs.values():
        d.mkdir(parents=True, exist_ok=True)

    # Helper function to safely write DataFrames to CSV
    def _write_df(df: Optional[pd.DataFrame], path: Path) -> None:
        if df is not None and not df.empty:
            # Write to CSV without the integer index to maintain clean tabular structure
            df.to_csv(path, index=False, encoding='utf-8')

    # Helper function to safely write dictionaries/dataclasses to JSON
    def _write_json(data: Any, path: Path) -> None:
        if data is not None:
            # If the data is a dataclass, convert it to a dictionary first
            if hasattr(data, "__dataclass_fields__"):
                data = asdict(data)
            # Write to JSON using the custom NumpyEncoder to handle non-native types
            with open(path, 'w', encoding='utf-8') as f:
                json.dump(data, f, indent=4, cls=NumpyEncoder)

    # 1. Archive Data Artifacts
    _write_df(end_to_end_report.validated_aligned_panel, dirs["data"] / "cleaned_aligned_panel.csv")
    _write_json(end_to_end_report.imputation_report, dirs["data"] / "imputation_report.json")

    # Re-isolate search and holdout panels for convenience if the aligned panel exists
    if end_to_end_report.validated_aligned_panel is not None:
        df_all = end_to_end_report.validated_aligned_panel
        _write_df(df_all[df_all["is_search_sample"]], dirs["data"] / "search_panel.csv")
        _write_df(df_all[df_all["is_holdout"]], dirs["data"] / "holdout_panel.csv")

    # 2. Archive Configuration Artifacts
    _write_json(end_to_end_report.quarantine_list, dirs["config"] / "quarantine_list.json")

    # 3. Archive Method Artifacts
    # Since methods are in-memory callables, we write a specification JSON documenting their presence
    method_specs = {
        "Run 1 Family": ["run_1_final", "run_1a", "run_1b"],
        "Run 2 Family": ["run_2_final", "run_2a", "run_2b"],
        "Run 3 Family": ["run_3_final", "run_3a", "run_3b"],
        "Benchmarks": ["simple_average", "pelasso_ex_post", "best_avg_flex", "best_nw_avg"]
    }
    _write_json(method_specs, dirs["methods"] / "method_specifications.json")

    # 4. Archive Results Artifacts
    _write_df(end_to_end_report.search_sample_rmse_table, dirs["tables"] / "search_sample_rmse.csv")
    _write_df(end_to_end_report.holdout_rmse_table, dirs["tables"] / "holdout_rmse.csv")
    _write_df(end_to_end_report.holdout_ex_covid_rmse_table, dirs["tables"] / "holdout_ex_covid_rmse.csv")
    _write_df(end_to_end_report.dm_summary_table, dirs["tables"] / "dm_summary.csv")
    _write_df(end_to_end_report.experiment_count_table, dirs["tables"] / "experiment_counts.csv")

    if end_to_end_report.robustness_tables is not None:
        for name, df in end_to_end_report.robustness_tables.items():
            _write_df(df, dirs["tables"] / f"robustness_{name}.csv")

    # 5. Archive Search Artifacts (Logs)
    if end_to_end_report.search_logs is not None:
        for run_id, df_log in end_to_end_report.search_logs.items():
            # Write TSV logs using tab separator
            if df_log is not None:
                df_log.to_csv(dirs["logs"] / f"results_run_{run_id}.tsv", sep='\t', index=False, encoding='utf-8')

    _write_json(end_to_end_report.methodology_drift_summary, dirs["logs"] / "methodology_drift_summary.json")

    # 6. Archive Provenance and Fidelity Artifacts
    _write_json([asdict(r) for r in conclusions_records], dirs["provenance"] / "conclusions_validation.json")
    _write_df(fidelity_df, dirs["provenance"] / "fidelity_classification.csv")
    _write_json(end_to_end_report.sample_partition_metadata, dirs["provenance"] / "partition_metadata.json")
    _write_json(end_to_end_report.baseline_validation_report, dirs["provenance"] / "baseline_validation.json")

    # 7. Compute Cryptographic Checksums
    checksums = {}
    # Walk the directory tree to find all files
    for filepath in base_dir.rglob('*'):
        if filepath.is_file():
            # Compute the SHA-256 hash for the file
            file_hash = _compute_sha256(filepath)
            # Store the relative path and its hash
            rel_path = str(filepath.relative_to(base_dir))
            checksums[rel_path] = file_hash

    # Write the checksums manifest to the root of the archive directory
    with open(base_dir / "checksums.json", 'w', encoding='utf-8') as f:
        json.dump(checksums, f, indent=4)

    # 8. Compress the Archive
    # Create a zip archive of the entire base directory
    archive_path = shutil.make_archive(
        base_name=str(base_dir),
        format='zip',
        root_dir=str(base_dir.parent),
        base_dir=base_dir.name
    )

    # Return the absolute path to the zip file and the checksum dictionary
    return archive_path, checksums

# -------------------------------------------------------------------------------------------------------------------------------
# Task 32, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass
class Task32FinalReport:
    """
    A structured, implementation-grade container that aggregates the finalized artifacts
    of the ultimate validation and archival phase. This report serves as the capstone
    of the replication pipeline, encapsulating the empirical verification of the
    scientific conclusions, the epistemological fidelity classification, and the
    cryptographically secured reproducibility archive.

    Attributes:
        conclusions_validation (List[ConclusionValidationRecord]): The empirical
            verification of the five core scientific claims.
        fidelity_classification (pd.DataFrame): The tabular mapping of pipeline
            components to their exact reproducibility categories.
        archive_path (str): The absolute filesystem path to the compressed zip archive.
        archive_checksums (Dict[str, str]): The SHA-256 cryptographic hashes for
            every file contained within the reproducibility package.
    """
    # The list of structured records verifying the manuscript's scientific claims
    conclusions_validation: List[ConclusionValidationRecord]
    # The pandas DataFrame documenting the epistemological boundaries of the replication
    fidelity_classification: pd.DataFrame
    # The absolute path to the generated .zip file containing all artifacts
    archive_path: str
    # The dictionary mapping relative file paths to their SHA-256 hashes
    archive_checksums: Dict[str, str]

    def __post_init__(self) -> None:
        """
        Performs rigorous post-initialization validation to ensure the structural
        integrity of the final capstone report.

        Raises:
            TypeError: If the attributes do not match the required types.
            ValueError: If the archive path is empty or the checksums are missing.
        """
        # Verify that conclusions_validation is a list
        if not isinstance(self.conclusions_validation, list):
            raise TypeError("Task32FinalReport: conclusions_validation must be a list.")

        # Verify that fidelity_classification is a pandas DataFrame
        if not isinstance(self.fidelity_classification, pd.DataFrame):
            raise TypeError("Task32FinalReport: fidelity_classification must be a pandas.DataFrame.")

        # Verify that archive_path is a non-empty string
        if not isinstance(self.archive_path, str) or not self.archive_path.strip():
            raise ValueError("Task32FinalReport: archive_path must be a non-empty string.")

        # Verify that archive_checksums is a non-empty dictionary
        if not isinstance(self.archive_checksums, dict) or not self.archive_checksums:
            raise ValueError("Task32FinalReport: archive_checksums must be a non-empty dictionary.")


def execute_task_32_final_validation_and_archival(
    end_to_end_report: Any, # Expected: Task30EndToEndReport
    output_directory: str
) -> Task32FinalReport:
    """
    Orchestrates Task 32: Validates the empirical results against the published
    scientific conclusions, generates the epistemological fidelity classification,
    and compiles all artifacts into a cryptographically secured zip archive.

    Args:
        end_to_end_report (Task30EndToEndReport): The comprehensive pipeline report.
        output_directory (str): The target directory for the uncompressed archive tree.

    Returns:
        Task32FinalReport: The comprehensive capstone report.

    Raises:
        ValueError: If the required evaluation tables are missing from the end-to-end report.
    """
    # Extract the required evaluation tables from the end-to-end report
    search_table = end_to_end_report.search_sample_rmse_table
    holdout_table = end_to_end_report.holdout_rmse_table

    # Enforce the fail-fast mandate: validation cannot proceed without the evaluation tables
    if search_table is None or holdout_table is None:
        raise ValueError(
            "Fatal: Cannot perform final validation. The search_sample_rmse_table or "
            "holdout_rmse_table is missing from the end-to-end report. Ensure the pipeline "
            "was executed in 'holdout_evaluation' or 'robustness' mode."
        )

    # Step 1: Validate against the published scientific conclusions
    # Execute the rigorous logical evaluation of the empirical metrics
    conclusions_records = validate_scientific_conclusions(
        search_table=search_table,
        holdout_table=holdout_table
    )

    # Step 2: State exactly what was reproduced and what was not
    # Generate the immutable fidelity classification matrix
    fidelity_df = generate_fidelity_classification()

    # Step 3: Archive the full reproducibility package
    # Execute the filesystem I/O, serialization, checksum computation, and compression
    archive_path, checksums = create_reproducibility_archive(
        end_to_end_report=end_to_end_report,
        output_dir_str=output_directory,
        conclusions_records=conclusions_records,
        fidelity_df=fidelity_df
    )

    # Return the composite capstone report
    return Task32FinalReport(
        conclusions_validation=conclusions_records,
        fidelity_classification=fidelity_df,
        archive_path=archive_path,
        archive_checksums=checksums
    )

# %%
# Top-Level Orchestrator

# ==============================================================================
# Master Orchestrator: Execute the Complete Auditable AI Agent Loop Pipeline
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Master Orchestrator: Integrate Tasks 30, 31, and 32
# -------------------------------------------------------------------------------------------------------------------------------

def execute_master_pipeline(
    df_spf_panel_wide: pd.DataFrame,
    df_gdp_target_series: pd.DataFrame,
    study_configuration: Dict[str, Any],
    mode: str,
    output_directory: str,
    data_provenance: str = "original_H1_gdp",
    declared_panel_scope: str = "full_panel",
    df_independent_panel: Optional[pd.DataFrame] = None,
    df_independent_target: Optional[pd.DataFrame] = None,
    vintage_documentation: Optional[str] = None
) -> Dict[str, Any]:
    """
    The top-level master orchestrator that sequentially executes the core pipeline (Task 30),
    the robustness analyses (Task 31), and the final validation and archival (Task 32).

    This function enforces the strict Directed Acyclic Graph (DAG) of the research protocol,
    handling early halts gracefully and aggregating all generated artifacts into a single,
    comprehensive dictionary.

    Args:
        df_spf_panel_wide (pd.DataFrame): The raw, unvalidated SPF forecaster panel.
        df_gdp_target_series (pd.DataFrame): The raw, unvalidated GDP target series.
        study_configuration (Dict[str, Any]): The comprehensive study configuration.
        mode (str): Execution mode ('discovery', 'benchmark_only', 'holdout_evaluation', 'robustness').
        output_directory (str): The target filesystem path for the final zip archive.
        data_provenance (str): Identifier for the data source (affects validation tolerances).
        declared_panel_scope (str): The expected temporal scope of the input data.
        df_independent_panel (Optional[pd.DataFrame]): The independent forecaster panel (for robustness).
        df_independent_target (Optional[pd.DataFrame]): The independent GDP target series (for robustness).
        vintage_documentation (Optional[str]): Metadata describing the independent data source.

    Returns:
        Dict[str, Any]: A dictionary containing the artifacts of each step:
            - 'master_status': str ('SUCCESS', 'HALTED_AT_TASK_30', 'ERROR')
            - 'task_30_report': Task30EndToEndReport
            - 'task_31_report': Optional[Task31RobustnessReport]
            - 'task_32_report': Optional[Task32FinalReport]
            - 'master_error_trace': Optional[str]
    """
    # Initialize the master output dictionary with default None values
    master_results: Dict[str, Any] = {
        "master_status": "PENDING",
        "task_30_report": None,
        "task_31_report": None,
        "task_32_report": None,
        "master_error_trace": None
    }

    try:
        # -------------------------------------------------------------------------
        # Execute Task 30: The End-to-End Core Pipeline
        # -------------------------------------------------------------------------
        # This task handles validation, cleansing, alignment, imputation, evaluator
        # construction, benchmark reproduction, and (conditionally) the agentic loop.
        report_30 = execute_task_30_end_to_end_orchestrator(
            df_spf_panel_wide=df_spf_panel_wide,
            df_gdp_target_series=df_gdp_target_series,
            study_configuration=study_configuration,
            mode=mode,
            data_provenance=data_provenance,
            declared_panel_scope=declared_panel_scope
        )

        # Store the Task 30 report in the master dictionary
        master_results["task_30_report"] = report_30

        # Check for a fail-fast halt in the core pipeline (e.g., schema violation)
        if report_30.halt_diagnostics is not None:
            master_results["master_status"] = "HALTED_AT_TASK_30"
            # Return immediately; downstream tasks cannot proceed without a valid core state
            return master_results

        # -------------------------------------------------------------------------
        # Execute Task 31: Robustness Analyses (Conditional on Mode)
        # -------------------------------------------------------------------------
        # This task is only executed if the mode explicitly requests robustness checks
        # and the required holdout table was successfully generated by Task 30.
        if mode == "robustness" and report_30.holdout_rmse_table is not None:
            report_31 = execute_task_31_run_robustness_analyses(
                df_canonical_holdout_table=report_30.holdout_rmse_table,
                study_configuration=study_configuration,
                data_provenance=data_provenance,
                orchestrator_callable=execute_task_30_end_to_end_orchestrator,
                df_independent_panel=df_independent_panel,
                df_independent_target=df_independent_target,
                vintage_documentation=vintage_documentation
            )
            # Store the Task 31 report in the master dictionary
            master_results["task_31_report"] = report_31

        # -------------------------------------------------------------------------
        # Execute Task 32: Final Validation, Truthfulness Audit, and Archival
        # -------------------------------------------------------------------------
        # Task 32 requires the evaluation tables to validate the scientific conclusions.
        # If the pipeline was run in a mode that does not produce these tables (e.g., 'discovery'),
        # we skip archival to prevent a ValueError.
        if report_30.search_sample_rmse_table is not None and report_30.holdout_rmse_table is not None:
            report_32 = execute_task_32_final_validation_and_archival(
                end_to_end_report=report_30,
                output_directory=output_directory
            )
            # Store the Task 32 report in the master dictionary
            master_results["task_32_report"] = report_32
            master_results["master_status"] = "SUCCESS"
        else:
            # If tables are missing, the pipeline succeeded in its limited mode, but archival is skipped
            master_results["master_status"] = "SUCCESS_WITHOUT_ARCHIVAL"
            master_results["master_error_trace"] = "Task 32 skipped: Evaluation tables not generated in current mode."

    except Exception as e:
        # Catch any unexpected top-level exceptions that bypassed the task-specific handlers
        error_context = traceback.format_exc()
        master_results["master_status"] = "ERROR"
        master_results["master_error_trace"] = f"Master Orchestrator failed: {str(e)}\n\n{error_context}"

    # Return the comprehensive master dictionary containing all generated artifacts
    return master_results
